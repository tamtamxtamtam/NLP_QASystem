# %% [markdown]
# <a href="https://colab.research.google.com/github/tamtamxtamtam/NLP_QASystem/blob/main/QA_btl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.chdir('/content/drive/My Drive/Zalo Challenge/2019')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # **Import folder + Install package**
#
#
# *   transfrormers
# *   fastBPE
# *   FAIRSeq

# %%
pwd
# Out:
# '/content/drive/My Drive/Zalo Challenge/2019'

# %%
# !nvidia-smi
# Out:
# Tue Nov 24 10:57:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/3a/83/e74092e7f24a08d751aa59b37a9fc572b2e4af3918cb66f7766c3affb1b4/transformers-3.5.1-py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 8.6MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Collecting tokenizers==0.9.3
#   Downloading https://files.pythonhosted.org/packages/4c/34/b39eb9994bc3c999270b69c9eea40ecc6f0e97991dba28282b9fd32d44ee/tokenizers-0.9.3-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 26.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Collecting sentencepiece==0.1.91
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 49.0MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 52.1MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->transformers) (50.3.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=c21e64fb1104860ce12bde6329eaf7593dbe4d1e171c14d2dd19e39f3db22ceb
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.9.3 transformers-3.5.1

# %%
# !pip install fastBPE
# !pip install fairseq
# Out:
# Collecting fastBPE
#   Downloading https://files.pythonhosted.org/packages/e1/37/f97181428a5d151501b90b2cebedf97c81b034ace753606a3cda5ad4e6e2/fastBPE-0.1.0.tar.gz
# Building wheels for collected packages: fastBPE
#   Building wheel for fastBPE (setup.py) ... done
#   Created wheel for fastBPE: filename=fastBPE-0.1.0-cp36-cp36m-linux_x86_64.whl size=481486 sha256=d9bfb21657b573265b30a4ffdc9e79785d9f77329606ec94936bce93216e02ed
#   Stored in directory: /root/.cache/pip/wheels/f3/0c/9c/fc62058b4d473a5602bcd3d3edfece796f123875379ea82d79
# Successfully built fastBPE
# Installing collected packages: fastBPE
# Successfully installed fastBPE-0.1.0
# Collecting fairseq
#   Downloading https://files.pythonhosted.org/packages/2c/da/7c7032988dade3b21ccfd5b226e50b382abfd3459129d67240bb004506ae/fairseq-0.10.1-cp36-cp36m-manylinux1_x86_64.whl (1.7MB)
#      |████████████████████████████████| 1.7MB 9.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2019.12.20)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.21)
# Collecting hydra-core
#   Downloading https://files.pythonhosted.org/packages/f0/1f/7f502b9e37596164111655861370b08626f46f9e4524433c354f472765d4/hydra_core-1.0.4-py3-none-any.whl (122kB)
#      |████████████████████████████████| 122kB 48.9MB/s
# Collecting sacrebleu>=1.4.12
#   Downloading https://files.pythonhosted.org/packages/a3/c4/8e948f601a4f9609e8b2b58f31966cb13cf17b940b82aa3e767f01c42c52/sacrebleu-1.4.14-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 9.5MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.41.1)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.7.0+cu101)
# Collecting antlr4-python3-runtime==4.8
#   Downloading https://files.pythonhosted.org/packages/56/02/789a0bddf9c9b31b14c3e79ec22b9656185a803dc31c15f006f9855ece0d/antlr4-python3-runtime-4.8.tar.gz (112kB)
#      |████████████████████████████████| 112kB 29.9MB/s
# Collecting omegaconf>=2.0.5
#   Downloading https://files.pythonhosted.org/packages/e5/f6/043b6d255dd6fbf2025110cea35b87f4c5100a181681d8eab496269f0d5b/omegaconf-2.0.5-py3-none-any.whl
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core->fairseq) (3.3.0)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/89/a6/3814b7107e0788040870e8825eebf214d72166adf656ba7d4bf14759a06a/portalocker-2.0.0-py2.py3-none-any.whl
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (0.16.0)
# Collecting PyYAML>=5.1.*
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 30.0MB/s
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core->fairseq) (3.4.0)
# Building wheels for collected packages: antlr4-python3-runtime, PyYAML
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-cp36-none-any.whl size=141230 sha256=2e64c7499c0f8ce53973ed84e0e1bbaedfaa5a40f73b9f514fdea3019f8828d1
#   Stored in directory: /root/.cache/pip/wheels/e3/e2/fa/b78480b448b8579ddf393bebd3f47ee23aa84c89b6a78285c8
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=90ca2fa3c6fce21e9faf901db3c426dcd5e2af29b0ab76c72d209fe4c2ccfb1e
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built antlr4-python3-runtime PyYAML
# Installing collected packages: antlr4-python3-runtime, PyYAML, omegaconf, hydra-core, portalocker, sacrebleu, fairseq
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.3.1 antlr4-python3-runtime-4.8 fairseq-0.10.1 hydra-core-1.0.4 omegaconf-2.0.5 portalocker-2.0.0 sacrebleu-1.4.14

# %% [markdown]
# # **VNcoreNLP**

# %%
# Install the vncorenlp python wrapper
# !pip install vncorenlp

# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/ 
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# Collecting vncorenlp
#   Downloading https://files.pythonhosted.org/packages/71/c2/96a60cf75421ecc740829fa920c617b3dd7fa6791e17554e7c6f3e7d7fca/vncorenlp-1.0.3.tar.gz (2.6MB)
#      |████████████████████████████████| 2.7MB 8.0MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vncorenlp) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (1.24.3)
# Building wheels for collected packages: vncorenlp
#   Building wheel for vncorenlp (setup.py) ... done
#   Created wheel for vncorenlp: filename=vncorenlp-1.0.3-cp36-none-any.whl size=2645934 sha256=b8474a465431c740164be625fee8efd948d8f68d36dc0eccd9fbb94fc3f2c390
#   Stored in directory: /root/.cache/pip/wheels/09/54/8b/043667de6091d06a381d7745f44174504a9a4a56ecc9380c54
# Successfully built vncorenlp
# Installing collected packages: vncorenlp
# Successfully installed vncorenlp-1.0.3

# %%
# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
#!mkdir -p vncorenlp/models/wordsegmenter
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
#!mv VnCoreNLP-1.1.1.jar vncorenlp/ 
#!mv vi-vocab vncorenlp/models/wordsegmenter/
#!mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/

# %%
ls
# Out:
# PhoBERT_base_fairseq/        PhoBERT_base_transformers.tar.gz  test.json
# PhoBERT_base_fairseq.tar.gz  QA.ipynb                          train.json
# PhoBERT_base_transformers/   squad_vi.json                     vncorenlp/

# %%
from vncorenlp import VnCoreNLP
rdrsegmenter = VnCoreNLP("/content/drive/My Drive/Zalo Challenge/2019/vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m') 

text = "Đại học Công Nghệ, Đại học Quốc Gia Hà Nội."

word_segmented_text = rdrsegmenter.tokenize(text) 
print(word_segmented_text)
# Out:
# [['Đại_học', 'Công_Nghệ', ',', 'Đại_học', 'Quốc_Gia', 'Hà_Nội', '.']]

# %% [markdown]
# # **PhoBERT - VinAIResearch**
# not re

# %%
# !wget https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# !tar -xzvf PhoBERT_base_transformers.tar.gz
# Out:
# --2020-11-21 03:08:17--  https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 13.225.207.128, 13.225.207.14, 13.225.207.105, ...
# Connecting to public.vinai.io (public.vinai.io)|13.225.207.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322405979 (307M) [application/x-tar]
# Saving to: ‘PhoBERT_base_transformers.tar.gz’
#
# PhoBERT_base_transf 100%[===================>] 307.47M  76.0MB/s    in 4.1s
#
# 2020-11-21 03:08:21 (75.4 MB/s) - ‘PhoBERT_base_transformers.tar.gz’ saved [322405979/322405979]
#
# PhoBERT_base_transformers/
# PhoBERT_base_transformers/config.json
# PhoBERT_base_transformers/bpe.codes
# PhoBERT_base_transformers/model.bin
# PhoBERT_base_transformers/dict.txt

# %%
# !wget https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# !tar -xzvf PhoBERT_base_fairseq.tar.gz
# Out:
# --2020-11-21 03:08:33--  https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 54.192.30.23, 54.192.30.67, 54.192.30.106, ...
# Connecting to public.vinai.io (public.vinai.io)|54.192.30.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1243308020 (1.2G) [application/x-tar]
# Saving to: ‘PhoBERT_base_fairseq.tar.gz’
#
# PhoBERT_base_fairse 100%[===================>]   1.16G  57.4MB/s    in 25s
#
# 2020-11-21 03:08:59 (47.3 MB/s) - ‘PhoBERT_base_fairseq.tar.gz’ saved [1243308020/1243308020]
#
# PhoBERT_base_fairseq/
# PhoBERT_base_fairseq/bpe.codes
# PhoBERT_base_fairseq/model.pt
# PhoBERT_base_fairseq/dict.txt

# %% [markdown]
# # ***Load Model***

# %%
from fairseq.data.encoders.fastbpe import fastBPE
from fairseq.data import Dictionary
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--bpe-codes', 
    default="/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/bpe.codes",
    required=False,
    type=str,
    help='path to fastBPE BPE'
)
args, unknown = parser.parse_known_args()
bpe = fastBPE(args)

# Load the dictionary
vocab = Dictionary()
vocab.add_from_file("/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/dict.txt")

# %%
bpe.encode("Ngày hôm nay thật tuyệt!")
# Out:
# 'Ngày hôm nay thật tuyệ@@ t@@ !'

# %%
vocab.encode_line('<s> ' + 'Ngày hôm nay thật tuyệ@@ t@@ !' + ' </s>')
# Out:
# tensor([    0,   319,   654,   136,   520, 46530,  1187,   381,     2,     2],
#        dtype=torch.int32)

# %% [markdown]
# # Get Data

# %%
import re
import json

train_path = '/content/drive/My Drive/Zalo Challenge/2019/train.json'
test_path = '/content/drive/My Drive/Zalo Challenge/2019/test.json'
squad_path = '/content/drive/My Drive/Zalo Challenge/2019/squad_vi.json'

train_text, train_labels = [], []
test_id, test_question, test_title, test_text = [], [], [], []

with open(train_path) as train_file:
    data = json.load(train_file)
    # Process data
    for case in data:
        # Process X
        train_text.append([case['question'], case['text']])
        # Process y
        train_labels.append(1 if case['label'] == True else 0)


with open(test_path) as test_file:
    test_data = json.load(test_file)
    # Process data
    for case in test_data:
        for paragraph in case['paragraphs']:
          test_id.append([case['__id__']])
          test_question.append([case['question']])
          test_title.append([case['title']])
          test_text.append([paragraph['text']])

with open(squad_path) as extra_file:
    extra_data = json.load(extra_file)
    for data in extra_data['data']:
        for paragraph in data['paragraphs']:
          for qas in paragraph['qas']:
            for ans in qas['answers']:
              train_text.append([qas['question'], ans['text'] ])
              train_labels.append(1 if qas['is_impossible'] == True else 0 )

# %%
len(train_text)
# Out:
# 98212

# %%
from sklearn.model_selection import train_test_split

train_sents, val_sents, train_labels, val_labels = train_test_split(train_text, train_labels, test_size=0.1, random_state = 42 )

# %%
len(val_sents)
# Out:
# 9822

# %%
train_sents
# Out:
# [['Tại sao phân loại này đã được thực hiện?',
#   'chỉ duy nhất cho mục đích của việc tiếp cận những lợi ích hành động khẳng định,'],
#  ['Có bao nhiêu đầu đã thập được cho là có?', 'lăm tứ chi,'],
#  ['Ai mà Scout nghĩ có thể cô đơn hơn so với Boo Radley?', ''],
#  ['Hệ mặt trời được hình thành khi nào',
#   'Hệ Mặt Trời ( hay Thái Dương Hệ ) là một hệ hành tinh có Mặt Trời ở trung tâm và các thiên thể nằm trong phạm vi lực hấp dẫn của Mặt Trời , tất cả chúng được hình thành từ sự suy sụp của một đám mây phân tử khổng lồ cách đây gần 4,6 tỷ năm .'],
#  ['Có gì năm một giá trị TZ mới sẽ áp dụng cho?', 'tất cả các năm,'],
#  ['Đâu là Topshop nằm ở đâu?', 'trụ sở tại London'],
#  ['Gì đã bị hủy bỏ trong năm nay của thần tượng?', 'Idol Gives Back'],
#  ['Nơi nào tiệc nhà nước xảy ra?', 'trong Ballroom;'],
#  ['CDPs là gì?', 'nơi điều tra dân số-định'],
#  ['Ngày quốc tế hạnh phúc bắt nguồn từ quốc gia nào',
#   'Ngày Quốc tế Hạnh phúc sau khi công bố đã được nhiều quốc gia trên thế giới ủng hộ. Đến nay, đã có 193 quốc gia thành viên hưởng ứng và cam kết sẽ ủng hộ ngày này bằng các nỗ lực nâng cao chất lượng cuộc sống, xây dựng xã hội công bằng, phát triển bền vững, nhằm đem lại hạnh phúc cho người dân.'],
#  ['Có gì Tennessee ghi âm công ty đầu tiên phát huy Elvis Presley?',
#   'Sun Records,'],
#  ['Trong những hướng chính bên ngoài Plymouth được Devonport nằm ở đâu?',
#   'tây'],
#  ['một tên khác cho thời đại Tokugawa là gì?', 'thời Edo)'],
#  ['Vua bóng đá Pele vô địch thế giới lần thứ 3 khi World Cup được tổ chức ở đâu',
#   'Giải vô địch bóng đá thế giới 2022 () sẽ là giải vô địch bóng đá thế giới lần thứ 22, dự kiến được tổ chức ở Qatar. Vòng chung kết sẽ diễn ra với sự tham gia của 32 đội tuyển bóng đá quốc gia gồm cả đội chủ nhà Qatar. Đây là lần thứ 2 giải vô địch bóng đá thế giới được tổ chức tại châu Á (sau giải vô địch bóng đá thế giới 2002 ở Nhật Bản và Hàn Quốc), là lần đầu tiên được tổ chức tại một quốc gia thuộc Trung Đông và cũng là lần đầu tiên được tổ chức tại một quốc gia thuộc Thế giới Ả Rập. Qatar là quốc gia châu Á thứ 3 được đăng cai World Cup.'],
#  ['Như Chrome tăng sử dụng, trình duyệt sử dụng đã tiếp tục giảm?',
#   'trình duyệt Internet Explorer,'],
#  ['Có gì tỷ lệ dân số khu vực của Valencia là Moriscos?', 'một'],
#  ['Immaculate Conception là gì một đại diện của tránh?',
#   'ban đầu chỉ tội lỗi,'],
#  ['một số diễn viên người Bồ Đào Nha ghi nhận là ai?',
#   'Joaquim de Almeida, Daniela ruah, Maria de Medeiros, Diogo Infante, Soraia Chaves, Riverside, Lucia Moniz, và Diogo Morgado'],
#  ['Ai sản xuất hầu hết các đồ gốm Hispano-Moresque?', 'thợ gốm mudejar'],
#  ['Charles VII Chamberlain lệnh phải làm là gì?', 'leo Mont Aiguille'],
#  ['một trong những chi phí ban đầu so với ngoài vòng pháp luật trong truyền thuyết là gì?',
#   'họ "săn hươu của nhà vua"'],
#  ['đại học y khoa phạm ngọc thành thành lập khi nào',
#   'Trường Đại học Y khoa Phạm Ngọc Thạch là một Trường ĐH Y Khoa đa ngành , được thành lập từ năm 1989 , trực thuộc Uỷ ban Nhân Dân Tp.HCM. Tới tháng 3/2005 , “ Đơn vị Huấn luyện Kỹ năng Y khoa ” của Trường được hình thành . Từ những bước đi đầu tiên , trải qua 13 năm ( 2005-2018 ) , với 04 giai đoạn hoạt động , Trung tâm đã đồng hành và trưởng thành cùng sự phát triển chung của Trường , hoàn thành tốt những nhiệm vụ được giao , đồng thời Trung tâm luôn năng động , sáng tạo , chủ động đề xuất nhiều giải pháp có tính đột phá , vượt khó , chấp nhận mọi thách thức về nhân sự ; cơ sở vật chất , trang thiết bị và kinh nghiệm huấn luyện ...'],
#  ['tên của video âm nhạc mà Jackie Chan làm cho sự kiện này là gì?',
#   'Promise";'],
#  ['hai chương trình khác nhau được cung cấp tại Schoold Báo chí KU là gì?',
#   'Tin tức và Thông tin và Truyền chiến lược'],
#  ['Một sonnet 1830 đã được viết về Chopin bởi những gì người đàn ông?',
#   'Leon Ulrich'],
#  ['Bao nhiêu doanh thu được tạo ra hàng năm của dịch vụ xe buýt công cộng ở London?',
#   '850 triệu £'],
#  ['một số chất xúc tác được sử dụng trong làm mát hydro là gì',
#   'oxit sắt, than hoạt tính, amiăng platinized, kim loại đất hiếm, các hợp chất uranium, oxit cromic, hoặc một số hợp chất niken,'],
#  ['lý thuyết cho rằng vật chất được tạo thành từ các khối xây dựng rời rạc được gọi là gì?',
#   'lý thuyết hạt của vật chất,'],
#  ['Khi nào một cuộc nội chiến Nigeria bắt đầu?', '1967'],
#  ['Khi đã NYC bắt đầu tan rã các trường cao Bronx lớn?',
#   'năm 1990, thành phố'],
#  ['Điều gì có thể gây ra tình trạng nạn đói?', 'hạn hán'],
#  ['Ngôn ngữ chính thức ở Singapore là gì',
#   'Ngày nay , về tổng thể , tiếng Mã Lai được nói trong cộng đồng người Singapore gốc Mã Lai , chỉ 16,8% người Singapore biết đọc viết tiếng Mã Lai và chỉ 12% sử dụng nó làm ngôn ngữ mẹ đẻ .'],
#  ['Chiến tranh Triều Tiên kết thúc vào năm nào',
#   '( ... ) Khoảng chừng 2/3 tổng số tù binh chiến tranh Mỹ tại Triều Tiên chết vì tội ác chiến tranh .'],
#  ['Điều gì đã làm nhà nước Whitehead là chỉ số lớn nhất của một hình thức cao hơn của cuộc sống?',
#   'họ đang tích cực tham gia trong việc sửa đổi môi trường của họ,'],
#  ['Nước nào là người đầu tiên Mỹ bao giờ tuyên chiến trên?', 'Vương quốc Anh'],
#  ['Những gì được cho là tốt hơn phục vụ âm thanh tần số cao hơn, đĩa compact hoặc hồ sơ?',
#   'vinyl hồ sơ'],
#  ['Bao nhiêu là tiền của năm mùa đầu tiên của bản quyền truyền hình Sky?',
#   'Thỏa thuận bản quyền truyền hình Sky đầu tiên là giá trị 304 triệu £ hơn năm mùa'],
#  ['Khi được miền Bắc thua triều đại Jurchen Jin?', '1127'],
#  ['đặc điểm sinh học nhất ảnh hưởng gì đang được?',
#   'polygenes (nhiều gen khác nhau)'],
#  ['Mà loài đã Darwin so sánh với cuộc đấu tranh của con người để tồn tại?',
#   'nhà máy;'],
#  ['đang nghiên cứu các cơ quan viện trợ của Anh gọi là gì?',
#   'Drivers of Change'],
#  ['Ai huấn luyện viên Đại học đội bơi Arizona?', 'Frank Busch'],
#  ['quốc tịch gì là Juan Pardo?', 'Tây Ban Nha'],
#  ['Khi nào các Werhmacht vượt biên giới phía nam của Estonia?',
#   'ngày 7 tháng 7'],
#  ['Khi đã Russell di chuyển trụ sở Hội để Brooklyn?', 'năm 1909, kết hợp'],
#  ['Đồng tiền chung châu Âu với tên gọi EURO phát hành từ ngày nào',
#   'Litva là nước thành viên Liên minh châu Âu đã gia nhập khu vực đồng tiền chung châu Âu thông qua việc sử dụng đồng Euro vào ngày 1 tháng 1 năm 2015, trở thành nước cuối cùng trong số ba nước Baltic sử dụng đồng euro, sau Estonia (2011) và Latvia (2014). Trước đó, đồng tiền của Litva là litas, được đổi sang đồng euro với tỷ giá 3,4528 litas đổi được 1 euro.'],
#  ['Có bao nhiêu giáo viên Hồi giáo đang có ở Kerala?', '6000'],
#  ['sự kiện gì ở Anh trong thế kỷ 16 đã có một kết quả của nhiều trường hợp tử vong vì dị giáo?',
#   'châu Âu Cải cách'],
#  ['Ai có thể đầu tư vào thị trường nhà đất Mỹ qua MBS và CDO?',
#   'tổ chức và nhà đầu tư trên toàn thế giới'],
#  ['Việt Nam gia nhập tổ chức WTO năm nào',
#   'Vũ Khoan (sinh năm 1937) là một chính trị gia và là nhà ngoại giao Việt Nam, từng giữ chức vụ Bí thư Trung ương Đảng Cộng sản Việt Nam, Phó Thủ tướng phụ trách Kinh tế đối ngoại Việt Nam từ tháng 8 năm 2002 đến cuối tháng 6 năm 2006. Ông được nhiều người cho là có nhiều đóng góp tích cực trong quá trình đàm phán Hiệp định Thương mại Việt-Mỹ và quá trình gia nhập Tổ chức Thương mại Thế giới (WTO) của Việt Nam.'],
#  ['tình trạng phát triển nhất trong Tam Quốc là gì?', 'Ngô'],
#  ['đã trường hiện đại và ngữ pháp học kết hợp những gì để trở thành?',
#   'Tính toàn diện khu phố lớn,'],
#  ['đã nổi dậy để các biện pháp bóng đá mới bắt đầu thế nào?',
#   'liên trường Athletic Association'],
#  ['Đại học lớn nhất của Armenia là gì?', 'Đại học bang Yerevan,'],
#  ['Trên 01 Tháng 1 năm 2013, các Kulluk được căn cứ ngoài khơi bờ biển của đảo nào?',
#   'Sitkalidak Đảo'],
#  ['Khi là triều đại nhà Đường?', '618-907 CE)'],
#  ['Trong cơ sở giáo dục những gì được chương trình tìm thấy?',
#   'Đại học Nam Thái Bình Dương'],
#  ['chuyên môn của Joseph Dobrovský là gì?', 'ngôn ngữ học và sử học'],
#  ['Yếu tố thời tiết những gì tạo ra một sai lớn ở vùng khí hậu địa phương trong khu vực Seattle?',
#   'địa phương trong vi khí hậu,'],
#  ['Trong năm 1903, trong đó hai tổ chức được học Brigham Young Univesity thay thế bằng?',
#   'Brigham High School Young, và Đại học Brigham Young'],
#  ['Theo quy ước được Liên Hợp Quốc công nhận, Trái Đất có bao nhiêu đại dương',
#   'Lớp vỏ được chia thành hai kiểu theo phạm vi phân bố và đặc điểm hóa lý của nó là vỏ lục địa và vỏ đại dương. Vỏ đại dương dày 5 km đến 10 km, và được cấu tạo chủ yếu là basalt, diabase, và gabbro. Vỏ lục địa dày từ 30 km đến 50 km và được cấu tạo bởi các đá có tỷ trọng nhẹ hơn so với vỏ đại dương như granite.'],
#  ['Khi nào chính phủ Eritrea bắt đầu chính thức công nhận nhà thờ nào đó?',
#   'tháng 5 năm 2002,'],
#  ['Cơ quan quyền lực nhất của nhà nước ta',
#   'Khoản 3 Điều 2 Hiến pháp Việt Nam năm 2013 quy định: ""Quyền lực nhà nước là thống nhất, có sự phân công, phối hợp, kiểm soát giữa các cơ quan nhà nước trong việc thực hiện các quyền lập pháp, tư pháp, hành pháp."". Tổng bí thư Đảng Cộng sản Việt Nam Nguyễn Phú Trọng khẳng định ""Nhà nước ta không tam quyền phân lập"", nhấn mạnh Quốc hội là cơ quan quyền lực nhà nước cao nhất, các cơ quan nhà nước khác do quốc hội lập ra, phải báo cáo cho Quốc hội và bị Quốc hội giám sát. Tuy nhiên Quốc hội khóa XIV năm 2017 có hơn 95% số đại biểu là đảng viên Đảng Cộng sản Việt Nam.'],
#  ['Một gauge Pirani là chính xác trong phạm vi những gì dao động?',
#   '10 torr đến 10-3 torr,'],
#  ['Ai là nhà cung cấp đồng và coban sang Trung Quốc?', 'Congo'],
#  ['Ai thường có thể được tìm thấy theo dõi tàu cung unload tại Đảo Norfolk?',
#   'Khách thăm'],
#  ['tiểu bang nào tuyên bố ý định rút khỏi công ước quốc tế về các quyền dân sự và chính trị?',
#   'Bắc Triều Tiên'],
#  ['Mà phong trào khác được nó theo mô hình sau?', 'Solidaritat Catalana'],
#  ['Đinh Bộ Lĩnh gắn liền chiến công lừng lẫy nào',
#   'Chiến thắng lừng lẫy của Quân đội Đức trong trận chiến này gắn liền với chiến công oai hùng của viên Sĩ quan Erwin Rommel. Trong cuộc chiến đấu hai ngày, ông đã tóm gọn được nguyên một cứ điểm của quân Ý và thu được vô số tù binh và chiến lợi phẩm. Sau này, ông sẽ còn là một vị Thống chế xuất sắc của Đế chế Đức Quốc xã do Adolf Hitler đứng đầu.'],
#  ['Các phần mềm được viết bằng gì',
#   'Các hệ thống Logic được sử dụng cho các hoạt động cơ khí trình tự trong nhiều ứng dụng . Phần mềm PLC có thể được viết bằng nhiều cách khác nhau – sơ đồ bậc thang , SFC-sơ đồ hàm tuần tự hoặc bằng ngôn ngữ được gọi là danh sách báo cáo ( statement list ) .'],
#  ['Mà Carnival diễn ra ở Oruro ở Bolivia?', 'La Diablada'],
#  ['Danh tướng nào của nước ta nổi tiếng với tài lặn dưới nước',
#   'Yết Kiêu (1242-1301; chữ Hán: 歇驕) là anh hùng chống giặc ngoại xâm vào đời nhà Trần,ông là gia tướng và một trong 5 mãnh tướng dưới trướng Quốc công Tiết Chế Trần Quốc Tuấn, ông là người có công giúp Nhà Trần chống giặc Nguyên Mông vào thế kỷ XIII với biệt tài thủy chiến. Ông là người bơi lặn giỏi, đã sử dụng tài của mình để đục thuyền của quân xâm lược Nguyên Mông.'],
#  ['Khi đã Ấn Độ và Pakistan giành độc lập?', 'năm 1947,'],
#  ['là gì, theo như văn bản, thì thầm cho thời gian của họ?',
#   'nguyên âm và nasals,'],
#  ['Ngoài Pháp, đội khác được gắn với Anh cho số lần ra sân trong FIFA World Cup?',
#   'Tây Ban Nha'],
#  ['Ai hưởng lợi từ cách chức của Malenkov?', 'quyền'],
#  ["Trong đó thành phố đã Galerie de l'Effort Moderne xảy ra?", 'Paris'],
#  ['Đức tin có thể mang lại lợi ích vĩnh cửu gì?', 'sự cứu rỗi'],
#  ['Tính đến năm 2016 nước ta có bao nhiêu dự án BOT',
#   'Chi phí dự kiến của dự án xây dựng này là 3.798,440 tỷ đồng, trong đó dự án thành phần 1 (xây dựng phần cầu chính) có vốn đầu tư trên 2.210 tỷ đồng được thực hiện theo hình thức BOT; dự án thành phần 2 có vốn đầu tư là 1.588,261 từ nguồn vốn ngân sách Nhà nước.'],
#  ['Núi Thiên Ấn nằm bên dòng sông nổi tiếng nào ở tỉnh Quảng Ngãi',
#   'Thiên Ấn hay còn gọi là Kim Ấn Sơn là ngọn núi nằm ở tả ngạn sông Trà Khúc, thuộc địa phận xã Tịnh Ấn Đông và phường Trương Quang Trọng, Thành phố Quảng Ngãi, tỉnh Quảng Ngãi.'],
#  ['Nhà thờ Presbyterian thành lập ở New Mexico cung cấp một thay thế cho tôn giáo nào?',
#   'Công giáo,'],
#  ['Ứng dụng của lưu huỳnh là gì',
#   'Lưu huỳnh tetrachlorua phân huỷ trên -30 ° C ( 242 K ) thành sulfur dichloride và clo . Lưu huỳnh tetrachlorua dễ dàng thuỷ phân :  Lưu huỳnh tetrachlorua phản ứng với nước , tạo ra hydrogen chloride và Lưu huỳnh dioxide thông qua quá trình thuỷ phân .'],
#  ['Những gì hiện ATSC đứng cho?', 'Ủy ban Hệ Thống Truyền Hình nâng cao'],
#  ['Trong suốt lịch sử của châu Âu đã được lao động trẻ em được coi là tích cực?',
#   'Một số quan điểm cho rằng công việc là tốt cho nhân vật xây dựng và kỹ năng phát triển của trẻ'],
#  ['Nguyễn Văn Thiệu mất vào năm nào',
#   'Chỉ 4 ngày sau , Nguyễn Văn Thiệu đã bí mật lên máy bay thoát khỏi Sài Gòn vào đêm ngày 25/4/1975 . Cuộc ra đi của Nguyễn Văn Thiệu diễn ra bí mật trong đêm tối , dưới sự sắp đặt của Thomas Polgar - trưởng CIA ở Sài Gòn Để cho việc ra đi danh chính ngôn thuận , Trần Văn Hương ký quyết định cử Nguyễn Văn Thiệu là đặc sứ của Việt Nam Cộng hoà đến Đài Bắc để phúng điếu Tưởng Giới Thạch ( dù thực ra Tưởng Giới Thạch đã chết từ trước đó 3 tuần ) .'],
#  ['hit lớn từ album 1976 của Nữ hoàng là gì?',
#   'Somebody to Love", một bài hát'],
#  ['Ai là người thiết kế Khải Hoàn Môn ở Pháp',
#   'Năm 1806, sau chiến thắng Austerlitz, hoàng đế Napoléon Bonaparte quyết định xây dựng trên quảng trường Étoile một công trình vinh danh quân đội. Khải Hoàn Môn được kiến trúc sư Jean-François-Thérèse Chalgrin thiết kế, lấy cảm hứng từ các công trình cổ đại, cao 50 mét, rộng 45 mét. Sau Jean-François-Thérèse Chalgrin, những người kế nhiệm công việc xây dựng là Louis-Robert Goust và Jean-Nicolas Huyot.'],
#  ['làm gì cứng và sức mạnh đàn hồi phụ thuộc vào nhiều hơn khuyết tật?',
#   'âm thanh gỗ'],
#  ["Ai bắt đầu một diễn đàn hỗ trợ của quá trình hợp pháp Morales' của sự thay đổi?",
#   'đại diện từ các tổ chức'],
#  ['nhà cung cấp điện Richmond là ai?', 'Dominion Virginia điện'],
#  ['Nào trong hai người đã truy cập Chopin đã được dạy bởi ông trên đàn piano?',
#   'Pauline Viardot,'],
#  ['được ensambles smalled gồm những gì?',
#   'hai mandolin, mandola, và mandocello,'],
#  ['Có bao nhiêu sinh viên đã được thực hiện vào tháng giêng năm 1977?', 'hai'],
#  ['hạn những gì đề cập đến một cách khác, trong đó tiếng địa phương được phân biệt từ các ngôn ngữ?',
#   'quyền ngôn ngữ,'],
#  ['Nước nào là người đầu tiên có nguy cơ bị mặc định soverign?', ''],
#  ['năm gì chứng kiến sự bầu cử của một người bình dân đến văn phòng của Praetor?',
#   '337 BC,'],
#  ['con tàu đầu tiên bay vào vũ trụ tên là gì',
#   'Mars 4 được phóng lên bằng tên lửa đẩy mang tên Proton-K, một giai đoạn đẩy Blok D, bay từ sân bay vũ trụ Baikonur Site 81/23. Quá trình phóng lên diễn ra lúc 19:30:59 UTC ngày 21 tháng 7 năm 1973, với ba giai đoạn đầu tiên đặt tàu vũ trụ lên một quỹ đạo chờ thấp trước khi Blok D đẩy tàu vũ trụ này vào quỹ đạo nhật tâm liên kết với sao Hỏa.'],
#  ['Làm thế nào được Blue Ivy ghi trên Glory?', 'B'],
#  ['Trong những năm được Bern được xếp hạng là một trong 10 thành phố tốt nhất cho chất lượng sống của họ?',
#   '2010)'],
#  ['Một số trong những bức tường xung quanh mà mang tính bước ngoặt đã bị phá hủy trong năm 1930?',
#   'các Bargate'],
#  ['Ai đã thiết lập mô hình cảm thấy ở Trung Quốc?', 'Xie Bangxiu'],
#  ['của các nhóm nông nghiệp các loại cơ bản là gì?',
#   'trang trại hoặc các nhóm Pastoralist'],
#  ['giữa năm 1638 và 1648 những gì đường phố là EIC trụ sở trên?',
#   'Leadenhall đường'],
#  ['Đà Nẵng có bao nhiêu đơn vị hành chính',
#   'Thành phần cơ cấu khu vực hành chính thành phố Đà Nẵng là : 45 phường , 11 xã và 1 huyện không phân chia xã .'],
#  ['Trảo Nha là bút danh của nhà thơ nào?', 'Xuân Diệu'],
#  ['Những con chim đã phá vỡ một kỷ lục trong thế nào đến nay nó đã bay qua cuộc sống của nó?',
#   'Manx Shearwater'],
#  ['Ai chủ yếu chiếm phức xung quanh các trường đại học?', 'sinh viên thuê'],
#  ['Đâu Stalin nói ông sẽ cho phép các lực lượng không quân Liên Xô để hoạt động cho một số lượng hạn chế về thời gian?',
#   'không phận Trung Quốc,'],
#  ['Những gì thường đóng chỉ là một phần nhỏ trong cấu trúc của một gen?',
#   'protein mã hóa chuỗi thực tế'],
#  ['Có bao nhiêu đã Crazy in Love bán để trở thành một trong những đĩa đơn bán chạy nhất trong lịch sử?',
#   '8 triệu'],
#  ['New Delhi chia sẻ vị trí là điểm đến bán lẻ nhắm mục tiêu nhất tại các thị trường châu Á-Thái Bình Dương với những gì thành phố khác?',
#   'Bắc Kinh'],
#  ['Một trong những chương trình thời trang lớn nhất thế giới có tên là gì ở New York?',
#   'New York Fashion Week'],
#  ['là đại lý đặc biệt của FBI đã ban hành những gì nếu họ không bằng cấp đầu tiên của họ?',
#   'Glock 17 hoặc Glock 19,'],
#  ['Có gì khu vực của Namibia đã Orlam tộc giải quyết trong?', 'nam Namibia'],
#  ['Ai tin rằng họ là những người đại diện Han Tây đúng không?',
#   'quan chức nước ngoài'],
#  ['dân số của Trung Quốc trong 2 AD là gì?', '57.671.400'],
#  ['Khi nào các câu hỏi của các phản ứng tình dục của con người bắt đầu?',
#   'Từ ít nhất cuối thế kỷ XIX'],
#  ['Đâu là con trai Hoàng tử của Richard, Alexander Windsor, Bá tước?',
#   'Ulster;'],
#  ['Khi nước được giải phóng do nhu cầu cao, bơm trở swhat?',
#   'một máy phát thủy điện'],
#  ['Phần nào của nhà nước có sa mạc nhất; bắc, nam, đông hoặc tây?', 'nam'],
#  ['Khi được giới thiệu Windows 8.1?', 'Tháng Năm 14, 2013'],
#  ['Có bao nhiêu người sống trong các khu vực đô thị Miami-Dade?', '5'],
#  ['Có gì tên đã được đưa ra để pin pháo binh ven biển dựng lên ngay sau 1852?',
#   'Fort Rosecrans'],
#  ['không vỏ hạt bảo vệ những gì?', 'phôi'],
#  ['Trung Quốc có bao nhiêu dân tộc',
#   'Dân tộc Trung Hoa (, âm Hán Việt: "Trung Hoa Dân tộc") là một thuật từ chính trị gắn liền với lịch sử Trung Quốc về chủng tộc và xây dựng dân tộc.'],
#  ['Về bao nhiêu phòng khách sạn đang có ở Manhattan?',
#   '90.000 phòng khách sạn'],
#  ['Ai cung cấp đào tạo nghề ở Cork?', 'Trường Cork Thương mại'],
#  ['Những thành viên của Spectre đã bị coi là đã chết?', 'Franz Oberhauser'],
#  ['Loại màu sắc là màu đỏ và màu xanh lá cây?', 'bổ sung'],
#  ['Những gì đã phần nào bị phá hủy bởi vụ đánh bom Đồng minh vào năm 1944?',
#   'Romanesque Église Saint-Étienne,'],
#  ['Những người âm mưu lật đổ chế độ của Thái hậu Yan?', 'Sun Cheng'],
#  ['bản dịch tiếng Anh của Medri Bahri là gì?', 'biển đất")'],
#  ['Có bao nhiêu trạm gốc China Mobile đã ngừng làm việc?', '2.300'],
#  ['Huyện đảo Bạch Long Vỹ trực thuộc tỉnh thành phố nào',
#   'Do thành phố Hải Phòng và tỉnh Quảng Ninh tranh chấp dãy đảo phía bắc và đông bắc đảo Cát Bà nên một số hòn đảo ở phía bắc và tây bắc của xã hiện do tỉnh Quảng Ninh quản lý mặc dù chúng được thành phố Hải Phòng xem là thuộc về xã Phù Long. Một số đảo lớn trong số đó là đảo Quả Muỗm, đảo Quả Xoài, đảo Đá Chông....'],
#  ['nghiên cứu những gì cấp bằng sáng chế một quá trình dầu nước nóng để bitum tách?',
#   'TS'],
#  ['Ai ra lệnh quân đội?', 'các stadtholder,'],
#  ['Loài vật nào duy nhất thuộc lớp thú có thể bay',
#   'Dơi là động vật có vú duy nhất có thể bay được. Một số loài thú khác như chồn bay, sóc bay... trông có vẻ như có thể bay nhưng thực ra chúng chỉ có thể lượn - trong một khoảng cách có giới hạn. Khoảng 70% số loài dơi ăn sâu bọ, số còn lại chủ yếu ăn hoa quả và chỉ có vài loài ăn thịt. Dơi cần thiết cho sinh thái bởi chúng đóng vai trò thụ phấn hoa hay phát tán hạt cây, sự phân tán của nhiều loài cây lệ thuộc hoàn toàn vào dơi. Loài dơi nhỏ nhất là dơi mũi lợn Kitti chỉ dài 29–33 mm, nặng khoảng 2 gam. Loài lớn nhất là dơi quả đầu vàng lớn với sải cánh dài 1,5 m và cân nặng khoảng 1,2 kg.'],
#  ['Ai là thủ tướng cuối cùng để phục vụ đồng thời là Bộ trưởng Tài Chính?',
#   'Balfour'],
#  ['trọng tâm của Gucci Chime for Change chiến dịch là gì?',
#   'lan trao quyền cho nữ'],
#  ['Khi được Philadelphia Baptist Confession tạo?', '1742'],
#  ['Ai sở hữu nhãn hiệu hàng hoá Desperados?', 'Jerry Jones'],
#  ['Ai là người đầu tiên tìm ra Đà Lạt',
#   'Cùng với bác sĩ Alexandre Yersin khám phá ra Đà Lạt, có linh mục Robert thuộc Hội Thừa sai Paris (MEP) vào năm 1893. Đến 1917, linh mục quản lý của MEP tại Viễn Đông là Nicolas Couveur đã đến Đà Lạt với mục đích tìm nơi nghỉ dưỡng cho các giáo sĩ, và ông đã cho xây dựng một dưỡng viện giáo đồ nay là một phần của nhà xứ. Vào cuối tháng 4 năm 1920, Giám mục Quinton (Giám quản Tổng tòa tại Sài Gòn) ban quyết định thành lập Giáo phận Đà Lạt.'],
#  ['Ai phát minh ra cách đánh máy Unikey',
#   'UniKey là chương trình điều khiển bàn phím, hay còn gọi là bộ gõ, hỗ trợ nhập liệu tiếng Việt trên máy tính, chạy trên hệ điều hành Microsoft Windows, được phát triển bởi Phạm Kim Long. Ban đầu, phần mềm được phát hành theo giấy phép nguồn mở Giấy phép Công cộng GNU, tuy nhiên từ phiên bản 4.0 phát hành năm 2005 cho tới nay, tác giả đã không còn công bố mã nguồn nữa. Trên nền Linux phần mềm này được gọi là X-UniKey.'],
#  ['Những đặc điểm không vốn có trong thực tế tôn giáo La Mã?',
#   'đức tin hay giáo điều,'],
#  ['Trong giai đoạn trung cổ ở châu Âu vào cuối như những gì đã được bông xem?',
#   'nhập khẩu'],
#  ['Trong những loạt các tiếp xúc không có đi có lại thường làm việc?',
#   'giữa 1/1000 giây để 1/2'],
#  ['Ai Cập thuộc khu vực nào của châu Phi',
#   'Ai Cập cổ đại là một nền văn minh cổ đại nằm ở Đông Bắc châu Phi, tập trung dọc theo hạ lưu của sông Nile thuộc khu vực ngày nay là đất nước Ai Cập. Đây là một trong sáu nền văn minh phát sinh một cách độc lập trên thế giới. Nền văn minh Ai Cập được thống nhất lại vào năm 3150 TCN (theo trình tự thời gian của bảng niên đại Ai Cập) với sự thống nhất chính trị của Thượng và Hạ Ai Cập dưới thời vị pharaon đầu tiên (Narmer, thường được gọi là Menes). Lịch sử của Ai Cập cổ đại đã trải qua một loạt các thời kỳ vương quốc ổn định, và các giai đoạn hỗn loạn giữa chúng được gọi là các giai đoạn chuyển tiếp: Cổ Vương quốc thời kỳ Sơ kỳ Đồ đồng, Trung Vương quốc tương ứng giai đoạn Trung kỳ Đồ Đồng và Tân Vương quốc ứng với Hậu kỳ Đồ đồng.'],
#  ['Những gì đã có tên của bài hát dành riêng cho trẻ em?', 'Glory",'],
#  ['Khi nào bảng xếp hạng Adult Contemporary nhận tên hiện tại của nó?',
#   'ngày 07 tháng tư năm 1979,'],
#  ['Râm bụt là quốc hoa của nước nào',
#   '"Hibiscus rosa-sinensis" là quốc hoa của Malaysia, với tên gọi "Bunga Raya" trong tiếng Mã Lai, "Sembaruthi" trong tiếng Tamil tiếng Khmer pka rumyul (ផ្កា រំយោល)\u200b và "mamdaram" trong tiếng Telugu (మందారం).'],
#  ['Có bao nhiêu pound PCBs được ước tính được giữ lại trong các lớp trầm tích đằng sau đập Woods Pond?',
#   '11.000'],
#  ['Có gì nhà môi trường đã có thể làm, thay vì săn bắn?',
#   '(tái) kẻ săn mồi giới thiệu'],
#  ['Ai từ chối trẻ em khuyết tật là không thể tham dự một trường công lập?',
#   'bác sĩ hoặc gia sư đặc biệt'],
#  ['đã Carl von Voit và Max Rubner áp dụng những gì đến dinh dưỡng để nhận được kết quả của họ?',
#   'nguyên tắc của vật lý'],
#  ['lý thuyết Tarski của đã vượt qua sự phản đối nhất định với những gì quan niệm về sự thật?',
#   'sự thật như thư từ'],
#  ['giá gốc cho một pin thay thế từ Apple là gì?', '$ 99,'],
#  ['Đâu là nguồn khả năng của sự thay đổi đến sự hình thành manipular?',
#   'sao chép từ kẻ thù Samnite của Rome'],
#  ['Được từ Latin cho gia cầm cũng được dùng để mô tả những động vật nhỏ khác như trái ngược với bất kỳ poulty?',
#   'từ pullus chữ Latin, có nghĩa là động vật nhỏ'],
#  ['Khi quy tắc xã hội truyền thống có thể bị phá vỡ?',
#   'trong thời gian cai trị tồi'],
#  ['Có bao nhiêu dân thường bị người Nhật hy vọng sẽ giết trong cuộc tấn công kế hoạch của họ trên San Diego?',
#   'hàng chục ngàn thường dân'],
#  ['Đã có bất kỳ thay đổi để hạn chế đặt trên các mạng thông tin liên lạc ở Miến Điện?',
#   'Hạn chế về kiểm duyệt truyền thông đã được nới lỏng đáng kể trong tháng 8 2012'],
#  ['bản sắc gì mô hình tình trạng nổi lên do công việc của James Marcia?',
#   'Neo-Eriksonian"'],
#  ['không được gì coi là hợp lệ khi được thực hiện bởi các giáo phái khác?',
#   'rửa tội trước'],
#  ['Triều đại nào không lấy danh hiệu trạng nguyên',
#   'Nếu dựa theo danh sách này thì có 49 Trạng nguyên chính thức và Trạng nguyên đầu tiên là Nguyễn Quan Quang. Những người đỗ đầu các khoa thi từ năm 1246 trở về trước chưa đặt danh hiệu trạng nguyên.'],
#  ['Ai làm Nhân chứng Jehovah tin rằng giới thiệu tư duy độc lập?',
#   'Satan the Devil"'],
#  ['Kotick công ty là gì CEO của?', 'Activision Blizzard'],
#  ['Có bao nhiêu trường hợp bệnh lao đang hoạt động trong quá trình cả năm 2014?',
#   '9'],
#  ['Có gì nhân vật thường không chuẩn?', 'đa âm tiết'],
#  ['Trong bao nhiêu ngôn ngữ được sinh viên trong các cơ sở giáo dục đại học được đào tạo vào năm 1974?',
#   '47'],
#  ['Có bao nhiêu trạm cứu hỏa đang có trong giới hạn thành phố Southampton?',
#   'ba trạm cứu hỏa'],
#  ['Đâu là Orlasenke nằm ở đâu?', 'trong'],
#  ['tiêu đề của Whitehead tại Đại học London là bao nhiêu vào cuối năm 1918?',
#   'Trưởng Khoa Khoa học'],
#  ['Đâu là "Viễn Đông" lấy từ đâu?', 'của Ptolemy "Ấn Độ Vượt sông Hằng'],
#  ['không từ samyaksamadhi nghĩa là gì?', 'chánh định"'],
#  ['Làm thế nào xa trở lại những thông lệ ghi có thể được truy?', '1925'],
#  ['một số chữ viết tắt cho các mạch tích hợp là gì?',
#   'IC , vi mạch hoặc đơn giản là chip),'],
#  ['Mà đã Nelson mất bên tham gia trong năm 2008?', 'Malcolm Turnbull'],
#  ['tiểu bang nào đang ở trong một cuộc xung đột với Đông Ngô, và Shu Han?',
#   'Tào Ngụy,'],
#  ['Tại sao người Pháp và tiếng Anh không thể nắm quyền kiểm soát của lĩnh vực này?',
#   'thiếu thiết bị'],
#  ['Trong những năm đã Tito mô hình kế hoạch phát triển kinh tế của mình một cách độc lập từ Moscow?',
#   'năm 1948,'],
#  ['tổ chức những gì hiện các kiểm định chất lượng cho IGCSE ở Swaziland?',
#   'Cambridge International Khám'],
#  ['Những gì người khác còn được gọi là tăng sức mạnh?', 'ăng ten tăng'],
#  ['Tên chính thức của Indonesia là gì',
#   'Indonesia ( tên chính thức : Cộng hoà Indonesia , tiếng Indonesia : " Republik Indonesia " ) trước đó trong tài liệu tiếng Việt quốc gia này từng được gọi là " nước Nam Dương " , là một quốc gia nằm giữa Đông Nam Á và Châu Đại Dương . Indonesia được mệnh danh là " " Xứ sở vạn đảo " " , lãnh thổ của nó bao gồm " 13.487 " hòn đảo và với dân số khoảng 255 triệu người ( năm 2015 ) , đứng thứ tư thế giới về dân số .'],
#  ['đã nghiên cứu năm 2012 đã nói gì được nhân đôi bởi việc sử dụng bông GM?',
#   'bọ rùa, bắt kịp xu và nhện'],
#  ['Nepal có đường biên giới tiếp giáp quốc gia nào',
#   'Nepal (phiên âm tiếng Việt: Nê-pan; tiếng Nepal: नेपाल Về âm thanh nàyNepāl [neˈpal]), tên chính thức là nước Cộng hoà Dân chủ Liên bang Nepal (tiếng Nepal: सङ्घीय लोकतान्त्रिक गणतन्त्र नेपाल Sanghiya Loktāntrik Ganatantra Nepāl),[7] là một quốc gia nội lục tại Nam Á. Dân số quốc gia Himalaya này đạt 26,4 triệu vào năm 2011, sống trên lãnh thổ lớn thứ 93 thế giới.[3][8] Nepal giáp với Trung Quốc về phía bắc, giáp với Ấn Độ về phía nam, đông và tây. Nepal cách lãnh thổ Bangladesh 27 km tính từ mũi đông nam. Nepal đa dạng về địa lý, có các đồng bằng phì nhiêu, các đồi rừng cận núi cao, và có tám trong số mười núi cao nhất thế giới, trong đó có núi Everest. Kathmandu là thủ đô và thành phố lớn nhất của Nepal. Nepal là một quốc gia đa dân tộc, tiếng Nepal là ngôn ngữ chính thức.'],
#  ['Ai là vợ của Bill Gates', 'Melinda'],
#  ['quang phổ của các vị thần, bạn có thể nhận được trong Mexico City là gì?',
#   'thực phẩm cơ bản để siêu hàng xa xỉ cao cấp'],
#  ['Có gì xảy ra khi con chậm trễ phát tán từ nhóm sinh của họ?',
#   'giống Hợp tác xã'],
#  ['Casablanca là thành phố du lịch nổi tiếng của nước nào',
#   'Kể từ sau đó Casablanca đã tập trung vào công nghiệp và dịch vụ. Hiện nay, thành phố này đang phát triển công nghiệp du lịch. Casablanca là "thủ đô" kinh tế và kinh doanh của Maroc, trong khi Rabat là thủ đô về mặt chính trị.'],
#  ['Trạng chiếu của nước ta là ai',
#   'Phạm Đôn Lễ (chữ Hán: 范敦禮, 1457 - 1531), tự là Lư Khanh, là Trạng nguyên khoa Tân Sửu (1481), niên hiệu Hồng Đức 12, đời vua Lê Thánh Tông. Vì có công dạy dân làng dệt chiếu cói nên còn gọi là Trạng Chiếu hay Tam nguyên Đôn Lễ.[1][2]. Ông làm quan đến các chức Tả thị lang, rồi Thượng Thư.'],
#  ['Có bao nhiêu người ở Miến Điện hiện đang sử dụng một thị thực làm việc cho Thái Lan?',
#   '600.000 lao động nhập cư đăng ký từ Myanmar ở Thái Lan,'],
#  ['Ai giới thiệu Irving để Spielberg?', 'Brian De Palma,'],
#  ['Cuộc bầu cử quốc hội vào ngày 22 tháng 5 năm 2011 để bầu cử đại biểu cho quốc hội khóa mấy',
#   'Tại cuộc bầu cử Quốc hội ngày 22 tháng 5 năm 2011 (Đơn vị bầu cử Số 3: thị xã Thuận An, tỉnh Bình Dương), bà đã không trúng cử đại biểu Quốc hội Việt Nam khóa XIII (2011-2016).'],
#  ['Trong những năm đã Missolonghi rơi xuống người Ai Cập?', '1826'],
#  ['tổ chức những gì các nước phương Tây đã từ chối để nhận ra?',
#   'tiếng Estonia SSR,'],
#  ['hai ví dụ về hoạt động quân sự đơn phương Bồ Đào Nha độc lập là gì tiến hành ở nước ngoài?',
#   'Angola vào năm 1992 và ở Guinea-Bissau năm 1998'],
#  ['Có gì lý luận chính trị đã Popper nói không đáp ứng tiêu chí falsifiability của mình?',
#   'chủ nghĩa Mác'],
#  ['Từ những gì ngôn ngữ là tiếng Bồ Đào Nha có nguồn gốc?', 'Latin'],
#  ['lãnh đạo tinh thần của Trung tâm cộng đồng Đền Israel là ai?',
#   'Rabbi Shammai Engelmayer,'],
#  ['triều đại cai trị gì Vương quốc Hồi giáo IFAT?', 'triều đại Walashma'],
#  ['Phơi nhiễm HIV là gì',
#   'Hiệp sĩ đường phố Nguyễn Sin     Hiệp sĩ Nguyễn Sin điều trị phơi nhiễm HIV     Hiệp sĩ Nguyễn Sin khắc tinh của tội phạm     Hiệp sĩ Nguyễn Sin rong ruổi trên các ngả đường bắt tội phạm'],
#  ['Cơn bão Linda đổ bộ vaò Việt Nam vào năm nào',
#   'Bão nhiệt đới Linda, được biết đến ở Philippines với tên gọi Áp thấp nhiệt đới Openg, được biết đến tại Việt Nam với tên gọi cơn bão số 5 , là cơn bão thảm khốc nhất khi tấn công vào miền Nam Việt Nam trong vòng ít nhất 100 năm. Hình thành vào ngày 31 tháng 10 năm 1997 trên Biển Đông, Linda mạnh lên khi di chuyển về phía Tây và đã đổ bộ vào khu vực Nam Bộ Việt Nam trong ngày 2 tháng 11 với sức gió 100 km/giờ cùng với mưa lớn tận 500mm-700mm.Theo Trung tâm Cảnh báo Bão Liên hợp (JTWC) của Hoa Kỳ thì khi Linda khi tiến vào vịnh Thái Lan Linda tăng cấp thành bão cuồng phong, nhưng đã suy yếu lại thành bão nhiệt đới trước khi vượt bán đảo Mã Lai và đi vào vịnh Bengal.Tại đây, Linda một lần nữa đạt đến cường độ bão cuồng phong theo JTWC, tuy nhiên không lâu sau độ đứt gió tăng lên và dòng dẫn suy yếu trước khi tan rã vào ngày 9 tháng 11.'],
#  ['đã Katura Horton-Perinchief làm gì?',
#   'làm nên lịch sử khi trở thành nữ thợ lặn da đen đầu tiên thi đấu ở Thế vận hội Olympic'],
#  ['Mà các Phúc Âm đồng ý nhất với Athanasius?', 'Tin Mừng Gioan'],
#  ['một số phản đối cấm bóng đèn sợi đốt là gì?',
#   'cao hơn giải pháp thay thế và chất lượng thấp hơn của ánh sáng đèn huỳnh quang'],
#  ['nhóm những gì đã MLK tin rằng cần quan tâm hơn nữa từ FBI?',
#   'supremacists trắng'],
#  ['nam âu gồm những nước nào',
#   'Nam Âu là một khu vực địa lý thuộc châu Âu . Khái niệm này có thể thay đổi tuỳ cách nhìn nhận theo lĩnh vực khí hậu ( khí hậu Địa Trung Hải ) , địa lý hay ngôn ngữ - văn hoá .'],
#  ['Chuyện gì xảy ra khi các nhà khoa học cố gắng áp dụng khoa học để sắp xếp ra sự khác biệt xã hội?',
#   'nó tất cả sụp đổ'],
#  ['Ai đang nắm giữ kỷ lục bơi 100m bướm nhanh nhất', 'Joseph Schooling'],
#  ['Bao nhiêu doanh thu cho công ty được tạo ra bởi hệ thống BDS?', '$ 31'],
#  ["không 'chaetae' nghĩa là gì?", '")'],
#  ['Tham dự tổ chức thế tục của giáo dục đại học được xem là cần thiết nhưng thua kém những gì xã hội?',
#   'Haredi'],
#  ['chủ tịch ủy ban nhân dân hiện tại của Thái Bình là ai',
#   'Đặng Trọng Thăng ( sinh năm 1960 ) là một chính khách người Việt Nam . Ông hiện là Chủ tịch Uỷ ban nhân dân tỉnh Thái Bình.Ông từng là Chủ tịch Hội đồng nhân dân tỉnh Thái Bình .'],
#  ['Đa số người dân Brunei theo tôn giáo nào',
#   'Đa số người dân ở Tanjung Pandan là người Khách Gia và người Mã Lai. Các tôn giáo của người Hoa là Phật giáo, Công giáo và Tin lành.'],
#  ['Chùa Hà được xây dựng năm nào',
#   'Chùa Hà cùng với chùa Duyên Ninh là 2 ngôi chùa cầu duyên ở miền Bắc .'],
#  ['đã Brandenburg sử dụng những gì ghi để tinh chỉnh?', 'thuật toán nén MP3'],
#  ['Quốc hội Việt Nam mỗi năm họp mấy kỳ',
#   'Địa vị pháp lý của một đại biểu quốc hội được bắt đầu sau khi Quốc hội đã xác nhận tư cách đại biểu tại phiên họp đầu tiên của kỳ thứ nhất mỗi khóa Quốc hội. Nhiệm kỳ của đại biểu quốc hội được tính từ kỳ họp thứ nhất Quốc hội khóa đó đến kỳ họp thứ nhất Quốc hội khóa sau.'],
#  ['México nằm ở khu vực nào',
#   'México ( phiên âm : " " Mê-xi-cô " " hoặc " " Mê-hi-cô " " , , tiếng Nahuatl : " Mēxihco " ) , tên chính thức : Hợp chúng quốc México ( , ) , là một nước cộng hoà liên bang thuộc khu vực Bắc Mỹ . México là một quốc gia rộng lớn với diện tích gần 2 triệu km2 , đứng hàng thứ 14 trên thế giới và dân số khoảng 106 triệu người , đứng hàng thứ 11 trên thế giới .'],
#  ['tài liệu gì có tỷ lệ hấp thụ chỉ đạt 0,01%?', 'Teflon'],
#  ['Có bao nhiêu bán buôn các công ty ở Istanbul vào năm 1911?', '654'],
#  ['Ai là người thành lập Facebook',
#   'Facebook có thể truy cập được từ hầu như mọi thiết bị có khả năng kết nối Internet , từ máy tính để bàn , máy tính xách tay , máy tính bảng cho đến điện thoại thông minh . Sau khi đăng ký tài khoản trên Facebook , người dùng có thể tạo ra một hồ sơ tuỳ chỉnh cho biết tên của họ , nghề nghiệp , trường học ...'],
#  ['dân số của Saint Helena là gì?', '4.255'],
#  ['hạn nào được sử dụng để mô tả thời kỳ đồ đá mới giữa cuối trong giáo dục Mỹ?',
#   'giai đoạn hình thành'],
#  ['Mà con người không tiến hóa mối quan tâm nhân loại học bản thân với sự tiến hóa sinh học và văn hóa của?',
#   'quá khứ và hiện'],
#  ['Bao lâu thì các loại thuốc trừ sâu được sản xuất gần đây hơn là đánh giá cho sự an toàn?',
#   'mỗi 15 năm'],
#  ['phương pháp nào được sử dụng cho các thành phần kiểm tra dưới khối lượng công việc đột xuất?',
#   'Căng thẳng thử nghiệm'],
#  ['Tòa án đã viết những gì về ý kiến của Jefferson vì nó liên quan đến phạm vi và tác động của Tu chính án đầu tiên?',
#   'có thẩm quyền'],
#  ['Có gì hiếm khi được sử dụng?', 'brisure'],
#  ['ai là phó bí thư hiện tại của Đà Nẵng',
#   'Một số cán bộ Đà Nẵng bị bắt , khám xét nhà vì liên quan tới Vũ " nhôm " vì " Vi phạm các quy định về quản lý đất đai ” bao gồm : Ông Đào Tấn Bằng , sinh năm 1975 , nguyên Phó Chánh Văn phòng UBND TP. Đà Nẵng , nay là Bí thư Đảng uỷ khối các Khu công nghiệp TP. Đà Nẵng ; ôngNguyễn Viết Vĩnh , sinh năm 1978 , nguyên Trưởng phòng Quản lý đô thị , UBND TP. Đà Nẵng , nay là Giám đốc Cảng vụ đường thuỷ nội địa .'],
#  ['Những hành động đã ISIL mất chống lại các nhà báo phương Tây và nhân viên cứu trợ?',
#   'và xử trảm'],
#  ['Côn Sơn ca là tác phẩm của ai',
#   'Nguyễn Trãi là Nhà chính trị, Nhà địa lý, Nhà ngoại giao là anh hùng của dân tộc Việt Nam. Nguyễn Trãi lấy bút danh là Ức Trai. Ông sinh ra và lớn lên tại Kinh Thành Thăng Long. Cha là Nguyễn Phi Khanh quê ở làng Chi Ngại thuộc xã Công Hòa, huyện Chí Linh, tỉnh Hải Dương. Sau chuyển đến Nhị Khê thuộc Hà Tây cũ. Mẹ là Trần Thị Thái con gái quan tư đồ Trần Nguyên Đán. Cha mẹ ông sinh được năm người con nhưng không bao lâu mẹ của Nguyễn Trãi qua đời, anh em Nguyễn Trãi phải sống cùng ông ngoại là Trần Nguyên Đán tại Kinh Thành Thăng Long, rồi chuyển lên Côn Sơn, nhưng ông ngoại ông là Trần Nguyên Đán cũng qua đời vào năm 1390. Nguyễn Trãi cùng các anh em phải về Nhị Khê sống với cha. Được ông ngoại và cha trực tiếp dạy dỗ nên Nguyễn Trãi nổi tiếng là người có tài, có đức và có chí lớn. Năm 1400, ông đỗ Thái Học Sinh và được nhận chức Ngự Sử Đài Chánh Trưởng dưới thời Hồ. Năm 1407, nước ta bị giặc Minh xâm chiếm, theo lời dặn của cha, ông nặng nghĩa nước, trả thù nhà, ngày đêm nung nấu ý chí giết giặc, trăn trở kế bình Ngô. Sau Khi thoát khỏi sự truy sát của quân giặc, Nguyễn Trãi đến Lam Sơn tụ nghĩa, dự hội thề Lũng Nhai, Dâng Bình Ngô Sách.Trong những năm chiến đấu ông đã luôn sát cánh bên Lê Lợi và đưa ra nhiều mưu kế xuất sắc trong kháng chiến. Năm 1927, đất nước ca khúc khải hoàn, Nguyễn Trãi đã thay mặt Lê Lợ viết " Bình Ngô Đại Cáo".đó là bản tuyên ngôn độc lập, là áng thiên cổ hùng văn trong lịch sử Việt Nam. Bên cạnh sự nghiệp dựng nước ông đã để lại cho lịch sử những tác phẩm tiêu biểu: Quân Trung Từ Mệnh Tập, Bình Ngô Đại Cáo, Văn Bia Vĩnh Lăng, Quốc Âm Thi Tập... Những tác phẩm của ông kết tinh được những tư tưởng tiến bộ của thời đại, tinh hoa và khí phách của dân tộc. Năm 1937, Nguyễn Trãi thoát triều về Côn Sơn, ông đã viết bài Côn Sơn Ca để tỏ lòng mình Năm 17 tuổi, ông được vua Lê Thánh Tông trọng dụng phục hồi chức vụ cũ. Tháng 3 năm 1442, Nguyễn Trãi làm đề cho cuộc thi đại học đầu tiên thời Lê sơ. Năm 1442, vợ ông là bà Nguyễn Thị Lộ bị vu oan giết vua Lê Thánh Tông, nên vào ngày 19/9/1442, ông cùng dòng họ bị giết hại thảm khốc. Phải 22 năm sau gia đình ông mới được minh oan. Năm 1980, Nguyễn Trãi đã được công nhận là Danh Nhân Văn Hóa Thế giới.'],
#  ['Khi đã Spielberg và Irving kết hôn?', 'tháng 11 năm 1985,'],
#  ['Khi là lần cuối cùng Chicago Cubs xuất hiện vào mùa thu cổ điển?',
#   'năm 1945, mặc dù'],
#  ['Có bao nhiêu người tham gia thử giọng đầu tiên?', 'khoảng 10.000'],
#  ['Tại sao Madrid nhượng lãnh thổ sang Mỹ',
#   'Florida đã trở thành một gánh nặng sang Tây Ban Nha, trong đó không thể đủ khả năng để gửi người định cư hoặc đơn vị đồn trú'],
#  ['Bao nhiêu doanh thu đã Spectre sản xuất từ Anh, Scotland, và thị trường Ailen bởi 2016/02/21?',
#   '$ 138'],
#  ['năm gì được một nhà nghỉ Masonic toàn nữ tạo ra?', 'năm 1901,'],
#  ['Bến Nhà Rồng được bắt đầu xây vào năm nào',
#   'Năm 1919, hãng được phép xây bến bằng xi măng cốt sắt, nhưng không thực hiện được, phải đến tháng 3 năm 1930 mới hoàn thành bến mới, chỉ một bến nhưng dài tới 430 mét.'],
#  ['Đảo nào lớn nhất Ấn Độ Dương',
#   '"Adansonia grandidieri" là lớn nhất và nổi tiếng nhất của Madagascar trong sáu loài bao báp. Cây hùng vĩ và bất thường này là loài đặc hữu của đảo Madagascar, nơi mà nó là một loài nguy cấp bị đe dọa bởi sự xâm lấn đất nông nghiệp.'],
#  ['ca sĩ gì chỉ trích Carrie Underwood cho chiến thắng một giải thưởng nhạc đồng quê?',
#   'LeAnn Rimes,'],
#  ['đã Tướng Oreste Baratieri công bố gì ở vùng cao nguyên dọc theo bờ biển Eritrea?',
#   'mới thuộc địa của Ý Eritrea,'],
#  ['tên thay thế cajmere là gì?', 'Velvet Xanh'],
#  ['Cung An Định thuộc phong cách kiến trúc nào',
#   'Trong khu vực cung Diên Thọ có khoảng 20 công trình kiến trúc lớn nhỏ, vừa phong phú về loại hình vừa đa dạng về phong cách kiến trúc. Hiện nay chỉ còn lại các công trình sau.'],
#  ['Đa số người dân Ai Cập sống gần sông gì?', 'sông Nile,'],
#  ['đã lạc Celtic khai thác được gì từ dãy Alps?', 'đồng;'],
#  ['Hy Lạp là nhà đầu tư nước ngoài lớn nhất của khu vực gì?',
#   'Cộng hòa Macedonia'],
#  ['Khi một người hoặc động vật sẽ mất ý thức khi tiếp xúc với một chân không?',
#   'sau một vài giây'],
#  ['Không sử dụng UTC, Windows không thể khởi động đa với các phiên bản khác nhau của bản thân như bạn cần phải làm gì để sử dụng những loại đĩa?',
#   'một đĩa khởi động cứu hộ'],
#  ['Ai giới thiệu Nasser và vợ của ông?', 'Abdel Hamid Kazim,'],
#  ['Mà nhà thờ đã Reporters Without Borders treo một biểu ngữ phản đối?',
#   'nhà thờ Notre Dame'],
#  ['Có gì cho phép Rome nguồn một số quân của họ từ các khu vực khác gần đó?',
#   'liên minh quân sự với các dân tộc khác'],
#  ['Tại sao đường lên men hơn sẽ được thêm vào là bia trong quá trình sản xuất bia?',
#   'để tăng nồng độ cồn,'],
#  ['đã Henry cưới ai?', 'Eleanor xứ Aquitaine,'],
#  ['Là các phiên họp của Quốc hội thành phố tư nhân hoặc công cộng?', ''],
#  ['Có gì kinh sách mô tả việc săn bắn như nghề nghiệp và chấp nhận được?',
#   'Hindu'],
#  ['hoạt động Lingayen Vịnh hỗ trợ những gì đổ?', 'Luzon'],
#  ['dòng điện tạp chí các vấn đề phổ biến nhất ở Namibia là gì?',
#   'Cái nhìn sâu sắc Namibia,'],
#  ['Đã Thomas Newman soạn cân bằng tỷ số sau khi quay hoặc trong quá trình quay phim?',
#   'trong quay'],
#  ['nguyễn tấn dũng là ai',
#   'Nguyễn Tấn Dũng ( tên thường gọi : Ba Dũng , sinh ngày 17 tháng 11 năm 1949 tại Cà Mau ) là một chính trị gia Việt Nam . Ông là Thủ tướng chính phủ thứ sáu của Cộng hoà Xã hội chủ nghĩa Việt Nam ( 2006 – 2016 ) . Từ năm 1997 , ông cũng đồng thời là Đại biểu Quốc hội Việt Nam các khoá X , XI , XII , XIII thuộc đơn vị bầu cử khu vực 3 Thành phố Hải Phòng ( huyện Tiên Lãng ) , Uỷ viên Bộ Chính trị các khoá VIII , IX , X , XI , Trưởng ban Ban Chỉ đạo thi hành án phần tài sản vụ án EPCO - Minh Phụng từ năm 2002 .'],
#  ['các bộ phận của chiếc cúp là gì?',
#   '- tách bản thân, cộng với một nắp và một'],
#  ['Bao nhiêu gia tăng trong không gian đất đã điền của khu mỏ gây ra?',
#   'tám phần trăm'],
#  ['chủ tịch hiện nay của Hải Dương là ai',
#   'Vũ Thị Thuỷ ( sinh ngày 23 tháng 7 năm 1966 ) là một chính trị gia người Việt Nam . Bà hiện là đại biểu Quốc hội Việt Nam khoá XIV nhiệm kì 2016-2021 , thuộc đoàn đại biểu quốc hội tỉnh Hải Dương , Chủ tịch Hội Liên hiệp Phụ nữ tỉnh Hải Dương , Uỷ viên Uỷ ban Mặt trận Tổ quốc tỉnh Hải Dương , Uỷ viên Ban Chấp hành Trung ương Hội Liên hiệp Phụ nữ Việt Nam , Uỷ viên Uỷ ban Khoa học , Công nghệ và Môi trường của Quốc hội .'],
#  ['tổ chức những gì đã làm tất cả các chiến binh trên cả hai mặt của cuộc chiến thuộc về?',
#   'của Liên Hợp Quốc'],
#  ['Có gì vũ khí La Mã bắt đầu được sử dụng một lần nữa ở Trung sớm Cổ?',
#   'nỏ,'],
#  ['Ai được coi là "Bố già Atlantic City không?"', 'Nelson Johnson'],
#  ['cơ sở vật chất thủy lực của Melbourne đã giúp gì tạo ra rằng phát triển nhà cao tầng thúc đẩy?',
#   'thang máy,'],
#  ['có bao nhiêu tàu thuyền Torbay?', 'ba'],
#  ['Hy Lạp tổ chức gì là một thành viên sáng lập?', 'OECD)'],
#  ['Ai là vị Trưởng ban cháy cho đến tháng sáu năm 2008?',
#   'Russell (Rusty) Thomas'],
#  ['cơ sở cho "Thiên nhiên, Man và Thiên Chúa" là gì?',
#   'Đền của Gifford Lectures của 1932-1934'],
#  ['Trong những năm đã Royal Society of London được đưa ra một điều lệ của hoàng gia?',
#   '1662'],
#  ['Những phẩm chất vật lý là cần thiết cho gymastics nhịp nhàng?',
#   'linh hoạt, cân bằng, tốc độ, sức mạnh, sự phối hợp và cảm giác nhịp điệu'],
#  ['Ai mà các nicname "Die ROTEN" thuộc về?', 'Hannover 96'],
#  ['thuật ngữ cho khi tiếng địa phương A và B là hai bên dễ hiểu, phương ngữ B và C là dễ hiểu lẫn nhau, nhưng phương ngữ A và C không phải là dễ hiểu lẫn nhau là gì?',
#   'continua phương ngữ,'],
#  ['Ai được chính thức lật đổ bởi Constitutent hội Nam Tư vào ngày 29 tháng 11 năm 1945?',
#   'Vua Peter II'],
#  ['Có gì cựu lãnh đạo của một công ty sản xuất xe tham dự KU?',
#   'Alan Mulally'],
#  ['Khi được tên trường Đại học Washington sửa đổi?', 'năm 1856, Đại học'],
#  ['Ai là người đầu tiên trình tự bộ gen DNA-dựa?', 'Fred Sanger'],
#  ['Gì đã Wittgenstein và Hayek làm trong chiến tranh thế giới thứ nhất?',
#   'cả hai đều là cán bộ'],
#  ['Có gì từng là thủ đô của nước Pháp trong tinh thần trong suốt Nghề nghiệp?',
#   'Brazzaville'],
#  ['Mà câu lạc bộ EPA được Đại học Northwestern trong?',
#   'Green Power Leadership Club'],
#  ['Mà đại học là để hai chàng trai tham dự?', 'Eton College'],
#  ['Ai là châu Âu đầu tiên đến thăm hòn đảo này là?', 'Ferdinand Magellan'],
#  ['Ai lãnh đạo phong trào Dân quyền?', 'Mục sư Martin Luther King, Jr.'],
#  ['Nước nào là quê hương của ông già tuyết',
#   'Ông già Tuyết và mùa hè (tiếng Nga: "Дед Мороз и лето") là một phim hoạt hình nổi tiếng của Valentin Karavayev về ông già Tuyết và các bạn nhỏ với mùa hè.'],
#  ['Khi được các Anglo -Nga Entente ký?', '1907'],
#  ['cây gì chi được đặt theo tên của Avicenna?', 'Mắm'],
#  ['Nasser là một nhà lãnh đạo của nước nào?', ''],
#  ['giá trung bình của tài sản mỗi mét vuông ở trung tâm London vào tháng tư năm 2014 là gì?',
#   '€ 24.252'],
#  ['không "Hoogduits" dịch gì bằng tiếng Anh?', 'Cao Hà Lan",'],
#  ['Làm thế nào được sóng được sử dụng trong những cách thảo luận kiểm soát?',
#   'hài hoà'],
#  ['Nhận thức thông tin và duy trì nó là gì?', 'tình báo'],
#  ['Mà công việc lập pháp cấm việc sử dụng các ưu đãi về phân biệt chủng tộc đối với tuyển sinh ở bang California?',
#   'Dự luật 209'],
#  ['Người duy nhất 2 lần được tặng Huân chương Hồ Chí Minh là ai',
#   'Đại tướng Võ Nguyên Giáp là người đầu tiên được tặng thưởng Huân chương Hồ Chí Minh và cũng là người 2 lần được tặng thưởng ( lần thứ nhất năm 1950 và lần thứ hai năm 1979 ) .'],
#  ['Rigas Feraios đã bị giết bởi những kẻ ám sát Ottoman trong năm nào?',
#   '1798'],
#  ['hình học kiến trúc thi đua của vũ trụ làm gì?', 'Đời đời'],
#  ['Giám đốc công an thành phố Hà Nội là ai',
#   'Ông được bổ nhiệm làm Giám đốc Công an thành phố Hà Nội từ tháng 9 năm 2012, kế nhiệm Trung tướng Nguyễn Đức Nhanh nghỉ hưu.'],
#  ['Ai là đối thủ của Liên Xô trong Chiến tranh Lạnh?', 'Hoa Kỳ,'],
#  ['Thành phố có bao nhiêu trách nhiệm chủ trương lớn?',
#   'chính quyền địa phương có thể biện minh cho'],
#  ['Sau khi được đưa ra một số luật, một luật mới được chuẩn bị để công bố như những gì?',
#   'luật trượt'],
#  ['Ai làm cô tín dụng đối với nguồn cảm hứng để "thức dậy ở đó và làm những gì cô ấy đã làm"?',
#   'Whitney Houston,'],
#  ['Khi nào các Hashimiyya chinh phục Kufa?', '749,'],
#  ['Có gì trùng lặp đáng kể với Haredi Judiasm?', 'Chasidic Do Thái giáo'],
#  ['Có gì phát triển chính trị hình chính sách của người Anh?',
#   'chính phủ liên tiếp dẫn đầu bởi Newcastle và Pitt đã giảm'],
#  ['Đất nước nào ở châu Á được biết đến với "cuộc cách mạng trắng"',
#   'Phan Quỳnh Ngân còn được biết đến với nghệ danh Juna, là người đẹp giành giải Á hậu 3 cuộc thi "Hoa hậu doanh nhân người Việt châu Á năm 22017". Cô còn được biết tới với vai trò ca sĩ.'],
#  ['Locke cho rằng quyền tự nhiên để sở hữu được bắt nguồn từ những gì?',
#   'lao động $$ $. Dạy bởi Locke, Anthony Ashley-Cooper, 3rd Bá tước Shaftesbury viết vào năm 1706: "Có một ánh sáng hùng mạnh mà lây lan tự của nó trên toàn thế giới đặc biệt là ở hai quốc miễn phí của Anh và Hà Lan; kẻ ở gần giao châu Âu hiện nay lần lượt" . lý thuyết về quyền tự nhiên của Locke đã ảnh hưởng nhiều văn bản chính trị, trong đó có Tuyên bố Hoa Kỳ độc lập và Tuyên bố'],
#  ['một mục tiêu chính của kế hoạch cải cách thị trường của Iran là gì?',
#   'đa dạng hóa nền kinh tế dầu phụ thuộc của Iran'],
#  ['Trong những năm được Plymouth Sứ thành lập?', '1768'],
#  ['Khi nào các Jacquerie Pháp diễn ra?', '1358'],
#  ['Khi đã làm người đứng đầu chính phủ Quốc Dân Đảng Đài Loan?',
#   'ngày 10 tháng 12'],
#  ['Đâu Spectre quay phim diễn ra sau khi Roma?', 'Mexico City'],
#  ['Là tiếng Anh tại Puerto Rico thành công?', 'Nó đã hoàn toàn thất bại,'],
#  ['Làm thế nào đã Census Bureau thay đổi bộ sưu tập dữ liệu?',
#   'cho phép mọi người tự nhận là nhiều hơn một dân tộc'],
#  ['phần mềm gì đã của Apple sử dụng làm cơ sở cho phần mềm iPod của họ?', ''],
#  ["Khi đã Canal de l'Ourcq bắt đầu cung cấp Paris với nước?", 'năm 1809,'],
#  ['Trong bộ phim Dick Tracy, người đã Madonna đóng vai?',
#   'Breathless Mahoney'],
#  ['Tại sao Empires và Quốc của châu Âu cử?',
#   'sự đột biến của chủ nghĩa cộng hoà'],
#  ['lý do một dự luật đã vô tình assented năm 1976 là gì?',
#   'hai hóa đơn cùng tên đã có nguồn gốc từ'],
#  ['Nhà hát Broadway nằm ở đâu',
#   '( Năm 1937 , được biết đến như là Ciné Roma , khi trình chiếu các bộ phim Ý ) .'],
#  ['Một trong những trợ lý Chiefs của Staff Defense là dành cho dự trữ và những gì?',
#   'Cadets)'],
#  ['Làm thế nào mà Spielberg ảnh hưởng đến hành vi của công chúng?',
#   'nhiều ý nghĩ trong một giây trước khi đi vào nước trong mùa hè này'],
#  ['Khi được giai đoạn một hoàn thành?', 'năm 1988,'],
#  ['Có gì núi Nepal được khẳng định để thu hút khách du lịch?', 'dãy Himalaya'],
#  ['Có gì mảnh quần áo là macawis tương tự?', 'sarong như'],
#  ['Thuyết tiến hóa của Darwin ra đời vào năm nào',
#   'Để đáp trả, những người ủng hộ thuyết tiến hóa phản ứng rằng chưa có phát biểu của bất kỳ nhà khoa học nào, bao gồm cả Darwin, được xem là thiêng liêng bất khả xâm phạm bởi vì chính giả thuyết của Darwin cũng từng bị các nhà khoa học bác bỏ và hiệu chỉnh lại qua nhiều năm để hình thành nên Học thuyết Darwin mới và sau đó là thuyết tổng hợp tiến hóa hiện đại Tương tự, phát biểu nói rằng thuyết tiến hóa là niềm tin và chưa từng được quan sát thấy cũng bị bác bỏ; thuyết tiến hóa có chứng cứ ủng hộ mạnh mẽ mà không cần đến niềm tin.'],
#  ['Mà công ty phân phối NES đến Vương quốc Anh, Ý, và Úc?', 'Mattel'],
#  ['Khi là cuộc đụng độ Askeran?', 'ngày 22 tháng 2 năm 1988,'],
#  ['Ai là người châu Âu đầu tiên đi đến mũi Hảo Vọng?', 'Bartolomeu Dias'],
#  ['Ai dường như đã bị chi phối bởi mô hình hình học và trật tự?',
#   'Các nghệ sĩ'],
#  ['Nơi nào Yale sở hữu 500 mẫu Anh của các cơ sở thể thao?', 'tây New Haven,'],
#  ['nơi được marshall Jefferson dựa?', 'Chicago,'],
#  ['Melbourne dân bộ phận thống kê đã tăng bao nhiêu người mỗi năm kể từ năm 2005?',
#   '70.000'],
#  ['Ai phục kích Link và Midna?', 'Zant'],
# ...
#  ['con trai Meinhard của được đặt tên gì?', 'Patrick'],
#  ['Tư Mã Ý là ai',
#   'Tư Mã Ý ( chữ Hán : 司馬懿 ; 179 – 7 tháng 9 , 251 ) , biểu tự Trọng Đạt , là nhà chính trị , nhà quân sự phục vụ nước Tào Nguỵ thời kỳ Tam Quốc trong lịch sử Trung Quốc .'],
#  ['Tướng quân Nguyễn Sơn quê ở đâu',
#   'Travel blogger nổi tiếng Nguyễn Sơn Tùng     Bức ảnh yêu thích nhất của travel blogger Nguyễn Sơn Tùng     Travel blogger Nguyễn Sơn Tùng admin của fanpage Lạc'],
#  ['Mà được giải thưởng Chiếc giày vàng dành cho?',
#   'cầu thủ ghi bàn hàng đầu Premier League'],
#  ['Có bao nhiêu Billboard biểu đồ toppers đã thí sinh American Idol có trong vòng mười mùa đầu tiên?',
#   '345'],
#  ['Có bao nhiêu văn bản bằng ngôn ngữ Sumer đã sống sót đến ngày nay?',
#   'hàng trăm ngàn'],
#  ['bộ lạc gì là cấu trúc xã hội trước khi từ đâu?', 'Ba Lan'],
#  ['chữ viết tắt mà Đại học Kansas được biết đến là gì?', 'KU)'],
#  ['Loại cộng đồng được Siddhartha Gautama lớn lên ở?',
#   'Đó là một trong hai một nước cộng hòa nhỏ, trong trường hợp cha mình là một thủ lĩnh bầu, hoặc một đầu sỏ, trong trường hợp cha mình là một nhà tài phiệt'],
#  ['Giáo Hội Đông tin rằng những gì liên quan đến cái chết và ressurection?',
#   '"pre-mãi mãi" xác định bởi Cha'],
#  ['Dòng sông huyền thoại nào ở Tây Sơn gắn liền sự phát tích của vương triều Tây Sơn',
#   'Toàn bộ lãnh thổ phía nam sông Gianh, tương đương với lãnh thổ chúa Nguyễn cai quản trước đây, thuộc về Tây Sơn.'],
#  ['Mà quân đội đã có một nhóm các tình nguyện viên Armenia chiến đấu cho họ?',
#   'Nga Quân đội'],
#  ['Cao bao nhiêu Một Mỹ Plaza?', '500 feet'],
#  ['nén những gì không thể đạt được tỷ lệ nén cao?', 'Lossless'],
#  ['Có bao nhiêu các trung tâm khoa học hàn lâm lăm sức khỏe của Vương quốc Anh được đặt tại London?',
#   'ba'],
#  ['Bao lâu là cảnh săn bắn tại rustica biệt thự?', ''],
#  ['Có gì thường niên sự kiện tại BYU được thực hiện trong bộ nhớ của cựu chủ tịch Rex E. Lee, người đã xây dựng Bảo tàng Nghệ thuật trong khuôn viên trường?',
#   'ung thư gọi là Rex Lee Run'],
#  ['Những bài viết trong Hiến pháp Norweigan cung cấp một cách để ghi đè lên quyền phủ quyết của một quốc vương?',
#   'Điều 79'],
#  ['Theo một báo cáo của CDC năm 2008, có bao nhiêu bị cắn ở Mỹ mỗi năm?', '4'],
#  ['Làm thế nào để hạn chế rác thải ra môi trường',
#   'Lò đốt rác thải sinh hoạt (tiếng Anh: ) là một thiết bị hữu hiệu trong công tác xử lý rác thải giữ gìn môi trường xanh, phát triển bền vững.'],
#  ['Thành phố nào là thủ đô của Costa Rica',
#   'Cartago là một tỉnh của Costa Rica. Tỉnh này nằm ở trung bộ quốc gia này. Các tỉnh giáp ranh là: Limón về phía đông và San José về phía tây. Tỉnh lỵ là Cartago nguyên là thủ đô của Costa Rica. Tỉnh có diện tích 3.124,61 km2 (1) và dân số 461.163 người (2). Về mặt hành chính, tỉnh được chia thành 8 tổng. Tỉnh này được kết nối với San Jose băng một tuyến xa lộ 4 làn xe.'],
#  ['phải một sĩ quan cảnh sát tụng gì để nghi ngờ một khi bắt giữ /',
#   'Miranda cảnh báo'],
#  ['hạn khác đối với một phương ngữ tiêu chuẩn hoặc tiêu chuẩn hóa là gì?',
#   'ngôn ngữ tiêu chuẩn")'],
#  ['nữ đấu vật chuyên nghiệp gọi là ở Nhật Bản là gì?', 'Joshi puroresu'],
#  ['Có bao nhiêu của Đại lễ kính chính thống dành riêng cho Mary?', 'Năm'],
#  ['Ai đã làm Machiavelli thái độ khinh thị?',
#   'nhà văn về chính trị người đánh giá tất cả mọi thứ so với những lý tưởng tinh thần'],
#  ['Có bao nhiêu nhân viên đã Imperial nộp đánh giá về để đánh giá REF?',
#   '1,257'],
#  ['Nước nào thuyết phục Syria để thực sự từ bỏ vũ khí hóa học của nó?', 'Nga'],
#  ['Khi được Quân đội Canada kêu gọi hỗ trợ ở châu Âu?',
#   'Chiến tranh thế giới thứ nhất,'],
#  ['Ai đã báo cáo rằng Nintendo đã bán được 7 triệu hệ thống NES?',
#   'Tính toán!'],
#  ['bản dịch của văn bản được Sung gắn liền với là gì?', 'thơ'],
#  ['Ngôn ngữ nào đã viết nhà thờ phụng vụ trong?', 'Cyrillic'],
#  ['Đâu chúa Victoria và chồng bà để lại cho sau khi kết hôn của họ?', 'Đức;'],
#  ['Chuyện gì xảy ra với tiêu chảy viêm?',
#   'lỗ thụ động của chất lỏng giàu protein và giảm khả năng hấp thụ các chất lỏng bị mất'],
#  ['bản dịch Latin gián tiếp tiên tiến mà khoa học và văn hóa?', 'khoa học'],
#  ['Tổng thống Truman là gì nói với tại cuộc họp này?',
#   'ít nguy cơ can thiệp của Trung Quốc tại Hàn Quốc,'],
#  ['ngọn núi cao nhất ở Hy Lạp là gì?', 'Núi Olympus'],
#  ['Có bao nhiêu người đã chết trong các cuộc bạo loạn nhà máy dệt?',
#   'chín $ $$ người thiệt mạng. Trong khi hầu hết các RCC khăng khăng đòi thực hiện hai kẻ cầm đầu của bạo loạn, Nasser'],
#  ['Tên viết tắt của Diễn đàn hợp tác Á-Âu là gì',
#   'Diễn đàn Hợp tác Á-Âu (ASEM) là một quá trình đối thoại không chính thức được đưa ra sáng kiến năm 1996 với mục tiêu tăng cường hợp tác giữa các quốc gia châu Á và châu Âu, đặc biệt giữa các thành viên Liên minh châu Âu và ASEAN. ASEAN, được đại diện bởi vị Tổng thư ký của mình, là một trong 45 đối tác ASEM. Họ cũng chỉ định một đại diện trong ban quản lý Quỹ Á-Âu (ASEF), một tổ chức văn hoá xã hội gắn liền với cuộc Gặp gỡ.'],
#  ['Có gì thăng tiến trong Không quân Hoa Kỳ được điều chỉnh bởi một quá trình lựa chọn chính thức?',
#   'Xúc tiến tới chủ yếu qua'],
#  ['Ai ủng hộ anh em trai của John?', 'Eleanor,'],
#  ['lớp gì đã cá nhân từng là quan chức trong chính phủ thuộc về?',
#   'thường dân xã hội'],
#  ['phim gì khối cho thấy phim câm?', 'Im lặng Chủ Nhật Nights",'],
#  ['Có gì giảm từ ngày 5 đến thế kỷ thứ 13', 'Śrauta hy sinh'],
#  ['một lý luận Shakespeare là một nơi tốt để tập trung vào phê bình văn bản là gì?',
#   'văn bản, như truyền đi, chứa một lượng đáng kể các biến thể,'],
#  ['Trong loại của cuộc khủng hoảng đã Emperor Huân xa lánh bộ máy quan liêu?',
#   'cuộc khủng hoảng kinh tế'],
#  ['Có bao nhiêu đại diện nào tại Premier League có của Hiệp hội Câu lạc bộ châu Âu 2012-13?',
#   'Đối với mùa 2012-13 Premier League có 10 đại diện trong Hiệp hội:'],
#  ['Triều đại nào tồn tại lâu nhất trong lịch sử Trung Quốc',
#   'Tào Phi lên ngôi Hoàng đế , lập ra triều đại Tào Nguỵ ở miền bắc Trung Quốc , bắt đầu thời kỳ Tam Quốc ( Bắc Nguỵ , Tây Thục , Đông Ngô ) kéo dài 60 năm ( 220 - 280 ) nổi tiếng trong lịch sử Trung Quốc .'],
#  ['Ai đặt truy cập cơ sở dữ liệu?',
#   'ủy quyền (do chủ cơ sở dữ liệu) nhân sự đặc biệt'],
#  ['Những loại công dân làm các công dân của Saint Helena giữ?',
#   'Anh Lãnh thổ hải ngoại quyền công dân'],
#  ['tên viết 35 trang của Darwin về lý thuyết của ông là gì?',
#   '"Phác họa bút chì"'],
#  ['đã Darwin thừa nhận những gì về đặc điểm thu được trong chương một trong Nguồn gốc các loài?',
#   '"Các định luật chi phối thừa kế khá lạ'],
#  ['Điều gì đã làm luật hạn chế hút thuốc lá hoàn thành?',
#   'giảm số lượng người nhập viện vì hen suyễn'],
#  ['Khi được trong khuôn viên trường Cao đẳng Wye đóng cửa?',
#   'tháng 9 năm 2009'],
#  ['Về bao nhiêu người sống ở quần đảo Marshall vào năm 1862?', '10.000'],
#  ['Chính phủ dưới mà kinh nghiệm chuyển đổi sang đồng tiền thập phân?',
#   'Holt'],
#  ['một thực tế đáng chú ý hữu thần cá nhân là ai?', 'Thánh Tôma Aquinô'],
#  ['Mà tác giả của tiểu thuyết vẽ một bức chân dung ảm đạm của Victoria London?',
#   'Charles Dickens,'],
#  ['Trong trường hợp đang tải cầu cảng được tìm thấy trên Đảo Norfolk?',
#   'Kingston và Cascade,'],
#  ['Trong đó giai đoạn được triết lý của chủ nghĩa nhân văn tiếp theo được cập nhật?',
#   'Giác Ngộ Pháp,'],
#  ['Ai là thủ lĩnh khởi binh chống lại chính quyền đô hộ Đông Hán',
#   'Trong sử sách , hai bà được biết đến như những thủ lĩnh khởi binh chống lại chính quyền đô hộ của Đông Hán , lập ra một quốc gia với kinh đô tại Mê Linh và Trưng Trắc tự phong là Nữ vương . Thời kì của hai bà xen giữa Bắc thuộc lần 1 và Bắc thuộc lần 2 trong lịch sử Việt Nam .'],
#  ['Khi đã làm Spielberg và Irving ly dị?', '1989'],
#  ['Làm thế nào là hệ thống đường cao tốc Eritrea đặt tên?',
#   'theo phân loại đường'],
#  ['một cách thức mà những người nhập cư Nga tích hợp vào xã hội Alaska là gì?',
#   'kết hôn với những người bản địa Alaska'],
#  ['Luật pháp nào đã Obama trích dẫn trên 09 tháng 9 năm 2014?',
#   'sự ủy quyền năm 2001 cho Sử dụng Quân Lực lượng chống khủng bố ,'],
#  ['cái gì mà có thể gây ra việc tiếp nhận và giải mã nội dung của một thông điệp tới bị lỗi là gì?',
#   'tiếng ồn giao tiếp"'],
#  ['định dạng dự kiến ban đầu cho đĩa CD là gì?', 'dữ liệu lưu trữ'],
#  ['thể thao gì tờ New York Rangers chơi?', 'Hockey'],
#  ['Làm thế nào nên mức độ rủi ro đã được tiết lộ theo nhiều học giả?',
#   'đơn giản định dạng, dễ dàng hiểu'],
#  ['Một mảnh bằng chứng của các cộng đồng Đức tại thành phố thánh trong nửa sau của thế kỷ 11 là do những gì các mặt hàng được gửi từ Đức đến Jerusalem?',
#   'câu hỏi halakhic'],
#  ['Hộp công cụ cộng đồng có thể được tìm thấy ở đâu?', 'trực tuyến'],
#  ['Tại sao các Chamorros đưa đến Guam?', 'để phục vụ như dịch viên'],
#  ['mà cây trồng đã được đưa đến châu Âu từ thế giới Hồi giáo?',
#   'hạnh nhân và trái cây họ cam quýt'],
#  ['Thổ Nhĩ Kỳ độc lập từ năm nào',
#   'Người Síp Thổ Nhĩ Kỳ cuối cùng đã tuyên bố độc lập năm 1983 trở thành Cộng hoà Bắc Síp Thổ Nhĩ Kỳ , nhưng chỉ được mỗi Thổ Nhĩ Kỳ công nhận . Năm 1985 , Cộng hoà Bắc Síp Thổ Nhĩ Kỳ đưa ra một hiến pháp và tổ chức cuộc bầu cử đầu tiên .'],
#  ['dân số gì có đột biến mtDNA và atDNA, khiến họ khác biệt với người dân bản địa khác của châu Mỹ?',
#   'Alaska'],
#  ['Làm thế nào mà việc bán hàng thực tế của của G4 so với kỳ vọng bán hàng?',
#   'một phần ba của kỳ vọng,'],
#  ['Những gì hiện Darwin sử dụng để minh họa những ảnh hưởng của lựa chọn nhân tạo?',
#   'ưa thích nuôi chim bồ câu,'],
#  ['máy bay gì tính năng thiết kế cải thiện ra mắt và phục hồi chu kỳ flexibilty?',
#   'Một boong góc'],
#  ['ai là tác giả của phần mềm diệt virus D2',
#   'Phần mềm D32 là một chương trình chẩn đoán và diệt virus máy tính dành cho hệ điều hành Windows XP 32 bit. D32 là tên gọi tắt của "D2 for Windows 32". Đây là phần mềm chống virus chạy trên hệ điều hành Windows 32 bits đầu tiên của Việt Nam. Tiền thân của phần mềm này là D2 ("Diagnose and Destroy Viruses") anti-virus chạy trên hệ điều hành MS-DOS rất phổ biến ở Việt Nam từ thập niên 1990. Kể từ lúc phát hành (tháng 2 năm 2001) đến nay, D32 đã có nhiều cải tiến quan trọng; cùng với BKAV, D32 trở thành phần mềm diệt virus trên nhiều hệ thống công nghệ thông tin ở Việt Nam.'],
#  ['Việt Nam bình thường hóa quan hệ với Trung Quốc năm nào',
#   'Đầu năm 1978, tại Tokyo, ông Phan Hiền, thứ trưởng Ngoại giao Việt Nam tuyên bố: ""Việt Nam sẵn sàng bình thường hóa vô điều kiện với Hoa Kỳ"" (tức là Việt Nam sẽ không yêu cầu Hoa Kỳ phải bồi thường chiến tranh nữa). Tuy nhiên, lúc này Mỹ quan tâm tới việc đàm phán bình thường hoá quan hệ với Trung Quốc hơn, mà Trung Quốc và Việt Nam với khi đó lại đang là đối thủ, nên Hoa Kỳ đã bỏ qua vấn đề bình thường hóa quan hệ với Việt Nam.'],
#  ['một quốc gia có khả năng cho một nhà nước là gì?', ','],
#  ['đã Gaddifi tạo ra những gì triết lý chính trị?',
#   'của Lý thuyết Quốc tế thứ ba của ông'],
#  ['làm hầu hết các đô vật làm gì, theo như cách họ hành động?',
#   'miêu tả vai trò nhân vật,'],
#  ['Điều gì làm các loài chim đôi khi sử dụng để đánh giá và khẳng định sự thống trị xã hội?',
#   'bộ lông'],
#  ['Làm thế nào để kích thước của một bóng đèn halogen so sánh với một đèn sợi đốt?',
#   'bóng đèn như vậy là nhỏ hơn nhiều so với bóng đèn sợi đốt thông thường,'],
#  ['Bên cạnh trụ sở của Liên Hợp Quốc, người tổ chức nhiều cơ quan của Liên Hợp Quốc?',
#   'Liên bang Thụy Sĩ'],
#  ['Đại văn hào Goethe là nguười nước nào',
#   'Mục đích quan trọng của viện là hỗ trợ việc giao lưu văn hóa giữa Việt Nam, Đức và châu Âu. Viện Goethe Hà Nội ủng hộ và tổ chức nhiều chương trình để giới thiệu văn hóa Đức đến Việt Nam, nhằm tăng cường đối thoại văn hóa giữa hai nước.'],
#  ['Những thí sinh đã bị xóa khỏi chương trình để mô hình hóa cho một trang web người lớn?',
#   'Frenchie Davis'],
#  ['giám đốc công an hiện tại của thành phố Hồ Chí Minh là ai',
#   'Đại học Quốc gia Thành phố Hồ Chí Minh ( tiếng Anh : " Viet Nam National University , Ho Chi Minh City " ) là một trong năm hệ thống đại học quốc gia , được đặt tại Thành phố Hồ Chí Minh , được đánh giá là một trong 750 trường / nhóm trường đại học tốt nhất thế giới của Việt Nam .'],
#  ['công cụ gì rơi ra khỏi sử dụng sau thập niên 1760?', 'the'],
#  ['Gì được Lành Cơ Đốc Nhân chạy trốn từ đâu?', 'đàn áp tôn giáo'],
#  ['Làm thế nào các tránh Anh có đội ngũ lớn các binh sĩ ở lục địa châu Âu?',
#   'liên minh bản thân với một hoặc Continental nhiều cường quốc có lợi ích là đối chọi với những kẻ thù của họ, đặc biệt là'],
#  ['Ai định nghĩa những thay đổi pháp lý quan trọng?',
#   'Robert Bideleux và Ian Jeffries,'],
#  ['làm bergschrunds giống gì?', 'crevasses'],
#  ['Là cuộc họp tại Canberra một nhóm người hỗ trợ hoặc đối lập với Đảng Lao động Úc?',
#   'phản'],
#  ['Những gì đã hứa bởi Buda Vua Casimer?',
#   "quý tộc sẽ không còn phải chịu thuế 'phi thường',"],
#  ['Nước nào là Alsace sáp nhập vào trong 1871-1918', 'Đức'],
#  ['động vật gì được báo cáo là bị giết chết thường xuyên hơn cừu của sói tại Croatia?',
#   'con chó hoang dã lớn,'],
#  ['Ai đưa ra giả thuyết rằng máu đi qua các tĩnh mạch?',
#   'Praxagoras của Kos,'],
#  ['Vị vua nào lập nên nước Đại Ngu', 'Hồ Quý Ly'],
#  ['mô não là một cách tự nhiên mềm mại, nhưng có thể được cứng với những gì chất lỏng?',
#   'rượu'],
#  ['Khi được Nam Tucson reincorporated?', '1940'],
#  ['Bởi những gì năm đã được các trường học ở Oxford hoàn thành?', '1265,'],
#  ['Tác giả của truyện Truyền Kì Mạn Lục là ai',
#   '2. Văn học trung đại: tiều thuyết chương hồi, truyền kì, ký sự, truyện thơ.'],
#  ['các Xeer luật sư hệ thống gọi làm gì?', 'garxajiyaal'],
#  ['Loại mã hóa, tương tự hoặc kỹ thuật số, gây ra đĩa lade được succeptable thiệt hại?',
#   'analog'],
#  ['Chủ tịch hiện tại của Síp là ai?', 'Nicos Anastasiades'],
#  ['đâu DJ Marques Wyatt và Billy dài trở nên thành công?', 'Los Angeles'],
#  ['Bangladesh có diện tích đứng thứ mấy thế giới',
#   'Phần lớn diện tích ( hai phần ba diện tích ) nằm tại Bangladesh , một phần còn lại trở thành vườn quốc gia Sundarban của Ấn Độ . Cả hai khu vực đã được công nhận là một di sản thế giới của UNESCO phần của Bangladesh vào năm 1997 .'],
#  ['Tại sao Feynman quyết định từ chối một lời đề nghị từ các Viện nghiên cứu cao cấp?',
#   'không có nhiệm vụ giảng dạy:'],
#  ['tên của nhà thờ Presbyterian lớn nhất ở Mexico là gì?',
#   'Giáo Hội Presbyterian quốc gia ở Mexico (Iglesia Nacional Presbiteriana de México),'],
#  ['một động vật ăn thịt điển hình của chó ở những nơi như Turkmenistan là gì?',
#   'linh cẩu sọc'],
#  ['Khác với các ID3v1, mà tương tự như định dạng chuẩn cho thẻ tồn tại?',
#   'ID3v2,'],
#  ['Việt Nam có bao nhiêu tỉnh giáp với Lào',
#   'Việt Nam và Lào có đường biên giới chung dài 2067 km. Sau đây là danh sách các tỉnh của Lào và Việt Nam có biên giới chung với nhau, xếp theo vị trí từ Bắc xuống Nam.'],
#  ['Gì có xu hướng trở thành một trở ngại lớn khi so sánh các nền văn hóa?',
#   'Dịch'],
#  ['các nghệ sĩ đã thu hút nho như thật, chim bay lên và mổ vào họ là ai?',
#   'Zeuxis,'],
#  ['thực vật học là gì?', 'của đời sống thực vật'],
#  ['thành phố gì San Diego đến thứ hai để trong ngành công nghiệp công nghệ sinh học?',
#   'Boston'],
#  ['Khi được các Trận Austerlitz chiến đấu?', 'ngày 02 tháng 12,'],
#  ['các bộ phận mà sáp nhập vào Bộ chỉ huy hoạt động phần Canada là gì?',
#   'Canada lệnh, Bộ Tư lệnh quân viễn chinh Canada và Bộ Tư lệnh hỗ trợ vận hành Canada'],
#  ['tổng giám đốc công ty lọc hóa dầu bình sơn', 'Bùi Minh Tiến'],
#  ['tường phòng thủ mà bao quanh London vào năm 1642 được gọi là gì?',
#   'Lines Giao'],
#  ['Khi được các Máy đánh chữ chữ đầu tiên với một phím shift tạo?', '1878),'],
#  ['Tháp nghiêng Pisa ở Italy được xây dựng trong khoảng thời gian bao lâu',
#   'Tháp nghiêng Pisa là một công trình nghệ thuật, chưa xác định được là do ai thiết kế, được xây dựng trong ba giai đoạn với tổng thời gian khoảng 174 năm. Việc xây dựng lầu chuông tầng thứ nhất bằng đá cẩm thạch bắt đầu ngày 9 tháng 8, 1173, một giai đoạn của sự thịnh vượng và những thắng lợi quân sự. Tầng này được bao quanh bởi những cột có đầu cột kiểu cổ điển đỡ các vòm rèm. Ngày nay sau thời gian hàng thế kỷ cùng những ảnh hưởng thời tiết chúng vẫn còn nguyên vẹn.'],
#  ['Ai được bình chọn là nhà lãnh đạo đầu tiên của Đảng Lao động?',
#   'Ramsay MacDonald'],
#  ...]

# %% [markdown]
# # Preprocessing

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences


train_ids = []
for sent in train_sents:
    subwords1 = '<q> ' + bpe.encode(sent[0]) + ' </q>'
    encoded_sent1 = vocab.encode_line(subwords1, append_eos=True, add_if_not_exist=False).long().tolist()

    subwords2 = '<a> ' + bpe.encode(sent[1]) + ' </a>'
    encoded_sent2 = vocab.encode_line(subwords2, append_eos=True, add_if_not_exist=False).long().tolist()
    train_ids.append(encoded_sent1 + encoded_sent2)

val_ids = []
for sent in val_sents:
    subwords1 = '<q> ' + bpe.encode(sent[0]) + ' </q>'
    encoded_sent1 = vocab.encode_line(subwords1, append_eos=True, add_if_not_exist=False).long().tolist()

    subwords2 = '<a> ' + bpe.encode(sent[1]) + ' </a>'
    encoded_sent2 = vocab.encode_line(subwords2, append_eos=True, add_if_not_exist=False).long().tolist()
    val_ids.append(encoded_sent1 + encoded_sent2)

# %%
val_ids
# Out:
# [[3,
#   10046,
#   6222,
#   127,
#   6937,
#   7,
#   58,
#   237,
#   11,
#   718,
#   2537,
#   33,
#   29,
#   142,
#   3,
#   2,
#   3,
#   13708,
#   59035,
#   4,
#   9393,
#   178,
#   6,
#   2209,
#   22649,
#   7,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   11,
#   4026,
#   2608,
#   12,
#   9,
#   184,
#   4687,
#   30,
#   6216,
#   7,
#   10046,
#   14029,
#   20330,
#   146,
#   4026,
#   2608,
#   917,
#   63,
#   28,
#   1391,
#   40012,
#   1395,
#   4,
#   22563,
#   493,
#   6,
#   1252,
#   3139,
#   25717,
#   339,
#   12,
#   761,
#   28,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   3490,
#   1388,
#   39566,
#   5550,
#   15,
#   9,
#   2209,
#   2665,
#   3312,
#   6222,
#   50,
#   21931,
#   1384,
#   4,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   115,
#   61,
#   5603,
#   740,
#   2178,
#   89,
#   2477,
#   1252,
#   40865,
#   31829,
#   982,
#   14892,
#   1517,
#   565,
#   537,
#   127,
#   47,
#   49,
#   76,
#   29,
#   53,
#   26,
#   10046,
#   6222,
#   10,
#   3256,
#   2792,
#   6,
#   33,
#   43,
#   426,
#   78,
#   426,
#   29,
#   13323,
#   9,
#   12726,
#   4436,
#   127,
#   6937,
#   11,
#   5795,
#   32151,
#   5,
#   3,
#   2],
#  [3,
#   2080,
#   2082,
#   25,
#   460,
#   590,
#   71,
#   29,
#   4602,
#   91,
#   277,
#   8351,
#   3902,
#   3,
#   2,
#   3,
#   1129,
#   350,
#   590,
#   11918,
#   58953,
#   1517,
#   6,
#   7635,
#   196,
#   2446,
#   16021,
#   1982,
#   1948,
#   460,
#   590,
#   350,
#   590,
#   14157,
#   39,
#   5567,
#   8,
#   11918,
#   59763,
#   1517,
#   460,
#   590,
#   350,
#   10029,
#   19,
#   7303,
#   3227,
#   5796,
#   13208,
#   1008,
#   493,
#   350,
#   590,
#   11918,
#   58953,
#   1517,
#   1251,
#   2289,
#   6,
#   1284,
#   5628,
#   14067,
#   1981,
#   2308,
#   2080,
#   2082,
#   25,
#   460,
#   10029,
#   4,
#   6,
#   2209,
#   2665,
#   8351,
#   3902,
#   8,
#   647,
#   3464,
#   2537,
#   1125,
#   15947,
#   1517,
#   604,
#   350,
#   590,
#   5089,
#   187,
#   125,
#   6460,
#   2178,
#   6,
#   39424,
#   462,
#   187,
#   1008,
#   493,
#   350,
#   590,
#   11918,
#   58953,
#   12584,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   47,
#   56138,
#   2079,
#   9441,
#   110,
#   2537,
#   1893,
#   30,
#   4107,
#   23206,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   29,
#   14845,
#   1854,
#   4,
#   3,
#   2],
#  [3,
#   31766,
#   1677,
#   3437,
#   11374,
#   7520,
#   1176,
#   12151,
#   15,
#   21,
#   148,
#   9929,
#   1373,
#   29,
#   19444,
#   114,
#   3,
#   2,
#   3,
#   7771,
#   3,
#   2],
#  [3,
#   207,
#   18,
#   21,
#   148,
#   156,
#   355,
#   157,
#   30,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   11373,
#   36471,
#   3593,
#   37547,
#   13143,
#   3,
#   2],
#  [3,
#   4419,
#   64,
#   22442,
#   30,
#   778,
#   311,
#   10,
#   4415,
#   57060,
#   35102,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   4917,
#   3,
#   2285,
#   6,
#   4917,
#   1302,
#   4,
#   3,
#   2],
#  [3,
#   675,
#   5116,
#   148,
#   10,
#   4623,
#   11,
#   5717,
#   8410,
#   81,
#   15,
#   1093,
#   12813,
#   1906,
#   50350,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   8715,
#   10284,
#   3,
#   2],
#  [3,
#   2679,
#   11,
#   143,
#   33,
#   42,
#   16,
#   22563,
#   12726,
#   129,
#   1713,
#   13,
#   303,
#   248,
#   129,
#   24105,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   54691,
#   49777,
#   4553,
#   28909,
#   3,
#   2],
#  [3,
#   251,
#   8,
#   396,
#   417,
#   2902,
#   303,
#   248,
#   7,
#   2648,
#   57447,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   43,
#   1058,
#   78,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   668,
#   790,
#   4365,
#   13466,
#   506,
#   7,
#   8798,
#   1236,
#   114,
#   3,
#   2,
#   3,
#   9971,
#   60692,
#   35258,
#   3,
#   2],
#  [3,
#   9569,
#   5855,
#   148,
#   289,
#   537,
#   127,
#   1073,
#   1575,
#   30,
#   5649,
#   7295,
#   29240,
#   12,
#   78,
#   317,
#   29,
#   8878,
#   2326,
#   114,
#   3,
#   2,
#   3,
#   12752,
#   2954,
#   3,
#   2],
#  [3,
#   133,
#   545,
#   312,
#   7,
#   1337,
#   4258,
#   205,
#   418,
#   1430,
#   12,
#   29,
#   22190,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   58511,
#   9644,
#   1556,
#   3952,
#   14157,
#   137,
#   8963,
#   16529,
#   42312,
#   2722,
#   151,
#   23556,
#   696,
#   58772,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   11124,
#   1196,
#   765,
#   38815,
#   7646,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   29043,
#   31142,
#   1931,
#   4,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   1257,
#   43899,
#   36431,
#   32628,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   50642,
#   3449,
#   26254,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   418,
#   1430,
#   482,
#   989,
#   14,
#   11,
#   506,
#   20497,
#   223,
#   8404,
#   7621,
#   52144,
#   24,
#   18802,
#   16157,
#   15008,
#   29888,
#   42568,
#   6433,
#   23313,
#   114,
#   3,
#   2,
#   3,
#   1988,
#   3,
#   2],
#  [3,
#   13416,
#   26567,
#   230,
#   877,
#   7,
#   61,
#   705,
#   2201,
#   462,
#   2925,
#   47,
#   16,
#   3078,
#   12151,
#   3210,
#   13109,
#   114,
#   3,
#   2,
#   3,
#   2138,
#   462,
#   2925,
#   705,
#   1701,
#   22266,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   4447,
#   819,
#   10540,
#   1188,
#   67,
#   7,
#   4453,
#   13143,
#   33,
#   303,
#   2184,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   620,
#   28,
#   216,
#   1535,
#   3,
#   2],
#  [3,
#   9779,
#   983,
#   8,
#   175,
#   24,
#   47,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   154,
#   11,
#   16,
#   5855,
#   9339,
#   3,
#   2],
#  [3,
#   4106,
#   355,
#   157,
#   302,
#   835,
#   10,
#   452,
#   100,
#   103,
#   48,
#   5385,
#   33,
#   29,
#   50966,
#   114,
#   3,
#   2,
#   3,
#   2681,
#   3,
#   2],
#  [3,
#   39745,
#   15369,
#   8,
#   276,
#   737,
#   7,
#   58,
#   142,
#   3,
#   2,
#   3,
#   619,
#   246,
#   8370,
#   39745,
#   15369,
#   15,
#   16,
#   100,
#   88,
#   737,
#   1607,
#   934,
#   85,
#   6,
#   13,
#   87,
#   3448,
#   139,
#   7,
#   39745,
#   15369,
#   22,
#   418,
#   2697,
#   48,
#   4,
#   2226,
#   2106,
#   5460,
#   9730,
#   48,
#   4,
#   10955,
#   2477,
#   2104,
#   1267,
#   48,
#   22,
#   5,
#   3,
#   2],
#  [3,
#   125,
#   4264,
#   30992,
#   1073,
#   2537,
#   35,
#   350,
#   590,
#   156,
#   221,
#   148,
#   3,
#   2,
#   3,
#   125,
#   4264,
#   14,
#   24,
#   44,
#   3309,
#   4903,
#   12,
#   605,
#   36,
#   570,
#   2301,
#   1964,
#   1163,
#   5,
#   30992,
#   32,
#   2528,
#   380,
#   12,
#   36,
#   11297,
#   2697,
#   2958,
#   1738,
#   4,
#   1362,
#   1889,
#   30992,
#   32,
#   8,
#   3449,
#   4986,
#   2958,
#   1738,
#   1219,
#   3156,
#   35,
#   350,
#   590,
#   5,
#   29694,
#   1163,
#   28786,
#   22482,
#   11455,
#   29865,
#   1595,
#   11,
#   125,
#   2958,
#   1738,
#   2178,
#   200,
#   350,
#   590,
#   906,
#   806,
#   23250,
#   5887,
#   22,
#   22,
#   4488,
#   9031,
#   2958,
#   1738,
#   22,
#   22,
#   33,
#   29,
#   4284,
#   91,
#   14,
#   580,
#   2284,
#   33,
#   675,
#   18116,
#   4368,
#   9970,
#   177,
#   193,
#   89,
#   4264,
#   30992,
#   5,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   20368,
#   29159,
#   467,
#   28,
#   1401,
#   89,
#   5537,
#   33403,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   6744,
#   2326,
#   19,
#   3,
#   2],
#  [3,
#   6390,
#   8228,
#   4194,
#   8346,
#   8046,
#   187,
#   149,
#   142,
#   7,
#   98,
#   24703,
#   1432,
#   43,
#   136,
#   3,
#   2,
#   3,
#   6390,
#   8228,
#   4194,
#   8346,
#   8046,
#   3378,
#   10277,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   276,
#   10,
#   4623,
#   11,
#   2902,
#   2288,
#   24,
#   4447,
#   5942,
#   205,
#   2008,
#   11095,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   8,
#   2057,
#   7,
#   276,
#   3634,
#   848,
#   34,
#   9,
#   558,
#   1073,
#   462,
#   7,
#   2008,
#   11095,
#   1387,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   55613,
#   1517,
#   69,
#   127,
#   6937,
#   7,
#   4577,
#   2142,
#   7922,
#   1384,
#   2949,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   147,
#   29,
#   2617,
#   5442,
#   6,
#   52077,
#   3,
#   2],
#  [3,
#   4106,
#   222,
#   35,
#   3449,
#   222,
#   12289,
#   14,
#   7303,
#   5761,
#   12,
#   19271,
#   6430,
#   3078,
#   15082,
#   5089,
#   454,
#   7,
#   86,
#   35,
#   423,
#   9,
#   69,
#   3078,
#   7564,
#   10893,
#   6416,
#   12,
#   49,
#   930,
#   3685,
#   110,
#   2544,
#   56769,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   622,
#   13085,
#   1749,
#   4258,
#   3,
#   2],
#  [3,
#   567,
#   311,
#   45,
#   54776,
#   8410,
#   67,
#   12,
#   21,
#   29,
#   626,
#   302,
#   9642,
#   25,
#   93,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   33271,
#   1881,
#   4,
#   16529,
#   14405,
#   16529,
#   3,
#   2],
#  [3,
#   12297,
#   110,
#   574,
#   1164,
#   229,
#   40,
#   64,
#   24449,
#   3852,
#   1660,
#   7,
#   3490,
#   27986,
#   4819,
#   6902,
#   13,
#   1007,
#   24210,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   216,
#   542,
#   7,
#   490,
#   7620,
#   2380,
#   13388,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   2856,
#   7833,
#   11,
#   5717,
#   8410,
#   223,
#   9,
#   10525,
#   768,
#   24,
#   23421,
#   125,
#   66,
#   23250,
#   3490,
#   2288,
#   3705,
#   917,
#   9170,
#   2856,
#   5883,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   11297,
#   2697,
#   829,
#   61,
#   6,
#   2652,
#   3902,
#   3,
#   2],
#  [3,
#   251,
#   8,
#   61,
#   7236,
#   127,
#   7,
#   23720,
#   687,
#   47865,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   137,
#   99,
#   186,
#   29,
#   55427,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   14,
#   36406,
#   441,
#   9866,
#   21,
#   148,
#   64,
#   16,
#   100,
#   2105,
#   12053,
#   7,
#   69,
#   1692,
#   487,
#   7,
#   31201,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   167,
#   312,
#   3,
#   2],
#  [3,
#   184,
#   2379,
#   2178,
#   311,
#   7,
#   525,
#   679,
#   25,
#   590,
#   24051,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   59664,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   9,
#   184,
#   666,
#   85,
#   11,
#   5717,
#   8410,
#   12,
#   9,
#   14228,
#   3210,
#   475,
#   42,
#   9535,
#   3657,
#   9603,
#   2500,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   80,
#   294,
#   1494,
#   13776,
#   5796,
#   1384,
#   4,
#   9535,
#   9282,
#   3611,
#   1931,
#   4,
#   13276,
#   1866,
#   3385,
#   8017,
#   2225,
#   3353,
#   4,
#   12110,
#   36248,
#   9603,
#   1931,
#   4,
#   3,
#   2],
#  [3,
#   36479,
#   6,
#   15879,
#   3086,
#   273,
#   11,
#   133,
#   3348,
#   7,
#   86,
#   39,
#   28408,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   2106,
#   4698,
#   570,
#   13557,
#   6,
#   133,
#   69,
#   27979,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   12297,
#   8726,
#   12699,
#   20062,
#   235,
#   42,
#   16,
#   802,
#   42244,
#   114,
#   3,
#   2,
#   3,
#   57084,
#   28244,
#   4,
#   3,
#   2],
#  [3,
#   17617,
#   2183,
#   1981,
#   21439,
#   4456,
#   302,
#   33,
#   29,
#   142,
#   3,
#   2,
#   3,
#   1615,
#   431,
#   78,
#   624,
#   29,
#   7806,
#   2576,
#   4,
#   586,
#   2178,
#   105,
#   2208,
#   11639,
#   29899,
#   11,
#   1391,
#   1766,
#   35,
#   82,
#   127,
#   58020,
#   21573,
#   1206,
#   230,
#   336,
#   844,
#   479,
#   137,
#   1366,
#   8271,
#   2477,
#   7,
#   350,
#   590,
#   6,
#   1219,
#   20405,
#   1301,
#   4,
#   8271,
#   61,
#   946,
#   9,
#   58,
#   35,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   81,
#   9,
#   834,
#   639,
#   127,
#   1713,
#   58,
#   56665,
#   27375,
#   404,
#   245,
#   232,
#   298,
#   43,
#   1298,
#   78,
#   7086,
#   4,
#   2208,
#   11639,
#   29899,
#   159,
#   2908,
#   11,
#   2178,
#   13778,
#   5,
#   3,
#   2],
#  [3,
#   2918,
#   245,
#   7,
#   7977,
#   1252,
#   9,
#   325,
#   9733,
#   181,
#   1820,
#   181,
#   3078,
#   848,
#   13,
#   4089,
#   4301,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   1073,
#   12155,
#   9,
#   5887,
#   1893,
#   8351,
#   3902,
#   9,
#   325,
#   45,
#   34299,
#   1236,
#   18020,
#   1517,
#   6,
#   9733,
#   2209,
#   3518,
#   10631,
#   91,
#   9,
#   2209,
#   2665,
#   2697,
#   1889,
#   6425,
#   13154,
#   1400,
#   3,
#   2],
#  [3,
#   4106,
#   159,
#   5942,
#   7,
#   25869,
#   7358,
#   11,
#   5717,
#   8410,
#   12,
#   30531,
#   805,
#   2546,
#   32841,
#   114,
#   3,
#   2,
#   3,
#   159,
#   5942,
#   355,
#   157,
#   1906,
#   1981,
#   2308,
#   3,
#   2],
#  [3,
#   934,
#   14077,
#   109,
#   45,
#   15038,
#   687,
#   223,
#   9755,
#   3344,
#   1430,
#   43383,
#   6,
#   37,
#   2919,
#   26427,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   5218,
#   36913,
#   8369,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   590,
#   4957,
#   2475,
#   7968,
#   61,
#   724,
#   580,
#   7,
#   58405,
#   3907,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   5020,
#   3,
#   2],
#  [3,
#   2837,
#   142,
#   2146,
#   1766,
#   4819,
#   4443,
#   6470,
#   127,
#   6937,
#   3,
#   2,
#   3,
#   635,
#   181,
#   378,
#   226,
#   61219,
#   1301,
#   4,
#   21703,
#   5122,
#   40662,
#   201,
#   349,
#   13,
#   590,
#   3992,
#   39,
#   6111,
#   30,
#   14845,
#   1854,
#   4,
#   701,
#   11,
#   624,
#   509,
#   616,
#   12,
#   1298,
#   101,
#   6708,
#   797,
#   226,
#   61219,
#   10557,
#   168,
#   201,
#   349,
#   25,
#   82,
#   248,
#   349,
#   103,
#   8,
#   4159,
#   6111,
#   6,
#   8038,
#   2763,
#   14845,
#   19126,
#   21703,
#   5122,
#   40662,
#   32,
#   10,
#   221,
#   12,
#   226,
#   1084,
#   590,
#   3992,
#   7520,
#   930,
#   8038,
#   2763,
#   9878,
#   51,
#   17,
#   11,
#   40,
#   1302,
#   25319,
#   3,
#   2],
#  [3,
#   3344,
#   4422,
#   1340,
#   11095,
#   1517,
#   8,
#   148,
#   3,
#   2,
#   3,
#   3344,
#   4422,
#   1738,
#   25,
#   350,
#   590,
#   8,
#   204,
#   1893,
#   430,
#   1361,
#   568,
#   3078,
#   7564,
#   350,
#   590,
#   39,
#   1054,
#   33,
#   4721,
#   4422,
#   6,
#   2183,
#   675,
#   295,
#   558,
#   6467,
#   675,
#   4422,
#   8,
#   159,
#   5,
#   3,
#   2],
#  [3,
#   266,
#   28950,
#   13005,
#   6168,
#   127,
#   6937,
#   59270,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2067,
#   30590,
#   1850,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   56739,
#   53585,
#   1166,
#   14,
#   11,
#   170,
#   35,
#   1219,
#   3156,
#   39,
#   29,
#   3503,
#   30,
#   6744,
#   1765,
#   114,
#   3,
#   2,
#   3,
#   76,
#   113,
#   3,
#   2],
#  [3,
#   217,
#   178,
#   2379,
#   22986,
#   23651,
#   61,
#   14760,
#   3348,
#   7,
#   37653,
#   13815,
#   6419,
#   48303,
#   114,
#   3,
#   2,
#   3,
#   5940,
#   3482,
#   3,
#   2],
#  [3, 29, 21, 148, 14, 5728, 29100, 1073, 380, 2610, 114, 3, 2, 3, 16164, 3, 2],
#  [3,
#   229,
#   1430,
#   148,
#   8,
#   359,
#   551,
#   26,
#   1186,
#   2282,
#   25552,
#   34022,
#   14,
#   45,
#   166,
#   34,
#   37825,
#   56116,
#   114,
#   3,
#   2,
#   3,
#   18471,
#   61367,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   467,
#   1088,
#   22682,
#   1347,
#   4,
#   558,
#   294,
#   6,
#   215,
#   1301,
#   16846,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   8274,
#   11042,
#   3889,
#   4366,
#   24513,
#   3,
#   2],
#  [3,
#   2209,
#   4623,
#   21,
#   148,
#   14,
#   2178,
#   89,
#   7977,
#   1252,
#   22821,
#   2179,
#   10645,
#   36117,
#   1231,
#   29,
#   12515,
#   1556,
#   114,
#   3,
#   2,
#   3,
#   3449,
#   1093,
#   3,
#   2],
#  [3,
#   557,
#   2919,
#   1283,
#   167,
#   67,
#   12,
#   4851,
#   1947,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   8565,
#   33108,
#   15386,
#   4975,
#   14157,
#   210,
#   302,
#   34946,
#   1301,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   5228,
#   2919,
#   14,
#   21795,
#   2545,
#   4339,
#   9,
#   2765,
#   2652,
#   2057,
#   13749,
#   103,
#   67,
#   12,
#   7328,
#   94,
#   9,
#   316,
#   5191,
#   836,
#   7620,
#   114,
#   3,
#   2,
#   3,
#   45417,
#   3,
#   2],
#  [3,
#   14,
#   347,
#   26,
#   37454,
#   366,
#   1464,
#   700,
#   53,
#   26,
#   4986,
#   7542,
#   7,
#   35297,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   82,
#   29,
#   3,
#   2],
#  [3,
#   345,
#   127,
#   6937,
#   235,
#   34,
#   732,
#   179,
#   221,
#   8,
#   148,
#   3,
#   2,
#   3,
#   30540,
#   7038,
#   335,
#   551,
#   44,
#   2975,
#   212,
#   4762,
#   54711,
#   14,
#   111,
#   5237,
#   7172,
#   862,
#   682,
#   302,
#   7594,
#   2652,
#   7,
#   4542,
#   3685,
#   28,
#   61,
#   14114,
#   35,
#   7,
#   61,
#   235,
#   227,
#   10549,
#   46116,
#   13208,
#   217,
#   2975,
#   212,
#   235,
#   7,
#   572,
#   1634,
#   56412,
#   17,
#   85,
#   148,
#   957,
#   246,
#   15,
#   34,
#   2565,
#   1125,
#   15947,
#   1850,
#   4,
#   376,
#   30,
#   16,
#   1163,
#   12907,
#   8,
#   21,
#   5237,
#   418,
#   1889,
#   235,
#   10,
#   4623,
#   11,
#   4453,
#   430,
#   147,
#   9,
#   2537,
#   5855,
#   595,
#   9,
#   74,
#   61580,
#   5,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   11365,
#   188,
#   44,
#   10995,
#   1358,
#   604,
#   154,
#   50875,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   29,
#   7806,
#   2326,
#   19,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   5650,
#   8,
#   110,
#   5223,
#   18517,
#   35,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   504,
#   4604,
#   19,
#   3,
#   2],
#  [3,
#   2679,
#   1294,
#   12813,
#   2054,
#   222,
#   42,
#   8,
#   16,
#   139,
#   24,
#   208,
#   11,
#   9,
#   4089,
#   2140,
#   7,
#   8123,
#   3709,
#   1698,
#   51899,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   49911,
#   30096,
#   4423,
#   9948,
#   13470,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   6466,
#   4722,
#   30939,
#   9215,
#   52853,
#   7,
#   2697,
#   46924,
#   1187,
#   57968,
#   22,
#   3,
#   2,
#   3,
#   9470,
#   2225,
#   5276,
#   5681,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   14,
#   2105,
#   10125,
#   9032,
#   39040,
#   3611,
#   114,
#   3,
#   2,
#   3,
#   11993,
#   33736,
#   21855,
#   5028,
#   3,
#   2],
#  [3,
#   1203,
#   21,
#   29,
#   4917,
#   5315,
#   4,
#   2516,
#   14,
#   11,
#   701,
#   154,
#   64,
#   82,
#   129,
#   2657,
#   2665,
#   30,
#   18,
#   1129,
#   23206,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   16,
#   568,
#   2958,
#   1340,
#   11095,
#   1517,
#   9708,
#   19509,
#   2119,
#   3385,
#   1236,
#   9522,
#   4,
#   6,
#   36,
#   18,
#   1129,
#   1709,
#   14,
#   7520,
#   3931,
#   33,
#   3448,
#   6969,
#   159,
#   3348,
#   2529,
#   1465,
#   3,
#   2],
#  [3,
#   1196,
#   467,
#   2135,
#   13,
#   16,
#   212,
#   2919,
#   222,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   25234,
#   19,
#   3,
#   2],
#  [3,
#   29,
#   148,
#   14,
#   56424,
#   10263,
#   7236,
#   15012,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   29,
#   7806,
#   2576,
#   4,
#   1284,
#   5628,
#   1265,
#   3,
#   2],
#  [3,
#   2002,
#   2104,
#   4623,
#   21,
#   148,
#   14,
#   834,
#   2765,
#   33,
#   24,
#   1149,
#   1490,
#   16,
#   100,
#   9,
#   1188,
#   3011,
#   2657,
#   2665,
#   30,
#   13884,
#   56073,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   19363,
#   19678,
#   3773,
#   44863,
#   3,
#   2],
#  [3,
#   9326,
#   3056,
#   5955,
#   8348,
#   14,
#   682,
#   302,
#   7303,
#   10816,
#   48,
#   7,
#   10826,
#   34729,
#   537,
#   127,
#   39,
#   29,
#   40865,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   1230,
#   11641,
#   3,
#   2],
#  [3,
#   207,
#   18,
#   21,
#   148,
#   52,
#   6169,
#   7311,
#   983,
#   355,
#   28,
#   203,
#   482,
#   58229,
#   114,
#   3,
#   2,
#   3,
#   7974,
#   1749,
#   1302,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   11,
#   10969,
#   792,
#   268,
#   17940,
#   139,
#   16064,
#   20358,
#   4055,
#   15271,
#   25,
#   2791,
#   11,
#   819,
#   52530,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   30037,
#   3,
#   2],
#  [3,
#   6933,
#   142,
#   6714,
#   1291,
#   366,
#   13,
#   84,
#   12350,
#   47867,
#   3,
#   2,
#   3,
#   162,
#   26,
#   7128,
#   12350,
#   47867,
#   40214,
#   1187,
#   4,
#   4267,
#   4372,
#   28720,
#   50,
#   14770,
#   9013,
#   30,
#   849,
#   29,
#   53,
#   60,
#   7166,
#   3440,
#   47934,
#   21473,
#   3,
#   2],
#  [3,
#   29,
#   64,
#   5255,
#   713,
#   127,
#   6937,
#   1237,
#   3521,
#   7,
#   418,
#   1430,
#   167,
#   4422,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30398,
#   3,
#   2],
#  [3,
#   4586,
#   6700,
#   9423,
#   352,
#   81,
#   7,
#   58,
#   237,
#   8,
#   277,
#   3,
#   2,
#   3,
#   24479,
#   8381,
#   3774,
#   9423,
#   32406,
#   14157,
#   1196,
#   1125,
#   44611,
#   27,
#   60894,
#   3,
#   65,
#   2617,
#   6278,
#   114,
#   31,
#   964,
#   78,
#   76,
#   29,
#   2617,
#   1551,
#   2576,
#   37272,
#   4,
#   8,
#   626,
#   6700,
#   9423,
#   129,
#   624,
#   790,
#   4267,
#   1007,
#   29062,
#   6,
#   32,
#   8,
#   626,
#   6700,
#   352,
#   81,
#   12,
#   2546,
#   5717,
#   350,
#   43557,
#   1759,
#   946,
#   9423,
#   32406,
#   25,
#   632,
#   22737,
#   18176,
#   1301,
#   4,
#   149,
#   6958,
#   37122,
#   1395,
#   4,
#   1479,
#   1125,
#   11095,
#   1850,
#   4,
#   350,
#   43557,
#   3,
#   2],
#  [3,
#   10645,
#   7128,
#   150,
#   8,
#   187,
#   4439,
#   7,
#   58,
#   142,
#   3,
#   2,
#   3,
#   10645,
#   7128,
#   11,
#   906,
#   493,
#   385,
#   3348,
#   84,
#   6,
#   300,
#   856,
#   2301,
#   1981,
#   2308,
#   6222,
#   3902,
#   7,
#   68,
#   223,
#   761,
#   2209,
#   618,
#   10645,
#   7128,
#   5,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   58,
#   7520,
#   3931,
#   3398,
#   2608,
#   3959,
#   18116,
#   2121,
#   1709,
#   1832,
#   1962,
#   3,
#   2,
#   3,
#   10053,
#   485,
#   19640,
#   7520,
#   3931,
#   18715,
#   12726,
#   25,
#   323,
#   173,
#   33,
#   78,
#   4980,
#   29,
#   2527,
#   5,
#   162,
#   323,
#   18715,
#   12726,
#   23,
#   4,
#   2506,
#   2608,
#   273,
#   221,
#   8,
#   22,
#   3398,
#   2608,
#   33784,
#   18116,
#   8123,
#   7564,
#   4488,
#   8536,
#   7856,
#   1709,
#   1832,
#   1962,
#   22,
#   20,
#   8656,
#   58136,
#   151,
#   2180,
#   163,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   4805,
#   934,
#   908,
#   380,
#   136,
#   10,
#   1464,
#   26567,
#   98,
#   3,
#   2,
#   3,
#   4805,
#   934,
#   908,
#   14157,
#   4051,
#   934,
#   908,
#   13,
#   30,
#   29,
#   6744,
#   1556,
#   65,
#   19,
#   7,
#   14802,
#   8,
#   16,
#   275,
#   7,
#   7162,
#   7709,
#   34412,
#   4805,
#   934,
#   908,
#   339,
#   25,
#   84,
#   856,
#   216,
#   2615,
#   7,
#   7162,
#   7709,
#   34412,
#   4805,
#   23,
#   28,
#   216,
#   2615,
#   542,
#   2956,
#   275,
#   934,
#   10029,
#   4,
#   216,
#   542,
#   2956,
#   275,
#   22053,
#   1581,
#   4,
#   216,
#   553,
#   2956,
#   275,
#   52095,
#   5961,
#   1850,
#   4,
#   50,
#   216,
#   1535,
#   2956,
#   11918,
#   59763,
#   1517,
#   3490,
#   1400,
#   24861,
#   7013,
#   12584,
#   3,
#   2],
#  [3,
#   7594,
#   2652,
#   7,
#   159,
#   713,
#   94,
#   82,
#   2657,
#   9534,
#   28,
#   216,
#   85,
#   1016,
#   90,
#   2856,
#   349,
#   5089,
#   917,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   3007,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   8,
#   3345,
#   532,
#   462,
#   16,
#   12053,
#   1294,
#   12,
#   930,
#   4698,
#   7,
#   9,
#   186,
#   7235,
#   39,
#   857,
#   53393,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   462,
#   380,
#   16580,
#   1384,
#   27,
#   97,
#   8,
#   236,
#   236,
#   3345,
#   121,
#   2753,
#   8184,
#   2178,
#   311,
#   48,
#   8,
#   12,
#   2753,
#   8184,
#   11473,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   16,
#   2657,
#   1400,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   82,
#   181,
#   15012,
#   27,
#   3,
#   2],
#  [3,
#   3229,
#   29,
#   428,
#   11,
#   229,
#   40,
#   25,
#   302,
#   835,
#   142,
#   7,
#   350,
#   590,
#   3,
#   2,
#   3,
#   319,
#   4307,
#   8690,
#   14,
#   229,
#   40,
#   61,
#   2379,
#   14050,
#   16702,
#   5522,
#   586,
#   5171,
#   84,
#   3229,
#   25,
#   5194,
#   57082,
#   1701,
#   4,
#   537,
#   127,
#   15,
#   792,
#   12813,
#   2603,
#   2902,
#   9,
#   2665,
#   1766,
#   181,
#   84,
#   3229,
#   14157,
#   6059,
#   53171,
#   19,
#   14157,
#   229,
#   40,
#   6404,
#   4652,
#   7086,
#   19,
#   91,
#   1835,
#   676,
#   14367,
#   34956,
#   4,
#   3698,
#   26865,
#   27798,
#   3229,
#   7806,
#   1546,
#   4,
#   34811,
#   1479,
#   1432,
#   286,
#   39349,
#   5,
#   282,
#   32,
#   8,
#   110,
#   673,
#   27798,
#   352,
#   81,
#   12,
#   29,
#   3229,
#   7806,
#   36540,
#   3,
#   2],
#  [3,
#   92,
#   43,
#   380,
#   2919,
#   1464,
#   26567,
#   22514,
#   19278,
#   2052,
#   1746,
#   187,
#   33,
#   49,
#   862,
#   797,
#   412,
#   1600,
#   15991,
#   114,
#   3,
#   2,
#   3,
#   48,
#   16,
#   1439,
#   14157,
#   14754,
#   52513,
#   19,
#   3,
#   2],
#  [3,
#   618,
#   779,
#   251,
#   11,
#   1893,
#   5744,
#   811,
#   3365,
#   9,
#   1607,
#   5520,
#   174,
#   16580,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   7,
#   570,
#   6304,
#   431,
#   3,
#   2],
#  [3,
#   2918,
#   142,
#   7,
#   452,
#   460,
#   590,
#   47,
#   49,
#   42,
#   7483,
#   1698,
#   19762,
#   114,
#   3,
#   2,
#   3,
#   17,
#   10,
#   179,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   248,
#   12266,
#   14,
#   12300,
#   2753,
#   36717,
#   4,
#   3911,
#   7001,
#   4,
#   6,
#   8298,
#   56867,
#   154,
#   12,
#   29,
#   7806,
#   1854,
#   114,
#   3,
#   2,
#   3,
#   20232,
#   3902,
#   3,
#   2],
#  [3,
#   9,
#   3309,
#   3256,
#   463,
#   200,
#   19304,
#   48,
#   12,
#   49,
#   2906,
#   2608,
#   790,
#   4365,
#   845,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   23720,
#   687,
#   45182,
#   3,
#   2],
#  [3,
#   6034,
#   3333,
#   4138,
#   339,
#   25,
#   316,
#   5191,
#   142,
#   3,
#   2,
#   3,
#   3333,
#   4138,
#   8,
#   16,
#   3390,
#   705,
#   25,
#   316,
#   5191,
#   836,
#   5946,
#   4,
#   227,
#   2924,
#   553,
#   542,
#   3449,
#   6103,
#   1007,
#   3019,
#   4,
#   216,
#   542,
#   1219,
#   3156,
#   6,
#   216,
#   1535,
#   1507,
#   5,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   18098,
#   10,
#   11,
#   16,
#   3312,
#   6222,
#   49033,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   4418,
#   3,
#   2],
#  [3,
#   14,
#   6302,
#   2052,
#   13,
#   108,
#   21,
#   148,
#   14,
#   2665,
#   7594,
#   28,
#   569,
#   294,
#   7,
#   6209,
#   12968,
#   114,
#   3,
#   2,
#   3,
#   3224,
#   3902,
#   7606,
#   11297,
#   7,
#   46,
#   28,
#   2900,
#   39,
#   1586,
#   2106,
#   42,
#   16,
#   22649,
#   12481,
#   807,
#   626,
#   3,
#   2],
#  [3,
#   2679,
#   10,
#   4623,
#   2906,
#   2608,
#   16,
#   43,
#   4574,
#   183,
#   2919,
#   1093,
#   17,
#   4623,
#   80,
#   20373,
#   114,
#   3,
#   2,
#   3,
#   2603,
#   1981,
#   2308,
#   3,
#   2],
#  [3,
#   5586,
#   90,
#   4379,
#   3705,
#   157,
#   2925,
#   8410,
#   9,
#   4447,
#   819,
#   2657,
#   1388,
#   4985,
#   4,
#   86,
#   14,
#   47,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   157,
#   14,
#   1054,
#   33,
#   430,
#   574,
#   493,
#   2792,
#   976,
#   976,
#   2068,
#   834,
#   2765,
#   1340,
#   11095,
#   1517,
#   493,
#   2792,
#   159,
#   3348,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18116,
#   1163,
#   7,
#   387,
#   1924,
#   30939,
#   11254,
#   639,
#   5315,
#   1546,
#   22,
#   3,
#   2,
#   3,
#   23781,
#   355,
#   15,
#   853,
#   39,
#   30939,
#   30939,
#   2679,
#   14,
#   150,
#   57,
#   89,
#   490,
#   19464,
#   1871,
#   43798,
#   4,
#   19464,
#   1871,
#   17093,
#   1575,
#   6969,
#   58,
#   3,
#   31829,
#   2679,
#   14,
#   150,
#   523,
#   355,
#   11254,
#   48599,
#   1301,
#   4,
#   355,
#   11254,
#   639,
#   5315,
#   1546,
#   381,
#   4341,
#   2528,
#   829,
#   11254,
#   639,
#   29,
#   13170,
#   1581,
#   4,
#   94,
#   11254,
#   639,
#   7918,
#   280,
#   423,
#   12395,
#   1701,
#   4,
#   18,
#   2856,
#   9031,
#   2247,
#   148,
#   764,
#   38139,
#   1384,
#   4,
#   391,
#   2528,
#   829,
#   11254,
#   639,
#   29,
#   241,
#   5721,
#   16,
#   605,
#   61327,
#   300,
#   3245,
#   57351,
#   1701,
#   34976,
#   30939,
#   30939,
#   4,
#   387,
#   577,
#   14,
#   57,
#   33,
#   605,
#   36,
#   570,
#   2301,
#   18,
#   350,
#   43557,
#   3,
#   2],
#  [3,
#   5586,
#   90,
#   157,
#   15447,
#   1672,
#   4,
#   21,
#   148,
#   14,
#   11,
#   9,
#   69,
#   3213,
#   311,
#   2121,
#   67,
#   11,
#   43451,
#   18075,
#   25,
#   22514,
#   31352,
#   6,
#   22514,
#   21703,
#   3657,
#   1581,
#   114,
#   3,
#   2,
#   3,
#   1696,
#   8595,
#   4,
#   5069,
#   1494,
#   50410,
#   4,
#   3709,
#   25958,
#   151,
#   16064,
#   20358,
#   4055,
#   25699,
#   4,
#   3,
#   2],
#  [3,
#   3936,
#   4368,
#   148,
#   14,
#   43451,
#   18075,
#   59186,
#   1384,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   21634,
#   4368,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   61,
#   10540,
#   1188,
#   7,
#   452,
#   16021,
#   357,
#   37409,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3258,
#   645,
#   7,
#   2927,
#   452,
#   450,
#   45061,
#   3,
#   2],
#  [3,
#   1276,
#   7426,
#   11,
#   1073,
#   9534,
#   33,
#   137,
#   29,
#   2789,
#   20509,
#   114,
#   3,
#   2,
#   3,
#   2097,
#   14693,
#   3,
#   2],
#  [3,
#   1203,
#   43,
#   142,
#   387,
#   417,
#   2958,
#   292,
#   159,
#   2908,
#   53816,
#   114,
#   3,
#   2,
#   3,
#   964,
#   78,
#   163,
#   29,
#   41087,
#   3,
#   2],
#  [3,
#   21634,
#   7102,
#   1464,
#   26567,
#   230,
#   877,
#   18,
#   452,
#   22514,
#   31352,
#   11567,
#   114,
#   3,
#   2,
#   3,
#   17218,
#   52513,
#   37272,
#   4,
#   6169,
#   7311,
#   8,
#   3344,
#   4368,
#   3,
#   2],
#  [3,
#   450,
#   63,
#   3056,
#   378,
#   159,
#   3348,
#   142,
#   3,
#   2,
#   3,
#   29991,
#   378,
#   1218,
#   506,
#   7,
#   450,
#   14,
#   1188,
#   18,
#   350,
#   302,
#   21,
#   1362,
#   1430,
#   2537,
#   159,
#   181,
#   474,
#   66,
#   55,
#   2892,
#   2537,
#   16,
#   139,
#   16552,
#   2697,
#   4,
#   498,
#   298,
#   199,
#   50,
#   493,
#   8271,
#   2477,
#   339,
#   12,
#   306,
#   18,
#   450,
#   5,
#   783,
#   2559,
#   3056,
#   9,
#   493,
#   385,
#   91,
#   159,
#   3348,
#   7,
#   452,
#   618,
#   1710,
#   42,
#   385,
#   91,
#   9287,
#   6928,
#   4,
#   385,
#   91,
#   441,
#   6430,
#   4,
#   385,
#   91,
#   740,
#   1093,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   11,
#   906,
#   493,
#   7303,
#   10816,
#   53,
#   26,
#   41287,
#   54990,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   39154,
#   3,
#   2],
#  [3,
#   441,
#   148,
#   14,
#   3333,
#   1073,
#   2106,
#   30332,
#   1204,
#   9528,
#   5648,
#   2405,
#   18116,
#   15,
#   6010,
#   114,
#   3,
#   2,
#   3,
#   53334,
#   9528,
#   5648,
#   28861,
#   3,
#   2],
#  [3,
#   303,
#   8,
#   148,
#   5869,
#   989,
#   2587,
#   943,
#   13,
#   51987,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   303,
#   2184,
#   3,
#   2],
#  [3,
#   962,
#   15,
#   17204,
#   18294,
#   76,
#   6,
#   2064,
#   4567,
#   59216,
#   1850,
#   4,
#   64,
#   356,
#   129,
#   346,
#   41,
#   10,
#   373,
#   13,
#   51899,
#   2528,
#   380,
#   7,
#   1437,
#   57319,
#   51899,
#   114,
#   3,
#   2,
#   3,
#   2064,
#   4567,
#   15764,
#   3,
#   2],
#  [3,
#   2590,
#   570,
#   142,
#   119,
#   17,
#   585,
#   6920,
#   10,
#   4623,
#   11,
#   1389,
#   34376,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   32463,
#   1231,
#   187,
#   33,
#   166,
#   558,
#   620,
#   64,
#   86,
#   156,
#   63,
#   6,
#   387,
#   834,
#   11297,
#   2697,
#   7,
#   86,
#   3,
#   2],
#  [3,
#   12297,
#   8,
#   192,
#   84,
#   67,
#   12,
#   2747,
#   705,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   22980,
#   35062,
#   2573,
#   3,
#   2],
#  [3,
#   133,
#   3348,
#   5298,
#   212,
#   7,
#   9,
#   666,
#   3312,
#   806,
#   212,
#   154,
#   11,
#   34,
#   2330,
#   78,
#   3966,
#   29,
#   660,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   58511,
#   25341,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   1822,
#   7899,
#   13093,
#   5668,
#   357,
#   385,
#   6619,
#   3,
#   2,
#   3,
#   79,
#   18116,
#   3884,
#   350,
#   590,
#   3430,
#   4368,
#   5717,
#   6928,
#   7,
#   18116,
#   1163,
#   3751,
#   8317,
#   4,
#   43,
#   1769,
#   78,
#   173,
#   29,
#   8971,
#   4,
#   2042,
#   7899,
#   13093,
#   5668,
#   357,
#   14,
#   467,
#   16,
#   961,
#   1734,
#   13,
#   10969,
#   1093,
#   5922,
#   19238,
#   2663,
#   3019,
#   939,
#   5721,
#   385,
#   6619,
#   24,
#   7927,
#   3959,
#   159,
#   493,
#   5,
#   3,
#   2],
#  [3,
#   30939,
#   1000,
#   681,
#   7,
#   20623,
#   351,
#   1746,
#   401,
#   56234,
#   1487,
#   22,
#   14,
#   11,
#   675,
#   1201,
#   24,
#   24515,
#   64,
#   19271,
#   6430,
#   3705,
#   25837,
#   114,
#   3,
#   2,
#   3,
#   452,
#   3,
#   2],
#  [3,
#   8665,
#   56182,
#   1301,
#   4,
#   5116,
#   30419,
#   1187,
#   4,
#   6,
#   49,
#   4770,
#   2528,
#   9,
#   1607,
#   5959,
#   1906,
#   2178,
#   2919,
#   572,
#   276,
#   44,
#   280,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   819,
#   284,
#   2919,
#   57659,
#   1301,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   18,
#   414,
#   127,
#   2209,
#   32384,
#   1231,
#   718,
#   2936,
#   1430,
#   11,
#   819,
#   52530,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   29,
#   4917,
#   5381,
#   4,
#   3,
#   2],
#  [3,
#   373,
#   7195,
#   103,
#   67,
#   7,
#   423,
#   1463,
#   4379,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   42128,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   248,
#   5535,
#   14,
#   215,
#   266,
#   30939,
#   42160,
#   1302,
#   22,
#   561,
#   2856,
#   52006,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   346,
#   3,
#   2],
#  [3,
#   1276,
#   7426,
#   30,
#   33,
#   78,
#   8069,
#   15,
#   16,
#   2068,
#   2537,
#   639,
#   2199,
#   30419,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   242,
#   109,
#   365,
#   13,
#   105,
#   462,
#   397,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   14945,
#   45,
#   10,
#   4623,
#   11,
#   2902,
#   2203,
#   15,
#   16,
#   215,
#   184,
#   17632,
#   558,
#   34302,
#   114,
#   3,
#   2,
#   3,
#   12583,
#   14945,
#   22842,
#   4,
#   3,
#   2],
#  [3,
#   1783,
#   3139,
#   148,
#   140,
#   40,
#   54776,
#   1073,
#   12,
#   6112,
#   3056,
#   58975,
#   6108,
#   114,
#   3,
#   2,
#   3,
#   2856,
#   3,
#   2],
#  [3,
#   2454,
#   2234,
#   23533,
#   8,
#   73,
#   695,
#   7,
#   1692,
#   142,
#   3,
#   2,
#   3,
#   2080,
#   389,
#   3751,
#   5476,
#   708,
#   13591,
#   10801,
#   1179,
#   11,
#   1224,
#   302,
#   317,
#   1389,
#   15558,
#   4,
#   430,
#   2274,
#   21,
#   2198,
#   1645,
#   85,
#   2008,
#   4363,
#   27,
#   7236,
#   6588,
#   14876,
#   1301,
#   4,
#   12813,
#   45267,
#   1395,
#   4,
#   298,
#   16580,
#   1672,
#   4,
#   1447,
#   59742,
#   1395,
#   4,
#   639,
#   34139,
#   1187,
#   4,
#   309,
#   55690,
#   6,
#   2773,
#   6968,
#   4,
#   15,
#   9,
#   3520,
#   805,
#   1079,
#   15,
#   21,
#   819,
#   284,
#   1895,
#   187,
#   7,
#   1103,
#   914,
#   350,
#   10029,
#   27,
#   73,
#   2127,
#   10440,
#   1881,
#   4,
#   80,
#   2845,
#   9446,
#   4,
#   657,
#   18612,
#   1701,
#   135,
#   3089,
#   109,
#   3751,
#   5476,
#   124,
#   7834,
#   4006,
#   368,
#   26886,
#   387,
#   5924,
#   819,
#   284,
#   632,
#   914,
#   2106,
#   25177,
#   2008,
#   4,
#   73,
#   2127,
#   10440,
#   1881,
#   4,
#   2420,
#   24351,
#   21473,
#   3698,
#   1294,
#   975,
#   80,
#   2845,
#   9446,
#   4,
#   3364,
#   1698,
#   6406,
#   1698,
#   26824,
#   4,
#   3520,
#   805,
#   3114,
#   24351,
#   1395,
#   4,
#   630,
#   3649,
#   60926,
#   1494,
#   17182,
#   1672,
#   135,
#   32,
#   2528,
#   380,
#   12,
#   109,
#   389,
#   29,
#   45538,
#   5,
#   3223,
#   109,
#   389,
#   3751,
#   5476,
#   14157,
#   687,
#   124,
#   2420,
#   13906,
#   1782,
#   25591,
#   1701,
#   19,
#   8,
#   16,
#   3674,
#   5332,
#   1340,
#   8503,
#   10,
#   4762,
#   819,
#   2454,
#   2234,
#   39878,
#   21573,
#   559,
#   362,
#   27772,
#   4,
#   2301,
#   1981,
#   2308,
#   737,
#   11,
#   14945,
#   3900,
#   63,
#   150,
#   286,
#   1294,
#   7,
#   9,
#   1389,
#   687,
#   3520,
#   805,
#   1300,
#   363,
#   48,
#   30714,
#   109,
#   3040,
#   12584,
#   345,
#   1740,
#   56255,
#   30,
#   150,
#   316,
#   38,
#   11,
#   523,
#   21,
#   2226,
#   2106,
#   80,
#   914,
#   10932,
#   37659,
#   20330,
#   3,
#   2],
#  [3,
#   8984,
#   494,
#   11,
#   1073,
#   380,
#   127,
#   6937,
#   29,
#   12529,
#   25,
#   602,
#   3,
#   2,
#   3,
#   146,
#   1713,
#   1934,
#   17860,
#   862,
#   222,
#   50351,
#   2608,
#   87,
#   249,
#   39,
#   790,
#   123,
#   32841,
#   4,
#   73,
#   18,
#   14,
#   418,
#   235,
#   25,
#   3081,
#   58953,
#   12584,
#   635,
#   16290,
#   17648,
#   12,
#   3890,
#   13119,
#   2490,
#   9,
#   69,
#   17860,
#   862,
#   222,
#   14,
#   1073,
#   380,
#   40,
#   36,
#   675,
#   1591,
#   121,
#   494,
#   7,
#   16,
#   568,
#   4721,
#   4422,
#   175,
#   1395,
#   18800,
#   21473,
#   321,
#   49,
#   1073,
#   380,
#   40,
#   215,
#   1824,
#   494,
#   3081,
#   1432,
#   33,
#   78,
#   76,
#   29,
#   6353,
#   35,
#   149,
#   3081,
#   18176,
#   1301,
#   4,
#   13,
#   108,
#   286,
#   1362,
#   7,
#   215,
#   1824,
#   494,
#   23,
#   14,
#   418,
#   235,
#   25,
#   97,
#   137,
#   147,
#   6536,
#   9642,
#   6304,
#   99,
#   982,
#   8479,
#   5,
#   3,
#   2],
#  [3,
#   10150,
#   620,
#   7657,
#   2215,
#   8,
#   2765,
#   2652,
#   11297,
#   2697,
#   159,
#   7,
#   21,
#   538,
#   119,
#   17,
#   142,
#   3,
#   2,
#   3,
#   793,
#   136,
#   1696,
#   7657,
#   102,
#   10,
#   454,
#   356,
#   462,
#   142,
#   2902,
#   2203,
#   517,
#   620,
#   7657,
#   2215,
#   15,
#   316,
#   5191,
#   2765,
#   2652,
#   302,
#   835,
#   5,
#   3,
#   2],
#  [3,
#   184,
#   2379,
#   21,
#   148,
#   86,
#   69,
#   58,
#   17,
#   4623,
#   11,
#   2657,
#   2902,
#   15,
#   80,
#   294,
#   1494,
#   13776,
#   5796,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   326,
#   3902,
#   3,
#   2],
#  [3,
#   404,
#   602,
#   7162,
#   8608,
#   2030,
#   1966,
#   14760,
#   3348,
#   2679,
#   1070,
#   36171,
#   114,
#   3,
#   2,
#   3,
#   18742,
#   1517,
#   25,
#   1437,
#   3992,
#   3,
#   2],
#  [3,
#   2833,
#   1361,
#   21,
#   148,
#   14,
#   159,
#   493,
#   200,
#   87,
#   3078,
#   848,
#   10842,
#   50656,
#   5237,
#   34453,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   9,
#   27966,
#   2380,
#   770,
#   11635,
#   8251,
#   33602,
#   33950,
#   1384,
#   4,
#   3,
#   2],
#  [3,
#   2288,
#   567,
#   148,
#   11,
#   1073,
#   380,
#   24,
#   199,
#   40,
#   3201,
#   1701,
#   21356,
#   114,
#   3,
#   2,
#   3,
#   5058,
#   3173,
#   48514,
#   8526,
#   3907,
#   39806,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   146,
#   5228,
#   2919,
#   12,
#   37,
#   1692,
#   8,
#   16,
#   499,
#   40729,
#   12,
#   61,
#   1073,
#   12155,
#   7,
#   9,
#   626,
#   5924,
#   7,
#   11639,
#   42594,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   10413,
#   1555,
#   3,
#   2],
#  [3,
#   29,
#   148,
#   14,
#   18,
#   5955,
#   8348,
#   34550,
#   8536,
#   58,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   12941,
#   3415,
#   3,
#   2],
#  [3,
#   16,
#   418,
#   1889,
#   64,
#   6667,
#   34,
#   9,
#   2697,
#   1889,
#   85,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   401,
#   5199,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   12,
#   21,
#   675,
#   6892,
#   44567,
#   2537,
#   25,
#   590,
#   24051,
#   187,
#   28,
#   19695,
#   7167,
#   1345,
#   114,
#   3,
#   2,
#   3,
#   6522,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   58,
#   157,
#   2178,
#   89,
#   759,
#   2680,
#   7,
#   668,
#   630,
#   4391,
#   22682,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   17,
#   45,
#   15885,
#   2908,
#   34,
#   54751,
#   1301,
#   4,
#   3,
#   2],
#  [3,
#   162,
#   26,
#   89,
#   56417,
#   1384,
#   4,
#   4267,
#   8218,
#   26884,
#   11,
#   1510,
#   23647,
#   25,
#   602,
#   3,
#   2,
#   3,
#   962,
#   46105,
#   4,
#   11414,
#   4700,
#   675,
#   89,
#   733,
#   26,
#   60,
#   1443,
#   57246,
#   27375,
#   168,
#   25,
#   642,
#   11,
#   445,
#   46105,
#   4,
#   11,
#   1510,
#   23647,
#   35,
#   934,
#   18176,
#   10557,
#   3,
#   2],
#  [3,
#   16,
#   61,
#   2379,
#   2665,
#   7594,
#   85,
#   246,
#   15,
#   386,
#   6120,
#   1883,
#   40559,
#   13961,
#   1749,
#   4129,
#   151,
#   8767,
#   13961,
#   1749,
#   4129,
#   25869,
#   7358,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   38014,
#   24895,
#   39490,
#   3,
#   2],
#  [3,
#   16,
#   278,
#   248,
#   543,
#   13,
#   61,
#   475,
#   138,
#   147,
#   9,
#   215,
#   9707,
#   85,
#   138,
#   7,
#   215,
#   5273,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   430,
#   5273,
#   1611,
#   3,
#   2],
#  [3,
#   4031,
#   142,
#   36,
#   325,
#   2126,
#   27979,
#   1187,
#   4,
#   667,
#   2559,
#   42,
#   2126,
#   18265,
#   6,
#   1074,
#   22397,
#   1384,
#   4,
#   22912,
#   5447,
#   114,
#   3,
#   2,
#   3,
#   368,
#   3,
#   2],
#  [3,
#   622,
#   2288,
#   17,
#   2559,
#   58660,
#   5916,
#   30,
#   39,
#   28408,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   5255,
#   3256,
#   91,
#   18,
#   2374,
#   676,
#   7,
#   9,
#   3210,
#   25580,
#   1144,
#   4581,
#   127,
#   6937,
#   111,
#   18,
#   2608,
#   13143,
#   16088,
#   4453,
#   33,
#   275,
#   3,
#   2],
#  [3,
#   319,
#   142,
#   14,
#   11,
#   9,
#   23355,
#   11723,
#   5351,
#   3517,
#   1850,
#   55208,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   1298,
#   1641,
#   210,
#   29,
#   39587,
#   4,
#   3,
#   2],
#  [3,
#   47,
#   275,
#   778,
#   14,
#   199,
#   77,
#   21,
#   148,
#   9,
#   2301,
#   418,
#   4311,
#   7,
#   86,
#   6169,
#   7311,
#   1790,
#   3240,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   69,
#   558,
#   17,
#   240,
#   108,
#   25,
#   378,
#   84,
#   20999,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   6244,
#   2665,
#   2301,
#   30,
#   8840,
#   5135,
#   8,
#   939,
#   22366,
#   930,
#   3685,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   16,
#   40415,
#   7038,
#   24090,
#   32546,
#   1701,
#   4,
#   9393,
#   51862,
#   4,
#   151,
#   7520,
#   3931,
#   3,
#   2],
#  [3,
#   24444,
#   1098,
#   11,
#   675,
#   1201,
#   29,
#   1939,
#   6,
#   1531,
#   43451,
#   18075,
#   21,
#   148,
#   856,
#   1362,
#   10,
#   4623,
#   366,
#   7,
#   55905,
#   2659,
#   114,
#   3,
#   2,
#   3,
#   9079,
#   10705,
#   2508,
#   6,
#   5791,
#   1734,
#   10705,
#   2508,
#   3,
#   2],
#  [3,
#   1783,
#   3139,
#   230,
#   2951,
#   148,
#   14,
#   46953,
#   4263,
#   108,
#   10,
#   4623,
#   10,
#   12053,
#   1294,
#   15,
#   378,
#   56101,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   10771,
#   4774,
#   127,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   4089,
#   2140,
#   14,
#   2599,
#   701,
#   11,
#   12,
#   9,
#   110,
#   201,
#   5955,
#   3958,
#   10931,
#   114,
#   3,
#   2,
#   3,
#   22002,
#   3,
#   2],
#  [3,
#   4029,
#   316,
#   5191,
#   47,
#   380,
#   2919,
#   2587,
#   943,
#   3962,
#   235,
#   31700,
#   114,
#   3,
#   2,
#   3,
#   17,
#   10932,
#   2288,
#   13,
#   49,
#   5717,
#   8410,
#   4721,
#   4422,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   11,
#   215,
#   5273,
#   39,
#   127,
#   6937,
#   11,
#   199,
#   2610,
#   114,
#   3,
#   2,
#   3,
#   12109,
#   3,
#   2],
#  [3,
#   2679,
#   6254,
#   2697,
#   16,
#   110,
#   9929,
#   22560,
#   121,
#   139,
#   510,
#   89,
#   22442,
#   454,
#   6620,
#   114,
#   3,
#   2,
#   3,
#   2901,
#   3019,
#   2842,
#   226,
#   3,
#   2],
#  [3,
#   2925,
#   2792,
#   3518,
#   3959,
#   8,
#   8840,
#   24253,
#   15,
#   2925,
#   2412,
#   1660,
#   6248,
#   380,
#   136,
#   10,
#   1645,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   2543,
#   1660,
#   28108,
#   18658,
#   1301,
#   22,
#   3,
#   2],
#  [3,
#   499,
#   129,
#   82,
#   24590,
#   4930,
#   274,
#   12,
#   5843,
#   2833,
#   16,
#   18116,
#   3884,
#   22986,
#   67,
#   15,
#   82,
#   894,
#   618,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   24,
#   682,
#   44,
#   27924,
#   387,
#   987,
#   64,
#   46,
#   200,
#   87,
#   40957,
#   1565,
#   14,
#   4456,
#   302,
#   4089,
#   4301,
#   7,
#   69,
#   2528,
#   618,
#   3,
#   2],
#  [3,
#   3483,
#   1000,
#   1785,
#   11,
#   1362,
#   4365,
#   4542,
#   3936,
#   47,
#   22366,
#   148,
#   3,
#   2,
#   3,
#   1004,
#   675,
#   49,
#   7007,
#   4864,
#   12,
#   2127,
#   22535,
#   1881,
#   4,
#   3483,
#   1000,
#   1785,
#   50,
#   11,
#   1692,
#   574,
#   49,
#   5073,
#   21,
#   2958,
#   1734,
#   1821,
#   574,
#   15,
#   69,
#   36126,
#   6185,
#   1612,
#   311,
#   2317,
#   40610,
#   21,
#   2958,
#   1734,
#   1821,
#   574,
#   40865,
#   31829,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   127,
#   6937,
#   1626,
#   3705,
#   7564,
#   853,
#   40,
#   355,
#   350,
#   3,
#   2,
#   3,
#   61610,
#   3019,
#   7564,
#   6221,
#   564,
#   101,
#   127,
#   6937,
#   11,
#   3751,
#   13311,
#   3019,
#   1626,
#   40,
#   355,
#   350,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   350,
#   590,
#   127,
#   6937,
#   620,
#   40,
#   227,
#   10955,
#   3506,
#   3,
#   2,
#   3,
#   1117,
#   56619,
#   99,
#   14157,
#   19,
#   118,
#   50,
#   328,
#   8,
#   356,
#   1858,
#   836,
#   99,
#   8,
#   152,
#   2068,
#   2374,
#   127,
#   6937,
#   12,
#   2546,
#   5717,
#   620,
#   33,
#   10955,
#   3506,
#   10,
#   2068,
#   2537,
#   25837,
#   5,
#   3269,
#   42689,
#   1894,
#   1117,
#   56619,
#   2147,
#   31951,
#   39544,
#   11674,
#   3611,
#   3492,
#   14,
#   11,
#   111,
#   40,
#   1294,
#   12813,
#   33,
#   43,
#   445,
#   78,
#   163,
#   29,
#   9859,
#   39,
#   517,
#   620,
#   10955,
#   3506,
#   15265,
#   31865,
#   7382,
#   15,
#   2068,
#   2537,
#   3931,
#   18,
#   3490,
#   27986,
#   8,
#   39518,
#   50613,
#   47,
#   46,
#   682,
#   302,
#   18,
#   127,
#   6937,
#   510,
#   89,
#   1660,
#   6248,
#   40,
#   145,
#   227,
#   17,
#   32741,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   6850,
#   2198,
#   221,
#   58593,
#   3240,
#   114,
#   3,
#   2,
#   3,
#   6209,
#   1395,
#   3342,
#   5213,
#   676,
#   16275,
#   24188,
#   3,
#   2],
#  [3,
#   79,
#   37,
#   11,
#   9,
#   69,
#   1251,
#   2289,
#   1347,
#   50410,
#   114,
#   3,
#   2,
#   3,
#   12839,
#   16809,
#   1622,
#   4,
#   3,
#   2],
#  [3,
#   853,
#   9031,
#   148,
#   10,
#   21,
#   184,
#   1078,
#   24,
#   96,
#   28,
#   32000,
#   418,
#   37825,
#   56116,
#   114,
#   3,
#   2,
#   3,
#   8274,
#   28620,
#   3,
#   2],
#  [3,
#   1206,
#   835,
#   142,
#   8,
#   26950,
#   7,
#   103,
#   129,
#   23797,
#   114,
#   3,
#   2,
#   3,
#   33087,
#   6691,
#   7306,
#   10931,
#   4,
#   3,
#   2],
#  [3,
#   17,
#   2279,
#   8837,
#   4692,
#   1487,
#   32111,
#   14818,
#   4578,
#   178,
#   7344,
#   200,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   23433,
#   3,
#   2],
#  [3,
#   12297,
#   8726,
#   12699,
#   20062,
#   127,
#   6937,
#   96,
#   28,
#   224,
#   366,
#   7,
#   269,
#   35297,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   22514,
#   10447,
#   1931,
#   4742,
#   4,
#   3,
#   2],
#  [3,
#   13466,
#   6488,
#   675,
#   1510,
#   380,
#   35,
#   7,
#   302,
#   835,
#   1737,
#   8883,
#   1612,
#   8,
#   277,
#   3,
#   2,
#   3,
#   3333,
#   8641,
#   819,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   20,
#   355,
#   157,
#   27,
#   10550,
#   3378,
#   1612,
#   5218,
#   19900,
#   32283,
#   4,
#   467,
#   2135,
#   27,
#   13511,
#   19,
#   8,
#   3010,
#   1906,
#   819,
#   7,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   4,
#   5089,
#   187,
#   34128,
#   718,
#   2936,
#   452,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   5,
#   3,
#   2],
#  [3, 12297, 21, 18, 23, 235, 25, 28408, 1881, 114, 3, 2, 3, 15740, 3, 2],
#  [3,
#   29,
#   148,
#   14,
#   47,
#   27981,
#   4975,
#   21619,
#   5827,
#   10348,
#   1422,
#   59216,
#   3104,
#   3520,
#   32841,
#   114,
#   3,
#   2,
#   3,
#   6544,
#   3,
#   2],
#  [3,
#   242,
#   894,
#   55613,
#   1517,
#   1278,
#   22563,
#   32,
#   11,
#   328,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   5728,
#   2500,
#   1993,
#   4323,
#   7409,
#   22,
#   3,
#   2],
#  [3,
#   13825,
#   1734,
#   127,
#   6937,
#   7,
#   98,
#   1832,
#   3883,
#   8,
#   277,
#   3,
#   2,
#   3,
#   347,
#   29,
#   4602,
#   46,
#   8,
#   5932,
#   1734,
#   98,
#   21356,
#   1231,
#   621,
#   59426,
#   98,
#   4700,
#   30862,
#   1301,
#   4,
#   46,
#   300,
#   1766,
#   178,
#   23,
#   13,
#   30,
#   26,
#   4700,
#   30862,
#   1301,
#   4,
#   1832,
#   2331,
#   6,
#   1832,
#   3883,
#   1637,
#   44,
#   302,
#   98,
#   3883,
#   24327,
#   27375,
#   162,
#   37,
#   8,
#   2185,
#   5932,
#   1734,
#   98,
#   12917,
#   13,
#   30,
#   29,
#   12515,
#   26395,
#   3,
#   2],
#  [3,
#   9766,
#   8410,
#   3228,
#   2697,
#   1889,
#   42,
#   2747,
#   797,
#   14,
#   150,
#   11,
#   774,
#   8,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   40,
#   509,
#   18964,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   2679,
#   1906,
#   17055,
#   7833,
#   5520,
#   7596,
#   4157,
#   770,
#   11370,
#   6614,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   21703,
#   3613,
#   10448,
#   43769,
#   53683,
#   14405,
#   16529,
#   16529,
#   12,
#   21,
#   16359,
#   6304,
#   917,
#   53196,
#   4,
#   6,
#   11,
#   13557,
#   154,
#   223,
#   69,
#   5520,
#   6222,
#   6417,
#   56846,
#   33,
#   29,
#   36895,
#   6,
#   29,
#   3855,
#   1765,
#   27751,
#   35,
#   790,
#   192,
#   27772,
#   4,
#   7291,
#   6,
#   6417,
#   25,
#   275,
#   179,
#   74,
#   50,
#   8,
#   16,
#   230,
#   7,
#   23036,
#   6,
#   3,
#   2],
#  [3,
#   1283,
#   5294,
#   4439,
#   2765,
#   10317,
#   8,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   14210,
#   1007,
#   1463,
#   10,
#   1283,
#   5294,
#   3463,
#   6825,
#   6452,
#   7972,
#   20,
#   19312,
#   6452,
#   5650,
#   6789,
#   157,
#   19,
#   75,
#   12556,
#   2670,
#   7972,
#   20,
#   1551,
#   8160,
#   5650,
#   6789,
#   157,
#   19,
#   5,
#   1615,
#   363,
#   47877,
#   2615,
#   8,
#   3856,
#   810,
#   6,
#   405,
#   720,
#   2765,
#   2404,
#   8,
#   3100,
#   810,
#   4,
#   51,
#   35,
#   683,
#   2178,
#   15,
#   3449,
#   934,
#   1962,
#   20,
#   3680,
#   262,
#   32921,
#   19,
#   66,
#   720,
#   964,
#   810,
#   20,
#   358,
#   5650,
#   157,
#   19,
#   6,
#   5719,
#   720,
#   878,
#   2529,
#   208,
#   10716,
#   810,
#   5,
#   3,
#   2],
#  [3,
#   1737,
#   3978,
#   50,
#   10,
#   221,
#   328,
#   85,
#   8,
#   148,
#   3,
#   2,
#   3,
#   1737,
#   6458,
#   14252,
#   50,
#   11,
#   328,
#   8,
#   1737,
#   7749,
#   20,
#   12,
#   4,
#   1005,
#   23,
#   11,
#   328,
#   8,
#   1737,
#   6458,
#   7749,
#   31,
#   22,
#   6454,
#   1894,
#   1993,
#   9327,
#   4553,
#   11098,
#   22,
#   19,
#   4,
#   8,
#   16,
#   1005,
#   58,
#   2324,
#   385,
#   8249,
#   339,
#   25,
#   2765,
#   2652,
#   302,
#   835,
#   1696,
#   7657,
#   5,
#   1737,
#   10,
#   1283,
#   5294,
#   137,
#   445,
#   953,
#   5,
#   347,
#   1357,
#   4,
#   1005,
#   50,
#   10,
#   9,
#   221,
#   328,
#   8,
#   1005,
#   13388,
#   2583,
#   20,
#   90,
#   58,
#   10,
#   412,
#   656,
#   1373,
#   29,
#   19,
#   4,
#   1005,
#   2583,
#   2842,
#   20,
#   175,
#   24,
#   5207,
#   4766,
#   4006,
#   19,
#   4,
#   1005,
#   24193,
#   13957,
#   6,
#   8218,
#   13957,
#   20,
#   12,
#   790,
#   4267,
#   38195,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   5975,
#   15130,
#   8,
#   2697,
#   1889,
#   58,
#   4248,
#   118,
#   2324,
#   3,
#   2,
#   3,
#   1322,
#   4257,
#   159,
#   7,
#   569,
#   15130,
#   93,
#   8,
#   11565,
#   4,
#   6134,
#   42,
#   5408,
#   560,
#   325,
#   569,
#   142,
#   11,
#   240,
#   108,
#   25,
#   58,
#   2324,
#   2178,
#   89,
#   2975,
#   212,
#   235,
#   58,
#   4248,
#   1946,
#   262,
#   131,
#   10,
#   4623,
#   8,
#   73,
#   35364,
#   27375,
#   635,
#   37989,
#   5906,
#   4,
#   569,
#   61097,
#   1395,
#   4,
#   569,
#   4951,
#   103,
#   6,
#   6169,
#   7311,
#   8,
#   569,
#   3959,
#   26443,
#   42,
#   8,
#   73,
#   4257,
#   11044,
#   18109,
#   904,
#   31542,
#   7,
#   569,
#   15130,
#   93,
#   720,
#   48,
#   246,
#   15,
#   16,
#   515,
#   325,
#   569,
#   15130,
#   1560,
#   203,
#   569,
#   14157,
#   42,
#   569,
#   15130,
#   8978,
#   22231,
#   4,
#   569,
#   15130,
#   1898,
#   41317,
#   1384,
#   34976,
#   37272,
#   4,
#   13,
#   996,
#   231,
#   24,
#   5665,
#   9324,
#   3056,
#   378,
#   203,
#   653,
#   15,
#   73,
#   4257,
#   2529,
#   1465,
#   31536,
#   10557,
#   1322,
#   4257,
#   2037,
#   2697,
#   28,
#   6254,
#   10083,
#   39,
#   12840,
#   4894,
#   15,
#   569,
#   15130,
#   73,
#   13,
#   75,
#   3931,
#   14505,
#   103,
#   45,
#   2587,
#   223,
#   73,
#   676,
#   52530,
#   2008,
#   4,
#   6,
#   10,
#   4623,
#   1464,
#   479,
#   36,
#   325,
#   4174,
#   1387,
#   4,
#   2697,
#   1889,
#   10,
#   1659,
#   10615,
#   4,
#   1698,
#   15512,
#   1850,
#   4,
#   5109,
#   1850,
#   4,
#   16840,
#   1395,
#   4,
#   11142,
#   1347,
#   4,
#   6,
#   464,
#   26,
#   94,
#   2906,
#   44669,
#   27375,
#   10136,
#   203,
#   7,
#   569,
#   15130,
#   1898,
#   363,
#   676,
#   302,
#   286,
#   1783,
#   8,
#   4174,
#   1387,
#   4,
#   1236,
#   9479,
#   1384,
#   4,
#   1476,
#   22682,
#   1187,
#   4,
#   569,
#   6,
#   2697,
#   1889,
#   15903,
#   30428,
#   5,
#   5975,
#   15130,
#   3062,
#   54,
#   479,
#   5975,
#   43689,
#   4,
#   2697,
#   1889,
#   444,
#   1933,
#   58,
#   1701,
#   18020,
#   1187,
#   4,
#   6,
#   2697,
#   1889,
#   2956,
#   2906,
#   8,
#   2908,
#   203,
#   7,
#   569,
#   15130,
#   37653,
#   5,
#   1322,
#   676,
#   302,
#   203,
#   2697,
#   1889,
#   10,
#   5139,
#   43689,
#   4,
#   569,
#   6,
#   1698,
#   15512,
#   12584,
#   3,
#   2],
#  [3,
#   251,
#   10,
#   121,
#   298,
#   3056,
#   17,
#   11,
#   1140,
#   12,
#   6134,
#   351,
#   9,
#   24351,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   53,
#   939,
#   22366,
#   2199,
#   7833,
#   14,
#   11,
#   675,
#   32151,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   2284,
#   230,
#   33,
#   224,
#   1310,
#   25,
#   590,
#   1070,
#   18415,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   137,
#   139,
#   1425,
#   2477,
#   3,
#   2],
#  [3,
#   69,
#   25,
#   418,
#   1430,
#   1821,
#   1354,
#   311,
#   11,
#   5115,
#   14005,
#   53,
#   26,
#   1746,
#   401,
#   11,
#   328,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   26576,
#   2438,
#   22,
#   3,
#   2],
#  [3,
#   321,
#   277,
#   17,
#   551,
#   5941,
#   9393,
#   159,
#   13,
#   278,
#   96,
#   18302,
#   4115,
#   7,
#   222,
#   47441,
#   114,
#   3,
#   2,
#   3,
#   1706,
#   21177,
#   4,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   9,
#   69,
#   1302,
#   10210,
#   834,
#   462,
#   2925,
#   2177,
#   12,
#   3210,
#   22802,
#   2356,
#   6309,
#   1044,
#   22275,
#   770,
#   3787,
#   3288,
#   4055,
#   114,
#   3,
#   2,
#   3,
#   197,
#   760,
#   1294,
#   5268,
#   39,
#   69,
#   1302,
#   10210,
#   834,
#   24,
#   1073,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   462,
#   1914,
#   298,
#   127,
#   6937,
#   11,
#   5297,
#   320,
#   6,
#   5717,
#   8410,
#   12,
#   9,
#   993,
#   12836,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3855,
#   17651,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   217,
#   517,
#   620,
#   8,
#   993,
#   3489,
#   3705,
#   7564,
#   6,
#   2151,
#   4439,
#   159,
#   7,
#   302,
#   36951,
#   114,
#   3,
#   2,
#   3,
#   15351,
#   7621,
#   10030,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   35628,
#   856,
#   142,
#   150,
#   11,
#   1692,
#   4267,
#   9755,
#   6483,
#   413,
#   882,
#   3,
#   2,
#   3,
#   217,
#   18,
#   1875,
#   201,
#   6792,
#   59,
#   11,
#   7594,
#   49592,
#   1701,
#   4,
#   11,
#   1692,
#   718,
#   1740,
#   797,
#   34157,
#   4,
#   1981,
#   17173,
#   26389,
#   1395,
#   4,
#   9,
#   2665,
#   2025,
#   2079,
#   47,
#   586,
#   12538,
#   5255,
#   25,
#   69,
#   1709,
#   26427,
#   1395,
#   4,
#   125,
#   2220,
#   701,
#   221,
#   33,
#   614,
#   354,
#   2051,
#   71,
#   993,
#   836,
#   47203,
#   4,
#   47,
#   586,
#   28898,
#   4026,
#   19770,
#   23027,
#   5,
#   27126,
#   53077,
#   1187,
#   4,
#   1692,
#   4267,
#   9755,
#   6483,
#   50,
#   13,
#   16365,
#   2108,
#   1447,
#   9031,
#   2289,
#   12,
#   69,
#   1709,
#   26427,
#   21473,
#   783,
#   11,
#   5228,
#   4181,
#   5665,
#   8410,
#   47,
#   23106,
#   5,
#   4834,
#   4267,
#   6829,
#   1391,
#   1766,
#   11,
#   1742,
#   2054,
#   201,
#   1447,
#   9031,
#   273,
#   1875,
#   1551,
#   5511,
#   1447,
#   9031,
#   431,
#   22366,
#   50071,
#   10557,
#   1967,
#   790,
#   1692,
#   4267,
#   9755,
#   6483,
#   14157,
#   3012,
#   15584,
#   3012,
#   15165,
#   19,
#   1391,
#   1766,
#   11,
#   445,
#   2054,
#   201,
#   1447,
#   9031,
#   273,
#   1875,
#   24415,
#   1447,
#   9031,
#   426,
#   22366,
#   50071,
#   10557,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   4379,
#   3705,
#   1755,
#   34550,
#   724,
#   223,
#   9326,
#   3705,
#   50359,
#   9472,
#   3889,
#   11644,
#   114,
#   3,
#   2,
#   3,
#   53,
#   46377,
#   1118,
#   982,
#   8479,
#   4,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   44,
#   10,
#   579,
#   2665,
#   2652,
#   12,
#   29,
#   7806,
#   2686,
#   114,
#   3,
#   2,
#   3,
#   87,
#   286,
#   1645,
#   829,
#   58217,
#   2714,
#   4368,
#   25,
#   216,
#   553,
#   7,
#   179,
#   58,
#   14,
#   3931,
#   128,
#   53,
#   61,
#   10893,
#   1159,
#   7,
#   1058,
#   2856,
#   4006,
#   39,
#   16,
#   69,
#   1620,
#   59969,
#   1947,
#   33,
#   25479,
#   1701,
#   4,
#   3,
#   2],
#  [3,
#   350,
#   590,
#   3931,
#   1637,
#   3490,
#   2506,
#   3705,
#   33,
#   43,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   10658,
#   4436,
#   35291,
#   7,
#   792,
#   80,
#   4162,
#   1510,
#   3490,
#   3398,
#   3019,
#   11,
#   67,
#   5924,
#   2178,
#   89,
#   33,
#   43,
#   431,
#   78,
#   317,
#   29,
#   13652,
#   1546,
#   4,
#   53,
#   26,
#   305,
#   1522,
#   807,
#   611,
#   3931,
#   1637,
#   3490,
#   3398,
#   3019,
#   7,
#   58,
#   11918,
#   59763,
#   1517,
#   3074,
#   1093,
#   3698,
#   1645,
#   350,
#   10029,
#   4,
#   792,
#   80,
#   14,
#   1294,
#   2528,
#   3449,
#   1093,
#   80,
#   13,
#   996,
#   350,
#   590,
#   3931,
#   39451,
#   20330,
#   3,
#   2],
#  [3,
#   11598,
#   2958,
#   9534,
#   39,
#   4597,
#   204,
#   56825,
#   311,
#   11,
#   2906,
#   2608,
#   223,
#   22649,
#   12481,
#   21,
#   148,
#   50,
#   6365,
#   21931,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   302,
#   49965,
#   5603,
#   12481,
#   3,
#   2],
#  [3,
#   635,
#   126,
#   40865,
#   1672,
#   4,
#   337,
#   39,
#   29,
#   7806,
#   2326,
#   4,
#   11,
#   1746,
#   401,
#   11,
#   996,
#   24,
#   4578,
#   178,
#   16,
#   9393,
#   178,
#   53,
#   26,
#   167,
#   4422,
#   212,
#   2765,
#   26427,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   4917,
#   4,
#   3,
#   2],
#  [3, 1129, 1709, 4368, 166, 3936, 4368, 8, 1529, 10143, 114, 3, 2, 3, 3, 2],
#  [3,
#   12297,
#   21,
#   18,
#   2634,
#   13397,
#   4453,
#   430,
#   26254,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   460,
#   2615,
#   934,
#   31138,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   276,
#   11,
#   328,
#   8,
#   1117,
#   4189,
#   1347,
#   1302,
#   114,
#   3,
#   2,
#   3,
#   40223,
#   6108,
#   1384,
#   7809,
#   6,
#   3530,
#   1529,
#   13659,
#   3288,
#   2438,
#   4,
#   3,
#   2],
#  [3,
#   98,
#   8,
#   148,
#   8524,
#   57241,
#   1595,
#   339,
#   12103,
#   114,
#   3,
#   2,
#   3,
#   98,
#   4989,
#   6190,
#   2302,
#   3,
#   2],
#  [3,
#   2537,
#   2697,
#   148,
#   2906,
#   2608,
#   21,
#   148,
#   459,
#   675,
#   452,
#   187,
#   40047,
#   114,
#   3,
#   2,
#   3,
# ...
#   148,
#   4770,
#   3884,
#   11,
#   5717,
#   8410,
#   12,
#   4770,
#   2528,
#   24675,
#   140,
#   40,
#   30939,
#   8325,
#   10695,
#   1926,
#   30939,
#   114,
#   3,
#   2,
#   3,
#   2440,
#   3,
#   2],
#  [3,
#   22540,
#   5520,
#   142,
#   934,
#   1759,
#   34037,
#   7304,
#   3104,
#   30143,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   4988,
#   1347,
#   9052,
#   3,
#   2],
#  [3,
#   829,
#   61,
#   148,
#   2792,
#   525,
#   14,
#   11,
#   111,
#   33,
#   24,
#   47,
#   6220,
#   939,
#   50350,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   7,
#   3490,
#   7765,
#   3019,
#   9336,
#   181,
#   829,
#   3,
#   2],
#  [3,
#   35039,
#   8,
#   2902,
#   645,
#   7,
#   49,
#   12504,
#   1637,
#   28,
#   21,
#   148,
#   82,
#   316,
#   2608,
#   30428,
#   114,
#   3,
#   2,
#   3,
#   33870,
#   28565,
#   4082,
#   2455,
#   27680,
#   4,
#   3,
#   2],
#  [3,
#   962,
#   15,
#   24942,
#   6,
#   11595,
#   10515,
#   1197,
#   6,
#   8706,
#   17522,
#   6117,
#   10548,
#   4,
#   21,
#   148,
#   642,
#   423,
#   1073,
#   2106,
#   2528,
#   380,
#   12,
#   9,
#   215,
#   266,
#   57845,
#   114,
#   3,
#   2,
#   3,
#   5402,
#   3,
#   2],
#  [3,
#   14,
#   69,
#   4439,
#   12541,
#   222,
#   38454,
#   29179,
#   10,
#   148,
#   24,
#   96,
#   28,
#   930,
#   441,
#   2697,
#   27979,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   17,
#   108,
#   5408,
#   658,
#   184,
#   148,
#   3,
#   2],
#  [3,
#   2603,
#   1981,
#   2308,
#   129,
#   3532,
#   7,
#   1597,
#   2654,
#   8,
#   277,
#   3,
#   2,
#   3,
#   15607,
#   7221,
#   45888,
#   20,
#   10411,
#   34168,
#   23784,
#   1913,
#   26075,
#   53954,
#   7221,
#   45888,
#   4,
#   918,
#   1626,
#   22,
#   3490,
#   2506,
#   9,
#   5116,
#   9031,
#   13150,
#   506,
#   2935,
#   4957,
#   22,
#   19,
#   8,
#   5255,
#   11050,
#   64,
#   3532,
#   853,
#   9031,
#   983,
#   355,
#   7,
#   1597,
#   2654,
#   91,
#   12629,
#   11087,
#   6,
#   45107,
#   2949,
#   5128,
#   34595,
#   414,
#   127,
#   5717,
#   8410,
#   24,
#   369,
#   2226,
#   2607,
#   807,
#   5897,
#   22,
#   30737,
#   3033,
#   1565,
#   2292,
#   8038,
#   22,
#   33,
#   29,
#   5740,
#   5,
#   3,
#   2],
#  [3,
#   2603,
#   4770,
#   3884,
#   3335,
#   2151,
#   4439,
#   7,
#   350,
#   590,
#   29,
#   484,
#   8,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   1678,
#   104,
#   1118,
#   31081,
#   3594,
#   15033,
#   4,
#   2822,
#   201,
#   317,
#   27,
#   31,
#   7412,
#   829,
#   1678,
#   4598,
#   1118,
#   31081,
#   3594,
#   15033,
#   484,
#   38,
#   11,
#   13884,
#   437,
#   682,
#   302,
#   18,
#   585,
#   548,
#   1449,
#   13,
#   5522,
#   586,
#   790,
#   751,
#   3705,
#   7564,
#   35,
#   350,
#   590,
#   29,
#   484,
#   20,
#   1678,
#   10681,
#   37385,
#   32206,
#   484,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   962,
#   189,
#   142,
#   36,
#   325,
#   2126,
#   4453,
#   30428,
#   114,
#   3,
#   2,
#   3,
#   16,
#   109,
#   620,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   2528,
#   26255,
#   1231,
#   5855,
#   537,
#   127,
#   25,
#   2935,
#   7620,
#   114,
#   3,
#   2,
#   3,
#   2617,
#   504,
#   8383,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   298,
#   740,
#   7,
#   9527,
#   3679,
#   15447,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   13279,
#   4402,
#   21225,
#   3,
#   2],
#  [3,
#   3382,
#   16297,
#   2500,
#   2126,
#   11,
#   320,
#   221,
#   42,
#   702,
#   90,
#   21,
#   148,
#   2657,
#   2665,
#   30,
#   3382,
#   16297,
#   14681,
#   7,
#   69,
#   57774,
#   114,
#   3,
#   2,
#   3,
#   412,
#   795,
#   1834,
#   7,
#   1231,
#   4578,
#   2025,
#   1231,
#   3,
#   2],
#  [3,
#   581,
#   182,
#   1597,
#   2654,
#   101,
#   1030,
#   21,
#   148,
#   231,
#   10,
#   255,
#   675,
#   4422,
#   24,
#   12,
#   82,
#   29,
#   27313,
#   2029,
#   4339,
#   196,
#   15613,
#   27518,
#   114,
#   3,
#   2,
#   3,
#   128,
#   100,
#   525,
#   19356,
#   1881,
#   4,
#   558,
#   33040,
#   4,
#   6,
#   25374,
#   5377,
#   1430,
#   4578,
#   178,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   9,
#   490,
#   1731,
#   537,
#   127,
#   2734,
#   1347,
#   15250,
#   1581,
#   114,
#   3,
#   2,
#   3,
#   7618,
#   1366,
#   29,
#   55427,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   2675,
#   106,
#   1073,
#   2537,
#   33,
#   29,
#   6549,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   19236,
#   3,
#   2],
#  [3,
#   17,
#   51899,
#   9531,
#   2667,
#   3173,
#   4366,
#   104,
#   1645,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   343,
#   26728,
#   6281,
#   1384,
#   30939,
#   19,
#   3,
#   2],
#  [3,
#   22012,
#   8825,
#   1894,
#   8919,
#   2029,
#   2380,
#   18411,
#   11963,
#   7645,
#   2356,
#   104,
#   657,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2780,
#   9031,
#   3,
#   2],
#  [3, 2679, 8, 18, 298, 740, 3877, 3, 2, 3, 19793, 2573, 44149, 3, 2],
#  [3,
#   4834,
#   4365,
#   383,
#   40,
#   57,
#   240,
#   109,
#   1098,
#   58,
#   3,
#   2,
#   3,
#   1266,
#   129,
#   67,
#   8,
#   57,
#   121,
#   105,
#   20999,
#   1347,
#   4,
#   790,
#   4365,
#   4453,
#   430,
#   13,
#   3488,
#   109,
#   1570,
#   810,
#   39,
#   253,
#   383,
#   3250,
#   317,
#   232,
#   337,
#   94,
#   790,
#   4365,
#   56569,
#   5,
#   1584,
#   826,
#   137,
#   17477,
#   31,
#   26936,
#   80,
#   205,
#   20999,
#   1347,
#   4,
#   32463,
#   1231,
#   538,
#   13778,
#   5,
#   3,
#   2],
#  [3,
#   16,
#   4547,
#   11536,
#   28,
#   16,
#   61,
#   2379,
#   1391,
#   1766,
#   586,
#   6304,
#   14087,
#   3936,
#   4368,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2123,
#   1596,
#   3,
#   2],
#  [3,
#   11554,
#   656,
#   4444,
#   3198,
#   19661,
#   7,
#   2679,
#   1070,
#   4581,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   5301,
#   3198,
#   37367,
#   1581,
#   1581,
#   1850,
#   4,
#   3,
#   2],
#  [3,
#   221,
#   1529,
#   10143,
#   4,
#   145,
#   362,
#   44134,
#   29556,
#   1236,
#   4,
#   11,
#   5717,
#   8410,
#   13,
#   9,
#   230,
#   7,
#   16,
#   323,
#   128,
#   676,
#   302,
#   740,
#   33,
#   127,
#   303,
#   418,
#   54913,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   18783,
#   57501,
#   3,
#   2],
#  [3,
#   217,
#   166,
#   1898,
#   4229,
#   88,
#   115,
#   41,
#   4229,
#   2536,
#   12,
#   16,
#   6757,
#   924,
#   114,
#   3,
#   2,
#   3,
#   3631,
#   27043,
#   56784,
#   54031,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   6254,
#   11297,
#   16,
#   100,
#   215,
#   3531,
#   24,
#   548,
#   720,
#   8271,
#   47684,
#   4,
#   128,
#   13458,
#   2057,
#   13749,
#   6,
#   690,
#   2680,
#   379,
#   36,
#   31536,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   3053,
#   3,
#   2],
#  [3,
#   217,
#   148,
#   14,
#   13143,
#   1354,
#   7,
#   4567,
#   3931,
#   6933,
#   10413,
#   1966,
#   537,
#   127,
#   29,
#   2617,
#   1625,
#   2326,
#   114,
#   3,
#   2,
#   3,
#   38945,
#   1706,
#   3,
#   2],
#  [3,
#   186,
#   7235,
#   230,
#   877,
#   21,
#   148,
#   459,
#   369,
#   11,
#   1941,
#   666,
#   35,
#   16,
#   222,
#   418,
#   459,
#   352,
#   28979,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   4867,
#   3,
#   2],
#  [3,
#   503,
#   1766,
#   7038,
#   42,
#   300,
#   301,
#   1690,
#   1914,
#   298,
#   10,
#   4623,
#   1820,
#   181,
#   5089,
#   917,
#   2067,
#   298,
#   6,
#   54990,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   11919,
#   5298,
#   11015,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   1400,
#   7,
#   8978,
#   6267,
#   8,
#   25,
#   216,
#   553,
#   20378,
#   2545,
#   3377,
#   4,
#   5024,
#   4145,
#   32032,
#   114,
#   3,
#   2,
#   3,
#   40902,
#   6,
#   49198,
#   3,
#   2],
#  [3,
#   5228,
#   2919,
#   21,
#   148,
#   14,
#   2665,
#   2652,
#   30,
#   49,
#   335,
#   44,
#   9,
#   3705,
#   3931,
#   963,
#   14833,
#   1607,
#   23277,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   3126,
#   5228,
#   2919,
#   3,
#   2],
#  [3,
#   5076,
#   462,
#   12,
#   574,
#   917,
#   2068,
#   3010,
#   1073,
#   2106,
#   14,
#   41,
#   1289,
#   89,
#   21,
#   148,
#   166,
#   302,
#   58481,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   16,
#   9731,
#   42928,
#   21523,
#   1993,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   43,
#   53,
#   26,
#   11,
#   1083,
#   357,
#   56138,
#   2079,
#   9441,
#   14,
#   675,
#   1201,
#   42338,
#   4,
#   46,
#   38,
#   917,
#   9170,
#   19828,
#   16809,
#   114,
#   3,
#   2,
#   3,
#   4696,
#   3,
#   2],
#  [3,
#   4106,
#   215,
#   9707,
#   142,
#   9,
#   4368,
#   5214,
#   18,
#   2178,
#   89,
#   33,
#   78,
#   426,
#   813,
#   187,
#   40047,
#   114,
#   3,
#   2,
#   3,
#   406,
#   2119,
#   4,
#   3,
#   2],
#  [3,
#   2003,
#   2240,
#   55328,
#   197,
#   151,
#   128,
#   72,
#   12,
#   21,
#   29,
#   38937,
#   114,
#   3,
#   2,
#   3,
#   128,
#   3,
#   2],
#  [3,
#   30992,
#   11,
#   1073,
#   2537,
#   127,
#   6937,
#   35,
#   350,
#   590,
#   29,
#   142,
#   3,
#   2,
#   3,
#   41461,
#   5353,
#   2726,
#   2491,
#   696,
#   113,
#   1030,
#   1030,
#   18,
#   305,
#   33,
#   29,
#   1105,
#   510,
#   373,
#   1600,
#   56303,
#   266,
#   462,
#   284,
#   22,
#   27154,
#   1791,
#   10423,
#   22,
#   20,
#   18660,
#   53664,
#   19,
#   5,
#   434,
#   813,
#   4,
#   834,
#   266,
#   4338,
#   127,
#   6937,
#   28,
#   30992,
#   14,
#   11,
#   40,
#   641,
#   15,
#   221,
#   328,
#   22,
#   22,
#   5,
#   382,
#   350,
#   590,
#   9,
#   215,
#   266,
#   11,
#   2528,
#   380,
#   101,
#   127,
#   280,
#   1465,
#   9,
#   834,
#   4264,
#   363,
#   4,
#   380,
#   35,
#   14,
#   10,
#   1120,
#   215,
#   266,
#   363,
#   11,
#   1073,
#   1575,
#   34,
#   1906,
#   819,
#   337,
#   39,
#   43,
#   317,
#   78,
#   445,
#   29,
#   1056,
#   20,
#   1421,
#   13511,
#   107,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   1893,
#   5207,
#   142,
#   14,
#   18427,
#   37024,
#   1073,
#   2537,
#   33,
#   29,
#   8878,
#   1854,
#   114,
#   3,
#   2,
#   3,
#   15904,
#   8468,
#   39560,
#   36099,
#   17668,
#   3,
#   2],
#  [3,
#   6364,
#   15111,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   1624,
#   1340,
#   11095,
#   1517,
#   1016,
#   570,
#   64,
#   22986,
#   23651,
#   61,
#   85,
#   7311,
#   28,
#   3448,
#   139,
#   147,
#   1007,
#   24210,
#   1395,
#   4,
#   1219,
#   20405,
#   1301,
#   4,
#   2901,
#   3019,
#   6,
#   9,
#   1362,
#   1889,
#   3,
#   2],
#  [3,
#   45996,
#   1384,
#   4,
#   9,
#   41342,
#   362,
#   28,
#   618,
#   42017,
#   1301,
#   4,
#   6,
#   6169,
#   192,
#   569,
#   1362,
#   38269,
#   5298,
#   13,
#   18,
#   85,
#   8,
#   21,
#   302,
#   230,
#   7,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   385,
#   95,
#   2104,
#   3,
#   2],
#  [3,
#   18,
#   142,
#   8,
#   2185,
#   286,
#   26865,
#   380,
#   136,
#   7,
#   1832,
#   5631,
#   3,
#   2,
#   3,
#   168,
#   8,
#   268,
#   8302,
#   6488,
#   406,
#   8513,
#   2546,
#   98,
#   1832,
#   5631,
#   98,
#   1832,
#   5631,
#   4,
#   34128,
#   1430,
#   34128,
#   718,
#   2965,
#   1738,
#   4,
#   10969,
#   9970,
#   4,
#   1479,
#   9642,
#   4,
#   7056,
#   9642,
#   6,
#   4154,
#   80,
#   7,
#   3019,
#   1093,
#   5,
#   3,
#   2],
#  [3,
#   8271,
#   2477,
#   9,
#   1362,
#   3011,
#   8415,
#   3040,
#   6571,
#   1664,
#   96,
#   24,
#   1820,
#   181,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   455,
#   376,
#   10417,
#   44004,
#   1701,
#   22,
#   3,
#   2],
#  [3,
#   7751,
#   1430,
#   1816,
#   39572,
#   4916,
#   32739,
#   4826,
#   2753,
#   1302,
#   17355,
#   418,
#   29,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   39572,
#   4916,
#   32739,
#   19062,
#   3636,
#   23299,
#   4826,
#   2753,
#   1302,
#   17355,
#   14157,
#   65,
#   418,
#   43,
#   1443,
#   78,
#   3160,
#   29,
#   8878,
#   2326,
#   19,
#   8,
#   229,
#   34946,
#   1301,
#   4,
#   18,
#   585,
#   1709,
#   2507,
#   1166,
#   35235,
#   21473,
#   619,
#   8,
#   229,
#   1430,
#   1964,
#   493,
#   7,
#   21150,
#   107,
#   14157,
#   1709,
#   8595,
#   15831,
#   619,
#   11,
#   55,
#   30,
#   89,
#   36,
#   215,
#   266,
#   19868,
#   27,
#   11630,
#   163,
#   732,
#   1714,
#   7,
#   778,
#   14157,
#   7806,
#   2686,
#   37272,
#   4,
#   619,
#   171,
#   49,
#   463,
#   413,
#   14157,
#   7806,
#   2326,
#   37272,
#   4,
#   1383,
#   8201,
#   939,
#   413,
#   14157,
#   7806,
#   2147,
#   37272,
#   4,
#   5927,
#   9513,
#   89,
#   289,
#   14157,
#   7806,
#   1765,
#   37272,
#   4,
#   251,
#   18,
#   1824,
#   46,
#   413,
#   14157,
#   7806,
#   39459,
#   6,
#   13698,
#   5855,
#   7,
#   1142,
#   6536,
#   11018,
#   14157,
#   7806,
#   51627,
#   3,
#   2],
#  [3,
#   2120,
#   148,
#   262,
#   142,
#   9,
#   80,
#   9534,
#   4436,
#   2608,
#   788,
#   675,
#   18,
#   3305,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   1603,
#   6028,
#   3,
#   2],
#  [3,
#   1579,
#   1487,
#   2952,
#   21,
#   148,
#   2153,
#   7102,
#   7,
#   58,
#   11314,
#   8,
#   110,
#   34550,
#   8536,
#   3593,
#   36841,
#   1231,
#   16,
#   1389,
#   25349,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   16989,
#   770,
#   3787,
#   1487,
#   6107,
#   7,
#   16,
#   110,
#   34550,
#   8536,
#   25329,
#   11644,
#   450,
#   930,
#   5603,
#   7,
#   10694,
#   18987,
#   3,
#   2],
#  [3,
#   2515,
#   378,
#   2765,
#   2404,
#   78,
#   4889,
#   82,
#   7,
#   22437,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   978,
#   3,
#   2],
#  [3,
#   5470,
#   1696,
#   11,
#   1251,
#   2289,
#   29,
#   142,
#   3,
#   2,
#   3,
#   347,
#   37,
#   4,
#   5470,
#   1696,
#   1251,
#   121,
#   3362,
#   20070,
#   4,
#   11575,
#   961,
#   1529,
#   16720,
#   4,
#   1568,
#   1251,
#   33,
#   790,
#   4267,
#   9755,
#   6483,
#   20,
#   3012,
#   15584,
#   3012,
#   6268,
#   19,
#   5,
#   635,
#   1568,
#   1696,
#   50,
#   3230,
#   300,
#   36,
#   380,
#   1889,
#   862,
#   121,
#   4993,
#   42,
#   2838,
#   2263,
#   4,
#   1347,
#   20420,
#   4,
#   3844,
#   4,
#   28493,
#   4623,
#   380,
#   61,
#   3936,
#   2097,
#   6,
#   14119,
#   4148,
#   7,
#   18,
#   9235,
#   1696,
#   1710,
#   8123,
#   908,
#   2389,
#   1357,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   302,
#   675,
#   6933,
#   7811,
#   4942,
#   1493,
#   114,
#   3,
#   2,
#   3,
#   73,
#   443,
#   46,
#   8919,
#   5779,
#   3,
#   2],
#  [3,
#   3880,
#   5076,
#   764,
#   83,
#   13397,
#   561,
#   11,
#   248,
#   1740,
#   148,
#   3,
#   2,
#   3,
#   3880,
#   561,
#   248,
#   22,
#   8763,
#   3330,
#   11196,
#   22,
#   35,
#   3490,
#   33101,
#   266,
#   350,
#   590,
#   101,
#   129,
#   613,
#   6,
#   22,
#   1982,
#   1740,
#   103,
#   7,
#   718,
#   13466,
#   17860,
#   22,
#   35,
#   5,
#   3,
#   2],
#  [3,
#   1203,
#   21,
#   148,
#   316,
#   5191,
#   14,
#   2958,
#   1340,
#   11095,
#   1517,
#   3033,
#   14896,
#   548,
#   1698,
#   22095,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3080,
#   2615,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   316,
#   5191,
#   145,
#   12,
#   6117,
#   13724,
#   1749,
#   8251,
#   189,
#   320,
#   558,
#   286,
#   16,
#   12,
#   21,
#   215,
#   1302,
#   10210,
#   834,
#   103,
#   67,
#   570,
#   681,
#   7,
#   389,
#   2482,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   23355,
#   20818,
#   40995,
#   40214,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   6744,
#   2326,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   21,
#   148,
#   3010,
#   1073,
#   2106,
#   1073,
#   1575,
#   9699,
#   30036,
#   173,
#   5887,
#   39349,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   1977,
#   15824,
#   7888,
#   19474,
#   3,
#   2],
#  [3,
#   1004,
#   5955,
#   5024,
#   1791,
#   4,
#   13980,
#   50,
#   10,
#   2183,
#   4568,
#   142,
#   3,
#   2,
#   3,
#   168,
#   418,
#   40,
#   6,
#   103,
#   72,
#   25,
#   5955,
#   5024,
#   1791,
#   4,
#   55842,
#   4104,
#   12584,
#   3,
#   2],
#  [3,
#   11654,
#   5294,
#   58,
#   2369,
#   103,
#   129,
#   849,
#   34,
#   570,
#   681,
#   3,
#   2,
#   3,
#   251,
#   11,
#   774,
#   8,
#   6103,
#   4439,
#   54,
#   2935,
#   8311,
#   187,
#   166,
#   239,
#   129,
#   76,
#   570,
#   681,
#   28,
#   1283,
#   5294,
#   4,
#   33,
#   137,
#   5334,
#   9593,
#   7972,
#   4,
#   6,
#   66,
#   103,
#   48,
#   2369,
#   5,
#   6380,
#   28,
#   452,
#   100,
#   54,
#   231,
#   8,
#   6103,
#   4439,
#   1666,
#   129,
#   163,
#   53,
#   2935,
#   5946,
#   4,
#   2935,
#   93,
#   6,
#   2935,
#   4957,
#   5,
#   3,
#   2],
#  [3,
#   14,
#   59119,
#   1301,
#   3206,
#   5761,
#   21,
#   148,
#   26,
#   47,
#   49,
#   34,
#   7594,
#   2792,
#   525,
#   17437,
#   114,
#   3,
#   2,
#   3,
#   3258,
#   645,
#   7,
#   16,
#   212,
#   588,
#   76,
#   10,
#   1041,
#   525,
#   3634,
#   56284,
#   4,
#   3,
#   2],
#  [3,
#   1650,
#   142,
#   20999,
#   1395,
#   4,
#   145,
#   362,
#   27366,
#   4,
#   8,
#   16,
#   12,
#   82,
#   226,
#   1084,
#   3705,
#   3931,
#   700,
#   733,
#   67,
#   12,
#   301,
#   15673,
#   114,
#   3,
#   2,
#   3,
#   31897,
#   12868,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   4396,
#   40468,
#   9553,
#   6020,
#   111,
#   2610,
#   114,
#   3,
#   2,
#   3,
#   43,
#   431,
#   78,
#   445,
#   29,
#   2456,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   47,
#   21,
#   526,
#   1087,
#   906,
#   1361,
#   6361,
#   3198,
#   2302,
#   32906,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   69,
#   1612,
#   55613,
#   1517,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   11,
#   1832,
#   45970,
#   23277,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   78,
#   210,
#   29,
#   7671,
#   3,
#   2],
#  [3,
#   319,
#   40565,
#   3269,
#   1527,
#   4379,
#   2416,
#   29,
#   11,
#   1391,
#   1766,
#   25,
#   602,
#   3,
#   2,
#   3,
#   10137,
#   45110,
#   4,
#   440,
#   3269,
#   1766,
#   40565,
#   3269,
#   1527,
#   4379,
#   31,
#   2220,
#   1093,
#   5577,
#   1527,
#   29,
#   484,
#   1391,
#   1766,
#   12155,
#   33048,
#   1713,
#   1934,
#   15250,
#   2008,
#   4,
#   380,
#   1889,
#   91,
#   80,
#   9310,
#   94,
#   58,
#   1820,
#   1447,
#   5577,
#   39038,
#   10838,
#   3,
#   2],
#  [3,
#   1391,
#   1766,
#   148,
#   17,
#   240,
#   108,
#   121,
#   3011,
#   13,
#   108,
#   10842,
#   50656,
#   14,
#   43451,
#   18075,
#   2150,
#   1009,
#   1007,
#   24210,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   3269,
#   1766,
#   8517,
#   9967,
#   3019,
#   7564,
#   3,
#   2],
#  [3,
#   404,
#   189,
#   142,
#   1145,
#   1189,
#   2515,
#   23523,
#   4453,
#   430,
#   39,
#   9755,
#   20331,
#   114,
#   3,
#   2,
#   3,
#   1597,
#   2654,
#   3,
#   2],
#  [3,
#   2679,
#   320,
#   3309,
#   2475,
#   351,
#   13,
#   61,
#   498,
#   8329,
#   7,
#   6222,
#   1252,
#   6,
#   61,
#   380,
#   1283,
#   7,
#   9013,
#   6519,
#   12,
#   790,
#   3258,
#   139,
#   289,
#   17186,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   28833,
#   3,
#   2],
#  [3,
#   2653,
#   139,
#   37,
#   221,
#   8,
#   179,
#   58,
#   11,
#   328,
#   8,
#   223,
#   6134,
#   351,
#   9,
#   58,
#   96,
#   355,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   37772,
#   4694,
#   917,
#   9170,
#   11,
#   5717,
#   8410,
#   121,
#   355,
#   157,
#   223,
#   9,
#   159,
#   2149,
#   7,
#   36,
#   3705,
#   25837,
#   4,
#   667,
#   2559,
#   42,
#   18565,
#   1395,
#   4,
#   2134,
#   6,
#   4379,
#   3705,
#   157,
#   3,
#   2],
#  [3,
#   2679,
#   682,
#   302,
#   698,
#   1981,
#   2308,
#   15571,
#   33,
#   29,
#   14845,
#   2147,
#   114,
#   3,
#   2,
#   3,
#   43078,
#   12110,
#   4380,
#   50535,
#   28406,
#   3,
#   2],
#  [3,
#   6933,
#   1206,
#   1709,
#   72,
#   642,
#   26,
#   1464,
#   26567,
#   126,
#   3,
#   2,
#   3,
#   434,
#   1556,
#   3020,
#   982,
#   8479,
#   4,
#   11414,
#   20623,
#   1387,
#   13170,
#   1187,
#   4,
#   46,
#   25,
#   642,
#   210,
#   46105,
#   4,
#   17,
#   297,
#   1464,
#   26567,
#   57246,
#   27375,
#   1322,
#   8,
#   11414,
#   3344,
#   12350,
#   72,
#   46226,
#   27375,
#   3,
#   2],
#  ...]

# %%
## thử sau
MAX_LEN = 145

train_ids = pad_sequences(train_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")
val_ids = pad_sequences(val_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
train_masks = []
for sent in train_ids:
    mask = [int(token_id > 0) for token_id in sent]
    train_masks.append(mask)

val_masks = []
for sent in val_ids:
    mask = [int(token_id > 0) for token_id in sent]

    val_masks.append(mask)

# %% [markdown]
# # **Model**
# Transformers của Hugging Face

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import torch
train_inputs = torch.tensor(train_ids)
val_inputs = torch.tensor(val_ids)
train_labels = torch.tensor(train_labels)
val_labels = torch.tensor(val_labels)
train_masks = torch.tensor(train_masks)
val_masks = torch.tensor(val_masks)

train_data = TensorDataset(train_inputs, train_masks, train_labels)
#train_data = TensorDataset(train_inputs, train_labels)
train_sampler = SequentialSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=32)

val_data = TensorDataset(val_inputs, val_masks, val_labels)
#val_data = TensorDataset(val_inputs, val_labels)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=32)

# %%
from transformers import RobertaForSequenceClassification, RobertaConfig, AdamW

config = RobertaConfig.from_pretrained(
    "/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/config.json", from_tf=False, num_labels = 2, output_hidden_states=False,
)
BERT_SA = RobertaForSequenceClassification.from_pretrained(
    "/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin",
    config=config
)
# Out:
# Some weights of the model checkpoint at /content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at /content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
BERT_SA.cuda()
print('Done')
# Out:
# Done

# %%
import numpy as np
from sklearn.metrics import f1_score, accuracy_score

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    
    F1_score = f1_score(pred_flat, labels_flat, average='macro')
    
    return accuracy_score(pred_flat, labels_flat), F1_score

# %%
import random
from tqdm import tqdm_notebook
device = 'cuda'
epochs = 10

param_optimizer = list(BERT_SA.named_parameters())
no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]

optimizer = AdamW(optimizer_grouped_parameters, lr=1e-5, correct_bias=False)


for epoch_i in range(0, epochs):
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    total_loss = 0
    BERT_SA.train()
    train_accuracy = 0
    nb_train_steps = 0
    train_f1 = 0
    
    for step, batch in tqdm_notebook(enumerate(train_dataloader)):
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        BERT_SA.zero_grad()
        outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask, 
            labels=b_labels)
        loss = outputs[0]
        total_loss += loss.item()
        
        logits = outputs[1].detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        tmp_train_accuracy, tmp_train_f1 = flat_accuracy(logits, label_ids)
        train_accuracy += tmp_train_accuracy
        train_f1 += tmp_train_f1
        nb_train_steps += 1
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(BERT_SA.parameters(), 1.0)
        optimizer.step()
        
    avg_train_loss = total_loss / len(train_dataloader)
    print(" Accuracy: {0:.4f}".format(train_accuracy/nb_train_steps))
    print(" F1 score: {0:.4f}".format(train_f1/nb_train_steps))
    print(" Average training loss: {0:.4f}".format(avg_train_loss))

    print("Running Validation...")
    BERT_SA.eval()
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    eval_f1 = 0
    for batch in tqdm_notebook(val_dataloader):

        batch = tuple(t.to(device) for t in batch)

        b_input_ids, b_input_mask, b_labels = batch

        with torch.no_grad():
            outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask)
            logits = outputs[0]
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            tmp_eval_accuracy, tmp_eval_f1 = flat_accuracy(logits, label_ids)

            eval_accuracy += tmp_eval_accuracy
            eval_f1 += tmp_eval_f1
            nb_eval_steps += 1
    print(" Accuracy: {0:.4f}".format(eval_accuracy/nb_eval_steps))
    print(" F1 score: {0:.4f}".format(eval_f1/nb_eval_steps))
print("Training complete!")
# Out:
# ======== Epoch 1 / 10 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9573
#  F1 score: 0.7484
#  Average training loss: 0.0950
# Running Validation...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9651
#  F1 score: 0.8193
# ======== Epoch 2 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9755
#  F1 score: 0.8669
#  Average training loss: 0.0646
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9645
#  F1 score: 0.8308
# ======== Epoch 3 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9837
#  F1 score: 0.9134
#  Average training loss: 0.0483
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9640
#  F1 score: 0.8390
# ======== Epoch 4 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9890
#  F1 score: 0.9435
#  Average training loss: 0.0371
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9672
#  F1 score: 0.8338
# ======== Epoch 5 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9922
#  F1 score: 0.9595
#  Average training loss: 0.0281
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9669
#  F1 score: 0.8423
# ======== Epoch 6 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9941
#  F1 score: 0.9693
#  Average training loss: 0.0224
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9689
#  F1 score: 0.8413
# ======== Epoch 7 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9952
#  F1 score: 0.9761
#  Average training loss: 0.0187
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9686
#  F1 score: 0.8436
# ======== Epoch 8 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9964
#  F1 score: 0.9803
#  Average training loss: 0.0148
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9659
#  F1 score: 0.8358
# ======== Epoch 9 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9964
#  F1 score: 0.9818
#  Average training loss: 0.0144
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9694
#  F1 score: 0.8479
# ======== Epoch 10 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9973
#  F1 score: 0.9852
#  Average training loss: 0.0119
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9624
#  F1 score: 0.8346
# Training complete!

# %%
BERT_SA.save("QA.h5")

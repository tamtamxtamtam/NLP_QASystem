# %% [markdown]
# <a href="https://colab.research.google.com/github/tamtamxtamtam/NLP_QASystem/blob/main/QA_btl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.chdir('/content/drive/My Drive/Zalo Challenge/2019')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # **Import folder + Install package**
#
#
# *   transfrormers
# *   fastBPE
# *   FAIRSeq

# %%
pwd
# Out:
# '/content/drive/My Drive/Zalo Challenge/2019'

# %%
# !nvidia-smi
# Out:
# Wed Nov 25 03:35:30 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/3a/83/e74092e7f24a08d751aa59b37a9fc572b2e4af3918cb66f7766c3affb1b4/transformers-3.5.1-py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 29.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Collecting sentencepiece==0.1.91
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 46.7MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from transformers) (3.12.4)
# Collecting tokenizers==0.9.3
#   Downloading https://files.pythonhosted.org/packages/4c/34/b39eb9994bc3c999270b69c9eea40ecc6f0e97991dba28282b9fd32d44ee/tokenizers-0.9.3-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 44.7MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 51.0MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->transformers) (50.3.2)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=6171101117f43b0a05d17d60ab891664e2015162b7ab70f23fb10c127d991233
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.9.3 transformers-3.5.1

# %%
# !pip install fastBPE
# !pip install fairseq
# Out:
# Collecting fastBPE
#   Downloading https://files.pythonhosted.org/packages/e1/37/f97181428a5d151501b90b2cebedf97c81b034ace753606a3cda5ad4e6e2/fastBPE-0.1.0.tar.gz
# Building wheels for collected packages: fastBPE
#   Building wheel for fastBPE (setup.py) ... done
#   Created wheel for fastBPE: filename=fastBPE-0.1.0-cp36-cp36m-linux_x86_64.whl size=481505 sha256=1b73f617b4ba2b7106c172945692b638e43173de2386aa139f0b7bb5ea9ec709
#   Stored in directory: /root/.cache/pip/wheels/f3/0c/9c/fc62058b4d473a5602bcd3d3edfece796f123875379ea82d79
# Successfully built fastBPE
# Installing collected packages: fastBPE
# Successfully installed fastBPE-0.1.0
# Collecting fairseq
#   Downloading https://files.pythonhosted.org/packages/2c/da/7c7032988dade3b21ccfd5b226e50b382abfd3459129d67240bb004506ae/fairseq-0.10.1-cp36-cp36m-manylinux1_x86_64.whl (1.7MB)
#      |████████████████████████████████| 1.7MB 12.4MB/s
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.8)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.41.1)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.7.0+cu101)
# Collecting hydra-core
#   Downloading https://files.pythonhosted.org/packages/f0/1f/7f502b9e37596164111655861370b08626f46f9e4524433c354f472765d4/hydra_core-1.0.4-py3-none-any.whl (122kB)
#      |████████████████████████████████| 122kB 52.9MB/s
# Collecting sacrebleu>=1.4.12
#   Downloading https://files.pythonhosted.org/packages/a3/c4/8e948f601a4f9609e8b2b58f31966cb13cf17b940b82aa3e767f01c42c52/sacrebleu-1.4.14-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (0.16.0)
# Collecting antlr4-python3-runtime==4.8
#   Downloading https://files.pythonhosted.org/packages/56/02/789a0bddf9c9b31b14c3e79ec22b9656185a803dc31c15f006f9855ece0d/antlr4-python3-runtime-4.8.tar.gz (112kB)
#      |████████████████████████████████| 112kB 3.2MB/s
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from hydra-core->fairseq) (3.3.0)
# Collecting omegaconf>=2.0.5
#   Downloading https://files.pythonhosted.org/packages/e5/f6/043b6d255dd6fbf2025110cea35b87f4c5100a181681d8eab496269f0d5b/omegaconf-2.0.5-py3-none-any.whl
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/89/a6/3814b7107e0788040870e8825eebf214d72166adf656ba7d4bf14759a06a/portalocker-2.0.0-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core->fairseq) (3.4.0)
# Collecting PyYAML>=5.1.*
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 45.7MB/s
# Building wheels for collected packages: antlr4-python3-runtime, PyYAML
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-cp36-none-any.whl size=141230 sha256=e7a936beddf14c8cab6cb6ea2b8959232c0a7839c600a8719c8539852bb27a63
#   Stored in directory: /root/.cache/pip/wheels/e3/e2/fa/b78480b448b8579ddf393bebd3f47ee23aa84c89b6a78285c8
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=32117a3fa2d2c14adb757a27cef1f06808ffecec48715be82950db2200419178
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built antlr4-python3-runtime PyYAML
# Installing collected packages: antlr4-python3-runtime, PyYAML, omegaconf, hydra-core, portalocker, sacrebleu, fairseq
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.3.1 antlr4-python3-runtime-4.8 fairseq-0.10.1 hydra-core-1.0.4 omegaconf-2.0.5 portalocker-2.0.0 sacrebleu-1.4.14

# %% [markdown]
# # **VNcoreNLP**

# %%
# Install the vncorenlp python wrapper
# !pip install vncorenlp

# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/ 
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# Collecting vncorenlp
#   Downloading https://files.pythonhosted.org/packages/71/c2/96a60cf75421ecc740829fa920c617b3dd7fa6791e17554e7c6f3e7d7fca/vncorenlp-1.0.3.tar.gz (2.6MB)
#      |████████████████████████████████| 2.7MB 16.2MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vncorenlp) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (3.0.4)
# Building wheels for collected packages: vncorenlp
#   Building wheel for vncorenlp (setup.py) ... done
#   Created wheel for vncorenlp: filename=vncorenlp-1.0.3-cp36-none-any.whl size=2645934 sha256=aa6e5bf64cef44efac10a5f67191566d7671b0ccd1a78928d81d31989a3e3bb3
#   Stored in directory: /root/.cache/pip/wheels/09/54/8b/043667de6091d06a381d7745f44174504a9a4a56ecc9380c54
# Successfully built vncorenlp
# Installing collected packages: vncorenlp
# Successfully installed vncorenlp-1.0.3

# %%
# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
#!mkdir -p vncorenlp/models/wordsegmenter
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
#!wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
#!mv VnCoreNLP-1.1.1.jar vncorenlp/ 
#!mv vi-vocab vncorenlp/models/wordsegmenter/
#!mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/

# %%
ls
# Out:
# config.json                       pytorch_model.bin  test_labels
# PhoBERT_base_fairseq/             QA.h5/             test_pred
# PhoBERT_base_fairseq.tar.gz       QA.ipynb           train.json
# PhoBERT_base_transformers/        squad_vi.json      vncorenlp/
# PhoBERT_base_transformers.tar.gz  test.json

# %%
from vncorenlp import VnCoreNLP
rdrsegmenter = VnCoreNLP("/content/drive/My Drive/Zalo Challenge/2019/vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m') 

text = "Đại học Công Nghệ, Đại học Quốc Gia Hà Nội."

word_segmented_text = rdrsegmenter.tokenize(text) 
print(word_segmented_text)
# Out:
# [['Đại_học', 'Công_Nghệ', ',', 'Đại_học', 'Quốc_Gia', 'Hà_Nội', '.']]

# %% [markdown]
# # **PhoBERT - VinAIResearch**
# not re

# %%
# !wget https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# !tar -xzvf PhoBERT_base_transformers.tar.gz
# Out:
# --2020-11-21 03:08:17--  https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 13.225.207.128, 13.225.207.14, 13.225.207.105, ...
# Connecting to public.vinai.io (public.vinai.io)|13.225.207.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322405979 (307M) [application/x-tar]
# Saving to: ‘PhoBERT_base_transformers.tar.gz’
#
# PhoBERT_base_transf 100%[===================>] 307.47M  76.0MB/s    in 4.1s
#
# 2020-11-21 03:08:21 (75.4 MB/s) - ‘PhoBERT_base_transformers.tar.gz’ saved [322405979/322405979]
#
# PhoBERT_base_transformers/
# PhoBERT_base_transformers/config.json
# PhoBERT_base_transformers/bpe.codes
# PhoBERT_base_transformers/model.bin
# PhoBERT_base_transformers/dict.txt

# %%
# !wget https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# !tar -xzvf PhoBERT_base_fairseq.tar.gz
# Out:
# --2020-11-21 03:08:33--  https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 54.192.30.23, 54.192.30.67, 54.192.30.106, ...
# Connecting to public.vinai.io (public.vinai.io)|54.192.30.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1243308020 (1.2G) [application/x-tar]
# Saving to: ‘PhoBERT_base_fairseq.tar.gz’
#
# PhoBERT_base_fairse 100%[===================>]   1.16G  57.4MB/s    in 25s
#
# 2020-11-21 03:08:59 (47.3 MB/s) - ‘PhoBERT_base_fairseq.tar.gz’ saved [1243308020/1243308020]
#
# PhoBERT_base_fairseq/
# PhoBERT_base_fairseq/bpe.codes
# PhoBERT_base_fairseq/model.pt
# PhoBERT_base_fairseq/dict.txt

# %% [markdown]
# # ***Load Model***

# %%
from fairseq.data.encoders.fastbpe import fastBPE
from fairseq.data import Dictionary
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--bpe-codes', 
    default="/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/bpe.codes",
    required=False,
    type=str,
    help='path to fastBPE BPE'
)
args, unknown = parser.parse_known_args()
bpe = fastBPE(args)

# Load the dictionary
vocab = Dictionary()
vocab.add_from_file("/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/dict.txt")

# %%
bpe.encode("Ngày hôm nay thật tuyệt!")
# Out:
# 'Ngày hôm nay thật tuyệ@@ t@@ !'

# %%
vocab.encode_line('<s> ' + 'Ngày hôm nay thật tuyệ@@ t@@ !' + ' </s>')
# Out:
# tensor([    0,   319,   654,   136,   520, 46530,  1187,   381,     2,     2],
#        dtype=torch.int32)

# %% [markdown]
# # Get Data

# %%
import re
import json

train_path = '/content/drive/My Drive/Zalo Challenge/2019/train.json'
squad_path = '/content/drive/My Drive/Zalo Challenge/2019/squad_vi.json'

train_text, train_labels = [], []

with open(train_path) as train_file:
    data = json.load(train_file)
    # Process data
    for case in data:
        # Process X
        question = rdrsegmenter.tokenize(case['question'])
        question = ' '.join([' '.join(x) for x in question])

        answer = rdrsegmenter.tokenize(case['text'])
        answer = ' '.join([' '.join(x) for x in answer])
        train_text.append([question, answer])
        # Process y
        train_labels.append(1 if case['label'] == True else 0)


with open(squad_path) as extra_file:
    extra_data = json.load(extra_file)
    for data in extra_data['data']:
        for paragraph in data['paragraphs']:
          for qas in paragraph['qas']:
            for ans in qas['answers']:
              question = rdrsegmenter.tokenize(qas['question'])
              question = ' '.join([' '.join(x) for x in question])

              answer = rdrsegmenter.tokenize(ans['text'])
              answer = ' '.join([' '.join(x) for x in answer])
              train_text.append([question, answer ])
              train_labels.append(1 if qas['is_impossible'] == True else 0 )

# %%
len(train_text)
# Out:
# 98212

# %%
from sklearn.model_selection import train_test_split

train_sents, val_sents, train_labels, val_labels = train_test_split(train_text, train_labels, test_size=0.1, random_state = 42 )

# %%
len(val_sents)
# Out:
# 9822

# %%
train_sents
# Out:
# [['Tại_sao phân_loại này đã được thực_hiện ?',
#   'chỉ duy_nhất cho mục_đích của việc tiếp_cận những lợi_ích hành_động khẳng_định ,'],
#  ['Có bao_nhiêu đầu đã thập được cho là có ?', 'lăm tứ_chi ,'],
#  ['Ai mà Scout nghĩ có_thể cô_đơn hơn so với Boo_Radley ?', ''],
#  ['Hệ mặt_trời được hình_thành khi nào',
#   'Hệ_Mặt_Trời ( hay Thái_Dương Hệ ) là một hệ hành_tinh có Mặt_Trời ở trung_tâm và các thiên_thể nằm trong phạm_vi_lực hấp_dẫn của Mặt_Trời , tất_cả chúng được hình_thành từ sự suy_sụp của một đám mây phân_tử khổng_lồ cách đây gần 4,6 tỷ năm .'],
#  ['Có gì năm một giá_trị TZ mới sẽ áp_dụng cho ?', 'tất_cả các năm ,'],
#  ['Đâu là Topshop nằm ở đâu ?', 'trụ_sở tại London'],
#  ['Gì đã bị huỷ_bỏ trong năm nay của thần_tượng ?', 'Idol_Gives_Back'],
#  ['Nơi nào tiệc nhà_nước xảy ra ?', 'trong Ballroom ;'],
#  ['CDPs là gì ?', 'nơi điều_tra dân số-định'],
#  ['Ngày quốc_tế hạnh_phúc bắt_nguồn từ quốc_gia nào',
#   'Ngày Quốc_tế Hạnh_phúc sau khi công_bố đã được nhiều quốc_gia trên thế_giới ủng_hộ . Đến nay , đã có 193 quốc_gia thành_viên hưởng_ứng và cam_kết sẽ ủng_hộ ngày này bằng các nỗ_lực nâng cao chất_lượng cuộc_sống , xây_dựng xã_hội công_bằng , phát_triển bền_vững , nhằm đem lại hạnh_phúc cho người_dân .'],
#  ['Có gì Tennessee ghi_âm công_ty đầu_tiên phát_huy Elvis_Presley ?',
#   'Sun_Records ,'],
#  ['Trong những hướng chính bên ngoài Plymouth được Devonport nằm ở đâu ?',
#   'tây'],
#  ['một tên khác cho thời_đại Tokugawa là gì ?', 'thời Edo )'],
#  ['Vua bóng_đá Pele vô_địch thế_giới lần thứ 3 khi World_Cup được tổ_chức ở đâu',
#   'Giải_vô_địch_bóng_đá thế_giới 2022 ( ) sẽ là giải_vô_địch_bóng_đá thế_giới lần thứ 22 , dự_kiến được tổ_chức ở Qatar . Vòng chung_kết sẽ diễn ra với sự tham_gia của 32 đội_tuyển bóng_đá quốc_gia gồm cả đội chủ nhà Qatar . Đây là lần thứ 2 giải_vô_địch_bóng_đá thế_giới được tổ_chức tại châu_Á ( sau giải_vô_địch_bóng_đá thế_giới 2002 ở Nhật_Bản và Hàn_Quốc ) , là lần đầu_tiên được tổ_chức tại một quốc_gia thuộc Trung_Đông và cũng là lần đầu_tiên được tổ_chức tại một quốc_gia thuộc Thế_giới Ả_Rập . Qatar là quốc_gia châu_Á thứ 3 được đăng_cai World_Cup .'],
#  ['Như Chrome tăng sử_dụng , trình_duyệt sử_dụng đã tiếp_tục giảm ?',
#   'trình_duyệt Internet_Explorer ,'],
#  ['Có gì tỷ_lệ dân_số khu_vực của Valencia là Moriscos ?', 'một'],
#  ['Immaculate_Conception là gì một đại_diện của tránh ?',
#   'ban_đầu chỉ_tội lỗi ,'],
#  ['một_số diễn_viên người Bồ_Đào_Nha ghi_nhận là ai ?',
#   'Joaquim de Almeida , Daniela ruah , Maria de Medeiros , Diogo_Infante , Soraia_Chaves , Riverside , Lucia_Moniz , và Diogo_Morgado'],
#  ['Ai sản_xuất hầu_hết các đồ gốm Hispano-Moresque ?', 'thợ gốm mudejar'],
#  ['Charles_VII_Chamberlain lệnh phải làm là gì ?', 'leo Mont_Aiguille'],
#  ['một trong những chi_phí ban_đầu so với ngoài vòng pháp_luật trong truyền_thuyết là gì ?',
#   'họ " săn hươu của nhà_vua "'],
#  ['đại_học y_khoa phạm ngọc thành thành_lập khi nào',
#   'Trường Đại_học Y_khoa Phạm_Ngọc_Thạch là một Trường ĐH Y_Khoa đa ngành , được thành_lập từ năm 1989 , trực_thuộc Uỷ_ban_Nhân_Dân Tp.HCM. Tới tháng 3/2005 , “ Đơn_vị Huấn_luyện Kỹ_năng Y_khoa ” của Trường được hình_thành . Từ những bước_đi đầu_tiên , trải qua 13 năm ( 2005-2018 ) , với 04 giai_đoạn hoạt_động , Trung_tâm đã đồng_hành và trưởng_thành cùng sự phát_triển chung của Trường , hoàn_thành tốt những nhiệm_vụ được giao , đồng_thời Trung_tâm luôn năng_động , sáng_tạo , chủ_động đề_xuất nhiều giải_pháp có tính đột_phá , vượt khó , chấp_nhận mọi thách_thức về nhân_sự ; cơ_sở vật_chất , trang_thiết_bị và kinh_nghiệm huấn_luyện ...'],
#  ['tên của video âm_nhạc mà Jackie_Chan làm cho sự_kiện này là gì ?',
#   'Promise " ;'],
#  ['hai chương_trình khác nhau được cung_cấp tại Schoold_Báo chí KU là gì ?',
#   'Tin_tức và Thông_tin và Truyền chiến_lược'],
#  ['Một sonnet 1830 đã được viết về Chopin bởi những gì người đàn_ông ?',
#   'Leon_Ulrich'],
#  ['Bao_nhiêu doanh_thu được tạo ra hàng năm của dịch_vụ xe_buýt công_cộng ở London ?',
#   '850 triệu £'],
#  ['một_số chất_xúc_tác được sử_dụng trong làm mát hydro là gì',
#   'oxit sắt , than hoạt_tính , amiăng platinized , kim_loại đất_hiếm , các hợp_chất uranium , oxit cromic , hoặc một_số hợp_chất niken ,'],
#  ['lý_thuyết cho rằng vật_chất được tạo thành từ các khối xây_dựng rời_rạc được gọi là gì ?',
#   'lý_thuyết hạt của vật_chất ,'],
#  ['Khi nào một cuộc nội_chiến Nigeria bắt_đầu ?', '1967'],
#  ['Khi đã NYC bắt_đầu tan_rã các trường cao Bronx lớn ?',
#   'năm 1990 , thành_phố'],
#  ['Điều gì có_thể gây ra tình_trạng nạn đói ?', 'hạn_hán'],
#  ['Ngôn_ngữ chính_thức ở Singapore là gì',
#   'Ngày_nay , về tổng_thể , tiếng Mã_Lai được nói trong cộng_đồng người Singapore gốc Mã_Lai , chỉ 16,8% người Singapore biết đọc viết tiếng Mã_Lai và chỉ 12% sử_dụng nó làm ngôn_ngữ mẹ đẻ .'],
#  ['Chiến_tranh Triều_Tiên kết_thúc vào năm nào',
#   '( ... ) Khoảng chừng 2/3 tổng_số tù_binh chiến_tranh Mỹ tại Triều_Tiên chết vì tội_ác chiến_tranh .'],
#  ['Điều gì đã làm nhà_nước Whitehead là chỉ_số lớn nhất của một hình_thức cao hơn của cuộc_sống ?',
#   'họ đang tích_cực tham_gia trong việc sửa_đổi môi_trường của họ ,'],
#  ['Nước nào là người đầu_tiên Mỹ bao_giờ tuyên_chiến trên ?',
#   'Vương_quốc_Anh'],
#  ['Những gì được cho là tốt hơn phục_vụ âm_thanh tần_số cao hơn , đĩa_compact hoặc hồ_sơ ?',
#   'vinyl hồ_sơ'],
#  ['Bao_nhiêu là tiền của năm mùa đầu_tiên của bản_quyền truyền_hình Sky ?',
#   'Thoả_thuận bản_quyền truyền_hình Sky đầu_tiên là giá_trị 304 triệu £ hơn năm mùa'],
#  ['Khi được miền Bắc thua triều_đại Jurchen_Jin ?', '1127'],
#  ['đặc_điểm sinh_học nhất ảnh_hưởng gì đang được ?',
#   'polygenes ( nhiều gen khác nhau )'],
#  ['Mà loài đã Darwin so_sánh với cuộc đấu_tranh của con_người để tồn_tại ?',
#   'nhà_máy ;'],
#  ['đang nghiên_cứu các cơ_quan viện_trợ của Anh gọi_là gì ?',
#   'Drivers of Change'],
#  ['Ai huấn_luyện_viên Đại_học đội bơi Arizona ?', 'Frank_Busch'],
#  ['quốc_tịch gì là Juan_Pardo ?', 'Tây_Ban_Nha'],
#  ['Khi nào các Werhmacht vượt biên_giới phía nam của Estonia ?',
#   'ngày 7 tháng 7'],
#  ['Khi đã Russell di_chuyển trụ_sở Hội để Brooklyn ?', 'năm 1909 , kết_hợp'],
#  ['Đồng_tiền chung châu_Âu với tên gọi EURO phát_hành từ ngày nào',
#   'Litva là nước thành_viên Liên_minh châu_Âu đã gia_nhập khu_vực đồng_tiền chung châu_Âu thông_qua việc sử_dụng đồng Euro vào ngày 1 tháng 1 năm 2015 , trở_thành nước cuối_cùng trong số ba nước Baltic sử_dụng đồng euro , sau Estonia ( 2011 ) và Latvia ( 2014 ) . Trước đó , đồng_tiền của Litva là litas , được đổi sang đồng euro với tỷ_giá 3,4528 litas đổi được 1 euro .'],
#  ['Có bao_nhiêu giáo_viên Hồi_giáo đang có ở Kerala ?', '6000'],
#  ['sự_kiện gì ở Anh trong thế_kỷ 16 đã có một kết_quả của nhiều trường_hợp tử_vong vì dị_giáo ?',
#   'châu_Âu_Cải cách'],
#  ['Ai có_thể đầu_tư vào thị_trường nhà_đất Mỹ qua MBS và CDO ?',
#   'tổ_chức và nhà_đầu_tư trên toàn thế_giới'],
#  ['Việt_Nam gia_nhập tổ_chức WTO năm nào',
#   'Vũ_Khoan ( sinh năm 1937 ) là một chính_trị_gia và là nhà ngoại_giao Việt_Nam , từng giữ chức_vụ Bí_thư Trung_ương Đảng_Cộng_sản_Việt_Nam , Phó Thủ_tướng phụ_trách Kinh_tế đối_ngoại Việt_Nam từ tháng 8 năm 2002 đến cuối tháng 6 năm 2006 . Ông được nhiều người cho là có nhiều đóng_góp tích_cực trong quá_trình đàm_phán Hiệp_định Thương_mại Việt-Mỹ và quá_trình gia_nhập Tổ_chức Thương_mại Thế_giới ( WTO ) của Việt_Nam .'],
#  ['tình_trạng phát_triển nhất trong Tam_Quốc là gì ?', 'Ngô'],
#  ['đã trường hiện_đại và ngữ_pháp_học kết_hợp những gì để trở_thành ?',
#   'Tính toàn_diện khu_phố lớn ,'],
#  ['đã nổi_dậy để các biện_pháp bóng_đá mới bắt_đầu thế_nào ?',
#   'liên trường Athletic_Association'],
#  ['Đại_học lớn nhất của Armenia là gì ?', 'Đại_học bang Yerevan ,'],
#  ['Trên 01 Tháng 1 năm 2013 , các Kulluk được căn_cứ ngoài khơi bờ biển của đảo nào ?',
#   'Sitkalidak_Đảo'],
#  ['Khi là triều_đại nhà Đường ?', '618-907 CE )'],
#  ['Trong cơ_sở giáo_dục những gì được chương_trình tìm thấy ?',
#   'Đại_học Nam_Thái_Bình_Dương'],
#  ['chuyên_môn của Joseph_Dobrovský là gì ?', 'ngôn_ngữ_học và sử_học'],
#  ['Yếu_tố thời_tiết những gì tạo ra một sai lớn ở vùng khí_hậu địa_phương trong khu_vực Seattle ?',
#   'địa_phương trong vi_khí_hậu ,'],
#  ['Trong năm 1903 , trong đó hai tổ_chức được học Brigham_Young_Univesity thay_thế bằng ?',
#   'Brigham_High_School_Young , và Đại_học Brigham_Young'],
#  ['Theo quy_ước được Liên_Hợp_Quốc công_nhận , Trái_Đất có bao_nhiêu đại_dương',
#   'Lớp vỏ được chia thành hai kiểu theo phạm_vi phân_bố và đặc_điểm hoá_lý của nó là vỏ lục_địa và vỏ đại_dương . Vỏ đại_dương dày 5 km đến 10 km , và được cấu_tạo chủ_yếu là basalt , diabase , và gabbro . Vỏ lục_địa dày từ 30 km đến 50 km và được cấu_tạo bởi các đá có tỷ_trọng nhẹ hơn so với vỏ đại_dương như granite .'],
#  ['Khi nào chính_phủ Eritrea bắt_đầu chính_thức công_nhận nhà_thờ nào đó ?',
#   'tháng 5 năm 2002 ,'],
#  ['Cơ_quan_quyền_lực nhất của nhà_nước ta',
#   'Khoản 3 Điều 2 Hiến_pháp Việt_Nam năm 2013 quy_định : " " Quyền_lực nhà_nước là thống_nhất , có sự phân_công , phối_hợp , kiểm_soát giữa các cơ_quan nhà_nước trong việc thực_hiện các quyền lập_pháp , tư_pháp , hành_pháp . " " . Tổng_bí_thư Đảng_Cộng_sản_Việt_Nam Nguyễn_Phú_Trọng khẳng_định " " Nhà_nước ta không tam_quyền_phân_lập " " , nhấn_mạnh Quốc_hội là cơ_quan_quyền_lực nhà_nước cao nhất , các cơ_quan nhà_nước khác do quốc_hội lập ra , phải báo_cáo cho Quốc_hội và bị Quốc_hội giám_sát . Tuy_nhiên Quốc_hội khoá XIV năm 2017 có hơn 95% số đại_biểu là đảng_viên Đảng_Cộng_sản_Việt_Nam .'],
#  ['Một gauge Pirani là chính_xác trong phạm_vi những gì dao_động ?',
#   '10 torr đến 10-3 torr ,'],
#  ['Ai là nhà_cung_cấp đồng và coban sang Trung_Quốc ?', 'Congo'],
#  ['Ai thường có_thể được tìm thấy theo_dõi tàu cung unload tại Đảo_Norfolk ?',
#   'Khách thăm'],
#  ['tiểu_bang nào tuyên_bố ý_định rút khỏi công_ước quốc_tế về các quyền dân_sự và chính_trị ?',
#   'Bắc_Triều_Tiên'],
#  ['Mà phong_trào khác được nó theo mô_hình sau ?', 'Solidaritat_Catalana'],
#  ['Đinh_Bộ_Lĩnh gắn liền chiến_công lừng_lẫy nào',
#   'Chiến_thắng lừng_lẫy của Quân_đội Đức trong trận chiến này gắn liền với chiến_công oai_hùng của viên Sĩ_quan Erwin_Rommel . Trong cuộc chiến_đấu hai ngày , ông đã tóm gọn được nguyên một cứ_điểm của quân Ý và thu được vô_số tù_binh và chiến_lợi_phẩm . Sau_này , ông sẽ còn là một vị Thống_chế xuất_sắc của Đế_chế Đức Quốc xã do Adolf_Hitler đứng đầu .'],
#  ['Các phần_mềm được viết bằng gì',
#   'Các hệ_thống Logic được sử_dụng cho các hoạt_động cơ_khí trình_tự trong nhiều ứng_dụng . Phần_mềm PLC có_thể được viết bằng nhiều cách khác nhau – sơ_đồ bậc thang , SFC-sơ đồ hàm tuần_tự hoặc bằng ngôn_ngữ được gọi là danh_sách báo_cáo ( statement list ) .'],
#  ['Mà Carnival diễn ra ở Oruro ở Bolivia ?', 'La_Diablada'],
#  ['Danh_tướng nào của nước ta nổi_tiếng với tài lặn dưới nước',
#   'Yết_Kiêu ( 1242-1301 ; chữ Hán : 歇驕 ) là anh_hùng chống giặc ngoại_xâm vào đời nhà Trần , ông là gia tướng và một trong 5 mãnh_tướng dưới_trướng Quốc_công Tiết_Chế Trần_Quốc_Tuấn , ông là người có công giúp Nhà Trần chống giặc Nguyên Mông vào thế_kỷ XIII với biệt_tài thuỷ_chiến . Ông là người bơi lặn giỏi , đã sử_dụng tài của mình để đục thuyền của quân xâm_lược Nguyên Mông .'],
#  ['Khi đã Ấn_Độ và Pakistan giành độc_lập ?', 'năm 1947 ,'],
#  ['là gì , theo như văn_bản , thì_thầm cho thời_gian của họ ?',
#   'nguyên_âm và nasals ,'],
#  ['Ngoài Pháp , đội khác được gắn với Anh cho số lần ra sân trong FIFA World_Cup ?',
#   'Tây_Ban_Nha'],
#  ['Ai hưởng lợi từ cách_chức của Malenkov ?', 'quyền'],
#  ["Trong đó thành_phố đã Galerie de l ' Effort_Moderne xảy ra ?", 'Paris'],
#  ['Đức_tin có_thể mang lại lợi_ích vĩnh_cửu gì ?', 'sự cứu_rỗi'],
#  ['Tính đến năm 2016 nước ta có bao_nhiêu dự_án BOT',
#   'Chi_phí dự_kiến của dự_án xây_dựng này là 3.798,440 tỷ đồng , trong đó dự_án thành_phần 1 ( xây_dựng phần cầu chính ) có vốn đầu_tư trên 2.210 tỷ đồng được thực_hiện theo hình_thức BOT ; dự_án thành_phần 2 có vốn đầu_tư là 1.588,261 từ nguồn vốn ngân_sách Nhà_nước .'],
#  ['Núi Thiên_Ấn nằm bên dòng sông nổi_tiếng nào ở tỉnh Quảng_Ngãi',
#   'Thiên_Ấn hay còn gọi là Kim_Ấn_Sơn là ngọn núi nằm ở tả_ngạn sông Trà_Khúc , thuộc địa_phận xã Tịnh_Ấn_Đông và phường Trương_Quang_Trọng , Thành_phố Quảng_Ngãi , tỉnh Quảng_Ngãi .'],
#  ['Nhà_thờ Presbyterian thành_lập ở New_Mexico cung_cấp một thay_thế cho tôn_giáo nào ?',
#   'Công_giáo ,'],
#  ['Ứng_dụng của lưu_huỳnh là gì',
#   'Lưu_huỳnh tetrachlorua phân_huỷ trên -30 ° C ( 242 K ) thành sulfur dichloride và clo . Lưu_huỳnh tetrachlorua dễ_dàng thuỷ phân : Lưu_huỳnh tetrachlorua phản_ứng với nước , tạo ra hydrogen chloride và Lưu_huỳnh dioxide thông_qua quá_trình thuỷ_phân .'],
#  ['Những gì hiện ATSC đứng cho ?', 'Uỷ_ban Hệ_Thống Truyền_Hình nâng cao'],
#  ['Trong suốt lịch_sử của châu_Âu đã được lao_động trẻ_em được coi là tích_cực ?',
#   'Một_số quan_điểm cho rằng công_việc là tốt cho nhân_vật xây_dựng và kỹ_năng phát_triển của trẻ'],
#  ['Nguyễn_Văn_Thiệu mất vào năm nào',
#   'Chỉ 4 ngày sau , Nguyễn_Văn_Thiệu đã bí_mật lên máy_bay thoát khỏi Sài_Gòn vào đêm_ngày 25/4/1975 . Cuộc ra đi của Nguyễn_Văn_Thiệu diễn ra bí_mật trong đêm_tối , dưới sự sắp_đặt của Thomas_Polgar - trưởng CIA ở Sài_Gòn Để cho việc ra đi danh_chính_ngôn_thuận , Trần_Văn_Hương ký quyết_định cử Nguyễn_Văn_Thiệu là đặc sứ của Việt_Nam Cộng_hoà đến Đài_Bắc để phúng_điếu Tưởng_Giới_Thạch ( dù thực_ra Tưởng_Giới_Thạch đã chết từ trước đó 3 tuần ) .'],
#  ['hit lớn từ album 1976 của Nữ_hoàng là gì ?',
#   'Somebody to Love " , một bài hát'],
#  ['Ai là người thiết_kế Khải_Hoàn_Môn ở Pháp',
#   'Năm 1806 , sau chiến_thắng Austerlitz , hoàng_đế Napoléon_Bonaparte quyết_định xây_dựng trên quảng_trường Étoile một công_trình vinh_danh quân_đội . Khải_Hoàn_Môn được kiến_trúc_sư Jean-François-Thérèse Chalgrin thiết_kế , lấy cảm_hứng từ các công_trình cổ_đại , cao 50 mét , rộng 45 mét . Sau Jean-François-Thérèse Chalgrin , những người kế_nhiệm công_việc xây_dựng là Louis-Robert Goust và Jean-Nicolas Huyot .'],
#  ['làm gì cứng và sức_mạnh đàn_hồi phụ_thuộc vào nhiều hơn khuyết_tật ?',
#   'âm_thanh gỗ'],
#  ["Ai bắt_đầu một diễn_đàn hỗ_trợ của quá_trình hợp_pháp Morales ' của sự thay_đổi ?",
#   'đại_diện từ các tổ_chức'],
#  ['nhà_cung_cấp điện Richmond là ai ?', 'Dominion_Virginia điện'],
#  ['Nào trong hai người đã truy_cập Chopin đã được dạy bởi ông trên đàn piano ?',
#   'Pauline_Viardot ,'],
#  ['được ensambles smalled gồm những gì ?',
#   'hai mandolin , mandola , và mandocello ,'],
#  ['Có bao_nhiêu sinh_viên đã được thực_hiện vào tháng_giêng năm 1977 ?',
#   'hai'],
#  ['hạn những gì đề_cập đến một_cách khác , trong đó tiếng_địa_phương được phân_biệt từ các ngôn_ngữ ?',
#   'quyền ngôn_ngữ ,'],
#  ['Nước nào là người đầu_tiên có nguy_cơ bị mặc_định soverign ?', ''],
#  ['năm gì chứng_kiến sự bầu_cử của một người bình_dân đến văn_phòng của Praetor ?',
#   '337 BC ,'],
#  ['con tàu đầu_tiên bay vào vũ_trụ tên là gì',
#   'Mars 4 được phóng lên bằng tên_lửa đẩy mang tên Proton-K , một giai_đoạn đẩy Blok_D , bay từ sân_bay vũ_trụ Baikonur_Site 8 1/2 3 . Quá_trình phóng lên diễn ra lúc 19:30:59 UTC ngày 21 tháng 7 năm 1973 , với ba giai_đoạn đầu_tiên đặt tàu_vũ_trụ lên một quỹ_đạo chờ thấp trước khi Blok_D đẩy tàu_vũ_trụ này vào quỹ_đạo nhật tâm liên_kết với sao_Hoả .'],
#  ['Làm thế_nào được Blue_Ivy ghi trên Glory ?', 'B'],
#  ['Trong những năm được Bern được xếp_hạng là một trong 10 thành_phố tốt nhất cho chất_lượng sống của họ ?',
#   '2010 )'],
#  ['Một_số trong những bức tường xung_quanh mà mang tính bước_ngoặt đã bị phá_huỷ trong năm 1930 ?',
#   'các Bargate'],
#  ['Ai đã thiết_lập mô_hình cảm_thấy ở Trung_Quốc ?', 'Xie_Bangxiu'],
#  ['của các nhóm nông_nghiệp các loại cơ_bản là gì ?',
#   'trang_trại hoặc các nhóm Pastoralist'],
#  ['giữa năm 1638 và 1648 những gì đường_phố là EIC trụ_sở trên ?',
#   'Leadenhall đường'],
#  ['Đà_Nẵng có bao_nhiêu đơn_vị hành_chính',
#   'Thành_phần cơ_cấu khu_vực hành_chính thành_phố Đà_Nẵng là : 45 phường , 11 xã và 1 huyện không phân_chia xã .'],
#  ['Trảo_Nha là bút_danh của nhà_thơ nào ?', 'Xuân_Diệu'],
#  ['Những con chim đã phá vỡ một kỷ_lục trong thế_nào đến nay nó đã bay qua cuộc_sống của nó ?',
#   'Manx_Shearwater'],
#  ['Ai chủ_yếu chiếm phức xung_quanh các trường đại_học ?', 'sinh_viên thuê'],
#  ['Đâu_Stalin nói ông sẽ cho_phép các lực_lượng không_quân Liên_Xô để hoạt_động cho một số_lượng hạn_chế về thời_gian ?',
#   'không_phận Trung_Quốc ,'],
#  ['Những gì thường đóng chỉ là một phần nhỏ trong cấu_trúc của một gen ?',
#   'protein mã_hoá chuỗi thực_tế'],
#  ['Có bao_nhiêu đã Crazy in Love bán để trở_thành một trong những đĩa đơn bán_chạy nhất trong lịch_sử ?',
#   '8 triệu'],
#  ['New_Delhi chia_sẻ vị_trí là điểm đến bán_lẻ nhắm mục_tiêu nhất tại các thị_trường châu Á-Thái Bình_Dương với những gì thành_phố khác ?',
#   'Bắc_Kinh'],
#  ['Một trong những chương_trình thời_trang lớn nhất thế_giới có tên là gì ở New_York ?',
#   'New_York_Fashion_Week'],
#  ['là đại_lý đặc_biệt của FBI đã ban_hành những gì nếu họ không bằng_cấp đầu_tiên của họ ?',
#   'Glock 17 hoặc Glock 19 ,'],
#  ['Có gì khu_vực của Namibia đã Orlam tộc giải_quyết trong ?', 'nam Namibia'],
#  ['Ai tin rằng họ là những người đại_diện Han_Tây đúng không ?',
#   'quan_chức nước_ngoài'],
#  ['dân_số của Trung_Quốc trong 2 AD là gì ?', '57.671.400'],
#  ['Khi nào các câu hỏi của các phản_ứng tình_dục của con_người bắt_đầu ?',
#   'Từ ít_nhất cuối thế_kỷ XIX'],
#  ['Đâu là con trai Hoàng_tử của Richard , Alexander_Windsor , Bá_tước ?',
#   'Ulster ;'],
#  ['Khi nước được giải_phóng do nhu_cầu cao , bơm trở swhat ?',
#   'một máy phát thuỷ_điện'],
#  ['Phần_nào của nhà_nước có sa_mạc nhất ; bắc , nam , đông hoặc tây ?', 'nam'],
#  ['Khi được giới_thiệu Windows 8.1 ?', 'Tháng_Năm 14 , 2013'],
#  ['Có bao_nhiêu người sống trong các khu_vực đô_thị Miami-Dade ?', '5'],
#  ['Có gì tên đã được đưa ra để pin pháo_binh ven biển dựng lên ngay sau 1852 ?',
#   'Fort_Rosecrans'],
#  ['không vỏ hạt bảo_vệ những gì ?', 'phôi'],
#  ['Trung_Quốc có bao_nhiêu dân_tộc',
#   'Dân_tộc Trung_Hoa ( , âm Hán_Việt : " Trung_Hoa Dân_tộc " ) là một thuật từ chính_trị gắn liền với lịch_sử Trung_Quốc về chủng_tộc và xây_dựng dân_tộc .'],
#  ['Về bao_nhiêu phòng khách_sạn đang có ở Manhattan ?',
#   '90.000 phòng khách_sạn'],
#  ['Ai cung_cấp đào_tạo nghề ở Cork ?', 'Trường Cork_Thương mại'],
#  ['Những thành_viên của Spectre đã bị coi là đã chết ?', 'Franz_Oberhauser'],
#  ['Loại màu_sắc là màu đỏ và màu xanh lá cây ?', 'bổ_sung'],
#  ['Những gì đã phần_nào bị phá_huỷ bởi vụ đánh bom Đồng_minh vào năm 1944 ?',
#   'Romanesque_Église Saint-Étienne ,'],
#  ['Những người âm_mưu lật_đổ chế_độ của Thái_hậu Yan ?', 'Sun_Cheng'],
#  ['bản dịch tiếng Anh của Medri_Bahri là gì ?', 'biển đất " )'],
#  ['Có bao_nhiêu trạm gốc China_Mobile đã ngừng làm_việc ?', '2.300'],
#  ['Huyện đảo Bạch_Long_Vỹ trực_thuộc tỉnh thành_phố nào',
#   'Do thành_phố Hải_Phòng và tỉnh Quảng_Ninh tranh_chấp dãy đảo phía bắc và đông bắc đảo Cát_Bà nên một_số hòn đảo ở phía bắc và tây bắc của xã hiện do tỉnh Quảng_Ninh quản_lý mặc_dù chúng được thành_phố Hải_Phòng xem là thuộc về xã Phù_Long . Một_số đảo lớn trong số đó là đảo Quả_Muỗm , đảo Quả_Xoài , đảo Đá_Chông ....'],
#  ['nghiên_cứu những gì cấp bằng_sáng_chế một quá_trình dầu nước nóng để bitum tách ?',
#   'TS'],
#  ['Ai ra_lệnh quân_đội ?', 'các stadtholder ,'],
#  ['Loài vật nào duy_nhất thuộc lớp thú có_thể bay',
#   'Dơi là động_vật_có_vú duy_nhất có_thể bay được . Một_số loài thú khác như chồn bay , sóc bay ... trông có_vẻ như có_thể bay nhưng thực_ra chúng chỉ có_thể lượn - trong một khoảng_cách có giới_hạn . Khoảng 70% số loài dơi ăn sâu_bọ , số còn lại chủ_yếu ăn hoa_quả và chỉ có vài loài ăn thịt . Dơi cần_thiết cho sinh_thái bởi chúng đóng vai_trò thụ_phấn hoa hay phát_tán hạt cây , sự phân_tán của nhiều loài cây lệ_thuộc hoàn_toàn vào dơi . Loài dơi nhỏ nhất là dơi mũi lợn Kitti chỉ dài 29 – 33 mm , nặng khoảng 2 gam . Loài lớn nhất là dơi quả đầu vàng lớn với sải cánh dài 1,5 m và cân nặng khoảng 1,2 kg .'],
#  ['Ai là thủ_tướng cuối_cùng để phục_vụ đồng_thời là Bộ_trưởng Tài_Chính ?',
#   'Balfour'],
#  ['trọng_tâm của Gucci Chime for Change chiến_dịch là gì ?',
#   'lan trao quyền cho nữ'],
#  ['Khi được Philadelphia_Baptist_Confession tạo ?', '1742'],
#  ['Ai sở_hữu nhãn_hiệu hàng_hoá Desperados ?', 'Jerry_Jones'],
#  ['Ai là người đầu_tiên tìm ra Đà_Lạt',
#   'Cùng với bác_sĩ Alexandre_Yersin khám_phá ra Đà_Lạt , có linh_mục Robert thuộc Hội Thừa sai Paris ( MEP ) vào năm 1893 . Đến 1917 , linh_mục quản_lý của MEP tại Viễn_Đông là Nicolas_Couveur đã đến Đà_Lạt với mục_đích tìm nơi nghỉ_dưỡng cho các giáo_sĩ , và ông đã cho xây_dựng một dưỡng viện giáo_đồ nay là một phần của nhà xứ . Vào cuối tháng 4 năm 1920 , Giám_mục Quinton ( Giám_quản Tổng toà tại Sài_Gòn ) ban quyết_định thành_lập Giáo_phận Đà_Lạt .'],
#  ['Ai phát_minh ra cách đánh_máy Unikey',
#   'UniKey là chương_trình điều_khiển bàn_phím , hay còn gọi là bộ_gõ , hỗ_trợ nhập liệu tiếng Việt trên máy_tính , chạy trên hệ_điều_hành Microsoft Windows , được phát_triển bởi Phạm_Kim_Long . Ban_đầu , phần_mềm được phát_hành theo giấy_phép nguồn mở Giấy_phép Công_cộng GNU , tuy_nhiên từ phiên_bản 4.0 phát_hành năm 2005 cho tới nay , tác_giả đã không còn công_bố mã nguồn nữa . Trên nền Linux phần_mềm này được gọi là X-UniKey.'],
#  ['Những đặc_điểm không vốn có trong thực_tế tôn_giáo La_Mã ?',
#   'đức_tin hay giáo_điều ,'],
#  ['Trong giai_đoạn trung_cổ ở châu_Âu vào cuối như những gì đã được bông xem ?',
#   'nhập_khẩu'],
#  ['Trong những loạt các tiếp_xúc không có_đi_có_lại thường làm_việc ?',
#   'giữa 1/1000 giây để 1/2'],
#  ['Ai_Cập thuộc khu_vực nào của châu_Phi',
#   'Ai_Cập cổ_đại là một nền văn_minh cổ_đại nằm ở Đông_Bắc châu_Phi , tập_trung dọc theo hạ_lưu của sông Nile thuộc khu_vực ngày_nay là đất_nước Ai_Cập . Đây là một trong sáu nền văn_minh phát_sinh một_cách độc_lập trên thế_giới . Nền văn_minh Ai_Cập được thống_nhất lại vào năm 3150 TCN ( theo trình_tự thời_gian của bảng niên_đại Ai_Cập ) với sự thống_nhất chính_trị của Thượng và Hạ_Ai_Cập dưới thời vị pharaon đầu_tiên ( Narmer , thường được gọi là Menes ) . Lịch_sử của Ai_Cập cổ_đại đã trải qua một loạt các thời_kỳ vương_quốc ổn_định , và các giai_đoạn hỗn_loạn giữa chúng được gọi là các giai_đoạn chuyển_tiếp : Cổ_Vương quốc thời_kỳ Sơ_kỳ Đồ đồng , Trung_Vương quốc tương_ứng giai_đoạn Trung kỳ Đồ_Đồng và Tân_Vương_quốc ứng với Hậu kỳ Đồ đồng .'],
#  ['Những gì đã có tên của bài hát dành riêng cho trẻ_em ?', 'Glory " ,'],
#  ['Khi nào bảng xếp_hạng Adult_Contemporary nhận tên hiện_tại của nó ?',
#   'ngày 07 tháng tư năm 1979 ,'],
#  ['Râm_bụt là quốc hoa của nước nào',
#   '" Hibiscus rosa-sinensis " là quốc hoa của Malaysia , với tên gọi " Bunga_Raya " trong tiếng Mã_Lai , " Sembaruthi " trong tiếng Tamil tiếng Khmer pka rumyul ( ផ្កា រំយោល ) \u200b và " mamdaram " trong tiếng Telugu ( మందారం ) .'],
#  ['Có bao_nhiêu pound PCBs được ước_tính được giữ lại trong các lớp trầm_tích đằng sau đập Woods_Pond ?',
#   '11.000'],
#  ['Có gì nhà môi_trường đã có_thể làm , thay_vì săn_bắn ?',
#   '( tái ) kẻ săn mồi giới_thiệu'],
#  ['Ai từ_chối trẻ_em khuyết_tật là không_thể tham_dự một trường công_lập ?',
#   'bác_sĩ hoặc gia_sư đặc_biệt'],
#  ['đã Carl von Voit và Max_Rubner áp_dụng những gì đến dinh_dưỡng để nhận được kết_quả của họ ?',
#   'nguyên_tắc của vật_lý'],
#  ['lý_thuyết Tarski của đã vượt qua sự phản_đối nhất_định với những gì quan_niệm về sự_thật ?',
#   'sự_thật như thư_từ'],
#  ['giá gốc cho một pin thay_thế từ Apple là gì ?', '$ 99 ,'],
#  ['Đâu là nguồn khả_năng của sự thay_đổi đến sự hình_thành manipular ?',
#   'sao_chép từ kẻ_thù Samnite của Rome'],
#  ['Được từ Latin cho gia_cầm cũng được dùng để mô_tả những động_vật nhỏ khác như trái_ngược với bất_kỳ poulty ?',
#   'từ pullus chữ Latin , có nghĩa là động_vật nhỏ'],
#  ['Khi quy_tắc xã_hội truyền_thống có_thể bị phá vỡ ?',
#   'trong thời_gian cai_trị tồi'],
#  ['Có bao_nhiêu dân_thường bị người Nhật hy_vọng sẽ giết trong cuộc tấn_công kế_hoạch của họ trên San_Diego ?',
#   'hàng chục ngàn thường_dân'],
#  ['Đã có bất_kỳ thay_đổi để hạn_chế đặt trên các mạng thông_tin liên_lạc ở Miến_Điện ?',
#   'Hạn_chế về kiểm_duyệt truyền_thông đã được nới lỏng đáng_kể trong tháng 8 2012'],
#  ['bản_sắc gì mô_hình tình_trạng nổi lên do công_việc của James_Marcia ?',
#   'Neo-Eriksonian "'],
#  ['không được gì coi là hợp_lệ khi được thực_hiện bởi các giáo_phái khác ?',
#   'rửa_tội trước'],
#  ['Triều_đại nào không lấy danh_hiệu trạng_nguyên',
#   'Nếu dựa theo danh_sách này thì có 49 Trạng_nguyên chính_thức và Trạng_nguyên đầu_tiên là Nguyễn_Quan_Quang . Những người đỗ đầu các khoa thi từ năm 1246 trở về trước chưa đặt danh_hiệu trạng_nguyên .'],
#  ['Ai làm Nhân_chứng Jehovah tin rằng giới_thiệu tư_duy độc_lập ?',
#   'Satan the Devil "'],
#  ['Kotick công_ty là gì CEO của ?', 'Activision_Blizzard'],
#  ['Có bao_nhiêu trường_hợp bệnh lao đang hoạt_động trong quá_trình cả năm 2014 ?',
#   '9'],
#  ['Có gì nhân_vật thường không chuẩn ?', 'đa_âm tiết'],
#  ['Trong bao_nhiêu ngôn_ngữ được sinh_viên trong các cơ_sở giáo_dục đại_học được đào_tạo vào năm 1974 ?',
#   '47'],
#  ['Có bao_nhiêu trạm cứu_hoả đang có trong giới_hạn thành_phố Southampton ?',
#   'ba trạm cứu_hoả'],
#  ['Đâu là Orlasenke nằm ở đâu ?', 'trong'],
#  ['tiêu_đề của Whitehead tại Đại_học London là bao_nhiêu vào cuối năm 1918 ?',
#   'Trưởng Khoa_Khoa học'],
#  ['Đâu là " Viễn_Đông " lấy từ đâu ?', 'của Ptolemy " Ấn_Độ Vượt sông Hằng'],
#  ['không từ samyaksamadhi nghĩa_là gì ?', 'chánh định "'],
#  ['Làm thế_nào xa trở_lại những thông_lệ ghi có_thể được truy ?', '1925'],
#  ['một_số chữ_viết tắt cho các mạch_tích_hợp là gì ?',
#   'IC , vi_mạch hoặc đơn_giản là chip ) ,'],
#  ['Mà đã Nelson mất bên tham_gia trong năm 2008 ?', 'Malcolm_Turnbull'],
#  ['tiểu_bang nào đang ở trong một cuộc xung_đột với Đông_Ngô , và Shu_Han ?',
#   'Tào_Nguỵ ,'],
#  ['Tại_sao người Pháp và tiếng Anh không_thể nắm quyền kiểm_soát của lĩnh_vực này ?',
#   'thiếu thiết_bị'],
#  ['Trong những năm đã Tito mô_hình kế_hoạch phát_triển kinh_tế của mình một_cách độc_lập từ Moscow ?',
#   'năm 1948 ,'],
#  ['tổ_chức những gì hiện các kiểm_định chất_lượng cho IGCSE ở Swaziland ?',
#   'Cambridge_International_Khám'],
#  ['Những gì người khác còn được gọi là tăng sức_mạnh ?', 'ăng ten tăng'],
#  ['Tên chính_thức của Indonesia là gì',
#   'Indonesia ( tên chính_thức : Cộng_hoà Indonesia , tiếng Indonesia : " Republik_Indonesia " ) trước đó trong tài_liệu tiếng Việt quốc_gia này từng được gọi là " nước Nam_Dương " , là một quốc_gia nằm giữa Đông_Nam_Á và Châu_Đại_Dương . Indonesia được mệnh_danh là " " Xứ_sở vạn đảo " " , lãnh_thổ của nó bao_gồm " 13.487 " hòn đảo và với dân_số khoảng 255 triệu người ( năm 2015 ) , đứng thứ tư thế_giới về dân_số .'],
#  ['đã nghiên_cứu năm 2012 đã nói gì được nhân đôi bởi việc sử_dụng bông GM ?',
#   'bọ_rùa , bắt kịp xu và nhện'],
#  ['Nepal có đường biên_giới tiếp_giáp quốc_gia nào',
#   'Nepal ( phiên_âm tiếng Việt : Nê-pan ; tiếng Nepal : नेपाल Về âm_thanh nàyNepāl [ neˈpal ] ) , tên chính_thức là nước Cộng_hoà Dân_chủ Liên_bang Nepal ( tiếng Nepal : सङ्घीय लोकतान्त्रिक गणतन्त्र नेपाल Sanghiya_Loktāntrik_Ganatantra_Nepāl ) , [ 7 ] là một quốc_gia nội lục tại Nam Á. Dân_số quốc_gia Himalaya này đạt 26,4 triệu vào năm 2011 , sống trên lãnh_thổ lớn thứ 93 thế_giới . [ 3 ] [ 8 ] Nepal giáp với Trung_Quốc về phía bắc , giáp với Ấn_Độ về phía nam , đông và tây . Nepal cách lãnh_thổ Bangladesh 27 km tính từ mũi đông nam . Nepal đa_dạng về địa_lý , có các đồng_bằng phì_nhiêu , các đồi rừng cận núi cao , và có tám trong số mười núi cao nhất thế_giới , trong đó có núi Everest . Kathmandu là thủ_đô và thành_phố lớn nhất của Nepal . Nepal là một quốc_gia đa dân_tộc , tiếng Nepal là ngôn_ngữ chính_thức .'],
#  ['Ai là vợ của Bill_Gates', 'Melinda'],
#  ['quang_phổ của các vị thần , bạn có_thể nhận được trong Mexico City là gì ?',
#   'thực_phẩm cơ_bản để siêu hàng xa_xỉ cao_cấp'],
#  ['Có gì xảy ra khi con chậm_trễ phát_tán từ nhóm sinh của họ ?',
#   'giống Hợp_tác_xã'],
#  ['Casablanca là thành_phố du_lịch nổi_tiếng của nước nào',
#   'Kể từ sau đó Casablanca đã tập_trung vào công_nghiệp và dịch_vụ . Hiện_nay , thành_phố này đang phát_triển công_nghiệp du_lịch . Casablanca là " thủ_đô " kinh_tế và kinh_doanh của Maroc , trong khi Rabat là thủ_đô về mặt chính_trị .'],
#  ['Trạng chiếu của nước ta là ai',
#   'Phạm_Đôn_Lễ ( chữ Hán : 范敦禮 , 1457 - 1531 ) , tự là Lư_Khanh , là Trạng_nguyên khoa Tân_Sửu ( 1481 ) , niên_hiệu Hồng_Đức_12 , đời vua Lê_Thánh_Tông . Vì có công dạy dân_làng dệt chiếu cói nên còn gọi là Trạng_Chiếu hay Tam_nguyên Đôn_Lễ . [ 1 ] [ 2 ] . Ông làm quan đến các chức Tả thị_lang , rồi Thượng_Thư .'],
#  ['Có bao_nhiêu người ở Miến_Điện hiện đang sử_dụng một thị_thực làm_việc cho Thái_Lan ?',
#   '600.000 lao_động nhập_cư đăng_ký từ Myanmar ở Thái_Lan ,'],
#  ['Ai giới_thiệu Irving để Spielberg ?', 'Brian_De_Palma ,'],
#  ['Cuộc bầu_cử quốc_hội vào ngày 22 tháng 5 năm 2011 để bầu_cử đại_biểu cho quốc_hội khoá mấy',
#   'Tại cuộc bầu_cử Quốc_hội ngày 22 tháng 5 năm 2011 ( Đơn_vị bầu_cử Số 3 : thị_xã Thuận_An , tỉnh Bình_Dương ) , bà đã không trúng_cử đại_biểu Quốc_hội Việt_Nam khoá XIII ( 2011-2016 ) .'],
#  ['Trong những năm đã Missolonghi rơi xuống người Ai_Cập ?', '1826'],
#  ['tổ_chức những gì các nước phương Tây đã từ_chối để nhận ra ?',
#   'tiếng Estonia SSR ,'],
#  ['hai ví_dụ về hoạt_động quân_sự đơn_phương Bồ_Đào_Nha độc_lập là gì tiến_hành ở nước_ngoài ?',
#   'Angola vào năm 1992 và ở Guinea-Bissau năm 1998'],
#  ['Có gì lý_luận chính_trị đã Popper nói không đáp_ứng tiêu_chí falsifiability của mình ?',
#   'chủ_nghĩa Mác'],
#  ['Từ những gì ngôn_ngữ là tiếng Bồ_Đào_Nha có nguồn_gốc ?', 'Latin'],
#  ['lãnh_đạo tinh_thần của Trung_tâm cộng_đồng Đền Israel là ai ?',
#   'Rabbi_Shammai_Engelmayer ,'],
#  ['triều_đại cai_trị gì Vương_quốc Hồi_giáo IFAT ?', 'triều_đại Walashma'],
#  ['Phơi nhiễm HIV là gì',
#   'Hiệp_sĩ đường_phố Nguyễn_Sin_Hiệp_sĩ Nguyễn_Sin điều_trị phơi nhiễm HIV Hiệp_sĩ Nguyễn_Sin khắc_tinh của tội_phạm Hiệp_sĩ Nguyễn_Sin rong_ruổi trên các ngả đường bắt_tội phạm'],
#  ['Cơn bão Linda đổ_bộ vaò Việt_Nam vào năm nào',
#   'Bão nhiệt_đới Linda , được biết đến ở Philippines với tên gọi Áp_thấp_nhiệt_đới Openg , được biết đến tại Việt_Nam với tên gọi cơn bão số 5 , là cơn bão thảm_khốc nhất khi tấn_công vào miền Nam Việt_Nam trong vòng ít_nhất 100 năm . Hình_thành vào ngày 31 tháng 10 năm 1997 trên Biển Đông , Linda mạnh lên khi di_chuyển về phía Tây và đã đổ_bộ vào khu_vực Nam_Bộ Việt_Nam trong ngày 2 tháng 11 với sức gió 100 km / giờ cùng với mưa lớn tận 500 mm-700 mm.Theo Trung_tâm Cảnh_báo Bão_Liên hợp ( JTWC ) của Hoa_Kỳ thì khi Linda khi tiến vào vịnh Thái_Lan Linda tăng cấp thành bão cuồng_phong , nhưng đã suy_yếu lại thành bão nhiệt_đới trước khi vượt bán_đảo Mã_Lai và đi vào vịnh Bengal.Tại đây , Linda một lần nữa đạt đến cường_độ bão cuồng_phong theo JTWC , tuy_nhiên không lâu sau độ đứt gió tăng lên và dòng dẫn suy_yếu trước khi tan_rã vào ngày 9 tháng 11 .'],
#  ['đã Katura Horton-Perinchief làm gì ?',
#   'làm_nên lịch_sử khi trở_thành nữ thợ lặn da đen đầu_tiên thi_đấu ở Thế_vận_hội Olympic'],
#  ['Mà các Phúc_Âm đồng_ý nhất với Athanasius ?', 'Tin_Mừng Gioan'],
#  ['một_số phản_đối cấm bóng_đèn sợi đốt là gì ?',
#   'cao hơn giải_pháp thay_thế và chất_lượng thấp hơn của ánh_sáng đèn_huỳnh_quang'],
#  ['nhóm những gì đã MLK tin rằng cần quan_tâm hơn_nữa từ FBI ?',
#   'supremacists trắng'],
#  ['nam âu gồm những nước nào',
#   'Nam_Âu là một khu_vực địa_lý thuộc châu_Âu . Khái_niệm này có_thể thay_đổi tuỳ cách nhìn_nhận theo lĩnh_vực khí_hậu ( khí_hậu Địa_Trung_Hải ) , địa_lý hay ngôn_ngữ - văn_hoá .'],
#  ['Chuyện gì xảy ra khi các nhà_khoa_học cố_gắng áp_dụng khoa_học để sắp_xếp ra sự khác_biệt xã_hội ?',
#   'nó tất_cả sụp_đổ'],
#  ['Ai đang nắm giữ kỷ_lục bơi 100m bướm nhanh nhất', 'Joseph_Schooling'],
#  ['Bao_nhiêu doanh_thu cho công_ty được tạo ra bởi hệ_thống BDS ?', '$ 31'],
#  ["không ' chaetae ' nghĩa_là gì ?", '" )'],
#  ['Tham_dự tổ_chức thế_tục của giáo_dục đại_học được xem là cần_thiết nhưng thua_kém những gì xã_hội ?',
#   'Haredi'],
#  ['chủ_tịch uỷ_ban_nhân_dân hiện_tại của Thái_Bình là ai',
#   'Đặng_Trọng_Thăng ( sinh năm 1960 ) là một chính_khách người Việt_Nam . Ông hiện là Chủ_tịch Uỷ_ban_nhân_dân tỉnh Thái Bình.Ông từng là Chủ_tịch Hội_đồng_nhân_dân tỉnh Thái_Bình .'],
#  ['Đa_số người_dân Brunei theo tôn_giáo nào',
#   'Đa_số người_dân ở Tanjung_Pandan là người Khách Gia và người Mã_Lai . Các tôn_giáo của người Hoa là Phật_giáo , Công_giáo và Tin lành .'],
#  ['Chùa Hà được xây_dựng năm nào',
#   'Chùa Hà cùng với chùa Duyên_Ninh là 2 ngôi chùa cầu_duyên ở miền Bắc .'],
#  ['đã Brandenburg sử_dụng những gì ghi để tinh_chỉnh ?', 'thuật_toán nén MP3'],
#  ['Quốc_hội Việt_Nam mỗi năm họp mấy kỳ',
#   'Địa_vị pháp_lý của một đại_biểu quốc_hội được bắt_đầu sau khi Quốc_hội đã xác_nhận tư_cách đại_biểu tại phiên họp đầu_tiên của kỳ thứ nhất mỗi khoá Quốc_hội . Nhiệm_kỳ của đại_biểu quốc_hội được tính từ kỳ họp thứ nhất Quốc_hội khoá đó đến kỳ họp thứ nhất Quốc_hội khoá sau .'],
#  ['México nằm ở khu_vực nào',
#   'México ( phiên_âm : " " Mê-xi-cô " " hoặc " " Mê-hi-cô " " , , tiếng Nahuatl : " Mēxihco " ) , tên chính_thức : Hợp chúng quốc México ( , ) , là một nước cộng_hoà liên_bang thuộc khu_vực Bắc_Mỹ . México là một quốc_gia rộng_lớn với diện_tích gần 2 triệu km2 , đứng hàng thứ 14 trên thế_giới và dân_số khoảng 106 triệu người , đứng hàng thứ 11 trên thế_giới .'],
#  ['tài_liệu gì có tỷ_lệ hấp_thụ chỉ đạt 0,01% ?', 'Teflon'],
#  ['Có bao_nhiêu bán_buôn các công_ty ở Istanbul vào năm 1911 ?', '654'],
#  ['Ai là người thành_lập Facebook',
#   'Facebook có_thể truy_cập được từ hầu_như mọi thiết_bị có khả_năng kết_nối Internet , từ máy_tính_để_bàn , máy_tính_xách_tay , máy_tính bảng cho đến điện_thoại thông_minh . Sau khi đăng_ký tài_khoản trên Facebook , người dùng có_thể tạo ra một hồ_sơ tuỳ chỉnh cho biết tên của họ , nghề_nghiệp , trường_học ...'],
#  ['dân_số của Saint_Helena là gì ?', '4.255'],
#  ['hạn nào được sử_dụng để mô_tả thời_kỳ đồ đá mới giữa cuối trong giáo_dục Mỹ ?',
#   'giai_đoạn hình_thành'],
#  ['Mà con_người không tiến_hoá mối quan_tâm nhân_loại_học bản_thân với sự tiến_hoá sinh_học và văn_hoá của ?',
#   'quá_khứ và hiện'],
#  ['Bao_lâu thì các loại thuốc_trừ_sâu được sản_xuất gần đây hơn là đánh_giá cho sự an_toàn ?',
#   'mỗi 15 năm'],
#  ['phương_pháp nào được sử_dụng cho các thành_phần kiểm_tra dưới khối_lượng công_việc đột_xuất ?',
#   'Căng_thẳng thử_nghiệm'],
#  ['Toà_án đã viết những gì về ý_kiến của Jefferson vì nó liên_quan đến phạm_vi và tác_động của Tu_chính án đầu_tiên ?',
#   'có thẩm_quyền'],
#  ['Có gì hiếm khi được sử_dụng ?', 'brisure'],
#  ['ai là phó bí_thư hiện_tại của Đà_Nẵng',
#   'Một_số cán_bộ Đà_Nẵng bị bắt , khám_xét nhà vì liên_quan tới Vũ " nhôm " vì " Vi_phạm các quy_định về quản_lý đất_đai ” bao_gồm : Ông Đào_Tấn_Bằng , sinh năm 1975 , nguyên Phó Chánh Văn_phòng UBND TP. Đà_Nẵng , nay là Bí_thư Đảng_uỷ khối các Khu công_nghiệp TP. Đà_Nẵng ; ôngNguyễn Viết_Vĩnh , sinh năm 1978 , nguyên Trưởng phòng Quản_lý đô_thị , UBND TP. Đà_Nẵng , nay là Giám_đốc Cảng_vụ đường_thuỷ nội_địa .'],
#  ['Những hành_động đã ISIL mất chống lại các nhà_báo phương Tây và nhân_viên cứu_trợ ?',
#   'và xử_trảm'],
#  ['Côn_Sơn ca là tác_phẩm của ai',
#   'Nguyễn_Trãi là Nhà chính_trị , Nhà địa_lý , Nhà ngoại_giao là anh_hùng của dân_tộc Việt_Nam . Nguyễn_Trãi lấy bút_danh là Ức_Trai . Ông sinh ra và lớn lên tại Kinh_Thành Thăng_Long . Cha là Nguyễn_Phi_Khanh quê ở làng Chi_Ngại thuộc xã Công_Hoà , huyện Chí_Linh , tỉnh Hải_Dương . Sau chuyển đến Nhị_Khê thuộc Hà_Tây cũ . Mẹ là Trần_Thị_Thái con gái quan tư_đồ Trần_Nguyên_Đán . Cha_mẹ ông sinh được năm người con nhưng không bao_lâu mẹ của Nguyễn_Trãi qua_đời , anh_em Nguyễn_Trãi phải sống cùng ông ngoại là Trần_Nguyên_Đán tại Kinh_Thành Thăng_Long , rồi chuyển lên Côn_Sơn , nhưng ông ngoại ông là Trần_Nguyên_Đán cũng qua_đời vào năm 1390 . Nguyễn_Trãi cùng các anh_em phải về Nhị_Khê sống với cha . Được ông ngoại và cha trực_tiếp dạy_dỗ nên Nguyễn_Trãi nổi_tiếng là người có tài , có đức và có chí lớn . Năm 1400 , ông đỗ Thái_Học_Sinh và được nhận chức Ngự_Sử_Đài Chánh_Trưởng dưới thời Hồ . Năm 1407 , nước ta bị giặc Minh xâm_chiếm , theo lời dặn của cha , ông nặng nghĩa nước , trả_thù nhà , ngày_đêm nung_nấu ý_chí giết giặc , trăn_trở kế bình Ngô . Sau Khi thoát khỏi sự truy_sát của quân giặc , Nguyễn_Trãi đến Lam_Sơn tụ_nghĩa , dự hội thề Lũng_Nhai , Dâng_Bình_Ngô Sách.Trong những năm chiến_đấu ông đã luôn sát_cánh bên Lê_Lợi và đưa ra nhiều mưu_kế xuất_sắc trong kháng_chiến . Năm 1927 , đất_nước ca_khúc khải_hoàn , Nguyễn_Trãi đã thay_mặt Lê_Lợ viết " Bình_Ngô Đại_Cáo " . đó là bản tuyên_ngôn độc_lập , là áng thiên_cổ hùng văn trong lịch_sử Việt_Nam . Bên cạnh sự_nghiệp dựng nước ông đã để lại cho lịch_sử những tác_phẩm tiêu_biểu : Quân Trung_Từ_Mệnh_Tập , Bình_Ngô Đại_Cáo , Văn_Bia Vĩnh_Lăng , Quốc_Âm Thi_Tập ... Những tác_phẩm của ông kết_tinh được những tư_tưởng tiến_bộ của thời_đại , tinh_hoa và khí_phách của dân_tộc . Năm 1937 , Nguyễn_Trãi thoát triều về Côn_Sơn , ông đã viết bài Côn_Sơn_Ca để tỏ lòng mình Năm 17 tuổi , ông được vua Lê_Thánh_Tông trọng_dụng phục_hồi chức_vụ cũ . Tháng 3 năm 1442 , Nguyễn_Trãi làm đề cho cuộc thi đại_học đầu_tiên thời Lê_sơ . Năm 1442 , vợ ông là bà Nguyễn_Thị_Lộ bị vu_oan giết vua Lê_Thánh_Tông , nên vào ngày 19/9/1442 , ông cùng dòng_họ bị giết_hại thảm_khốc . Phải 22 năm sau gia_đình ông mới được minh_oan . Năm 1980 , Nguyễn_Trãi đã được công_nhận là Danh_Nhân Văn_Hoá Thế_giới .'],
#  ['Khi đã Spielberg và Irving kết_hôn ?', 'tháng 11 năm 1985 ,'],
#  ['Khi là lần cuối_cùng Chicago_Cubs xuất_hiện vào mùa thu cổ_điển ?',
#   'năm 1945 , mặc_dù'],
#  ['Có bao_nhiêu người tham_gia thử giọng đầu_tiên ?', 'khoảng 10.000'],
#  ['Tại_sao Madrid nhượng lãnh_thổ sang Mỹ',
#   'Florida đã trở_thành một gánh nặng sang Tây_Ban_Nha , trong đó không_thể đủ khả_năng để gửi người định_cư hoặc đơn_vị đồn_trú'],
#  ['Bao_nhiêu doanh_thu đã Spectre sản_xuất từ Anh , Scotland , và thị_trường Ailen bởi 20 16/02 / 21 ?',
#   '$ 138'],
#  ['năm gì được một nhà_nghỉ Masonic toàn nữ tạo ra ?', 'năm 1901 ,'],
#  ['Bến Nhà_Rồng được bắt_đầu xây vào năm nào',
#   'Năm 1919 , hãng được phép xây bến bằng xi_măng cốt sắt , nhưng không thực_hiện được , phải đến tháng 3 năm 1930 mới hoàn_thành bến mới , chỉ một bến nhưng dài tới 430 mét .'],
#  ['Đảo nào lớn nhất Ấn_Độ Dương',
#   '" Adansonia grandidieri " là lớn nhất và nổi_tiếng nhất của Madagascar trong sáu loài bao báp . Cây hùng_vĩ và bất_thường này là loài đặc_hữu của đảo Madagascar , nơi mà nó là một loài nguy_cấp bị đe_doạ bởi sự xâm_lấn đất nông_nghiệp .'],
#  ['ca_sĩ gì chỉ_trích Carrie_Underwood cho chiến_thắng một giải_thưởng nhạc_đồng_quê ?',
#   'LeAnn_Rimes ,'],
#  ['đã Tướng Oreste_Baratieri công_bố gì ở vùng cao_nguyên dọc theo bờ biển Eritrea ?',
#   'mới thuộc địa của Ý Eritrea ,'],
#  ['tên thay_thế cajmere là gì ?', 'Velvet_Xanh'],
#  ['Cung_An_Định thuộc phong_cách kiến_trúc nào',
#   'Trong khu_vực cung Diên_Thọ có khoảng 20 công_trình kiến_trúc lớn_nhỏ , vừa phong_phú về loại_hình vừa đa_dạng về phong_cách kiến_trúc . Hiện_nay chỉ còn lại các công_trình sau .'],
#  ['Đa_số người_dân Ai_Cập sống gần sông gì ?', 'sông Nile ,'],
#  ['đã lạc Celtic khai_thác được gì từ dãy Alps ?', 'đồng ;'],
#  ['Hy_Lạp là nhà_đầu_tư nước_ngoài lớn nhất của khu_vực gì ?',
#   'Cộng_hoà Macedonia'],
#  ['Khi một người hoặc động_vật sẽ mất ý_thức khi tiếp_xúc với một chân_không ?',
#   'sau một_vài giây'],
#  ['Không sử_dụng UTC , Windows không_thể khởi_động đa với các phiên_bản khác nhau của bản_thân như bạn cần phải làm gì để sử_dụng những loại đĩa ?',
#   'một đĩa khởi_động cứu_hộ'],
#  ['Ai giới_thiệu Nasser và vợ của ông ?', 'Abdel_Hamid_Kazim ,'],
#  ['Mà nhà_thờ đã Reporters_Without_Borders treo một biểu_ngữ phản_đối ?',
#   'nhà_thờ Notre_Dame'],
#  ['Có gì cho_phép Rome nguồn một_số quân của họ từ các khu_vực khác gần đó ?',
#   'liên_minh quân_sự với các dân_tộc khác'],
#  ['Tại_sao đường lên_men hơn sẽ được thêm vào là bia trong quá_trình sản_xuất bia ?',
#   'để tăng nồng_độ cồn ,'],
#  ['đã Henry cưới ai ?', 'Eleanor xứ Aquitaine ,'],
#  ['Là các phiên họp của Quốc_hội thành_phố tư_nhân hoặc công_cộng ?', ''],
#  ['Có gì kinh sách mô_tả việc săn_bắn như nghề_nghiệp và chấp_nhận được ?',
#   'Hindu'],
#  ['hoạt_động Lingayen_Vịnh hỗ_trợ những gì đổ ?', 'Luzon'],
#  ['dòng_điện tạp_chí các vấn_đề phổ_biến nhất ở Namibia là gì ?',
#   'Cái nhìn sâu_sắc Namibia ,'],
#  ['Đã_Thomas_Newman soạn cân_bằng tỷ_số sau khi quay hoặc trong quá_trình quay_phim ?',
#   'trong quay'],
#  ['nguyễn_tấn dũng là ai',
#   'Nguyễn_Tấn_Dũng ( tên thường gọi : Ba Dũng , sinh ngày 17 tháng 11 năm 1949 tại Cà_Mau ) là một chính_trị_gia Việt_Nam . Ông là Thủ_tướng chính_phủ thứ_sáu của Cộng_hoà_Xã_hội_chủ_nghĩa_Việt_Nam ( 2006 – 2016 ) . Từ năm 1997 , ông cũng đồng_thời là Đại_biểu Quốc_hội Việt_Nam các khoá X , XI , XII , XIII thuộc đơn_vị bầu_cử khu_vực 3 Thành_phố Hải_Phòng ( huyện Tiên_Lãng ) , Uỷ_viên Bộ_Chính_trị các khoá VIII , IX , X , XI , Trưởng ban Ban Chỉ_đạo thi_hành án phần tài_sản vụ án EPCO - Minh_Phụng từ năm 2002 .'],
#  ['các bộ_phận của chiếc cúp là gì ?',
#   '- tách bản_thân , cộng với một nắp và một'],
#  ['Bao_nhiêu gia_tăng trong không_gian đất đã điền của khu mỏ gây ra ?',
#   'tám phần_trăm'],
#  ['chủ_tịch hiện_nay của Hải_Dương là ai',
#   'Vũ_Thị_Thuỷ ( sinh ngày 23 tháng 7 năm 1966 ) là một chính_trị_gia người Việt_Nam . Bà hiện là đại_biểu Quốc_hội Việt_Nam khoá XIV nhiệm_kì 2016-2021 , thuộc đoàn đại_biểu quốc_hội tỉnh Hải_Dương , Chủ_tịch Hội Liên_hiệp Phụ_nữ tỉnh Hải_Dương , Uỷ_viên Uỷ_ban Mặt_trận Tổ_quốc tỉnh Hải_Dương , Uỷ_viên Ban_Chấp_hành Trung_ương Hội Liên_hiệp Phụ_nữ Việt_Nam , Uỷ_viên Uỷ_ban Khoa_học , Công_nghệ và Môi_trường của Quốc_hội .'],
#  ['tổ_chức những gì đã làm tất_cả các chiến_binh trên cả hai mặt của cuộc_chiến thuộc về ?',
#   'của Liên_Hợp_Quốc'],
#  ['Có gì vũ_khí La_Mã bắt_đầu được sử_dụng một lần nữa ở Trung sớm Cổ ?',
#   'nỏ ,'],
#  ['Ai được coi là " Bố_già Atlantic_City không ? "', 'Nelson_Johnson'],
#  ['cơ_sở vật_chất thuỷ_lực của Melbourne đã giúp gì tạo ra rằng phát_triển nhà cao_tầng thúc_đẩy ?',
#   'thang_máy ,'],
#  ['có bao_nhiêu tàu_thuyền Torbay ?', 'ba'],
#  ['Hy_Lạp tổ_chức gì là một thành_viên sáng_lập ?', 'OECD )'],
#  ['Ai là vị Trưởng ban cháy cho đến tháng sáu năm 2008 ?',
#   'Russell ( Rusty ) Thomas'],
#  ['cơ_sở cho " Thiên_nhiên , Man và Thiên_Chúa " là gì ?',
#   'Đền của Gifford_Lectures của 1932-1934'],
#  ['Trong những năm đã Royal_Society of London được đưa ra một điều_lệ của hoàng_gia ?',
#   '1662'],
#  ['Những phẩm_chất vật_lý là cần_thiết cho gymastics nhịp_nhàng ?',
#   'linh_hoạt , cân_bằng , tốc_độ , sức_mạnh , sự phối_hợp và cảm_giác nhịp_điệu'],
#  ['Ai mà các nicname " Die_ROTEN " thuộc về ?', 'Hannover 96'],
#  ['thuật_ngữ cho khi tiếng_địa_phương A và B là hai bên dễ hiểu , phương_ngữ B và C là dễ hiểu lẫn nhau , nhưng phương_ngữ A và C không phải là dễ hiểu lẫn nhau là gì ?',
#   'continua phương_ngữ ,'],
#  ['Ai được chính_thức lật_đổ bởi Constitutent hội Nam_Tư vào ngày 29 tháng 11 năm 1945 ?',
#   'Vua_Peter_II'],
#  ['Có gì cựu lãnh_đạo của một công_ty sản_xuất xe tham_dự KU ?',
#   'Alan_Mulally'],
#  ['Khi được tên trường Đại_học Washington sửa_đổi ?', 'năm 1856 , Đại_học'],
#  ['Ai là người đầu_tiên trình_tự bộ gen DNA-dựa ?', 'Fred_Sanger'],
#  ['Gì đã Wittgenstein và Hayek làm trong chiến_tranh thế_giới thứ nhất ?',
#   'cả hai đều là cán_bộ'],
#  ['Có gì từng là thủ_đô của nước Pháp trong tinh_thần trong suốt Nghề_nghiệp ?',
#   'Brazzaville'],
#  ['Mà câu_lạc_bộ EPA được Đại_học Northwestern trong ?',
#   'Green_Power_Leadership_Club'],
#  ['Mà đại_học là để hai chàng trai tham_dự ?', 'Eton_College'],
#  ['Ai là châu_Âu đầu_tiên đến thăm hòn đảo này là ?', 'Ferdinand_Magellan'],
#  ['Ai lãnh_đạo phong_trào Dân_quyền ?', 'Mục_sư Martin_Luther_King , Jr .'],
#  ['Nước nào là quê_hương của ông_già tuyết',
#   'Ông_già Tuyết và mùa hè ( tiếng Nga : " Дед_Мороз и лето " ) là một phim_hoạt_hình nổi_tiếng của Valentin_Karavayev về ông_già Tuyết và các bạn nhỏ với mùa hè .'],
#  ['Khi được các Anglo - Nga Entente ký ?', '1907'],
#  ['cây gì chi được đặt theo tên của Avicenna ?', 'Mắm'],
#  ['Nasser là một nhà_lãnh_đạo của nước nào ?', ''],
#  ['giá trung_bình của tài_sản mỗi mét_vuông ở trung_tâm London vào tháng tư năm 2014 là gì ?',
#   '€ 24.252'],
#  ['không " Hoogduits " dịch gì bằng tiếng Anh ?', 'Cao_Hà_Lan " ,'],
#  ['Làm thế_nào được sóng được sử_dụng trong những cách thảo_luận kiểm_soát ?',
#   'hài_hoà'],
#  ['Nhận_thức thông_tin và duy_trì nó là gì ?', 'tình_báo'],
#  ['Mà công_việc lập_pháp cấm việc sử_dụng các ưu_đãi về phân_biệt chủng_tộc đối_với tuyển_sinh ở bang California ?',
#   'Dự_luật 209'],
#  ['Người duy_nhất 2 lần được tặng Huân_chương Hồ_Chí_Minh là ai',
#   'Đại_tướng Võ_Nguyên_Giáp là người đầu_tiên được tặng_thưởng Huân_chương Hồ_Chí_Minh và cũng là người 2 lần được tặng_thưởng ( lần thứ nhất năm 1950 và lần thứ hai năm 1979 ) .'],
#  ['Rigas_Feraios đã bị giết bởi những kẻ ám_sát Ottoman trong năm nào ?',
#   '1798'],
#  ['hình_học kiến_trúc thi_đua của vũ_trụ làm gì ?', 'Đời_đời'],
#  ['Giám_đốc công_an thành_phố Hà_Nội là ai',
#   'Ông được bổ_nhiệm làm Giám_đốc Công_an thành_phố Hà_Nội từ tháng 9 năm 2012 , kế_nhiệm Trung_tướng Nguyễn_Đức_Nhanh nghỉ hưu .'],
#  ['Ai là đối_thủ của Liên_Xô trong Chiến_tranh_Lạnh ?', 'Hoa_Kỳ ,'],
#  ['Thành_phố có bao_nhiêu trách_nhiệm chủ_trương lớn ?',
#   'chính_quyền địa_phương có_thể biện_minh cho'],
#  ['Sau khi được đưa ra một_số luật , một luật mới được chuẩn_bị để công_bố như những gì ?',
#   'luật trượt'],
#  ['Ai làm cô tín_dụng đối_với nguồn cảm_hứng để " thức dậy ở đó và làm những gì cô ấy đã làm " ?',
#   'Whitney_Houston ,'],
#  ['Khi nào các Hashimiyya chinh_phục Kufa ?', '749 ,'],
#  ['Có gì trùng_lặp đáng_kể với Haredi_Judiasm ?', 'Chasidic_Do_Thái giáo'],
#  ['Có gì phát_triển chính_trị hình chính_sách của người Anh ?',
#   'chính_phủ liên_tiếp dẫn_đầu bởi Newcastle và Pitt đã giảm'],
#  ['Đất_nước nào ở châu_Á được biết đến với " cuộc cách_mạng trắng "',
#   'Phan_Quỳnh_Ngân còn được biết đến với nghệ_danh Juna , là người đẹp giành giải Á_hậu 3 cuộc thi " Hoa_hậu doanh_nhân người Việt châu_Á năm 22017 " . Cô còn được biết tới với vai_trò ca_sĩ .'],
#  ['Locke cho rằng quyền tự_nhiên để sở_hữu được bắt_nguồn từ những gì ?',
#   'lao_động $$ $ . Dạy bởi Locke , Anthony Ashley-Cooper , 3rd Bá_tước Shaftesbury viết vào năm 1706 : " Có một ánh_sáng hùng_mạnh mà lây_lan tự của nó trên toàn thế_giới đặc_biệt là ở hai quốc miễn_phí của Anh và Hà_Lan ; kẻ ở gần giao châu_Âu hiện_nay lần_lượt " . lý_thuyết về quyền tự_nhiên của Locke đã ảnh_hưởng nhiều văn_bản chính_trị , trong đó có Tuyên_bố Hoa_Kỳ độc_lập và Tuyên_bố'],
#  ['một mục_tiêu chính của kế_hoạch cải_cách thị_trường của Iran là gì ?',
#   'đa_dạng_hoá nền kinh_tế dầu phụ_thuộc của Iran'],
#  ['Trong những năm được Plymouth_Sứ thành_lập ?', '1768'],
#  ['Khi nào các Jacquerie_Pháp diễn ra ?', '1358'],
#  ['Khi đã làm người đứng đầu chính_phủ Quốc_Dân Đảng Đài_Loan ?',
#   'ngày 10 tháng 12'],
#  ['Đâu_Spectre quay_phim diễn ra sau khi Roma ?', 'Mexico City'],
#  ['Là tiếng Anh tại Puerto_Rico thành_công ?', 'Nó đã hoàn_toàn thất_bại ,'],
#  ['Làm thế_nào đã Census_Bureau thay_đổi bộ sưu_tập dữ_liệu ?',
#   'cho_phép mọi người tự nhận là nhiều hơn một dân_tộc'],
#  ['phần_mềm gì đã của Apple sử_dụng làm cơ_sở cho phần_mềm iPod của họ ?', ''],
#  ["Khi đã Canal de l ' Ourcq bắt_đầu cung_cấp Paris với nước ?", 'năm 1809 ,'],
#  ['Trong bộ phim Dick_Tracy , người đã Madonna đóng vai ?',
#   'Breathless_Mahoney'],
#  ['Tại_sao Empires và Quốc của châu_Âu cử ?',
#   'sự đột_biến của chủ_nghĩa cộng_hoà'],
#  ['lý_do một dự_luật đã vô_tình assented năm 1976 là gì ?',
#   'hai hoá_đơn cùng tên đã có nguồn_gốc từ'],
#  ['Nhà_hát Broadway nằm ở đâu',
#   '( Năm 1937 , được biết đến như là Ciné_Roma , khi trình_chiếu các bộ phim Ý ) .'],
#  ['Một trong những trợ_lý Chiefs của Staff_Defense là dành cho dự_trữ và những gì ?',
#   'Cadets )'],
#  ['Làm thế_nào mà Spielberg ảnh_hưởng đến hành_vi của công_chúng ?',
#   'nhiều ý_nghĩ trong một giây trước khi đi vào nước trong mùa hè này'],
#  ['Khi được giai_đoạn một hoàn_thành ?', 'năm 1988 ,'],
#  ['Có gì núi Nepal được khẳng_định để thu_hút khách du_lịch ?',
#   'dãy Himalaya'],
#  ['Có gì mảnh quần_áo là macawis tương_tự ?', 'sarong như'],
#  ['Thuyết_tiến_hoá của Darwin ra_đời vào năm nào',
# ...
#  ['Tướng_quân Nguyễn_Sơn quê ở đâu',
#   'Travel blogger nổi_tiếng Nguyễn_Sơn_Tùng_Bức ảnh yêu thích nhất của travel blogger Nguyễn_Sơn_Tùng_Travel blogger Nguyễn_Sơn_Tùng admin của fanpage Lạc'],
#  ['Mà được giải_thưởng Chiếc giày vàng dành cho ?',
#   'cầu_thủ ghi_bàn hàng_đầu Premier_League'],
#  ['Có bao_nhiêu Billboard biểu_đồ toppers đã thí_sinh American_Idol có trong vòng mười mùa đầu_tiên ?',
#   '345'],
#  ['Có bao_nhiêu văn_bản bằng ngôn_ngữ Sumer đã sống_sót đến ngày_nay ?',
#   'hàng trăm_ngàn'],
#  ['bộ_lạc gì là cấu_trúc xã_hội trước khi từ đâu ?', 'Ba_Lan'],
#  ['chữ_viết tắt mà Đại_học Kansas được biết đến là gì ?', 'KU )'],
#  ['Loại cộng_đồng được Siddhartha_Gautama lớn lên ở ?',
#   'Đó là một trong hai một nước cộng_hoà nhỏ , trong trường_hợp cha mình là một thủ_lĩnh bầu , hoặc một đầu_sỏ , trong trường_hợp cha mình là một nhà tài_phiệt'],
#  ['Giáo_Hội Đông tin rằng những gì liên_quan đến cái chết và ressurection ?',
#   '" pre-mãi mãi " xác_định bởi Cha'],
#  ['Dòng sông huyền_thoại nào ở Tây_Sơn gắn liền sự phát_tích của vương_triều Tây_Sơn',
#   'Toàn_bộ lãnh_thổ phía nam sông Gianh , tương_đương với lãnh_thổ chúa Nguyễn cai_quản trước_đây , thuộc về Tây_Sơn .'],
#  ['Mà quân_đội đã có một nhóm các tình_nguyện_viên Armenia chiến_đấu cho họ ?',
#   'Nga Quân_đội'],
#  ['Cao bao_nhiêu Một Mỹ Plaza ?', '500 feet'],
#  ['nén những gì không_thể đạt được tỷ_lệ nén cao ?', 'Lossless'],
#  ['Có bao_nhiêu các trung_tâm khoa_học hàn_lâm lăm sức_khoẻ của Vương_quốc_Anh được đặt tại London ?',
#   'ba'],
#  ['Bao_lâu là cảnh săn_bắn tại rustica biệt_thự ?', ''],
#  ['Có gì thường_niên sự_kiện tại BYU được thực_hiện trong bộ_nhớ của cựu chủ_tịch Rex E. Lee , người đã xây_dựng Bảo_tàng Nghệ_thuật trong khuôn_viên trường ?',
#   'ung_thư gọi là Rex_Lee_Run'],
#  ['Những bài viết trong Hiến_pháp Norweigan cung_cấp một_cách để ghi đè lên quyền phủ_quyết của một quốc_vương ?',
#   'Điều 79'],
#  ['Theo một báo_cáo của CDC năm 2008 , có bao_nhiêu bị cắn ở Mỹ mỗi năm ?',
#   '4'],
#  ['Làm thế_nào để hạn_chế rác_thải ra môi_trường',
#   'Lò đốt rác_thải sinh_hoạt ( tiếng Anh : ) là một thiết_bị hữu_hiệu trong công_tác xử_lý rác_thải giữ_gìn môi_trường xanh , phát_triển bền_vững .'],
#  ['Thành_phố nào là thủ_đô của Costa_Rica',
#   'Cartago là một tỉnh của Costa_Rica . Tỉnh này nằm ở trung_bộ quốc_gia này . Các tỉnh giáp_ranh là : Limón về phía đông và San_José về phía tây . Tỉnh_lỵ là Cartago nguyên là thủ_đô của Costa_Rica . Tỉnh có diện_tích 3.124,61 km2 ( 1 ) và dân_số 461.163 người ( 2 ) . Về mặt hành_chính , tỉnh được chia thành 8 tổng . Tỉnh này được kết_nối với San_Jose băng một tuyến xa_lộ 4 làn xe .'],
#  ['phải một sĩ_quan cảnh_sát tụng gì để nghi_ngờ một_khi bắt_giữ /',
#   'Miranda cảnh_báo'],
#  ['hạn khác đối_với một phương_ngữ tiêu_chuẩn hoặc tiêu_chuẩn_hoá là gì ?',
#   'ngôn_ngữ tiêu_chuẩn " )'],
#  ['nữ đấu_vật chuyên_nghiệp gọi là ở Nhật_Bản là gì ?', 'Joshi puroresu'],
#  ['Có bao_nhiêu của Đại_lễ kính chính_thống dành riêng cho Mary ?', 'Năm'],
#  ['Ai đã làm Machiavelli thái_độ khinh_thị ?',
#   'nhà_văn về chính_trị người đánh_giá tất_cả mọi thứ so với những lý_tưởng tinh_thần'],
#  ['Có bao_nhiêu nhân_viên đã Imperial nộp đánh_giá về để đánh_giá REF ?',
#   '1,257'],
#  ['Nước nào thuyết_phục Syria để thực_sự từ_bỏ vũ_khí_hoá_học của nó ?',
#   'Nga'],
#  ['Khi được Quân_đội Canada kêu_gọi hỗ_trợ ở châu_Âu ?',
#   'Chiến_tranh thế_giới thứ nhất ,'],
#  ['Ai đã báo_cáo rằng Nintendo đã bán được 7 triệu hệ_thống NES ?',
#   'Tính_toán !'],
#  ['bản dịch của văn_bản được Sung gắn liền với là gì ?', 'thơ'],
#  ['Ngôn_ngữ nào đã viết nhà_thờ phụng vụ trong ?', 'Cyrillic'],
#  ['Đâu chúa Victoria và chồng bà để lại cho sau khi kết_hôn của họ ?',
#   'Đức ;'],
#  ['Chuyện gì xảy ra với tiêu_chảy viêm ?',
#   'lỗ thụ_động của chất_lỏng giàu protein và giảm khả_năng hấp_thụ các chất_lỏng bị mất'],
#  ['bản dịch Latin gián_tiếp tiên_tiến mà khoa_học và văn_hoá ?', 'khoa_học'],
#  ['Tổng_thống Truman là gì nói với tại cuộc họp này ?',
#   'ít nguy_cơ can_thiệp của Trung_Quốc tại Hàn_Quốc ,'],
#  ['ngọn núi cao nhất ở Hy_Lạp là gì ?', 'Núi Olympus'],
#  ['Có bao_nhiêu người đã chết trong các cuộc bạo_loạn nhà_máy dệt ?',
#   'chín $ $$ người thiệt_mạng . Trong khi hầu_hết các RCC khăng_khăng đòi thực_hiện hai kẻ cầm_đầu của bạo_loạn , Nasser'],
#  ['Tên viết tắt của Diễn_đàn hợp_tác Á-Âu là gì',
#   'Diễn_đàn Hợp_tác Á-Âu ( ASEM ) là một quá_trình đối_thoại không chính_thức được đưa ra sáng_kiến năm 1996 với mục_tiêu tăng_cường hợp_tác giữa các quốc_gia châu_Á và châu_Âu , đặc_biệt giữa các thành_viên Liên_minh châu_Âu và ASEAN . ASEAN , được đại_diện bởi vị Tổng_thư_ký của mình , là một trong 45 đối_tác ASEM . Họ cũng chỉ_định một đại_diện trong ban quản_lý Quỹ Á-Âu ( ASEF ) , một tổ_chức văn_hoá xã_hội gắn liền với cuộc Gặp_gỡ .'],
#  ['Có gì thăng_tiến trong Không_quân Hoa_Kỳ được điều_chỉnh bởi một quá_trình lựa_chọn chính_thức ?',
#   'Xúc_tiến tới chủ_yếu qua'],
#  ['Ai ủng_hộ anh_em trai của John ?', 'Eleanor ,'],
#  ['lớp gì đã cá_nhân từng là quan_chức trong chính_phủ thuộc về ?',
#   'thường_dân xã_hội'],
#  ['phim gì khối cho thấy phim_câm ?', 'Im_lặng Chủ_Nhật Nights " ,'],
#  ['Có gì giảm từ ngày 5 đến thế_kỷ thứ 13', 'Śrauta hy_sinh'],
#  ['một lý_luận Shakespeare là một nơi tốt để tập_trung vào phê_bình văn_bản là gì ?',
#   'văn_bản , như truyền đi , chứa một lượng đáng_kể các biến_thể ,'],
#  ['Trong loại của cuộc khủng_hoảng đã Emperor_Huân xa_lánh bộ_máy quan_liêu ?',
#   'cuộc khủng_hoảng_kinh_tế'],
#  ['Có bao_nhiêu đại_diện nào tại Premier_League có của Hiệp_hội Câu_lạc_bộ châu_Âu 2012-13 ?',
#   'Đối_với mùa 2012-13 Premier_League có 10 đại_diện trong Hiệp_hội :'],
#  ['Triều_đại nào tồn_tại lâu nhất trong lịch_sử Trung_Quốc',
#   'Tào_Phi lên_ngôi Hoàng_đế , lập ra triều_đại Tào_Nguỵ ở miền bắc Trung_Quốc , bắt_đầu thời_kỳ Tam_Quốc ( Bắc_Nguỵ , Tây_Thục , Đông_Ngô ) kéo_dài 60 năm ( 220 - 280 ) nổi_tiếng trong lịch_sử Trung_Quốc .'],
#  ['Ai đặt truy_cập cơ_sở_dữ_liệu ?',
#   'uỷ_quyền ( do chủ cơ_sở_dữ_liệu ) nhân_sự đặc_biệt'],
#  ['Những loại công_dân làm các công_dân của Saint_Helena giữ ?',
#   'Anh Lãnh_thổ hải_ngoại quyền_công_dân'],
#  ['tên viết 35 trang của Darwin về lý_thuyết của ông là gì ?',
#   '" Phác_hoạ bút_chì "'],
#  ['đã Darwin thừa_nhận những gì về đặc_điểm thu được trong chương một trong Nguồn_gốc các loài ?',
#   '" Các định_luật chi_phối thừa_kế khá lạ'],
#  ['Điều gì đã làm_luật hạn_chế hút thuốc_lá hoàn_thành ?',
#   'giảm số_lượng người nhập_viện vì hen_suyễn'],
#  ['Khi được trong khuôn_viên trường Cao_đẳng Wye đóng_cửa ?',
#   'tháng 9 năm 2009'],
#  ['Về bao_nhiêu người sống ở quần_đảo_Marshall vào năm 1862 ?', '10.000'],
#  ['Chính_phủ dưới mà kinh_nghiệm chuyển_đổi sang đồng_tiền thập_phân ?',
#   'Holt'],
#  ['một thực_tế đáng chú_ý hữu thần cá_nhân là ai ?', 'Thánh_Tôma_Aquinô'],
#  ['Mà tác_giả của tiểu_thuyết vẽ một bức chân_dung ảm_đạm của Victoria_London ?',
#   'Charles_Dickens ,'],
#  ['Trong trường_hợp đang tải cầu_cảng được tìm thấy trên Đảo_Norfolk ?',
#   'Kingston và Cascade ,'],
#  ['Trong đó giai_đoạn được triết_lý của chủ_nghĩa_nhân_văn tiếp_theo được cập_nhật ?',
#   'Giác_Ngộ Pháp ,'],
#  ['Ai là thủ_lĩnh khởi_binh chống lại chính_quyền đô_hộ Đông_Hán',
#   'Trong sử_sách , hai bà được biết đến như những thủ_lĩnh khởi_binh chống lại chính_quyền đô_hộ của Đông_Hán , lập ra một quốc_gia với kinh_đô tại Mê_Linh và Trưng_Trắc tự phong là Nữ_vương . Thời_kì của hai bà xen giữa Bắc_thuộc lần 1 và Bắc_thuộc lần 2 trong lịch_sử Việt_Nam .'],
#  ['Khi đã làm Spielberg và Irving ly_dị ?', '1989'],
#  ['Làm thế_nào là hệ_thống đường_cao_tốc Eritrea đặt tên ?',
#   'theo phân_loại đường'],
#  ['một_cách thức mà những người nhập_cư Nga tích_hợp vào xã_hội Alaska là gì ?',
#   'kết_hôn với những người bản_địa Alaska'],
#  ['Luật_pháp nào đã Obama trích_dẫn trên 09 tháng 9 năm 2014 ?',
#   'sự uỷ_quyền năm 2001 cho Sử_dụng Quân_Lực_lượng chống khủng_bố ,'],
#  ['cái gì mà có_thể gây ra việc tiếp_nhận và giải_mã nội_dung của một thông_điệp tới bị lỗi là gì ?',
#   'tiếng ồn giao_tiếp "'],
#  ['định_dạng dự_kiến ban_đầu cho đĩa CD là gì ?', 'dữ_liệu lưu_trữ'],
#  ['thể_thao gì tờ New_York_Rangers chơi ?', 'Hockey'],
#  ['Làm thế_nào nên mức_độ rủi_ro đã được tiết_lộ theo nhiều học_giả ?',
#   'đơn_giản định_dạng , dễ_dàng hiểu'],
#  ['Một mảnh bằng_chứng của các cộng_đồng Đức tại thành_phố thánh trong nửa sau của thế_kỷ 11 là do những gì các mặt_hàng được gửi từ Đức đến Jerusalem ?',
#   'câu hỏi halakhic'],
#  ['Hộp công_cụ cộng_đồng có_thể được tìm thấy ở đâu ?', 'trực_tuyến'],
#  ['Tại_sao các Chamorros đưa đến Guam ?', 'để phục_vụ như dịch viên'],
#  ['mà cây_trồng đã được đưa đến châu_Âu từ thế_giới Hồi_giáo ?',
#   'hạnh_nhân và trái_cây họ cam quýt'],
#  ['Thổ_Nhĩ_Kỳ độc_lập từ năm nào',
#   'Người Síp Thổ_Nhĩ_Kỳ cuối_cùng đã tuyên_bố độc_lập năm 1983 trở_thành Cộng_hoà Bắc_Síp_Thổ_Nhĩ Kỳ , nhưng chỉ được mỗi Thổ_Nhĩ_Kỳ công_nhận . Năm 1985 , Cộng_hoà Bắc_Síp_Thổ_Nhĩ Kỳ đưa ra một hiến_pháp và tổ_chức cuộc bầu_cử đầu_tiên .'],
#  ['dân_số gì có đột_biến mtDNA và atDNA , khiến họ khác_biệt với người_dân bản_địa khác của châu_Mỹ ?',
#   'Alaska'],
#  ['Làm thế_nào mà việc bán hàng thực_tế của của G4 so với kỳ_vọng bán hàng ?',
#   'một phần ba của kỳ_vọng ,'],
#  ['Những gì hiện Darwin sử_dụng để minh_hoạ những ảnh_hưởng của lựa_chọn nhân_tạo ?',
#   'ưa_thích nuôi chim bồ_câu ,'],
#  ['máy_bay gì tính_năng thiết_kế cải_thiện ra_mắt và phục_hồi chu_kỳ flexibilty ?',
#   'Một boong góc'],
#  ['ai là tác_giả của phần_mềm diệt virus D2',
#   'Phần_mềm D32 là một chương_trình chẩn_đoán và diệt virus máy_tính dành cho hệ_điều_hành Windows_XP 32 bit . D32 là tên gọi tắt của " D 2 for Windows 32 " . Đây là phần_mềm chống virus chạy trên hệ_điều_hành Windows 32 bits đầu_tiên của Việt_Nam . Tiền_thân của phần_mềm này là D2 ( " Diagnose and Destroy_Viruses " ) anti-virus chạy trên hệ_điều_hành MS-DOS rất phổ_biến ở Việt_Nam từ thập_niên 1990 . Kể từ lúc phát_hành ( tháng 2 năm 2001 ) đến nay , D32 đã có nhiều cải_tiến quan_trọng ; cùng với BKAV , D32 trở_thành phần_mềm diệt virus trên nhiều hệ_thống công_nghệ_thông_tin ở Việt_Nam .'],
#  ['Việt_Nam bình_thường_hoá quan_hệ với Trung_Quốc năm nào',
#   'Đầu năm 1978 , tại Tokyo , ông Phan_Hiền , thứ_trưởng Ngoại_giao Việt_Nam tuyên_bố : " " Việt_Nam sẵn_sàng bình_thường_hoá vô_điều_kiện với Hoa_Kỳ " " ( tức_là Việt_Nam sẽ không yêu_cầu Hoa_Kỳ phải bồi_thường chiến_tranh nữa ) . Tuy_nhiên , lúc này Mỹ_quan tâm tới việc đàm_phán bình_thường_hoá quan_hệ với Trung_Quốc hơn , mà Trung_Quốc và Việt_Nam với khi đó lại đang là đối_thủ , nên Hoa_Kỳ đã bỏ_qua vấn_đề bình_thường_hoá quan_hệ với Việt_Nam .'],
#  ['một quốc_gia có khả_năng cho một nhà_nước là gì ?', ','],
#  ['đã Gaddifi tạo ra những gì triết_lý chính_trị ?',
#   'của Lý_thuyết Quốc_tế thứ ba của ông'],
#  ['làm hầu_hết các đô_vật làm gì , theo như cách họ hành_động ?',
#   'miêu_tả vai_trò nhân_vật ,'],
#  ['Điều gì làm các loài chim đôi_khi sử_dụng để đánh_giá và khẳng_định sự thống_trị xã_hội ?',
#   'bộ lông'],
#  ['Làm thế_nào để kích_thước của một bóng_đèn halogen so_sánh với một đèn sợi đốt ?',
#   'bóng_đèn như_vậy là nhỏ hơn nhiều so với bóng_đèn sợi đốt thông_thường ,'],
#  ['Bên cạnh trụ_sở của Liên_Hợp_Quốc , người tổ_chức nhiều cơ_quan của Liên_Hợp_Quốc ?',
#   'Liên_bang Thuỵ_Sĩ'],
#  ['Đại văn_hào Goethe là nguười nước nào',
#   'Mục_đích quan_trọng của viện là hỗ_trợ việc giao_lưu văn_hoá giữa Việt_Nam , Đức và châu_Âu . Viện Goethe Hà_Nội ủng_hộ và tổ_chức nhiều chương_trình để giới_thiệu văn_hoá Đức đến Việt_Nam , nhằm tăng_cường đối_thoại văn_hoá giữa hai nước .'],
#  ['Những thí_sinh đã bị xoá khỏi chương_trình để mô_hình_hoá cho một trang_web người_lớn ?',
#   'Frenchie_Davis'],
#  ['giám_đốc công_an hiện_tại của thành_phố Hồ_Chí_Minh là ai',
#   'Đại_học Quốc_gia Thành_phố Hồ_Chí_Minh ( tiếng Anh : " Viet_Nam_National_University , Ho_Chi_Minh_City " ) là một trong năm hệ_thống đại_học quốc_gia , được đặt tại Thành_phố Hồ_Chí_Minh , được đánh_giá là một trong 750 trường / nhóm trường đại_học tốt nhất thế_giới của Việt_Nam .'],
#  ['công_cụ gì rơi ra khỏi sử_dụng sau thập_niên 1760 ?', 'the'],
#  ['Gì được Lành_Cơ_Đốc_Nhân chạy trốn từ đâu ?', 'đàn_áp tôn_giáo'],
#  ['Làm thế_nào các tránh Anh có đội_ngũ lớn các binh_sĩ ở lục_địa châu_Âu ?',
#   'liên_minh bản_thân với một hoặc Continental nhiều cường_quốc có lợi_ích là đối_chọi với những kẻ_thù của họ , đặc_biệt là'],
#  ['Ai định_nghĩa những thay_đổi pháp_lý quan_trọng ?',
#   'Robert_Bideleux và Ian_Jeffries ,'],
#  ['làm bergschrunds giống gì ?', 'crevasses'],
#  ['Là cuộc họp tại Canberra một nhóm người hỗ_trợ hoặc đối_lập với Đảng Lao_động Úc ?',
#   'phản'],
#  ['Những gì đã hứa bởi Buda_Vua_Casimer ?',
#   "quý_tộc sẽ không còn phải chịu thuế ' phi_thường ' ,"],
#  ['Nước nào là Alsace sáp_nhập vào trong 1871-1918', 'Đức'],
#  ['động_vật gì được báo_cáo là bị giết chết thường_xuyên hơn cừu của sói tại Croatia ?',
#   'con chó hoang_dã lớn ,'],
#  ['Ai đưa ra giả_thuyết rằng máu đi qua các tĩnh_mạch ?',
#   'Praxagoras của Kos ,'],
#  ['Vị vua nào lập nên nước Đại_Ngu', 'Hồ_Quý_Ly'],
#  ['mô não là một_cách tự_nhiên mềm_mại , nhưng có_thể được cứng với những gì chất_lỏng ?',
#   'rượu'],
#  ['Khi được Nam_Tucson reincorporated ?', '1940'],
#  ['Bởi những gì năm đã được các trường_học ở Oxford hoàn_thành ?', '1265 ,'],
#  ['Tác_giả của truyện Truyền_Kì Mạn_Lục là ai',
#   '2 . Văn_học trung_đại : tiều thuyết chương_hồi , truyền_kì , ký_sự , truyện_thơ .'],
#  ['các Xeer luật_sư hệ_thống gọi làm gì ?', 'garxajiyaal'],
#  ['Loại mã_hoá , tương_tự hoặc kỹ_thuật_số , gây ra đĩa lade được succeptable thiệt_hại ?',
#   'analog'],
#  ['Chủ_tịch hiện_tại của Síp là ai ?', 'Nicos_Anastasiades'],
#  ['đâu DJ Marques_Wyatt và Billy dài trở_nên thành_công ?', 'Los_Angeles'],
#  ['Bangladesh có diện_tích đứng thứ mấy thế_giới',
#   'Phần_lớn diện_tích ( hai_phần_ba diện_tích ) nằm tại Bangladesh , một phần còn lại trở_thành vườn_quốc_gia Sundarban của Ấn_Độ . Cả hai khu_vực đã được công_nhận là một di_sản thế_giới của UNESCO phần của Bangladesh vào năm 1997 .'],
#  ['Tại_sao Feynman quyết_định từ_chối một lời đề_nghị từ các Viện nghiên_cứu cao_cấp ?',
#   'không có nhiệm_vụ giảng_dạy :'],
#  ['tên của nhà_thờ Presbyterian lớn nhất ở Mexico là gì ?',
#   'Giáo_Hội Presbyterian quốc_gia ở Mexico ( Iglesia_Nacional_Presbiteriana de México ) ,'],
#  ['một động_vật ăn thịt điển_hình của chó ở những nơi như Turkmenistan là gì ?',
#   'linh_cẩu sọc'],
#  ['Khác với các ID3v1 , mà tương_tự như định_dạng chuẩn cho thẻ tồn_tại ?',
#   'ID3v2 ,'],
#  ['Việt_Nam có bao_nhiêu tỉnh giáp với Lào',
#   'Việt_Nam và Lào có đường biên_giới chung dài 2067 km . Sau đây là danh_sách các tỉnh của Lào và Việt_Nam có biên_giới chung với nhau , xếp theo vị_trí từ Bắc xuống Nam .'],
#  ['Gì có xu_hướng trở_thành một trở_ngại lớn khi so_sánh các nền văn_hoá ?',
#   'Dịch'],
#  ['các nghệ_sĩ đã thu_hút nho như thật , chim bay lên và mổ vào họ là ai ?',
#   'Zeuxis ,'],
#  ['thực_vật_học là gì ?', 'của đời_sống thực_vật'],
#  ['thành_phố gì San_Diego đến thứ hai để trong ngành công_nghiệp công_nghệ_sinh_học ?',
#   'Boston'],
#  ['Khi được các Trận_Austerlitz chiến_đấu ?', 'ngày 02 tháng 12 ,'],
#  ['các bộ_phận mà sáp_nhập vào Bộ_chỉ_huy hoạt_động phần Canada là gì ?',
#   'Canada lệnh , Bộ_Tư_lệnh quân viễn_chinh Canada và Bộ_Tư_lệnh hỗ_trợ vận_hành Canada'],
#  ['tổng_giám_đốc công_ty lọc hoá_dầu bình_sơn', 'Bùi_Minh_Tiến'],
#  ['tường phòng_thủ mà bao quanh London vào năm 1642 được gọi là gì ?',
#   'Lines_Giao'],
#  ['Khi được các Máy đánh chữ chữ đầu_tiên với một phím shift tạo ?',
#   '1878 ) ,'],
#  ['Tháp nghiêng Pisa ở Italy được xây_dựng trong khoảng thời_gian bao_lâu',
#   'Tháp nghiêng Pisa là một công_trình nghệ_thuật , chưa xác_định được là do ai thiết_kế , được xây_dựng trong ba giai_đoạn với tổng thời_gian khoảng 174 năm . Việc xây_dựng lầu chuông tầng thứ nhất bằng đá cẩm_thạch bắt_đầu ngày 9 tháng 8 , 1173 , một giai_đoạn của sự thịnh_vượng và những thắng_lợi quân_sự . Tầng này được bao quanh bởi những cột có đầu cột kiểu cổ_điển đỡ các vòm rèm . Ngày_nay sau thời_gian hàng thế_kỷ cùng những ảnh_hưởng thời_tiết chúng vẫn còn nguyên_vẹn .'],
#  ['Ai được bình_chọn là nhà_lãnh_đạo đầu_tiên của Đảng Lao_động ?',
#   'Ramsay_MacDonald'],
#  ...]

# %% [markdown]
# # Preprocessing

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences


train_ids = []
for sent in train_sents:
    subwords1 = '<q> ' + bpe.encode(sent[0]) + ' </q>'
    encoded_sent1 = vocab.encode_line(subwords1, append_eos=True, add_if_not_exist=False).long().tolist()

    subwords2 = '<a> ' + bpe.encode(sent[1]) + ' </a>'
    encoded_sent2 = vocab.encode_line(subwords2, append_eos=True, add_if_not_exist=False).long().tolist()
    train_ids.append(encoded_sent1 + encoded_sent2)

val_ids = []
for sent in val_sents:
    subwords1 = '<q> ' + bpe.encode(sent[0]) + ' </q>'
    encoded_sent1 = vocab.encode_line(subwords1, append_eos=True, add_if_not_exist=False).long().tolist()

    subwords2 = '<a> ' + bpe.encode(sent[1]) + ' </a>'
    encoded_sent2 = vocab.encode_line(subwords2, append_eos=True, add_if_not_exist=False).long().tolist()
    val_ids.append(encoded_sent1 + encoded_sent2)

# %%
val_ids
# Out:
# [[3,
#   10046,
#   6222,
#   127,
#   6937,
#   7,
#   58,
#   237,
#   11,
#   718,
#   2537,
#   33,
#   29,
#   142,
#   3,
#   2,
#   3,
#   13708,
#   59035,
#   4,
#   9393,
#   178,
#   6,
#   2209,
#   22649,
#   7,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   11,
#   4026,
#   2608,
#   12,
#   9,
#   184,
#   4687,
#   30,
#   6216,
#   7,
#   10046,
#   14029,
#   20330,
#   146,
#   4026,
#   2608,
#   917,
#   63,
#   28,
#   1391,
#   40012,
#   1395,
#   4,
#   22563,
#   493,
#   6,
#   1252,
#   3139,
#   25717,
#   339,
#   12,
#   761,
#   28,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   3490,
#   1388,
#   39566,
#   5550,
#   15,
#   9,
#   2209,
#   2665,
#   3312,
#   6222,
#   50,
#   21931,
#   1384,
#   4,
#   982,
#   14892,
#   1517,
#   565,
#   10046,
#   6222,
#   115,
#   61,
#   5603,
#   740,
#   2178,
#   89,
#   2477,
#   1252,
#   40865,
#   31829,
#   982,
#   14892,
#   1517,
#   565,
#   537,
#   127,
#   47,
#   49,
#   76,
#   29,
#   53,
#   26,
#   10046,
#   6222,
#   10,
#   3256,
#   2792,
#   6,
#   33,
#   43,
#   426,
#   78,
#   426,
#   29,
#   13323,
#   9,
#   12726,
#   4436,
#   127,
#   6937,
#   11,
#   5795,
#   32151,
#   5,
#   3,
#   2],
#  [3,
#   2080,
#   2082,
#   25,
#   460,
#   590,
#   71,
#   29,
#   4602,
#   91,
#   277,
#   8351,
#   3902,
#   3,
#   2,
#   3,
#   1129,
#   350,
#   590,
#   11918,
#   58953,
#   1517,
#   6,
#   7635,
#   196,
#   2446,
#   16021,
#   1982,
#   1948,
#   460,
#   590,
#   350,
#   590,
#   14157,
#   39,
#   5567,
#   8,
#   11918,
#   59763,
#   1517,
#   460,
#   590,
#   350,
#   10029,
#   19,
#   7303,
#   3227,
#   5796,
#   13208,
#   1008,
#   493,
#   350,
#   590,
#   11918,
#   58953,
#   1517,
#   1251,
#   2289,
#   6,
#   1284,
#   5628,
#   14067,
#   1981,
#   2308,
#   2080,
#   2082,
#   25,
#   460,
#   10029,
#   4,
#   6,
#   2209,
#   2665,
#   8351,
#   3902,
#   8,
#   647,
#   3464,
#   2537,
#   1125,
#   15947,
#   1517,
#   604,
#   350,
#   590,
#   5089,
#   187,
#   125,
#   6460,
#   2178,
#   6,
#   39424,
#   462,
#   187,
#   1008,
#   493,
#   350,
#   590,
#   11918,
#   58953,
#   12584,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   47,
#   56138,
#   2079,
#   9441,
#   110,
#   2537,
#   1893,
#   30,
#   4107,
#   23206,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   29,
#   14845,
#   1854,
#   4,
#   3,
#   2],
#  [3,
#   31766,
#   1677,
#   3437,
#   11374,
#   7520,
#   1176,
#   12151,
#   15,
#   21,
#   148,
#   9929,
#   1373,
#   29,
#   19444,
#   114,
#   3,
#   2,
#   3,
#   7771,
#   3,
#   2],
#  [3,
#   207,
#   18,
#   21,
#   148,
#   156,
#   355,
#   157,
#   30,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   11373,
#   36471,
#   3593,
#   37547,
#   13143,
#   3,
#   2],
#  [3,
#   4419,
#   64,
#   22442,
#   30,
#   778,
#   311,
#   10,
#   4415,
#   57060,
#   35102,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   4917,
#   3,
#   2285,
#   6,
#   4917,
#   1302,
#   4,
#   3,
#   2],
#  [3,
#   675,
#   5116,
#   148,
#   10,
#   4623,
#   11,
#   5717,
#   8410,
#   81,
#   15,
#   1093,
#   12813,
#   1906,
#   50350,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   8715,
#   10284,
#   3,
#   2],
#  [3,
#   2679,
#   11,
#   143,
#   33,
#   42,
#   16,
#   22563,
#   12726,
#   129,
#   1713,
#   13,
#   303,
#   248,
#   129,
#   24105,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   54691,
#   49777,
#   4553,
#   28909,
#   3,
#   2],
#  [3,
#   251,
#   8,
#   396,
#   417,
#   2902,
#   303,
#   248,
#   7,
#   2648,
#   57447,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   43,
#   1058,
#   78,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   668,
#   790,
#   4365,
#   13466,
#   506,
#   7,
#   8798,
#   1236,
#   114,
#   3,
#   2,
#   3,
#   9971,
#   60692,
#   35258,
#   3,
#   2],
#  [3,
#   9569,
#   5855,
#   148,
#   289,
#   537,
#   127,
#   1073,
#   1575,
#   30,
#   5649,
#   7295,
#   29240,
#   12,
#   78,
#   317,
#   29,
#   8878,
#   2326,
#   114,
#   3,
#   2,
#   3,
#   12752,
#   2954,
#   3,
#   2],
#  [3,
#   133,
#   545,
#   312,
#   7,
#   1337,
#   4258,
#   205,
#   418,
#   1430,
#   12,
#   29,
#   22190,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   58511,
#   9644,
#   1556,
#   3952,
#   14157,
#   137,
#   8963,
#   16529,
#   42312,
#   2722,
#   151,
#   23556,
#   696,
#   58772,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   11124,
#   1196,
#   765,
#   38815,
#   7646,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   29043,
#   31142,
#   1931,
#   4,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   1257,
#   43899,
#   36431,
#   32628,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   50642,
#   3449,
#   26254,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   418,
#   1430,
#   482,
#   989,
#   14,
#   11,
#   506,
#   20497,
#   223,
#   8404,
#   7621,
#   52144,
#   24,
#   18802,
#   16157,
#   15008,
#   29888,
#   42568,
#   6433,
#   23313,
#   114,
#   3,
#   2,
#   3,
#   1988,
#   3,
#   2],
#  [3,
#   13416,
#   26567,
#   230,
#   877,
#   7,
#   61,
#   705,
#   2201,
#   462,
#   2925,
#   47,
#   16,
#   3078,
#   12151,
#   3210,
#   13109,
#   114,
#   3,
#   2,
#   3,
#   2138,
#   462,
#   2925,
#   705,
#   1701,
#   22266,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   4447,
#   819,
#   10540,
#   1188,
#   67,
#   7,
#   4453,
#   13143,
#   33,
#   303,
#   2184,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   620,
#   28,
#   216,
#   1535,
#   3,
#   2],
#  [3,
#   9779,
#   983,
#   8,
#   175,
#   24,
#   47,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   154,
#   11,
#   16,
#   5855,
#   9339,
#   3,
#   2],
#  [3,
#   4106,
#   355,
#   157,
#   302,
#   835,
#   10,
#   452,
#   100,
#   103,
#   48,
#   5385,
#   33,
#   29,
#   50966,
#   114,
#   3,
#   2,
#   3,
#   2681,
#   3,
#   2],
#  [3,
#   39745,
#   15369,
#   8,
#   276,
#   737,
#   7,
#   58,
#   142,
#   3,
#   2,
#   3,
#   619,
#   246,
#   8370,
#   39745,
#   15369,
#   15,
#   16,
#   100,
#   88,
#   737,
#   1607,
#   934,
#   85,
#   6,
#   13,
#   87,
#   3448,
#   139,
#   7,
#   39745,
#   15369,
#   22,
#   418,
#   2697,
#   48,
#   4,
#   2226,
#   2106,
#   5460,
#   9730,
#   48,
#   4,
#   10955,
#   2477,
#   2104,
#   1267,
#   48,
#   22,
#   5,
#   3,
#   2],
#  [3,
#   125,
#   4264,
#   30992,
#   1073,
#   2537,
#   35,
#   350,
#   590,
#   156,
#   221,
#   148,
#   3,
#   2,
#   3,
#   125,
#   4264,
#   14,
#   24,
#   44,
#   3309,
#   4903,
#   12,
#   605,
#   36,
#   570,
#   2301,
#   1964,
#   1163,
#   5,
#   30992,
#   32,
#   2528,
#   380,
#   12,
#   36,
#   11297,
#   2697,
#   2958,
#   1738,
#   4,
#   1362,
#   1889,
#   30992,
#   32,
#   8,
#   3449,
#   4986,
#   2958,
#   1738,
#   1219,
#   3156,
#   35,
#   350,
#   590,
#   5,
#   29694,
#   1163,
#   28786,
#   22482,
#   11455,
#   29865,
#   1595,
#   11,
#   125,
#   2958,
#   1738,
#   2178,
#   200,
#   350,
#   590,
#   906,
#   806,
#   23250,
#   5887,
#   22,
#   22,
#   4488,
#   9031,
#   2958,
#   1738,
#   22,
#   22,
#   33,
#   29,
#   4284,
#   91,
#   14,
#   580,
#   2284,
#   33,
#   675,
#   18116,
#   4368,
#   9970,
#   177,
#   193,
#   89,
#   4264,
#   30992,
#   5,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   20368,
#   29159,
#   467,
#   28,
#   1401,
#   89,
#   5537,
#   33403,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   6744,
#   2326,
#   19,
#   3,
#   2],
#  [3,
#   6390,
#   8228,
#   4194,
#   8346,
#   8046,
#   187,
#   149,
#   142,
#   7,
#   98,
#   24703,
#   1432,
#   43,
#   136,
#   3,
#   2,
#   3,
#   6390,
#   8228,
#   4194,
#   8346,
#   8046,
#   3378,
#   10277,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   276,
#   10,
#   4623,
#   11,
#   2902,
#   2288,
#   24,
#   4447,
#   5942,
#   205,
#   2008,
#   11095,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   8,
#   2057,
#   7,
#   276,
#   3634,
#   848,
#   34,
#   9,
#   558,
#   1073,
#   462,
#   7,
#   2008,
#   11095,
#   1387,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   55613,
#   1517,
#   69,
#   127,
#   6937,
#   7,
#   4577,
#   2142,
#   7922,
#   1384,
#   2949,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   147,
#   29,
#   2617,
#   5442,
#   6,
#   52077,
#   3,
#   2],
#  [3,
#   4106,
#   222,
#   35,
#   3449,
#   222,
#   12289,
#   14,
#   7303,
#   5761,
#   12,
#   19271,
#   6430,
#   3078,
#   15082,
#   5089,
#   454,
#   7,
#   86,
#   35,
#   423,
#   9,
#   69,
#   3078,
#   7564,
#   10893,
#   6416,
#   12,
#   49,
#   930,
#   3685,
#   110,
#   2544,
#   56769,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   622,
#   13085,
#   1749,
#   4258,
#   3,
#   2],
#  [3,
#   567,
#   311,
#   45,
#   54776,
#   8410,
#   67,
#   12,
#   21,
#   29,
#   626,
#   302,
#   9642,
#   25,
#   93,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   33271,
#   1881,
#   4,
#   16529,
#   14405,
#   16529,
#   3,
#   2],
#  [3,
#   12297,
#   110,
#   574,
#   1164,
#   229,
#   40,
#   64,
#   24449,
#   3852,
#   1660,
#   7,
#   3490,
#   27986,
#   4819,
#   6902,
#   13,
#   1007,
#   24210,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   216,
#   542,
#   7,
#   490,
#   7620,
#   2380,
#   13388,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   2856,
#   7833,
#   11,
#   5717,
#   8410,
#   223,
#   9,
#   10525,
#   768,
#   24,
#   23421,
#   125,
#   66,
#   23250,
#   3490,
#   2288,
#   3705,
#   917,
#   9170,
#   2856,
#   5883,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   11297,
#   2697,
#   829,
#   61,
#   6,
#   2652,
#   3902,
#   3,
#   2],
#  [3,
#   251,
#   8,
#   61,
#   7236,
#   127,
#   7,
#   23720,
#   687,
#   47865,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   137,
#   99,
#   186,
#   29,
#   55427,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   14,
#   36406,
#   441,
#   9866,
#   21,
#   148,
#   64,
#   16,
#   100,
#   2105,
#   12053,
#   7,
#   69,
#   1692,
#   487,
#   7,
#   31201,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   167,
#   312,
#   3,
#   2],
#  [3,
#   184,
#   2379,
#   2178,
#   311,
#   7,
#   525,
#   679,
#   25,
#   590,
#   24051,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   59664,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   9,
#   184,
#   666,
#   85,
#   11,
#   5717,
#   8410,
#   12,
#   9,
#   14228,
#   3210,
#   475,
#   42,
#   9535,
#   3657,
#   9603,
#   2500,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   80,
#   294,
#   1494,
#   13776,
#   5796,
#   1384,
#   4,
#   9535,
#   9282,
#   3611,
#   1931,
#   4,
#   13276,
#   1866,
#   3385,
#   8017,
#   2225,
#   3353,
#   4,
#   12110,
#   36248,
#   9603,
#   1931,
#   4,
#   3,
#   2],
#  [3,
#   36479,
#   6,
#   15879,
#   3086,
#   273,
#   11,
#   133,
#   3348,
#   7,
#   86,
#   39,
#   28408,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   2106,
#   4698,
#   570,
#   13557,
#   6,
#   133,
#   69,
#   27979,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   12297,
#   8726,
#   12699,
#   20062,
#   235,
#   42,
#   16,
#   802,
#   42244,
#   114,
#   3,
#   2,
#   3,
#   57084,
#   28244,
#   4,
#   3,
#   2],
#  [3,
#   17617,
#   2183,
#   1981,
#   21439,
#   4456,
#   302,
#   33,
#   29,
#   142,
#   3,
#   2,
#   3,
#   1615,
#   431,
#   78,
#   624,
#   29,
#   7806,
#   2576,
#   4,
#   586,
#   2178,
#   105,
#   2208,
#   11639,
#   29899,
#   11,
#   1391,
#   1766,
#   35,
#   82,
#   127,
#   58020,
#   21573,
#   1206,
#   230,
#   336,
#   844,
#   479,
#   137,
#   1366,
#   8271,
#   2477,
#   7,
#   350,
#   590,
#   6,
#   1219,
#   20405,
#   1301,
#   4,
#   8271,
#   61,
#   946,
#   9,
#   58,
#   35,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   81,
#   9,
#   834,
#   639,
#   127,
#   1713,
#   58,
#   56665,
#   27375,
#   404,
#   245,
#   232,
#   298,
#   43,
#   1298,
#   78,
#   7086,
#   4,
#   2208,
#   11639,
#   29899,
#   159,
#   2908,
#   11,
#   2178,
#   13778,
#   5,
#   3,
#   2],
#  [3,
#   2918,
#   245,
#   7,
#   7977,
#   1252,
#   9,
#   325,
#   9733,
#   181,
#   1820,
#   181,
#   3078,
#   848,
#   13,
#   4089,
#   4301,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   1073,
#   12155,
#   9,
#   5887,
#   1893,
#   8351,
#   3902,
#   9,
#   325,
#   45,
#   34299,
#   1236,
#   18020,
#   1517,
#   6,
#   9733,
#   2209,
#   3518,
#   10631,
#   91,
#   9,
#   2209,
#   2665,
#   2697,
#   1889,
#   6425,
#   13154,
#   1400,
#   3,
#   2],
#  [3,
#   4106,
#   159,
#   5942,
#   7,
#   25869,
#   7358,
#   11,
#   5717,
#   8410,
#   12,
#   30531,
#   805,
#   2546,
#   32841,
#   114,
#   3,
#   2,
#   3,
#   159,
#   5942,
#   355,
#   157,
#   1906,
#   1981,
#   2308,
#   3,
#   2],
#  [3,
#   934,
#   14077,
#   109,
#   45,
#   15038,
#   687,
#   223,
#   9755,
#   3344,
#   1430,
#   43383,
#   6,
#   37,
#   2919,
#   26427,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   5218,
#   36913,
#   8369,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   590,
#   4957,
#   2475,
#   7968,
#   61,
#   724,
#   580,
#   7,
#   58405,
#   3907,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   5020,
#   3,
#   2],
#  [3,
#   2837,
#   142,
#   2146,
#   1766,
#   4819,
#   4443,
#   6470,
#   127,
#   6937,
#   3,
#   2,
#   3,
#   635,
#   181,
#   378,
#   226,
#   61219,
#   1301,
#   4,
#   21703,
#   5122,
#   40662,
#   201,
#   349,
#   13,
#   590,
#   3992,
#   39,
#   6111,
#   30,
#   14845,
#   1854,
#   4,
#   701,
#   11,
#   624,
#   509,
#   616,
#   12,
#   1298,
#   101,
#   6708,
#   797,
#   226,
#   61219,
#   10557,
#   168,
#   201,
#   349,
#   25,
#   82,
#   248,
#   349,
#   103,
#   8,
#   4159,
#   6111,
#   6,
#   8038,
#   2763,
#   14845,
#   19126,
#   21703,
#   5122,
#   40662,
#   32,
#   10,
#   221,
#   12,
#   226,
#   1084,
#   590,
#   3992,
#   7520,
#   930,
#   8038,
#   2763,
#   9878,
#   51,
#   17,
#   11,
#   40,
#   1302,
#   25319,
#   3,
#   2],
#  [3,
#   3344,
#   4422,
#   1340,
#   11095,
#   1517,
#   8,
#   148,
#   3,
#   2,
#   3,
#   3344,
#   4422,
#   1738,
#   25,
#   350,
#   590,
#   8,
#   204,
#   1893,
#   430,
#   1361,
#   568,
#   3078,
#   7564,
#   350,
#   590,
#   39,
#   1054,
#   33,
#   4721,
#   4422,
#   6,
#   2183,
#   675,
#   295,
#   558,
#   6467,
#   675,
#   4422,
#   8,
#   159,
#   5,
#   3,
#   2],
#  [3,
#   266,
#   28950,
#   13005,
#   6168,
#   127,
#   6937,
#   59270,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2067,
#   30590,
#   1850,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   56739,
#   53585,
#   1166,
#   14,
#   11,
#   170,
#   35,
#   1219,
#   3156,
#   39,
#   29,
#   3503,
#   30,
#   6744,
#   1765,
#   114,
#   3,
#   2,
#   3,
#   76,
#   113,
#   3,
#   2],
#  [3,
#   217,
#   178,
#   2379,
#   22986,
#   23651,
#   61,
#   14760,
#   3348,
#   7,
#   37653,
#   13815,
#   6419,
#   48303,
#   114,
#   3,
#   2,
#   3,
#   5940,
#   3482,
#   3,
#   2],
#  [3, 29, 21, 148, 14, 5728, 29100, 1073, 380, 2610, 114, 3, 2, 3, 16164, 3, 2],
#  [3,
#   229,
#   1430,
#   148,
#   8,
#   359,
#   551,
#   26,
#   1186,
#   2282,
#   25552,
#   34022,
#   14,
#   45,
#   166,
#   34,
#   37825,
#   56116,
#   114,
#   3,
#   2,
#   3,
#   18471,
#   61367,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   467,
#   1088,
#   22682,
#   1347,
#   4,
#   558,
#   294,
#   6,
#   215,
#   1301,
#   16846,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   8274,
#   11042,
#   3889,
#   4366,
#   24513,
#   3,
#   2],
#  [3,
#   2209,
#   4623,
#   21,
#   148,
#   14,
#   2178,
#   89,
#   7977,
#   1252,
#   22821,
#   2179,
#   10645,
#   36117,
#   1231,
#   29,
#   12515,
#   1556,
#   114,
#   3,
#   2,
#   3,
#   3449,
#   1093,
#   3,
#   2],
#  [3,
#   557,
#   2919,
#   1283,
#   167,
#   67,
#   12,
#   4851,
#   1947,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   8565,
#   33108,
#   15386,
#   4975,
#   14157,
#   210,
#   302,
#   34946,
#   1301,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   5228,
#   2919,
#   14,
#   21795,
#   2545,
#   4339,
#   9,
#   2765,
#   2652,
#   2057,
#   13749,
#   103,
#   67,
#   12,
#   7328,
#   94,
#   9,
#   316,
#   5191,
#   836,
#   7620,
#   114,
#   3,
#   2,
#   3,
#   45417,
#   3,
#   2],
#  [3,
#   14,
#   347,
#   26,
#   37454,
#   366,
#   1464,
#   700,
#   53,
#   26,
#   4986,
#   7542,
#   7,
#   35297,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   82,
#   29,
#   3,
#   2],
#  [3,
#   345,
#   127,
#   6937,
#   235,
#   34,
#   732,
#   179,
#   221,
#   8,
#   148,
#   3,
#   2,
#   3,
#   30540,
#   7038,
#   335,
#   551,
#   44,
#   2975,
#   212,
#   4762,
#   54711,
#   14,
#   111,
#   5237,
#   7172,
#   862,
#   682,
#   302,
#   7594,
#   2652,
#   7,
#   4542,
#   3685,
#   28,
#   61,
#   14114,
#   35,
#   7,
#   61,
#   235,
#   227,
#   10549,
#   46116,
#   13208,
#   217,
#   2975,
#   212,
#   235,
#   7,
#   572,
#   1634,
#   56412,
#   17,
#   85,
#   148,
#   957,
#   246,
#   15,
#   34,
#   2565,
#   1125,
#   15947,
#   1850,
#   4,
#   376,
#   30,
#   16,
#   1163,
#   12907,
#   8,
#   21,
#   5237,
#   418,
#   1889,
#   235,
#   10,
#   4623,
#   11,
#   4453,
#   430,
#   147,
#   9,
#   2537,
#   5855,
#   595,
#   9,
#   74,
#   61580,
#   5,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   11365,
#   188,
#   44,
#   10995,
#   1358,
#   604,
#   154,
#   50875,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   29,
#   7806,
#   2326,
#   19,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   5650,
#   8,
#   110,
#   5223,
#   18517,
#   35,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   504,
#   4604,
#   19,
#   3,
#   2],
#  [3,
#   2679,
#   1294,
#   12813,
#   2054,
#   222,
#   42,
#   8,
#   16,
#   139,
#   24,
#   208,
#   11,
#   9,
#   4089,
#   2140,
#   7,
#   8123,
#   3709,
#   1698,
#   51899,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   49911,
#   30096,
#   4423,
#   9948,
#   13470,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   6466,
#   4722,
#   30939,
#   9215,
#   52853,
#   7,
#   2697,
#   46924,
#   1187,
#   57968,
#   22,
#   3,
#   2,
#   3,
#   9470,
#   2225,
#   5276,
#   5681,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   14,
#   2105,
#   10125,
#   9032,
#   39040,
#   3611,
#   114,
#   3,
#   2,
#   3,
#   11993,
#   33736,
#   21855,
#   5028,
#   3,
#   2],
#  [3,
#   1203,
#   21,
#   29,
#   4917,
#   5315,
#   4,
#   2516,
#   14,
#   11,
#   701,
#   154,
#   64,
#   82,
#   129,
#   2657,
#   2665,
#   30,
#   18,
#   1129,
#   23206,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   16,
#   568,
#   2958,
#   1340,
#   11095,
#   1517,
#   9708,
#   19509,
#   2119,
#   3385,
#   1236,
#   9522,
#   4,
#   6,
#   36,
#   18,
#   1129,
#   1709,
#   14,
#   7520,
#   3931,
#   33,
#   3448,
#   6969,
#   159,
#   3348,
#   2529,
#   1465,
#   3,
#   2],
#  [3,
#   1196,
#   467,
#   2135,
#   13,
#   16,
#   212,
#   2919,
#   222,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   25234,
#   19,
#   3,
#   2],
#  [3,
#   29,
#   148,
#   14,
#   56424,
#   10263,
#   7236,
#   15012,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   29,
#   7806,
#   2576,
#   4,
#   1284,
#   5628,
#   1265,
#   3,
#   2],
#  [3,
#   2002,
#   2104,
#   4623,
#   21,
#   148,
#   14,
#   834,
#   2765,
#   33,
#   24,
#   1149,
#   1490,
#   16,
#   100,
#   9,
#   1188,
#   3011,
#   2657,
#   2665,
#   30,
#   13884,
#   56073,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   19363,
#   19678,
#   3773,
#   44863,
#   3,
#   2],
#  [3,
#   9326,
#   3056,
#   5955,
#   8348,
#   14,
#   682,
#   302,
#   7303,
#   10816,
#   48,
#   7,
#   10826,
#   34729,
#   537,
#   127,
#   39,
#   29,
#   40865,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   1230,
#   11641,
#   3,
#   2],
#  [3,
#   207,
#   18,
#   21,
#   148,
#   52,
#   6169,
#   7311,
#   983,
#   355,
#   28,
#   203,
#   482,
#   58229,
#   114,
#   3,
#   2,
#   3,
#   7974,
#   1749,
#   1302,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   11,
#   10969,
#   792,
#   268,
#   17940,
#   139,
#   16064,
#   20358,
#   4055,
#   15271,
#   25,
#   2791,
#   11,
#   819,
#   52530,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   30037,
#   3,
#   2],
#  [3,
#   6933,
#   142,
#   6714,
#   1291,
#   366,
#   13,
#   84,
#   12350,
#   47867,
#   3,
#   2,
#   3,
#   162,
#   26,
#   7128,
#   12350,
#   47867,
#   40214,
#   1187,
#   4,
#   4267,
#   4372,
#   28720,
#   50,
#   14770,
#   9013,
#   30,
#   849,
#   29,
#   53,
#   60,
#   7166,
#   3440,
#   47934,
#   21473,
#   3,
#   2],
#  [3,
#   29,
#   64,
#   5255,
#   713,
#   127,
#   6937,
#   1237,
#   3521,
#   7,
#   418,
#   1430,
#   167,
#   4422,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30398,
#   3,
#   2],
#  [3,
#   4586,
#   6700,
#   9423,
#   352,
#   81,
#   7,
#   58,
#   237,
#   8,
#   277,
#   3,
#   2,
#   3,
#   24479,
#   8381,
#   3774,
#   9423,
#   32406,
#   14157,
#   1196,
#   1125,
#   44611,
#   27,
#   60894,
#   3,
#   65,
#   2617,
#   6278,
#   114,
#   31,
#   964,
#   78,
#   76,
#   29,
#   2617,
#   1551,
#   2576,
#   37272,
#   4,
#   8,
#   626,
#   6700,
#   9423,
#   129,
#   624,
#   790,
#   4267,
#   1007,
#   29062,
#   6,
#   32,
#   8,
#   626,
#   6700,
#   352,
#   81,
#   12,
#   2546,
#   5717,
#   350,
#   43557,
#   1759,
#   946,
#   9423,
#   32406,
#   25,
#   632,
#   22737,
#   18176,
#   1301,
#   4,
#   149,
#   6958,
#   37122,
#   1395,
#   4,
#   1479,
#   1125,
#   11095,
#   1850,
#   4,
#   350,
#   43557,
#   3,
#   2],
#  [3,
#   10645,
#   7128,
#   150,
#   8,
#   187,
#   4439,
#   7,
#   58,
#   142,
#   3,
#   2,
#   3,
#   10645,
#   7128,
#   11,
#   906,
#   493,
#   385,
#   3348,
#   84,
#   6,
#   300,
#   856,
#   2301,
#   1981,
#   2308,
#   6222,
#   3902,
#   7,
#   68,
#   223,
#   761,
#   2209,
#   618,
#   10645,
#   7128,
#   5,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   58,
#   7520,
#   3931,
#   3398,
#   2608,
#   3959,
#   18116,
#   2121,
#   1709,
#   1832,
#   1962,
#   3,
#   2,
#   3,
#   10053,
#   485,
#   19640,
#   7520,
#   3931,
#   18715,
#   12726,
#   25,
#   323,
#   173,
#   33,
#   78,
#   4980,
#   29,
#   2527,
#   5,
#   162,
#   323,
#   18715,
#   12726,
#   23,
#   4,
#   2506,
#   2608,
#   273,
#   221,
#   8,
#   22,
#   3398,
#   2608,
#   33784,
#   18116,
#   8123,
#   7564,
#   4488,
#   8536,
#   7856,
#   1709,
#   1832,
#   1962,
#   22,
#   20,
#   8656,
#   58136,
#   151,
#   2180,
#   163,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   4805,
#   934,
#   908,
#   380,
#   136,
#   10,
#   1464,
#   26567,
#   98,
#   3,
#   2,
#   3,
#   4805,
#   934,
#   908,
#   14157,
#   4051,
#   934,
#   908,
#   13,
#   30,
#   29,
#   6744,
#   1556,
#   65,
#   19,
#   7,
#   14802,
#   8,
#   16,
#   275,
#   7,
#   7162,
#   7709,
#   34412,
#   4805,
#   934,
#   908,
#   339,
#   25,
#   84,
#   856,
#   216,
#   2615,
#   7,
#   7162,
#   7709,
#   34412,
#   4805,
#   23,
#   28,
#   216,
#   2615,
#   542,
#   2956,
#   275,
#   934,
#   10029,
#   4,
#   216,
#   542,
#   2956,
#   275,
#   22053,
#   1581,
#   4,
#   216,
#   553,
#   2956,
#   275,
#   52095,
#   5961,
#   1850,
#   4,
#   50,
#   216,
#   1535,
#   2956,
#   11918,
#   59763,
#   1517,
#   3490,
#   1400,
#   24861,
#   7013,
#   12584,
#   3,
#   2],
#  [3,
#   7594,
#   2652,
#   7,
#   159,
#   713,
#   94,
#   82,
#   2657,
#   9534,
#   28,
#   216,
#   85,
#   1016,
#   90,
#   2856,
#   349,
#   5089,
#   917,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   3007,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   8,
#   3345,
#   532,
#   462,
#   16,
#   12053,
#   1294,
#   12,
#   930,
#   4698,
#   7,
#   9,
#   186,
#   7235,
#   39,
#   857,
#   53393,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   462,
#   380,
#   16580,
#   1384,
#   27,
#   97,
#   8,
#   236,
#   236,
#   3345,
#   121,
#   2753,
#   8184,
#   2178,
#   311,
#   48,
#   8,
#   12,
#   2753,
#   8184,
#   11473,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   16,
#   2657,
#   1400,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   82,
#   181,
#   15012,
#   27,
#   3,
#   2],
#  [3,
#   3229,
#   29,
#   428,
#   11,
#   229,
#   40,
#   25,
#   302,
#   835,
#   142,
#   7,
#   350,
#   590,
#   3,
#   2,
#   3,
#   319,
#   4307,
#   8690,
#   14,
#   229,
#   40,
#   61,
#   2379,
#   14050,
#   16702,
#   5522,
#   586,
#   5171,
#   84,
#   3229,
#   25,
#   5194,
#   57082,
#   1701,
#   4,
#   537,
#   127,
#   15,
#   792,
#   12813,
#   2603,
#   2902,
#   9,
#   2665,
#   1766,
#   181,
#   84,
#   3229,
#   14157,
#   6059,
#   53171,
#   19,
#   14157,
#   229,
#   40,
#   6404,
#   4652,
#   7086,
#   19,
#   91,
#   1835,
#   676,
#   14367,
#   34956,
#   4,
#   3698,
#   26865,
#   27798,
#   3229,
#   7806,
#   1546,
#   4,
#   34811,
#   1479,
#   1432,
#   286,
#   39349,
#   5,
#   282,
#   32,
#   8,
#   110,
#   673,
#   27798,
#   352,
#   81,
#   12,
#   29,
#   3229,
#   7806,
#   36540,
#   3,
#   2],
#  [3,
#   92,
#   43,
#   380,
#   2919,
#   1464,
#   26567,
#   22514,
#   19278,
#   2052,
#   1746,
#   187,
#   33,
#   49,
#   862,
#   797,
#   412,
#   1600,
#   15991,
#   114,
#   3,
#   2,
#   3,
#   48,
#   16,
#   1439,
#   14157,
#   14754,
#   52513,
#   19,
#   3,
#   2],
#  [3,
#   618,
#   779,
#   251,
#   11,
#   1893,
#   5744,
#   811,
#   3365,
#   9,
#   1607,
#   5520,
#   174,
#   16580,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   7,
#   570,
#   6304,
#   431,
#   3,
#   2],
#  [3,
#   2918,
#   142,
#   7,
#   452,
#   460,
#   590,
#   47,
#   49,
#   42,
#   7483,
#   1698,
#   19762,
#   114,
#   3,
#   2,
#   3,
#   17,
#   10,
#   179,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   248,
#   12266,
#   14,
#   12300,
#   2753,
#   36717,
#   4,
#   3911,
#   7001,
#   4,
#   6,
#   8298,
#   56867,
#   154,
#   12,
#   29,
#   7806,
#   1854,
#   114,
#   3,
#   2,
#   3,
#   20232,
#   3902,
#   3,
#   2],
#  [3,
#   9,
#   3309,
#   3256,
#   463,
#   200,
#   19304,
#   48,
#   12,
#   49,
#   2906,
#   2608,
#   790,
#   4365,
#   845,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   23720,
#   687,
#   45182,
#   3,
#   2],
#  [3,
#   6034,
#   3333,
#   4138,
#   339,
#   25,
#   316,
#   5191,
#   142,
#   3,
#   2,
#   3,
#   3333,
#   4138,
#   8,
#   16,
#   3390,
#   705,
#   25,
#   316,
#   5191,
#   836,
#   5946,
#   4,
#   227,
#   2924,
#   553,
#   542,
#   3449,
#   6103,
#   1007,
#   3019,
#   4,
#   216,
#   542,
#   1219,
#   3156,
#   6,
#   216,
#   1535,
#   1507,
#   5,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   18098,
#   10,
#   11,
#   16,
#   3312,
#   6222,
#   49033,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   4418,
#   3,
#   2],
#  [3,
#   14,
#   6302,
#   2052,
#   13,
#   108,
#   21,
#   148,
#   14,
#   2665,
#   7594,
#   28,
#   569,
#   294,
#   7,
#   6209,
#   12968,
#   114,
#   3,
#   2,
#   3,
#   3224,
#   3902,
#   7606,
#   11297,
#   7,
#   46,
#   28,
#   2900,
#   39,
#   1586,
#   2106,
#   42,
#   16,
#   22649,
#   12481,
#   807,
#   626,
#   3,
#   2],
#  [3,
#   2679,
#   10,
#   4623,
#   2906,
#   2608,
#   16,
#   43,
#   4574,
#   183,
#   2919,
#   1093,
#   17,
#   4623,
#   80,
#   20373,
#   114,
#   3,
#   2,
#   3,
#   2603,
#   1981,
#   2308,
#   3,
#   2],
#  [3,
#   5586,
#   90,
#   4379,
#   3705,
#   157,
#   2925,
#   8410,
#   9,
#   4447,
#   819,
#   2657,
#   1388,
#   4985,
#   4,
#   86,
#   14,
#   47,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   157,
#   14,
#   1054,
#   33,
#   430,
#   574,
#   493,
#   2792,
#   976,
#   976,
#   2068,
#   834,
#   2765,
#   1340,
#   11095,
#   1517,
#   493,
#   2792,
#   159,
#   3348,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18116,
#   1163,
#   7,
#   387,
#   1924,
#   30939,
#   11254,
#   639,
#   5315,
#   1546,
#   22,
#   3,
#   2,
#   3,
#   23781,
#   355,
#   15,
#   853,
#   39,
#   30939,
#   30939,
#   2679,
#   14,
#   150,
#   57,
#   89,
#   490,
#   19464,
#   1871,
#   43798,
#   4,
#   19464,
#   1871,
#   17093,
#   1575,
#   6969,
#   58,
#   3,
#   31829,
#   2679,
#   14,
#   150,
#   523,
#   355,
#   11254,
#   48599,
#   1301,
#   4,
#   355,
#   11254,
#   639,
#   5315,
#   1546,
#   381,
#   4341,
#   2528,
#   829,
#   11254,
#   639,
#   29,
#   13170,
#   1581,
#   4,
#   94,
#   11254,
#   639,
#   7918,
#   280,
#   423,
#   12395,
#   1701,
#   4,
#   18,
#   2856,
#   9031,
#   2247,
#   148,
#   764,
#   38139,
#   1384,
#   4,
#   391,
#   2528,
#   829,
#   11254,
#   639,
#   29,
#   241,
#   5721,
#   16,
#   605,
#   61327,
#   300,
#   3245,
#   57351,
#   1701,
#   34976,
#   30939,
#   30939,
#   4,
#   387,
#   577,
#   14,
#   57,
#   33,
#   605,
#   36,
#   570,
#   2301,
#   18,
#   350,
#   43557,
#   3,
#   2],
#  [3,
#   5586,
#   90,
#   157,
#   15447,
#   1672,
#   4,
#   21,
#   148,
#   14,
#   11,
#   9,
#   69,
#   3213,
#   311,
#   2121,
#   67,
#   11,
#   43451,
#   18075,
#   25,
#   22514,
#   31352,
#   6,
#   22514,
#   21703,
#   3657,
#   1581,
#   114,
#   3,
#   2,
#   3,
#   1696,
#   8595,
#   4,
#   5069,
#   1494,
#   50410,
#   4,
#   3709,
#   25958,
#   151,
#   16064,
#   20358,
#   4055,
#   25699,
#   4,
#   3,
#   2],
#  [3,
#   3936,
#   4368,
#   148,
#   14,
#   43451,
#   18075,
#   59186,
#   1384,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   21634,
#   4368,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   61,
#   10540,
#   1188,
#   7,
#   452,
#   16021,
#   357,
#   37409,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3258,
#   645,
#   7,
#   2927,
#   452,
#   450,
#   45061,
#   3,
#   2],
#  [3,
#   1276,
#   7426,
#   11,
#   1073,
#   9534,
#   33,
#   137,
#   29,
#   2789,
#   20509,
#   114,
#   3,
#   2,
#   3,
#   2097,
#   14693,
#   3,
#   2],
#  [3,
#   1203,
#   43,
#   142,
#   387,
#   417,
#   2958,
#   292,
#   159,
#   2908,
#   53816,
#   114,
#   3,
#   2,
#   3,
#   964,
#   78,
#   163,
#   29,
#   41087,
#   3,
#   2],
#  [3,
#   21634,
#   7102,
#   1464,
#   26567,
#   230,
#   877,
#   18,
#   452,
#   22514,
#   31352,
#   11567,
#   114,
#   3,
#   2,
#   3,
#   17218,
#   52513,
#   37272,
#   4,
#   6169,
#   7311,
#   8,
#   3344,
#   4368,
#   3,
#   2],
#  [3,
#   450,
#   63,
#   3056,
#   378,
#   159,
#   3348,
#   142,
#   3,
#   2,
#   3,
#   29991,
#   378,
#   1218,
#   506,
#   7,
#   450,
#   14,
#   1188,
#   18,
#   350,
#   302,
#   21,
#   1362,
#   1430,
#   2537,
#   159,
#   181,
#   474,
#   66,
#   55,
#   2892,
#   2537,
#   16,
#   139,
#   16552,
#   2697,
#   4,
#   498,
#   298,
#   199,
#   50,
#   493,
#   8271,
#   2477,
#   339,
#   12,
#   306,
#   18,
#   450,
#   5,
#   783,
#   2559,
#   3056,
#   9,
#   493,
#   385,
#   91,
#   159,
#   3348,
#   7,
#   452,
#   618,
#   1710,
#   42,
#   385,
#   91,
#   9287,
#   6928,
#   4,
#   385,
#   91,
#   441,
#   6430,
#   4,
#   385,
#   91,
#   740,
#   1093,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   11,
#   906,
#   493,
#   7303,
#   10816,
#   53,
#   26,
#   41287,
#   54990,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   39154,
#   3,
#   2],
#  [3,
#   441,
#   148,
#   14,
#   3333,
#   1073,
#   2106,
#   30332,
#   1204,
#   9528,
#   5648,
#   2405,
#   18116,
#   15,
#   6010,
#   114,
#   3,
#   2,
#   3,
#   53334,
#   9528,
#   5648,
#   28861,
#   3,
#   2],
#  [3,
#   303,
#   8,
#   148,
#   5869,
#   989,
#   2587,
#   943,
#   13,
#   51987,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   303,
#   2184,
#   3,
#   2],
#  [3,
#   962,
#   15,
#   17204,
#   18294,
#   76,
#   6,
#   2064,
#   4567,
#   59216,
#   1850,
#   4,
#   64,
#   356,
#   129,
#   346,
#   41,
#   10,
#   373,
#   13,
#   51899,
#   2528,
#   380,
#   7,
#   1437,
#   57319,
#   51899,
#   114,
#   3,
#   2,
#   3,
#   2064,
#   4567,
#   15764,
#   3,
#   2],
#  [3,
#   2590,
#   570,
#   142,
#   119,
#   17,
#   585,
#   6920,
#   10,
#   4623,
#   11,
#   1389,
#   34376,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   32463,
#   1231,
#   187,
#   33,
#   166,
#   558,
#   620,
#   64,
#   86,
#   156,
#   63,
#   6,
#   387,
#   834,
#   11297,
#   2697,
#   7,
#   86,
#   3,
#   2],
#  [3,
#   12297,
#   8,
#   192,
#   84,
#   67,
#   12,
#   2747,
#   705,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   22980,
#   35062,
#   2573,
#   3,
#   2],
#  [3,
#   133,
#   3348,
#   5298,
#   212,
#   7,
#   9,
#   666,
#   3312,
#   806,
#   212,
#   154,
#   11,
#   34,
#   2330,
#   78,
#   3966,
#   29,
#   660,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   58511,
#   25341,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   1822,
#   7899,
#   13093,
#   5668,
#   357,
#   385,
#   6619,
#   3,
#   2,
#   3,
#   79,
#   18116,
#   3884,
#   350,
#   590,
#   3430,
#   4368,
#   5717,
#   6928,
#   7,
#   18116,
#   1163,
#   3751,
#   8317,
#   4,
#   43,
#   1769,
#   78,
#   173,
#   29,
#   8971,
#   4,
#   2042,
#   7899,
#   13093,
#   5668,
#   357,
#   14,
#   467,
#   16,
#   961,
#   1734,
#   13,
#   10969,
#   1093,
#   5922,
#   19238,
#   2663,
#   3019,
#   939,
#   5721,
#   385,
#   6619,
#   24,
#   7927,
#   3959,
#   159,
#   493,
#   5,
#   3,
#   2],
#  [3,
#   30939,
#   1000,
#   681,
#   7,
#   20623,
#   351,
#   1746,
#   401,
#   56234,
#   1487,
#   22,
#   14,
#   11,
#   675,
#   1201,
#   24,
#   24515,
#   64,
#   19271,
#   6430,
#   3705,
#   25837,
#   114,
#   3,
#   2,
#   3,
#   452,
#   3,
#   2],
#  [3,
#   8665,
#   56182,
#   1301,
#   4,
#   5116,
#   30419,
#   1187,
#   4,
#   6,
#   49,
#   4770,
#   2528,
#   9,
#   1607,
#   5959,
#   1906,
#   2178,
#   2919,
#   572,
#   276,
#   44,
#   280,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   819,
#   284,
#   2919,
#   57659,
#   1301,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   18,
#   414,
#   127,
#   2209,
#   32384,
#   1231,
#   718,
#   2936,
#   1430,
#   11,
#   819,
#   52530,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   29,
#   4917,
#   5381,
#   4,
#   3,
#   2],
#  [3,
#   373,
#   7195,
#   103,
#   67,
#   7,
#   423,
#   1463,
#   4379,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   42128,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   248,
#   5535,
#   14,
#   215,
#   266,
#   30939,
#   42160,
#   1302,
#   22,
#   561,
#   2856,
#   52006,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   346,
#   3,
#   2],
#  [3,
#   1276,
#   7426,
#   30,
#   33,
#   78,
#   8069,
#   15,
#   16,
#   2068,
#   2537,
#   639,
#   2199,
#   30419,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   242,
#   109,
#   365,
#   13,
#   105,
#   462,
#   397,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   14945,
#   45,
#   10,
#   4623,
#   11,
#   2902,
#   2203,
#   15,
#   16,
#   215,
#   184,
#   17632,
#   558,
#   34302,
#   114,
#   3,
#   2,
#   3,
#   12583,
#   14945,
#   22842,
#   4,
#   3,
#   2],
#  [3,
#   1783,
#   3139,
#   148,
#   140,
#   40,
#   54776,
#   1073,
#   12,
#   6112,
#   3056,
#   58975,
#   6108,
#   114,
#   3,
#   2,
#   3,
#   2856,
#   3,
#   2],
#  [3,
#   2454,
#   2234,
#   23533,
#   8,
#   73,
#   695,
#   7,
#   1692,
#   142,
#   3,
#   2,
#   3,
#   2080,
#   389,
#   3751,
#   5476,
#   708,
#   13591,
#   10801,
#   1179,
#   11,
#   1224,
#   302,
#   317,
#   1389,
#   15558,
#   4,
#   430,
#   2274,
#   21,
#   2198,
#   1645,
#   85,
#   2008,
#   4363,
#   27,
#   7236,
#   6588,
#   14876,
#   1301,
#   4,
#   12813,
#   45267,
#   1395,
#   4,
#   298,
#   16580,
#   1672,
#   4,
#   1447,
#   59742,
#   1395,
#   4,
#   639,
#   34139,
#   1187,
#   4,
#   309,
#   55690,
#   6,
#   2773,
#   6968,
#   4,
#   15,
#   9,
#   3520,
#   805,
#   1079,
#   15,
#   21,
#   819,
#   284,
#   1895,
#   187,
#   7,
#   1103,
#   914,
#   350,
#   10029,
#   27,
#   73,
#   2127,
#   10440,
#   1881,
#   4,
#   80,
#   2845,
#   9446,
#   4,
#   657,
#   18612,
#   1701,
#   135,
#   3089,
#   109,
#   3751,
#   5476,
#   124,
#   7834,
#   4006,
#   368,
#   26886,
#   387,
#   5924,
#   819,
#   284,
#   632,
#   914,
#   2106,
#   25177,
#   2008,
#   4,
#   73,
#   2127,
#   10440,
#   1881,
#   4,
#   2420,
#   24351,
#   21473,
#   3698,
#   1294,
#   975,
#   80,
#   2845,
#   9446,
#   4,
#   3364,
#   1698,
#   6406,
#   1698,
#   26824,
#   4,
#   3520,
#   805,
#   3114,
#   24351,
#   1395,
#   4,
#   630,
#   3649,
#   60926,
#   1494,
#   17182,
#   1672,
#   135,
#   32,
#   2528,
#   380,
#   12,
#   109,
#   389,
#   29,
#   45538,
#   5,
#   3223,
#   109,
#   389,
#   3751,
#   5476,
#   14157,
#   687,
#   124,
#   2420,
#   13906,
#   1782,
#   25591,
#   1701,
#   19,
#   8,
#   16,
#   3674,
#   5332,
#   1340,
#   8503,
#   10,
#   4762,
#   819,
#   2454,
#   2234,
#   39878,
#   21573,
#   559,
#   362,
#   27772,
#   4,
#   2301,
#   1981,
#   2308,
#   737,
#   11,
#   14945,
#   3900,
#   63,
#   150,
#   286,
#   1294,
#   7,
#   9,
#   1389,
#   687,
#   3520,
#   805,
#   1300,
#   363,
#   48,
#   30714,
#   109,
#   3040,
#   12584,
#   345,
#   1740,
#   56255,
#   30,
#   150,
#   316,
#   38,
#   11,
#   523,
#   21,
#   2226,
#   2106,
#   80,
#   914,
#   10932,
#   37659,
#   20330,
#   3,
#   2],
#  [3,
#   8984,
#   494,
#   11,
#   1073,
#   380,
#   127,
#   6937,
#   29,
#   12529,
#   25,
#   602,
#   3,
#   2,
#   3,
#   146,
#   1713,
#   1934,
#   17860,
#   862,
#   222,
#   50351,
#   2608,
#   87,
#   249,
#   39,
#   790,
#   123,
#   32841,
#   4,
#   73,
#   18,
#   14,
#   418,
#   235,
#   25,
#   3081,
#   58953,
#   12584,
#   635,
#   16290,
#   17648,
#   12,
#   3890,
#   13119,
#   2490,
#   9,
#   69,
#   17860,
#   862,
#   222,
#   14,
#   1073,
#   380,
#   40,
#   36,
#   675,
#   1591,
#   121,
#   494,
#   7,
#   16,
#   568,
#   4721,
#   4422,
#   175,
#   1395,
#   18800,
#   21473,
#   321,
#   49,
#   1073,
#   380,
#   40,
#   215,
#   1824,
#   494,
#   3081,
#   1432,
#   33,
#   78,
#   76,
#   29,
#   6353,
#   35,
#   149,
#   3081,
#   18176,
#   1301,
#   4,
#   13,
#   108,
#   286,
#   1362,
#   7,
#   215,
#   1824,
#   494,
#   23,
#   14,
#   418,
#   235,
#   25,
#   97,
#   137,
#   147,
#   6536,
#   9642,
#   6304,
#   99,
#   982,
#   8479,
#   5,
#   3,
#   2],
#  [3,
#   10150,
#   620,
#   7657,
#   2215,
#   8,
#   2765,
#   2652,
#   11297,
#   2697,
#   159,
#   7,
#   21,
#   538,
#   119,
#   17,
#   142,
#   3,
#   2,
#   3,
#   793,
#   136,
#   1696,
#   7657,
#   102,
#   10,
#   454,
#   356,
#   462,
#   142,
#   2902,
#   2203,
#   517,
#   620,
#   7657,
#   2215,
#   15,
#   316,
#   5191,
#   2765,
#   2652,
#   302,
#   835,
#   5,
#   3,
#   2],
#  [3,
#   184,
#   2379,
#   21,
#   148,
#   86,
#   69,
#   58,
#   17,
#   4623,
#   11,
#   2657,
#   2902,
#   15,
#   80,
#   294,
#   1494,
#   13776,
#   5796,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   326,
#   3902,
#   3,
#   2],
#  [3,
#   404,
#   602,
#   7162,
#   8608,
#   2030,
#   1966,
#   14760,
#   3348,
#   2679,
#   1070,
#   36171,
#   114,
#   3,
#   2,
#   3,
#   18742,
#   1517,
#   25,
#   1437,
#   3992,
#   3,
#   2],
#  [3,
#   2833,
#   1361,
#   21,
#   148,
#   14,
#   159,
#   493,
#   200,
#   87,
#   3078,
#   848,
#   10842,
#   50656,
#   5237,
#   34453,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   9,
#   27966,
#   2380,
#   770,
#   11635,
#   8251,
#   33602,
#   33950,
#   1384,
#   4,
#   3,
#   2],
#  [3,
#   2288,
#   567,
#   148,
#   11,
#   1073,
#   380,
#   24,
#   199,
#   40,
#   3201,
#   1701,
#   21356,
#   114,
#   3,
#   2,
#   3,
#   5058,
#   3173,
#   48514,
#   8526,
#   3907,
#   39806,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   146,
#   5228,
#   2919,
#   12,
#   37,
#   1692,
#   8,
#   16,
#   499,
#   40729,
#   12,
#   61,
#   1073,
#   12155,
#   7,
#   9,
#   626,
#   5924,
#   7,
#   11639,
#   42594,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   10413,
#   1555,
#   3,
#   2],
#  [3,
#   29,
#   148,
#   14,
#   18,
#   5955,
#   8348,
#   34550,
#   8536,
#   58,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   12941,
#   3415,
#   3,
#   2],
#  [3,
#   16,
#   418,
#   1889,
#   64,
#   6667,
#   34,
#   9,
#   2697,
#   1889,
#   85,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   401,
#   5199,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   12,
#   21,
#   675,
#   6892,
#   44567,
#   2537,
#   25,
#   590,
#   24051,
#   187,
#   28,
#   19695,
#   7167,
#   1345,
#   114,
#   3,
#   2,
#   3,
#   6522,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   58,
#   157,
#   2178,
#   89,
#   759,
#   2680,
#   7,
#   668,
#   630,
#   4391,
#   22682,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   17,
#   45,
#   15885,
#   2908,
#   34,
#   54751,
#   1301,
#   4,
#   3,
#   2],
#  [3,
#   162,
#   26,
#   89,
#   56417,
#   1384,
#   4,
#   4267,
#   8218,
#   26884,
#   11,
#   1510,
#   23647,
#   25,
#   602,
#   3,
#   2,
#   3,
#   962,
#   46105,
#   4,
#   11414,
#   4700,
#   675,
#   89,
#   733,
#   26,
#   60,
#   1443,
#   57246,
#   27375,
#   168,
#   25,
#   642,
#   11,
#   445,
#   46105,
#   4,
#   11,
#   1510,
#   23647,
#   35,
#   934,
#   18176,
#   10557,
#   3,
#   2],
#  [3,
#   16,
#   61,
#   2379,
#   2665,
#   7594,
#   85,
#   246,
#   15,
#   386,
#   6120,
#   1883,
#   40559,
#   13961,
#   1749,
#   4129,
#   151,
#   8767,
#   13961,
#   1749,
#   4129,
#   25869,
#   7358,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   38014,
#   24895,
#   39490,
#   3,
#   2],
#  [3,
#   16,
#   278,
#   248,
#   543,
#   13,
#   61,
#   475,
#   138,
#   147,
#   9,
#   215,
#   9707,
#   85,
#   138,
#   7,
#   215,
#   5273,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   430,
#   5273,
#   1611,
#   3,
#   2],
#  [3,
#   4031,
#   142,
#   36,
#   325,
#   2126,
#   27979,
#   1187,
#   4,
#   667,
#   2559,
#   42,
#   2126,
#   18265,
#   6,
#   1074,
#   22397,
#   1384,
#   4,
#   22912,
#   5447,
#   114,
#   3,
#   2,
#   3,
#   368,
#   3,
#   2],
#  [3,
#   622,
#   2288,
#   17,
#   2559,
#   58660,
#   5916,
#   30,
#   39,
#   28408,
#   1881,
#   114,
#   3,
#   2,
#   3,
#   5255,
#   3256,
#   91,
#   18,
#   2374,
#   676,
#   7,
#   9,
#   3210,
#   25580,
#   1144,
#   4581,
#   127,
#   6937,
#   111,
#   18,
#   2608,
#   13143,
#   16088,
#   4453,
#   33,
#   275,
#   3,
#   2],
#  [3,
#   319,
#   142,
#   14,
#   11,
#   9,
#   23355,
#   11723,
#   5351,
#   3517,
#   1850,
#   55208,
#   302,
#   59035,
#   114,
#   3,
#   2,
#   3,
#   1298,
#   1641,
#   210,
#   29,
#   39587,
#   4,
#   3,
#   2],
#  [3,
#   47,
#   275,
#   778,
#   14,
#   199,
#   77,
#   21,
#   148,
#   9,
#   2301,
#   418,
#   4311,
#   7,
#   86,
#   6169,
#   7311,
#   1790,
#   3240,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   69,
#   558,
#   17,
#   240,
#   108,
#   25,
#   378,
#   84,
#   20999,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   6244,
#   2665,
#   2301,
#   30,
#   8840,
#   5135,
#   8,
#   939,
#   22366,
#   930,
#   3685,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   16,
#   40415,
#   7038,
#   24090,
#   32546,
#   1701,
#   4,
#   9393,
#   51862,
#   4,
#   151,
#   7520,
#   3931,
#   3,
#   2],
#  [3,
#   24444,
#   1098,
#   11,
#   675,
#   1201,
#   29,
#   1939,
#   6,
#   1531,
#   43451,
#   18075,
#   21,
#   148,
#   856,
#   1362,
#   10,
#   4623,
#   366,
#   7,
#   55905,
#   2659,
#   114,
#   3,
#   2,
#   3,
#   9079,
#   10705,
#   2508,
#   6,
#   5791,
#   1734,
#   10705,
#   2508,
#   3,
#   2],
#  [3,
#   1783,
#   3139,
#   230,
#   2951,
#   148,
#   14,
#   46953,
#   4263,
#   108,
#   10,
#   4623,
#   10,
#   12053,
#   1294,
#   15,
#   378,
#   56101,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   10771,
#   4774,
#   127,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   4089,
#   2140,
#   14,
#   2599,
#   701,
#   11,
#   12,
#   9,
#   110,
#   201,
#   5955,
#   3958,
#   10931,
#   114,
#   3,
#   2,
#   3,
#   22002,
#   3,
#   2],
#  [3,
#   4029,
#   316,
#   5191,
#   47,
#   380,
#   2919,
#   2587,
#   943,
#   3962,
#   235,
#   31700,
#   114,
#   3,
#   2,
#   3,
#   17,
#   10932,
#   2288,
#   13,
#   49,
#   5717,
#   8410,
#   4721,
#   4422,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   11,
#   215,
#   5273,
#   39,
#   127,
#   6937,
#   11,
#   199,
#   2610,
#   114,
#   3,
#   2,
#   3,
#   12109,
#   3,
#   2],
#  [3,
#   2679,
#   6254,
#   2697,
#   16,
#   110,
#   9929,
#   22560,
#   121,
#   139,
#   510,
#   89,
#   22442,
#   454,
#   6620,
#   114,
#   3,
#   2,
#   3,
#   2901,
#   3019,
#   2842,
#   226,
#   3,
#   2],
#  [3,
#   2925,
#   2792,
#   3518,
#   3959,
#   8,
#   8840,
#   24253,
#   15,
#   2925,
#   2412,
#   1660,
#   6248,
#   380,
#   136,
#   10,
#   1645,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   2543,
#   1660,
#   28108,
#   18658,
#   1301,
#   22,
#   3,
#   2],
#  [3,
#   499,
#   129,
#   82,
#   24590,
#   4930,
#   274,
#   12,
#   5843,
#   2833,
#   16,
#   18116,
#   3884,
#   22986,
#   67,
#   15,
#   82,
#   894,
#   618,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   24,
#   682,
#   44,
#   27924,
#   387,
#   987,
#   64,
#   46,
#   200,
#   87,
#   40957,
#   1565,
#   14,
#   4456,
#   302,
#   4089,
#   4301,
#   7,
#   69,
#   2528,
#   618,
#   3,
#   2],
#  [3,
#   3483,
#   1000,
#   1785,
#   11,
#   1362,
#   4365,
#   4542,
#   3936,
#   47,
#   22366,
#   148,
#   3,
#   2,
#   3,
#   1004,
#   675,
#   49,
#   7007,
#   4864,
#   12,
#   2127,
#   22535,
#   1881,
#   4,
#   3483,
#   1000,
#   1785,
#   50,
#   11,
#   1692,
#   574,
#   49,
#   5073,
#   21,
#   2958,
#   1734,
#   1821,
#   574,
#   15,
#   69,
#   36126,
#   6185,
#   1612,
#   311,
#   2317,
#   40610,
#   21,
#   2958,
#   1734,
#   1821,
#   574,
#   40865,
#   31829,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   127,
#   6937,
#   1626,
#   3705,
#   7564,
#   853,
#   40,
#   355,
#   350,
#   3,
#   2,
#   3,
#   61610,
#   3019,
#   7564,
#   6221,
#   564,
#   101,
#   127,
#   6937,
#   11,
#   3751,
#   13311,
#   3019,
#   1626,
#   40,
#   355,
#   350,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   350,
#   590,
#   127,
#   6937,
#   620,
#   40,
#   227,
#   10955,
#   3506,
#   3,
#   2,
#   3,
#   1117,
#   56619,
#   99,
#   14157,
#   19,
#   118,
#   50,
#   328,
#   8,
#   356,
#   1858,
#   836,
#   99,
#   8,
#   152,
#   2068,
#   2374,
#   127,
#   6937,
#   12,
#   2546,
#   5717,
#   620,
#   33,
#   10955,
#   3506,
#   10,
#   2068,
#   2537,
#   25837,
#   5,
#   3269,
#   42689,
#   1894,
#   1117,
#   56619,
#   2147,
#   31951,
#   39544,
#   11674,
#   3611,
#   3492,
#   14,
#   11,
#   111,
#   40,
#   1294,
#   12813,
#   33,
#   43,
#   445,
#   78,
#   163,
#   29,
#   9859,
#   39,
#   517,
#   620,
#   10955,
#   3506,
#   15265,
#   31865,
#   7382,
#   15,
#   2068,
#   2537,
#   3931,
#   18,
#   3490,
#   27986,
#   8,
#   39518,
#   50613,
#   47,
#   46,
#   682,
#   302,
#   18,
#   127,
#   6937,
#   510,
#   89,
#   1660,
#   6248,
#   40,
#   145,
#   227,
#   17,
#   32741,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   6850,
#   2198,
#   221,
#   58593,
#   3240,
#   114,
#   3,
#   2,
#   3,
#   6209,
#   1395,
#   3342,
#   5213,
#   676,
#   16275,
#   24188,
#   3,
#   2],
#  [3,
#   79,
#   37,
#   11,
#   9,
#   69,
#   1251,
#   2289,
#   1347,
#   50410,
#   114,
#   3,
#   2,
#   3,
#   12839,
#   16809,
#   1622,
#   4,
#   3,
#   2],
#  [3,
#   853,
#   9031,
#   148,
#   10,
#   21,
#   184,
#   1078,
#   24,
#   96,
#   28,
#   32000,
#   418,
#   37825,
#   56116,
#   114,
#   3,
#   2,
#   3,
#   8274,
#   28620,
#   3,
#   2],
#  [3,
#   1206,
#   835,
#   142,
#   8,
#   26950,
#   7,
#   103,
#   129,
#   23797,
#   114,
#   3,
#   2,
#   3,
#   33087,
#   6691,
#   7306,
#   10931,
#   4,
#   3,
#   2],
#  [3,
#   17,
#   2279,
#   8837,
#   4692,
#   1487,
#   32111,
#   14818,
#   4578,
#   178,
#   7344,
#   200,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   23433,
#   3,
#   2],
#  [3,
#   12297,
#   8726,
#   12699,
#   20062,
#   127,
#   6937,
#   96,
#   28,
#   224,
#   366,
#   7,
#   269,
#   35297,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   22514,
#   10447,
#   1931,
#   4742,
#   4,
#   3,
#   2],
#  [3,
#   13466,
#   6488,
#   675,
#   1510,
#   380,
#   35,
#   7,
#   302,
#   835,
#   1737,
#   8883,
#   1612,
#   8,
#   277,
#   3,
#   2,
#   3,
#   3333,
#   8641,
#   819,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   20,
#   355,
#   157,
#   27,
#   10550,
#   3378,
#   1612,
#   5218,
#   19900,
#   32283,
#   4,
#   467,
#   2135,
#   27,
#   13511,
#   19,
#   8,
#   3010,
#   1906,
#   819,
#   7,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   4,
#   5089,
#   187,
#   34128,
#   718,
#   2936,
#   452,
#   1206,
#   835,
#   1737,
#   8883,
#   1612,
#   5,
#   3,
#   2],
#  [3, 12297, 21, 18, 23, 235, 25, 28408, 1881, 114, 3, 2, 3, 15740, 3, 2],
#  [3,
#   29,
#   148,
#   14,
#   47,
#   27981,
#   4975,
#   21619,
#   5827,
#   10348,
#   1422,
#   59216,
#   3104,
#   3520,
#   32841,
#   114,
#   3,
#   2,
#   3,
#   6544,
#   3,
#   2],
#  [3,
#   242,
#   894,
#   55613,
#   1517,
#   1278,
#   22563,
#   32,
#   11,
#   328,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   5728,
#   2500,
#   1993,
#   4323,
#   7409,
#   22,
#   3,
#   2],
#  [3,
#   13825,
#   1734,
#   127,
#   6937,
#   7,
#   98,
#   1832,
#   3883,
#   8,
#   277,
#   3,
#   2,
#   3,
#   347,
#   29,
#   4602,
#   46,
#   8,
#   5932,
#   1734,
#   98,
#   21356,
#   1231,
#   621,
#   59426,
#   98,
#   4700,
#   30862,
#   1301,
#   4,
#   46,
#   300,
#   1766,
#   178,
#   23,
#   13,
#   30,
#   26,
#   4700,
#   30862,
#   1301,
#   4,
#   1832,
#   2331,
#   6,
#   1832,
#   3883,
#   1637,
#   44,
#   302,
#   98,
#   3883,
#   24327,
#   27375,
#   162,
#   37,
#   8,
#   2185,
#   5932,
#   1734,
#   98,
#   12917,
#   13,
#   30,
#   29,
#   12515,
#   26395,
#   3,
#   2],
#  [3,
#   9766,
#   8410,
#   3228,
#   2697,
#   1889,
#   42,
#   2747,
#   797,
#   14,
#   150,
#   11,
#   774,
#   8,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   40,
#   509,
#   18964,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   2679,
#   1906,
#   17055,
#   7833,
#   5520,
#   7596,
#   4157,
#   770,
#   11370,
#   6614,
#   1877,
#   114,
#   3,
#   2,
#   3,
#   21703,
#   3613,
#   10448,
#   43769,
#   53683,
#   14405,
#   16529,
#   16529,
#   12,
#   21,
#   16359,
#   6304,
#   917,
#   53196,
#   4,
#   6,
#   11,
#   13557,
#   154,
#   223,
#   69,
#   5520,
#   6222,
#   6417,
#   56846,
#   33,
#   29,
#   36895,
#   6,
#   29,
#   3855,
#   1765,
#   27751,
#   35,
#   790,
#   192,
#   27772,
#   4,
#   7291,
#   6,
#   6417,
#   25,
#   275,
#   179,
#   74,
#   50,
#   8,
#   16,
#   230,
#   7,
#   23036,
#   6,
#   3,
#   2],
#  [3,
#   1283,
#   5294,
#   4439,
#   2765,
#   10317,
#   8,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   14210,
#   1007,
#   1463,
#   10,
#   1283,
#   5294,
#   3463,
#   6825,
#   6452,
#   7972,
#   20,
#   19312,
#   6452,
#   5650,
#   6789,
#   157,
#   19,
#   75,
#   12556,
#   2670,
#   7972,
#   20,
#   1551,
#   8160,
#   5650,
#   6789,
#   157,
#   19,
#   5,
#   1615,
#   363,
#   47877,
#   2615,
#   8,
#   3856,
#   810,
#   6,
#   405,
#   720,
#   2765,
#   2404,
#   8,
#   3100,
#   810,
#   4,
#   51,
#   35,
#   683,
#   2178,
#   15,
#   3449,
#   934,
#   1962,
#   20,
#   3680,
#   262,
#   32921,
#   19,
#   66,
#   720,
#   964,
#   810,
#   20,
#   358,
#   5650,
#   157,
#   19,
#   6,
#   5719,
#   720,
#   878,
#   2529,
#   208,
#   10716,
#   810,
#   5,
#   3,
#   2],
#  [3,
#   1737,
#   3978,
#   50,
#   10,
#   221,
#   328,
#   85,
#   8,
#   148,
#   3,
#   2,
#   3,
#   1737,
#   6458,
#   14252,
#   50,
#   11,
#   328,
#   8,
#   1737,
#   7749,
#   20,
#   12,
#   4,
#   1005,
#   23,
#   11,
#   328,
#   8,
#   1737,
#   6458,
#   7749,
#   31,
#   22,
#   6454,
#   1894,
#   1993,
#   9327,
#   4553,
#   11098,
#   22,
#   19,
#   4,
#   8,
#   16,
#   1005,
#   58,
#   2324,
#   385,
#   8249,
#   339,
#   25,
#   2765,
#   2652,
#   302,
#   835,
#   1696,
#   7657,
#   5,
#   1737,
#   10,
#   1283,
#   5294,
#   137,
#   445,
#   953,
#   5,
#   347,
#   1357,
#   4,
#   1005,
#   50,
#   10,
#   9,
#   221,
#   328,
#   8,
#   1005,
#   13388,
#   2583,
#   20,
#   90,
#   58,
#   10,
#   412,
#   656,
#   1373,
#   29,
#   19,
#   4,
#   1005,
#   2583,
#   2842,
#   20,
#   175,
#   24,
#   5207,
#   4766,
#   4006,
#   19,
#   4,
#   1005,
#   24193,
#   13957,
#   6,
#   8218,
#   13957,
#   20,
#   12,
#   790,
#   4267,
#   38195,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   5975,
#   15130,
#   8,
#   2697,
#   1889,
#   58,
#   4248,
#   118,
#   2324,
#   3,
#   2,
#   3,
#   1322,
#   4257,
#   159,
#   7,
#   569,
#   15130,
#   93,
#   8,
#   11565,
#   4,
#   6134,
#   42,
#   5408,
#   560,
#   325,
#   569,
#   142,
#   11,
#   240,
#   108,
#   25,
#   58,
#   2324,
#   2178,
#   89,
#   2975,
#   212,
#   235,
#   58,
#   4248,
#   1946,
#   262,
#   131,
#   10,
#   4623,
#   8,
#   73,
#   35364,
#   27375,
#   635,
#   37989,
#   5906,
#   4,
#   569,
#   61097,
#   1395,
#   4,
#   569,
#   4951,
#   103,
#   6,
#   6169,
#   7311,
#   8,
#   569,
#   3959,
#   26443,
#   42,
#   8,
#   73,
#   4257,
#   11044,
#   18109,
#   904,
#   31542,
#   7,
#   569,
#   15130,
#   93,
#   720,
#   48,
#   246,
#   15,
#   16,
#   515,
#   325,
#   569,
#   15130,
#   1560,
#   203,
#   569,
#   14157,
#   42,
#   569,
#   15130,
#   8978,
#   22231,
#   4,
#   569,
#   15130,
#   1898,
#   41317,
#   1384,
#   34976,
#   37272,
#   4,
#   13,
#   996,
#   231,
#   24,
#   5665,
#   9324,
#   3056,
#   378,
#   203,
#   653,
#   15,
#   73,
#   4257,
#   2529,
#   1465,
#   31536,
#   10557,
#   1322,
#   4257,
#   2037,
#   2697,
#   28,
#   6254,
#   10083,
#   39,
#   12840,
#   4894,
#   15,
#   569,
#   15130,
#   73,
#   13,
#   75,
#   3931,
#   14505,
#   103,
#   45,
#   2587,
#   223,
#   73,
#   676,
#   52530,
#   2008,
#   4,
#   6,
#   10,
#   4623,
#   1464,
#   479,
#   36,
#   325,
#   4174,
#   1387,
#   4,
#   2697,
#   1889,
#   10,
#   1659,
#   10615,
#   4,
#   1698,
#   15512,
#   1850,
#   4,
#   5109,
#   1850,
#   4,
#   16840,
#   1395,
#   4,
#   11142,
#   1347,
#   4,
#   6,
#   464,
#   26,
#   94,
#   2906,
#   44669,
#   27375,
#   10136,
#   203,
#   7,
#   569,
#   15130,
#   1898,
#   363,
#   676,
#   302,
#   286,
#   1783,
#   8,
#   4174,
#   1387,
#   4,
#   1236,
#   9479,
#   1384,
#   4,
#   1476,
#   22682,
#   1187,
#   4,
#   569,
#   6,
#   2697,
#   1889,
#   15903,
#   30428,
#   5,
#   5975,
#   15130,
#   3062,
#   54,
#   479,
#   5975,
#   43689,
#   4,
#   2697,
#   1889,
#   444,
#   1933,
#   58,
#   1701,
#   18020,
#   1187,
#   4,
#   6,
#   2697,
#   1889,
#   2956,
#   2906,
#   8,
#   2908,
#   203,
#   7,
#   569,
#   15130,
#   37653,
#   5,
#   1322,
#   676,
#   302,
#   203,
#   2697,
#   1889,
#   10,
#   5139,
#   43689,
#   4,
#   569,
#   6,
#   1698,
#   15512,
#   12584,
#   3,
#   2],
#  [3,
#   251,
#   10,
#   121,
#   298,
#   3056,
#   17,
#   11,
#   1140,
#   12,
#   6134,
#   351,
#   9,
#   24351,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   53,
#   939,
#   22366,
#   2199,
#   7833,
#   14,
#   11,
#   675,
#   32151,
#   4,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   2284,
#   230,
#   33,
#   224,
#   1310,
#   25,
#   590,
#   1070,
#   18415,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   137,
#   139,
#   1425,
#   2477,
#   3,
#   2],
#  [3,
#   69,
#   25,
#   418,
#   1430,
#   1821,
#   1354,
#   311,
#   11,
#   5115,
#   14005,
#   53,
#   26,
#   1746,
#   401,
#   11,
#   328,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   30939,
#   26576,
#   2438,
#   22,
#   3,
#   2],
#  [3,
#   321,
#   277,
#   17,
#   551,
#   5941,
#   9393,
#   159,
#   13,
#   278,
#   96,
#   18302,
#   4115,
#   7,
#   222,
#   47441,
#   114,
#   3,
#   2,
#   3,
#   1706,
#   21177,
#   4,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   9,
#   69,
#   1302,
#   10210,
#   834,
#   462,
#   2925,
#   2177,
#   12,
#   3210,
#   22802,
#   2356,
#   6309,
#   1044,
#   22275,
#   770,
#   3787,
#   3288,
#   4055,
#   114,
#   3,
#   2,
#   3,
#   197,
#   760,
#   1294,
#   5268,
#   39,
#   69,
#   1302,
#   10210,
#   834,
#   24,
#   1073,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   462,
#   1914,
#   298,
#   127,
#   6937,
#   11,
#   5297,
#   320,
#   6,
#   5717,
#   8410,
#   12,
#   9,
#   993,
#   12836,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3855,
#   17651,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   217,
#   517,
#   620,
#   8,
#   993,
#   3489,
#   3705,
#   7564,
#   6,
#   2151,
#   4439,
#   159,
#   7,
#   302,
#   36951,
#   114,
#   3,
#   2,
#   3,
#   15351,
#   7621,
#   10030,
#   1187,
#   4,
#   3,
#   2],
#  [3,
#   35628,
#   856,
#   142,
#   150,
#   11,
#   1692,
#   4267,
#   9755,
#   6483,
#   413,
#   882,
#   3,
#   2,
#   3,
#   217,
#   18,
#   1875,
#   201,
#   6792,
#   59,
#   11,
#   7594,
#   49592,
#   1701,
#   4,
#   11,
#   1692,
#   718,
#   1740,
#   797,
#   34157,
#   4,
#   1981,
#   17173,
#   26389,
#   1395,
#   4,
#   9,
#   2665,
#   2025,
#   2079,
#   47,
#   586,
#   12538,
#   5255,
#   25,
#   69,
#   1709,
#   26427,
#   1395,
#   4,
#   125,
#   2220,
#   701,
#   221,
#   33,
#   614,
#   354,
#   2051,
#   71,
#   993,
#   836,
#   47203,
#   4,
#   47,
#   586,
#   28898,
#   4026,
#   19770,
#   23027,
#   5,
#   27126,
#   53077,
#   1187,
#   4,
#   1692,
#   4267,
#   9755,
#   6483,
#   50,
#   13,
#   16365,
#   2108,
#   1447,
#   9031,
#   2289,
#   12,
#   69,
#   1709,
#   26427,
#   21473,
#   783,
#   11,
#   5228,
#   4181,
#   5665,
#   8410,
#   47,
#   23106,
#   5,
#   4834,
#   4267,
#   6829,
#   1391,
#   1766,
#   11,
#   1742,
#   2054,
#   201,
#   1447,
#   9031,
#   273,
#   1875,
#   1551,
#   5511,
#   1447,
#   9031,
#   431,
#   22366,
#   50071,
#   10557,
#   1967,
#   790,
#   1692,
#   4267,
#   9755,
#   6483,
#   14157,
#   3012,
#   15584,
#   3012,
#   15165,
#   19,
#   1391,
#   1766,
#   11,
#   445,
#   2054,
#   201,
#   1447,
#   9031,
#   273,
#   1875,
#   24415,
#   1447,
#   9031,
#   426,
#   22366,
#   50071,
#   10557,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   4379,
#   3705,
#   1755,
#   34550,
#   724,
#   223,
#   9326,
#   3705,
#   50359,
#   9472,
#   3889,
#   11644,
#   114,
#   3,
#   2,
#   3,
#   53,
#   46377,
#   1118,
#   982,
#   8479,
#   4,
#   3,
#   2],
#  [3,
#   382,
#   423,
#   44,
#   10,
#   579,
#   2665,
#   2652,
#   12,
#   29,
#   7806,
#   2686,
#   114,
#   3,
#   2,
#   3,
#   87,
#   286,
#   1645,
#   829,
#   58217,
#   2714,
#   4368,
#   25,
#   216,
#   553,
#   7,
#   179,
#   58,
#   14,
#   3931,
#   128,
#   53,
#   61,
#   10893,
#   1159,
#   7,
#   1058,
#   2856,
#   4006,
#   39,
#   16,
#   69,
#   1620,
#   59969,
#   1947,
#   33,
#   25479,
#   1701,
#   4,
#   3,
#   2],
#  [3,
#   350,
#   590,
#   3931,
#   1637,
#   3490,
#   2506,
#   3705,
#   33,
#   43,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   10658,
#   4436,
#   35291,
#   7,
#   792,
#   80,
#   4162,
#   1510,
#   3490,
#   3398,
#   3019,
#   11,
#   67,
#   5924,
#   2178,
#   89,
#   33,
#   43,
#   431,
#   78,
#   317,
#   29,
#   13652,
#   1546,
#   4,
#   53,
#   26,
#   305,
#   1522,
#   807,
#   611,
#   3931,
#   1637,
#   3490,
#   3398,
#   3019,
#   7,
#   58,
#   11918,
#   59763,
#   1517,
#   3074,
#   1093,
#   3698,
#   1645,
#   350,
#   10029,
#   4,
#   792,
#   80,
#   14,
#   1294,
#   2528,
#   3449,
#   1093,
#   80,
#   13,
#   996,
#   350,
#   590,
#   3931,
#   39451,
#   20330,
#   3,
#   2],
#  [3,
#   11598,
#   2958,
#   9534,
#   39,
#   4597,
#   204,
#   56825,
#   311,
#   11,
#   2906,
#   2608,
#   223,
#   22649,
#   12481,
#   21,
#   148,
#   50,
#   6365,
#   21931,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   302,
#   49965,
#   5603,
#   12481,
#   3,
#   2],
#  [3,
#   635,
#   126,
#   40865,
#   1672,
#   4,
#   337,
#   39,
#   29,
#   7806,
#   2326,
#   4,
#   11,
#   1746,
#   401,
#   11,
#   996,
#   24,
#   4578,
#   178,
#   16,
#   9393,
#   178,
#   53,
#   26,
#   167,
#   4422,
#   212,
#   2765,
#   26427,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   4917,
#   4,
#   3,
#   2],
#  [3, 1129, 1709, 4368, 166, 3936, 4368, 8, 1529, 10143, 114, 3, 2, 3, 3, 2],
#  [3,
#   12297,
#   21,
#   18,
#   2634,
#   13397,
#   4453,
#   430,
#   26254,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   460,
#   2615,
#   934,
#   31138,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   276,
#   11,
#   328,
#   8,
#   1117,
#   4189,
#   1347,
#   1302,
#   114,
#   3,
#   2,
#   3,
#   40223,
#   6108,
#   1384,
#   7809,
#   6,
#   3530,
#   1529,
#   13659,
#   3288,
#   2438,
#   4,
#   3,
#   2],
#  [3,
#   98,
#   8,
#   148,
#   8524,
#   57241,
#   1595,
#   339,
#   12103,
#   114,
#   3,
#   2,
#   3,
#   98,
#   4989,
#   6190,
#   2302,
#   3,
#   2],
#  [3,
#   2537,
#   2697,
#   148,
#   2906,
#   2608,
#   21,
#   148,
#   459,
#   675,
#   452,
#   187,
#   40047,
#   114,
#   3,
#   2,
#   3,
# ...
#   148,
#   4770,
#   3884,
#   11,
#   5717,
#   8410,
#   12,
#   4770,
#   2528,
#   24675,
#   140,
#   40,
#   30939,
#   8325,
#   10695,
#   1926,
#   30939,
#   114,
#   3,
#   2,
#   3,
#   2440,
#   3,
#   2],
#  [3,
#   22540,
#   5520,
#   142,
#   934,
#   1759,
#   34037,
#   7304,
#   3104,
#   30143,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   4988,
#   1347,
#   9052,
#   3,
#   2],
#  [3,
#   829,
#   61,
#   148,
#   2792,
#   525,
#   14,
#   11,
#   111,
#   33,
#   24,
#   47,
#   6220,
#   939,
#   50350,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   7,
#   3490,
#   7765,
#   3019,
#   9336,
#   181,
#   829,
#   3,
#   2],
#  [3,
#   35039,
#   8,
#   2902,
#   645,
#   7,
#   49,
#   12504,
#   1637,
#   28,
#   21,
#   148,
#   82,
#   316,
#   2608,
#   30428,
#   114,
#   3,
#   2,
#   3,
#   33870,
#   28565,
#   4082,
#   2455,
#   27680,
#   4,
#   3,
#   2],
#  [3,
#   962,
#   15,
#   24942,
#   6,
#   11595,
#   10515,
#   1197,
#   6,
#   8706,
#   17522,
#   6117,
#   10548,
#   4,
#   21,
#   148,
#   642,
#   423,
#   1073,
#   2106,
#   2528,
#   380,
#   12,
#   9,
#   215,
#   266,
#   57845,
#   114,
#   3,
#   2,
#   3,
#   5402,
#   3,
#   2],
#  [3,
#   14,
#   69,
#   4439,
#   12541,
#   222,
#   38454,
#   29179,
#   10,
#   148,
#   24,
#   96,
#   28,
#   930,
#   441,
#   2697,
#   27979,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   17,
#   108,
#   5408,
#   658,
#   184,
#   148,
#   3,
#   2],
#  [3,
#   2603,
#   1981,
#   2308,
#   129,
#   3532,
#   7,
#   1597,
#   2654,
#   8,
#   277,
#   3,
#   2,
#   3,
#   15607,
#   7221,
#   45888,
#   20,
#   10411,
#   34168,
#   23784,
#   1913,
#   26075,
#   53954,
#   7221,
#   45888,
#   4,
#   918,
#   1626,
#   22,
#   3490,
#   2506,
#   9,
#   5116,
#   9031,
#   13150,
#   506,
#   2935,
#   4957,
#   22,
#   19,
#   8,
#   5255,
#   11050,
#   64,
#   3532,
#   853,
#   9031,
#   983,
#   355,
#   7,
#   1597,
#   2654,
#   91,
#   12629,
#   11087,
#   6,
#   45107,
#   2949,
#   5128,
#   34595,
#   414,
#   127,
#   5717,
#   8410,
#   24,
#   369,
#   2226,
#   2607,
#   807,
#   5897,
#   22,
#   30737,
#   3033,
#   1565,
#   2292,
#   8038,
#   22,
#   33,
#   29,
#   5740,
#   5,
#   3,
#   2],
#  [3,
#   2603,
#   4770,
#   3884,
#   3335,
#   2151,
#   4439,
#   7,
#   350,
#   590,
#   29,
#   484,
#   8,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   1678,
#   104,
#   1118,
#   31081,
#   3594,
#   15033,
#   4,
#   2822,
#   201,
#   317,
#   27,
#   31,
#   7412,
#   829,
#   1678,
#   4598,
#   1118,
#   31081,
#   3594,
#   15033,
#   484,
#   38,
#   11,
#   13884,
#   437,
#   682,
#   302,
#   18,
#   585,
#   548,
#   1449,
#   13,
#   5522,
#   586,
#   790,
#   751,
#   3705,
#   7564,
#   35,
#   350,
#   590,
#   29,
#   484,
#   20,
#   1678,
#   10681,
#   37385,
#   32206,
#   484,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   962,
#   189,
#   142,
#   36,
#   325,
#   2126,
#   4453,
#   30428,
#   114,
#   3,
#   2,
#   3,
#   16,
#   109,
#   620,
#   3,
#   2],
#  [3,
#   92,
#   21,
#   29,
#   14,
#   2528,
#   26255,
#   1231,
#   5855,
#   537,
#   127,
#   25,
#   2935,
#   7620,
#   114,
#   3,
#   2,
#   3,
#   2617,
#   504,
#   8383,
#   3,
#   2],
#  [3,
#   2679,
#   8,
#   18,
#   298,
#   740,
#   7,
#   9527,
#   3679,
#   15447,
#   1672,
#   114,
#   3,
#   2,
#   3,
#   13279,
#   4402,
#   21225,
#   3,
#   2],
#  [3,
#   3382,
#   16297,
#   2500,
#   2126,
#   11,
#   320,
#   221,
#   42,
#   702,
#   90,
#   21,
#   148,
#   2657,
#   2665,
#   30,
#   3382,
#   16297,
#   14681,
#   7,
#   69,
#   57774,
#   114,
#   3,
#   2,
#   3,
#   412,
#   795,
#   1834,
#   7,
#   1231,
#   4578,
#   2025,
#   1231,
#   3,
#   2],
#  [3,
#   581,
#   182,
#   1597,
#   2654,
#   101,
#   1030,
#   21,
#   148,
#   231,
#   10,
#   255,
#   675,
#   4422,
#   24,
#   12,
#   82,
#   29,
#   27313,
#   2029,
#   4339,
#   196,
#   15613,
#   27518,
#   114,
#   3,
#   2,
#   3,
#   128,
#   100,
#   525,
#   19356,
#   1881,
#   4,
#   558,
#   33040,
#   4,
#   6,
#   25374,
#   5377,
#   1430,
#   4578,
#   178,
#   3,
#   2],
#  [3,
#   251,
#   142,
#   9,
#   490,
#   1731,
#   537,
#   127,
#   2734,
#   1347,
#   15250,
#   1581,
#   114,
#   3,
#   2,
#   3,
#   7618,
#   1366,
#   29,
#   55427,
#   1395,
#   4,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   2675,
#   106,
#   1073,
#   2537,
#   33,
#   29,
#   6549,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   19236,
#   3,
#   2],
#  [3,
#   17,
#   51899,
#   9531,
#   2667,
#   3173,
#   4366,
#   104,
#   1645,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   343,
#   26728,
#   6281,
#   1384,
#   30939,
#   19,
#   3,
#   2],
#  [3,
#   22012,
#   8825,
#   1894,
#   8919,
#   2029,
#   2380,
#   18411,
#   11963,
#   7645,
#   2356,
#   104,
#   657,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2780,
#   9031,
#   3,
#   2],
#  [3, 2679, 8, 18, 298, 740, 3877, 3, 2, 3, 19793, 2573, 44149, 3, 2],
#  [3,
#   4834,
#   4365,
#   383,
#   40,
#   57,
#   240,
#   109,
#   1098,
#   58,
#   3,
#   2,
#   3,
#   1266,
#   129,
#   67,
#   8,
#   57,
#   121,
#   105,
#   20999,
#   1347,
#   4,
#   790,
#   4365,
#   4453,
#   430,
#   13,
#   3488,
#   109,
#   1570,
#   810,
#   39,
#   253,
#   383,
#   3250,
#   317,
#   232,
#   337,
#   94,
#   790,
#   4365,
#   56569,
#   5,
#   1584,
#   826,
#   137,
#   17477,
#   31,
#   26936,
#   80,
#   205,
#   20999,
#   1347,
#   4,
#   32463,
#   1231,
#   538,
#   13778,
#   5,
#   3,
#   2],
#  [3,
#   16,
#   4547,
#   11536,
#   28,
#   16,
#   61,
#   2379,
#   1391,
#   1766,
#   586,
#   6304,
#   14087,
#   3936,
#   4368,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   2123,
#   1596,
#   3,
#   2],
#  [3,
#   11554,
#   656,
#   4444,
#   3198,
#   19661,
#   7,
#   2679,
#   1070,
#   4581,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   5301,
#   3198,
#   37367,
#   1581,
#   1581,
#   1850,
#   4,
#   3,
#   2],
#  [3,
#   221,
#   1529,
#   10143,
#   4,
#   145,
#   362,
#   44134,
#   29556,
#   1236,
#   4,
#   11,
#   5717,
#   8410,
#   13,
#   9,
#   230,
#   7,
#   16,
#   323,
#   128,
#   676,
#   302,
#   740,
#   33,
#   127,
#   303,
#   418,
#   54913,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   18783,
#   57501,
#   3,
#   2],
#  [3,
#   217,
#   166,
#   1898,
#   4229,
#   88,
#   115,
#   41,
#   4229,
#   2536,
#   12,
#   16,
#   6757,
#   924,
#   114,
#   3,
#   2,
#   3,
#   3631,
#   27043,
#   56784,
#   54031,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   6254,
#   11297,
#   16,
#   100,
#   215,
#   3531,
#   24,
#   548,
#   720,
#   8271,
#   47684,
#   4,
#   128,
#   13458,
#   2057,
#   13749,
#   6,
#   690,
#   2680,
#   379,
#   36,
#   31536,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   3053,
#   3,
#   2],
#  [3,
#   217,
#   148,
#   14,
#   13143,
#   1354,
#   7,
#   4567,
#   3931,
#   6933,
#   10413,
#   1966,
#   537,
#   127,
#   29,
#   2617,
#   1625,
#   2326,
#   114,
#   3,
#   2,
#   3,
#   38945,
#   1706,
#   3,
#   2],
#  [3,
#   186,
#   7235,
#   230,
#   877,
#   21,
#   148,
#   459,
#   369,
#   11,
#   1941,
#   666,
#   35,
#   16,
#   222,
#   418,
#   459,
#   352,
#   28979,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   4867,
#   3,
#   2],
#  [3,
#   503,
#   1766,
#   7038,
#   42,
#   300,
#   301,
#   1690,
#   1914,
#   298,
#   10,
#   4623,
#   1820,
#   181,
#   5089,
#   917,
#   2067,
#   298,
#   6,
#   54990,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   11919,
#   5298,
#   11015,
#   3,
#   2],
#  [3,
#   503,
#   148,
#   1400,
#   7,
#   8978,
#   6267,
#   8,
#   25,
#   216,
#   553,
#   20378,
#   2545,
#   3377,
#   4,
#   5024,
#   4145,
#   32032,
#   114,
#   3,
#   2,
#   3,
#   40902,
#   6,
#   49198,
#   3,
#   2],
#  [3,
#   5228,
#   2919,
#   21,
#   148,
#   14,
#   2665,
#   2652,
#   30,
#   49,
#   335,
#   44,
#   9,
#   3705,
#   3931,
#   963,
#   14833,
#   1607,
#   23277,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   3126,
#   5228,
#   2919,
#   3,
#   2],
#  [3,
#   5076,
#   462,
#   12,
#   574,
#   917,
#   2068,
#   3010,
#   1073,
#   2106,
#   14,
#   41,
#   1289,
#   89,
#   21,
#   148,
#   166,
#   302,
#   58481,
#   1301,
#   114,
#   3,
#   2,
#   3,
#   16,
#   9731,
#   42928,
#   21523,
#   1993,
#   3,
#   2],
#  [3,
#   503,
#   1464,
#   26567,
#   43,
#   53,
#   26,
#   11,
#   1083,
#   357,
#   56138,
#   2079,
#   9441,
#   14,
#   675,
#   1201,
#   42338,
#   4,
#   46,
#   38,
#   917,
#   9170,
#   19828,
#   16809,
#   114,
#   3,
#   2,
#   3,
#   4696,
#   3,
#   2],
#  [3,
#   4106,
#   215,
#   9707,
#   142,
#   9,
#   4368,
#   5214,
#   18,
#   2178,
#   89,
#   33,
#   78,
#   426,
#   813,
#   187,
#   40047,
#   114,
#   3,
#   2,
#   3,
#   406,
#   2119,
#   4,
#   3,
#   2],
#  [3,
#   2003,
#   2240,
#   55328,
#   197,
#   151,
#   128,
#   72,
#   12,
#   21,
#   29,
#   38937,
#   114,
#   3,
#   2,
#   3,
#   128,
#   3,
#   2],
#  [3,
#   30992,
#   11,
#   1073,
#   2537,
#   127,
#   6937,
#   35,
#   350,
#   590,
#   29,
#   142,
#   3,
#   2,
#   3,
#   41461,
#   5353,
#   2726,
#   2491,
#   696,
#   113,
#   1030,
#   1030,
#   18,
#   305,
#   33,
#   29,
#   1105,
#   510,
#   373,
#   1600,
#   56303,
#   266,
#   462,
#   284,
#   22,
#   27154,
#   1791,
#   10423,
#   22,
#   20,
#   18660,
#   53664,
#   19,
#   5,
#   434,
#   813,
#   4,
#   834,
#   266,
#   4338,
#   127,
#   6937,
#   28,
#   30992,
#   14,
#   11,
#   40,
#   641,
#   15,
#   221,
#   328,
#   22,
#   22,
#   5,
#   382,
#   350,
#   590,
#   9,
#   215,
#   266,
#   11,
#   2528,
#   380,
#   101,
#   127,
#   280,
#   1465,
#   9,
#   834,
#   4264,
#   363,
#   4,
#   380,
#   35,
#   14,
#   10,
#   1120,
#   215,
#   266,
#   363,
#   11,
#   1073,
#   1575,
#   34,
#   1906,
#   819,
#   337,
#   39,
#   43,
#   317,
#   78,
#   445,
#   29,
#   1056,
#   20,
#   1421,
#   13511,
#   107,
#   19,
#   5,
#   3,
#   2],
#  [3,
#   1893,
#   5207,
#   142,
#   14,
#   18427,
#   37024,
#   1073,
#   2537,
#   33,
#   29,
#   8878,
#   1854,
#   114,
#   3,
#   2,
#   3,
#   15904,
#   8468,
#   39560,
#   36099,
#   17668,
#   3,
#   2],
#  [3,
#   6364,
#   15111,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   1624,
#   1340,
#   11095,
#   1517,
#   1016,
#   570,
#   64,
#   22986,
#   23651,
#   61,
#   85,
#   7311,
#   28,
#   3448,
#   139,
#   147,
#   1007,
#   24210,
#   1395,
#   4,
#   1219,
#   20405,
#   1301,
#   4,
#   2901,
#   3019,
#   6,
#   9,
#   1362,
#   1889,
#   3,
#   2],
#  [3,
#   45996,
#   1384,
#   4,
#   9,
#   41342,
#   362,
#   28,
#   618,
#   42017,
#   1301,
#   4,
#   6,
#   6169,
#   192,
#   569,
#   1362,
#   38269,
#   5298,
#   13,
#   18,
#   85,
#   8,
#   21,
#   302,
#   230,
#   7,
#   21,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   385,
#   95,
#   2104,
#   3,
#   2],
#  [3,
#   18,
#   142,
#   8,
#   2185,
#   286,
#   26865,
#   380,
#   136,
#   7,
#   1832,
#   5631,
#   3,
#   2,
#   3,
#   168,
#   8,
#   268,
#   8302,
#   6488,
#   406,
#   8513,
#   2546,
#   98,
#   1832,
#   5631,
#   98,
#   1832,
#   5631,
#   4,
#   34128,
#   1430,
#   34128,
#   718,
#   2965,
#   1738,
#   4,
#   10969,
#   9970,
#   4,
#   1479,
#   9642,
#   4,
#   7056,
#   9642,
#   6,
#   4154,
#   80,
#   7,
#   3019,
#   1093,
#   5,
#   3,
#   2],
#  [3,
#   8271,
#   2477,
#   9,
#   1362,
#   3011,
#   8415,
#   3040,
#   6571,
#   1664,
#   96,
#   24,
#   1820,
#   181,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   455,
#   376,
#   10417,
#   44004,
#   1701,
#   22,
#   3,
#   2],
#  [3,
#   7751,
#   1430,
#   1816,
#   39572,
#   4916,
#   32739,
#   4826,
#   2753,
#   1302,
#   17355,
#   418,
#   29,
#   1464,
#   26567,
#   3,
#   2,
#   3,
#   39572,
#   4916,
#   32739,
#   19062,
#   3636,
#   23299,
#   4826,
#   2753,
#   1302,
#   17355,
#   14157,
#   65,
#   418,
#   43,
#   1443,
#   78,
#   3160,
#   29,
#   8878,
#   2326,
#   19,
#   8,
#   229,
#   34946,
#   1301,
#   4,
#   18,
#   585,
#   1709,
#   2507,
#   1166,
#   35235,
#   21473,
#   619,
#   8,
#   229,
#   1430,
#   1964,
#   493,
#   7,
#   21150,
#   107,
#   14157,
#   1709,
#   8595,
#   15831,
#   619,
#   11,
#   55,
#   30,
#   89,
#   36,
#   215,
#   266,
#   19868,
#   27,
#   11630,
#   163,
#   732,
#   1714,
#   7,
#   778,
#   14157,
#   7806,
#   2686,
#   37272,
#   4,
#   619,
#   171,
#   49,
#   463,
#   413,
#   14157,
#   7806,
#   2326,
#   37272,
#   4,
#   1383,
#   8201,
#   939,
#   413,
#   14157,
#   7806,
#   2147,
#   37272,
#   4,
#   5927,
#   9513,
#   89,
#   289,
#   14157,
#   7806,
#   1765,
#   37272,
#   4,
#   251,
#   18,
#   1824,
#   46,
#   413,
#   14157,
#   7806,
#   39459,
#   6,
#   13698,
#   5855,
#   7,
#   1142,
#   6536,
#   11018,
#   14157,
#   7806,
#   51627,
#   3,
#   2],
#  [3,
#   2120,
#   148,
#   262,
#   142,
#   9,
#   80,
#   9534,
#   4436,
#   2608,
#   788,
#   675,
#   18,
#   3305,
#   1850,
#   114,
#   3,
#   2,
#   3,
#   1603,
#   6028,
#   3,
#   2],
#  [3,
#   1579,
#   1487,
#   2952,
#   21,
#   148,
#   2153,
#   7102,
#   7,
#   58,
#   11314,
#   8,
#   110,
#   34550,
#   8536,
#   3593,
#   36841,
#   1231,
#   16,
#   1389,
#   25349,
#   1387,
#   114,
#   3,
#   2,
#   3,
#   16989,
#   770,
#   3787,
#   1487,
#   6107,
#   7,
#   16,
#   110,
#   34550,
#   8536,
#   25329,
#   11644,
#   450,
#   930,
#   5603,
#   7,
#   10694,
#   18987,
#   3,
#   2],
#  [3,
#   2515,
#   378,
#   2765,
#   2404,
#   78,
#   4889,
#   82,
#   7,
#   22437,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   978,
#   3,
#   2],
#  [3,
#   5470,
#   1696,
#   11,
#   1251,
#   2289,
#   29,
#   142,
#   3,
#   2,
#   3,
#   347,
#   37,
#   4,
#   5470,
#   1696,
#   1251,
#   121,
#   3362,
#   20070,
#   4,
#   11575,
#   961,
#   1529,
#   16720,
#   4,
#   1568,
#   1251,
#   33,
#   790,
#   4267,
#   9755,
#   6483,
#   20,
#   3012,
#   15584,
#   3012,
#   6268,
#   19,
#   5,
#   635,
#   1568,
#   1696,
#   50,
#   3230,
#   300,
#   36,
#   380,
#   1889,
#   862,
#   121,
#   4993,
#   42,
#   2838,
#   2263,
#   4,
#   1347,
#   20420,
#   4,
#   3844,
#   4,
#   28493,
#   4623,
#   380,
#   61,
#   3936,
#   2097,
#   6,
#   14119,
#   4148,
#   7,
#   18,
#   9235,
#   1696,
#   1710,
#   8123,
#   908,
#   2389,
#   1357,
#   5,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   302,
#   675,
#   6933,
#   7811,
#   4942,
#   1493,
#   114,
#   3,
#   2,
#   3,
#   73,
#   443,
#   46,
#   8919,
#   5779,
#   3,
#   2],
#  [3,
#   3880,
#   5076,
#   764,
#   83,
#   13397,
#   561,
#   11,
#   248,
#   1740,
#   148,
#   3,
#   2,
#   3,
#   3880,
#   561,
#   248,
#   22,
#   8763,
#   3330,
#   11196,
#   22,
#   35,
#   3490,
#   33101,
#   266,
#   350,
#   590,
#   101,
#   129,
#   613,
#   6,
#   22,
#   1982,
#   1740,
#   103,
#   7,
#   718,
#   13466,
#   17860,
#   22,
#   35,
#   5,
#   3,
#   2],
#  [3,
#   1203,
#   21,
#   148,
#   316,
#   5191,
#   14,
#   2958,
#   1340,
#   11095,
#   1517,
#   3033,
#   14896,
#   548,
#   1698,
#   22095,
#   1701,
#   114,
#   3,
#   2,
#   3,
#   3080,
#   2615,
#   3,
#   2],
#  [3,
#   221,
#   7,
#   316,
#   5191,
#   145,
#   12,
#   6117,
#   13724,
#   1749,
#   8251,
#   189,
#   320,
#   558,
#   286,
#   16,
#   12,
#   21,
#   215,
#   1302,
#   10210,
#   834,
#   103,
#   67,
#   570,
#   681,
#   7,
#   389,
#   2482,
#   8,
#   1529,
#   10143,
#   114,
#   3,
#   2,
#   3,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   23355,
#   20818,
#   40995,
#   40214,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   6744,
#   2326,
#   37272,
#   4,
#   3,
#   2],
#  [3,
#   21,
#   148,
#   3010,
#   1073,
#   2106,
#   1073,
#   1575,
#   9699,
#   30036,
#   173,
#   5887,
#   39349,
#   2008,
#   114,
#   3,
#   2,
#   3,
#   1977,
#   15824,
#   7888,
#   19474,
#   3,
#   2],
#  [3,
#   1004,
#   5955,
#   5024,
#   1791,
#   4,
#   13980,
#   50,
#   10,
#   2183,
#   4568,
#   142,
#   3,
#   2,
#   3,
#   168,
#   418,
#   40,
#   6,
#   103,
#   72,
#   25,
#   5955,
#   5024,
#   1791,
#   4,
#   55842,
#   4104,
#   12584,
#   3,
#   2],
#  [3,
#   11654,
#   5294,
#   58,
#   2369,
#   103,
#   129,
#   849,
#   34,
#   570,
#   681,
#   3,
#   2,
#   3,
#   251,
#   11,
#   774,
#   8,
#   6103,
#   4439,
#   54,
#   2935,
#   8311,
#   187,
#   166,
#   239,
#   129,
#   76,
#   570,
#   681,
#   28,
#   1283,
#   5294,
#   4,
#   33,
#   137,
#   5334,
#   9593,
#   7972,
#   4,
#   6,
#   66,
#   103,
#   48,
#   2369,
#   5,
#   6380,
#   28,
#   452,
#   100,
#   54,
#   231,
#   8,
#   6103,
#   4439,
#   1666,
#   129,
#   163,
#   53,
#   2935,
#   5946,
#   4,
#   2935,
#   93,
#   6,
#   2935,
#   4957,
#   5,
#   3,
#   2],
#  [3,
#   14,
#   59119,
#   1301,
#   3206,
#   5761,
#   21,
#   148,
#   26,
#   47,
#   49,
#   34,
#   7594,
#   2792,
#   525,
#   17437,
#   114,
#   3,
#   2,
#   3,
#   3258,
#   645,
#   7,
#   16,
#   212,
#   588,
#   76,
#   10,
#   1041,
#   525,
#   3634,
#   56284,
#   4,
#   3,
#   2],
#  [3,
#   1650,
#   142,
#   20999,
#   1395,
#   4,
#   145,
#   362,
#   27366,
#   4,
#   8,
#   16,
#   12,
#   82,
#   226,
#   1084,
#   3705,
#   3931,
#   700,
#   733,
#   67,
#   12,
#   301,
#   15673,
#   114,
#   3,
#   2,
#   3,
#   31897,
#   12868,
#   4,
#   3,
#   2],
#  [3,
#   251,
#   11,
#   4396,
#   40468,
#   9553,
#   6020,
#   111,
#   2610,
#   114,
#   3,
#   2,
#   3,
#   43,
#   431,
#   78,
#   445,
#   29,
#   2456,
#   3,
#   2],
#  [3,
#   2679,
#   14,
#   47,
#   21,
#   526,
#   1087,
#   906,
#   1361,
#   6361,
#   3198,
#   2302,
#   32906,
#   1384,
#   114,
#   3,
#   2,
#   3,
#   69,
#   1612,
#   55613,
#   1517,
#   3,
#   2],
#  [3,
#   251,
#   14,
#   11,
#   1832,
#   45970,
#   23277,
#   1187,
#   114,
#   3,
#   2,
#   3,
#   78,
#   210,
#   29,
#   7671,
#   3,
#   2],
#  [3,
#   319,
#   40565,
#   3269,
#   1527,
#   4379,
#   2416,
#   29,
#   11,
#   1391,
#   1766,
#   25,
#   602,
#   3,
#   2,
#   3,
#   10137,
#   45110,
#   4,
#   440,
#   3269,
#   1766,
#   40565,
#   3269,
#   1527,
#   4379,
#   31,
#   2220,
#   1093,
#   5577,
#   1527,
#   29,
#   484,
#   1391,
#   1766,
#   12155,
#   33048,
#   1713,
#   1934,
#   15250,
#   2008,
#   4,
#   380,
#   1889,
#   91,
#   80,
#   9310,
#   94,
#   58,
#   1820,
#   1447,
#   5577,
#   39038,
#   10838,
#   3,
#   2],
#  [3,
#   1391,
#   1766,
#   148,
#   17,
#   240,
#   108,
#   121,
#   3011,
#   13,
#   108,
#   10842,
#   50656,
#   14,
#   43451,
#   18075,
#   2150,
#   1009,
#   1007,
#   24210,
#   1395,
#   114,
#   3,
#   2,
#   3,
#   3269,
#   1766,
#   8517,
#   9967,
#   3019,
#   7564,
#   3,
#   2],
#  [3,
#   404,
#   189,
#   142,
#   1145,
#   1189,
#   2515,
#   23523,
#   4453,
#   430,
#   39,
#   9755,
#   20331,
#   114,
#   3,
#   2,
#   3,
#   1597,
#   2654,
#   3,
#   2],
#  [3,
#   2679,
#   320,
#   3309,
#   2475,
#   351,
#   13,
#   61,
#   498,
#   8329,
#   7,
#   6222,
#   1252,
#   6,
#   61,
#   380,
#   1283,
#   7,
#   9013,
#   6519,
#   12,
#   790,
#   3258,
#   139,
#   289,
#   17186,
#   1487,
#   114,
#   3,
#   2,
#   3,
#   28833,
#   3,
#   2],
#  [3,
#   2653,
#   139,
#   37,
#   221,
#   8,
#   179,
#   58,
#   11,
#   328,
#   8,
#   223,
#   6134,
#   351,
#   9,
#   58,
#   96,
#   355,
#   27366,
#   114,
#   3,
#   2,
#   3,
#   37772,
#   4694,
#   917,
#   9170,
#   11,
#   5717,
#   8410,
#   121,
#   355,
#   157,
#   223,
#   9,
#   159,
#   2149,
#   7,
#   36,
#   3705,
#   25837,
#   4,
#   667,
#   2559,
#   42,
#   18565,
#   1395,
#   4,
#   2134,
#   6,
#   4379,
#   3705,
#   157,
#   3,
#   2],
#  [3,
#   2679,
#   682,
#   302,
#   698,
#   1981,
#   2308,
#   15571,
#   33,
#   29,
#   14845,
#   2147,
#   114,
#   3,
#   2,
#   3,
#   43078,
#   12110,
#   4380,
#   50535,
#   28406,
#   3,
#   2],
#  [3,
#   6933,
#   1206,
#   1709,
#   72,
#   642,
#   26,
#   1464,
#   26567,
#   126,
#   3,
#   2,
#   3,
#   434,
#   1556,
#   3020,
#   982,
#   8479,
#   4,
#   11414,
#   20623,
#   1387,
#   13170,
#   1187,
#   4,
#   46,
#   25,
#   642,
#   210,
#   46105,
#   4,
#   17,
#   297,
#   1464,
#   26567,
#   57246,
#   27375,
#   1322,
#   8,
#   11414,
#   3344,
#   12350,
#   72,
#   46226,
#   27375,
#   3,
#   2],
#  ...]

# %%
## thử sau
MAX_LEN = 145

train_ids = pad_sequences(train_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")
val_ids = pad_sequences(val_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
train_masks = []
for sent in train_ids:
    mask = [int(token_id > 0) for token_id in sent]
    train_masks.append(mask)

val_masks = []
for sent in val_ids:
    mask = [int(token_id > 0) for token_id in sent]

    val_masks.append(mask)

# %% [markdown]
# # **Model**
# Transformers của Hugging Face

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import torch
train_inputs = torch.tensor(train_ids)
val_inputs = torch.tensor(val_ids)
train_labels = torch.tensor(train_labels)
val_labels = torch.tensor(val_labels)
train_masks = torch.tensor(train_masks)
val_masks = torch.tensor(val_masks)

train_data = TensorDataset(train_inputs, train_masks, train_labels)
#train_data = TensorDataset(train_inputs, train_labels)
train_sampler = SequentialSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=32)

val_data = TensorDataset(val_inputs, val_masks, val_labels)
#val_data = TensorDataset(val_inputs, val_labels)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=32)

# %%
from transformers import RobertaForSequenceClassification, RobertaConfig, AdamW

config = RobertaConfig.from_pretrained(
    "/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/config.json", from_tf=False, num_labels = 2, output_hidden_states=False,
)
BERT_SA = RobertaForSequenceClassification.from_pretrained(
    "/content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin",
    config=config
)
# Out:
# Some weights of the model checkpoint at /content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at /content/drive/My Drive/Zalo Challenge/2019/PhoBERT_base_transformers/model.bin and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
BERT_SA.cuda()
print('Done')
# Out:
# Done

# %%
import numpy as np
from sklearn.metrics import f1_score, accuracy_score

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    
    F1_score = f1_score(pred_flat, labels_flat, average='macro')
    
    return accuracy_score(pred_flat, labels_flat), F1_score

# %%
import random
from tqdm import tqdm_notebook
device = 'cuda'
epochs = 10

param_optimizer = list(BERT_SA.named_parameters())
no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]

optimizer = AdamW(optimizer_grouped_parameters, lr=1e-5, correct_bias=False)


for epoch_i in range(0, epochs):
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    total_loss = 0
    BERT_SA.train()
    train_accuracy = 0
    nb_train_steps = 0
    train_f1 = 0
    
    for step, batch in tqdm_notebook(enumerate(train_dataloader)):
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        BERT_SA.zero_grad()
        outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask, 
            labels=b_labels)
        loss = outputs[0]
        total_loss += loss.item()
        
        logits = outputs[1].detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        tmp_train_accuracy, tmp_train_f1 = flat_accuracy(logits, label_ids)
        train_accuracy += tmp_train_accuracy
        train_f1 += tmp_train_f1
        nb_train_steps += 1
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(BERT_SA.parameters(), 1.0)
        optimizer.step()
        
    avg_train_loss = total_loss / len(train_dataloader)
    print(" Accuracy: {0:.4f}".format(train_accuracy/nb_train_steps))
    print(" F1 score: {0:.4f}".format(train_f1/nb_train_steps))
    print(" Average training loss: {0:.4f}".format(avg_train_loss))

    print("Running Validation...")
    BERT_SA.eval()
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    eval_f1 = 0
    for batch in tqdm_notebook(val_dataloader):

        batch = tuple(t.to(device) for t in batch)

        b_input_ids, b_input_mask, b_labels = batch

        with torch.no_grad():
            outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask)
            logits = outputs[0]
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            tmp_eval_accuracy, tmp_eval_f1 = flat_accuracy(logits, label_ids)

            eval_accuracy += tmp_eval_accuracy
            eval_f1 += tmp_eval_f1
            nb_eval_steps += 1
    print(" Accuracy: {0:.4f}".format(eval_accuracy/nb_eval_steps))
    print(" F1 score: {0:.4f}".format(eval_f1/nb_eval_steps))
print("Training complete!")
# Out:
# ======== Epoch 1 / 10 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9573
#  F1 score: 0.7484
#  Average training loss: 0.0950
# Running Validation...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9651
#  F1 score: 0.8193
# ======== Epoch 2 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9755
#  F1 score: 0.8669
#  Average training loss: 0.0646
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9645
#  F1 score: 0.8308
# ======== Epoch 3 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9837
#  F1 score: 0.9134
#  Average training loss: 0.0483
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9640
#  F1 score: 0.8390
# ======== Epoch 4 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9890
#  F1 score: 0.9435
#  Average training loss: 0.0371
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9672
#  F1 score: 0.8338
# ======== Epoch 5 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9922
#  F1 score: 0.9595
#  Average training loss: 0.0281
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9669
#  F1 score: 0.8423
# ======== Epoch 6 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9941
#  F1 score: 0.9693
#  Average training loss: 0.0224
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9689
#  F1 score: 0.8413
# ======== Epoch 7 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9952
#  F1 score: 0.9761
#  Average training loss: 0.0187
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9686
#  F1 score: 0.8436
# ======== Epoch 8 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9964
#  F1 score: 0.9803
#  Average training loss: 0.0148
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9659
#  F1 score: 0.8358
# ======== Epoch 9 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9964
#  F1 score: 0.9818
#  Average training loss: 0.0144
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9694
#  F1 score: 0.8479
# ======== Epoch 10 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9973
#  F1 score: 0.9852
#  Average training loss: 0.0119
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=307.0), HTML(value='')))
#  Accuracy: 0.9624
#  F1 score: 0.8346
# Training complete!

# %%
BERT_SA.
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-40-3fe486655b38> in <module>()
# ----> 1 BERT_SA.save("QA.h5",save_format='tf')
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'RobertaForSequenceClassification' object has no attribute 'save'

# %% [markdown]
# # **Pred lables (Test file)**

# %%
import json
test_path = '/content/drive/My Drive/Zalo Challenge/2019/test.json'
test_text = []

with open(test_path) as test_file:
    test_data = json.load(test_file)
    # Process data
    for case in test_data:
        for paragraph in case['paragraphs']:
          question = rdrsegmenter.tokenize(case['question'])
          question = ' '.join([' '.join(x) for x in question])

          answer = rdrsegmenter.tokenize(paragraph['text'])
          answer = ' '.join([' '.join(x) for x in answer])
          test_text.append([question, answer ])

# %%
test_text
# Out:
# [['Toà nhà nào cao nhất Việt_Nam',
#   'The_Landmark 81 là một toà nhà_chọc_trời trong tổ_hợp dự_án Vinhomes_Tân_Cảng , một dự_án có tổng mức đầu_tư 40.000 tỷ đồng , do Công_ty Cổ_phần Đầu_tư xây_dựng Tân_Liên_Phát thuộc Vingroup làm chủ đầu_tư . Toà tháp cao 81 tầng , hiện_tại là toà nhà cao nhất Việt_Nam và là toà nhà cao nhất Đông_Nam_Á từ tháng 3 năm 2018 .'],
#  ['Toà nhà nào cao nhất Việt_Nam',
#   'Toà tháp cao 81 tầng , hiện_tại là toà nhà cao nhất Việt_Nam và là toà nhà cao nhất Đông_Nam_Á từ tháng 3 năm 2018 . Dự_án được xây_dựng ở Tân_Cảng , quận Bình_Thạnh , ven sông Sài_Gòn . Dự_án được khởi_công ngày 26/07/2014 .'],
#  ['Messi thuận chân nào',
#   'Đôi chân ngắn nhưng mạnh_mẽ giúp Messi dễ_dàng tăng_tốc và sải chân nhanh giúp anh kiểm_soát bóng tốt khi rê dắt ở tốc_độ cao . Cựu huấn_luyện_viên Barcelona , Pep_Guardiola , từng nhận_xét rằng : " Messi là cầu_thủ duy_nhất chạy với bóng còn nhanh hơn là chạy không bóng . " Giống_Maradona , Messi là một cầu_thủ thuận chân trái .'],
#  ['Messi thuận chân nào',
#   'Cựu huấn_luyện_viên Barcelona , Pep_Guardiola , từng nhận_xét rằng : " Messi là cầu_thủ duy_nhất chạy với bóng còn nhanh hơn là chạy không bóng . " Giống_Maradona , Messi là một cầu_thủ thuận chân trái . Anh thường sử_dụng má ngoài chân trái khi giữ bóng , trong khi dùng má trong để dứt_điểm , chuyền bóng và kiến_tạo cho đồng_đội .'],
#  ['Messi thuận chân nào',
#   'Ngoài_ra anh còn một chân sút phạt chính và hay đảm_nhận các quả phạt_đền của đội . Khi đề_cập đến kĩ_năng dắt bóng của anh , Maradona đã từng nói : " Trái bóng dính chặt vào chân anh ấy ; Trong sự_nghiệp của mình tôi đã xem nhiều cầu_thủ xuất_chúng chơi bóng nhưng không ai giữ bóng tốt như Messi . " Maradona còn cho biết rằng ông tin Messi là cầu_thủ xuất_sắc nhất thế_giới hiện_tại .'],
#  ['Messi thuận chân nào',
#   'Khi đề_cập đến kĩ_năng dắt bóng của anh , Maradona đã từng nói : " Trái bóng dính chặt vào chân anh ấy ; Trong sự_nghiệp của mình tôi đã xem nhiều cầu_thủ xuất_chúng chơi bóng nhưng không ai giữ bóng tốt như Messi . " Maradona còn cho biết rằng ông tin Messi là cầu_thủ xuất_sắc nhất thế_giới hiện_tại .'],
#  ['Messi thuận chân nào',
#   'Ngày 11 tháng 3 năm 2010 , Messi được chọn làm đại_sứ thiện_chí của UNICEF . Hoạt_động đại_sứ UNICEF của Messi nhằm hỗ_trợ các quyền trẻ_em . Messi cũng nhận được sự ủng_hộ từ FC Barcelona , câu_lạc_bộ có mối liên_hệ chặt_chẽ với UNICEF .'],
#  ['Sao_Hoả còn được gọi là gì',
#   'Sao_Hoả còn gọi là : Hoả_Tinh , ( Tiếng Anh : Mars ) là hành_tinh thứ tư tính từ Mặt_Trời trong Thái_Dương Hệ . Đôi_khi hành_tinh này còn được gọi tên là Hoả_Tinh . Nó thường được gọi với tên khác là " Hành_tinh Đỏ " , do sắt ôxít có_mặt rất nhiều trên bề_mặt hành_tinh làm cho bề_mặt nó hiện lên với màu đỏ đặc_trưng .'],
#  ['Sao_Hoả còn được gọi là gì',
#   'Những bản_đồ về Sao_Hoả hiện_nay đã được cung_cấp trên một_số dịch_vụ trực_tuyến , như Google Mars .'],
#  ['Sao_Hoả còn được gọi là gì',
#   'Sao_Hoả trong ngôn_ngữ phương Tây được mang tên của vị thần chiến_tranh trong thần_thoại . Từ_hoả cũng là tên của một trong năm yếu_tố của ngũ_hành trong triết_học cổ Trung_Hoa . Biểu_tượng Sao_Hoả , gồm một vòng_tròn với một mũi_tên chỉ ra ngoài , cũng là biểu_tượng cho giống đực .'],
#  ['Hồ Hoàn_Kiếm nằm ở đâu',
#   'Hồ Hoàn_Kiếm ( chữ_Nôm : 湖還劍 hoặc 還劍湖 ) còn được gọi là Hồ Gươm ( trong , hồ này được gọi là Hồ Hoàn_Gươm - " Lac de Hoan_Guom " ) , là một hồ nước_ngọt tự_nhiên nằm ở trung_tâm thành_phố Hà_Nội . Hồ có diện_tích khoảng 12 ha . Trước_kia , hồ còn có các tên gọi là hồ Lục_Thuỷ ( vì nước có màu xanh quanh_năm ) , hồ Thuỷ_Quân ( dùng để duyệt thuỷ_binh ) , hồ_Tả_Vọng và Hữu_Vọng ( trong thời Lê_mạt ) .'],
#  ['Hồ Hoàn_Kiếm nằm ở đâu',
#   'Nhà_vua liền trả gươm cho rùa thần và rùa lặn xuống_nước biến mất . Từ đó hồ được lấy tên là hồ Hoàn_Kiếm . Tên hồ còn được lấy để đặt cho một quận trung_tâm của Hà_Nội ( quận Hoàn_Kiếm ) và là hồ nước duy_nhất của quận này cho đến ngày_nay .'],
#  ['Hồ Hoàn_Kiếm nằm ở đâu',
#   'Tiếp đó đổ ra nhánh chính của sông Hồng . Nơi rộng nhất phân lưu này hình_thành nên hồ Hoàn_Kiếm hiện_nay .'],
#  ['Hồ Hoàn_Kiếm nằm ở đâu',
#   'Chúa_Trịnh cho ngăn hồ lớn thành hồ_Tả_Vọng và Hữu_Vọng . Hồ_Hữu_Vọng được dùng làm nơi duyệt quân thuỷ_chiến của triều_đình . Đến đời Tự Đức ( 1847-1883 ) , hồ_Hữu_Vọng được gọi là hồ Thuỷ_Quân , còn hồ_Tả_Vọng chính là hồ Hoàn_Kiếm .'],
#  ['Hồ Hoàn_Kiếm nằm ở đâu',
#   '" Từ đó , hồ_Tả_Vọng bắt_đầu mang tên là Hồ Gươm hay hồ Hoàn_Kiếm "'],
#  ['Lionel_Messi sinh ra ở đâu',
#   'Lionel_Andrés " Leo " Messi_Cuccittini ( ; sinh ngày 24 tháng 6 năm 1987 ) , thường biết tới với tên gọi Lionel_Messi , là một cầu_thủ bóng_đá người Argentina hiện đang chơi ở vị_trí tiền_đạo cho câu_lạc_bộ Barcelona và đội_tuyển bóng_đá quốc_gia Argentina .'],
#  ['Lionel_Messi sinh ra ở đâu',
#   'Messi sinh ngày 24 tháng 6 năm 1987 ở Rosario , Argentina với bố là ông Jorge_Horacio_Messi ( sinh năm 1958 ) , một công_nhân nhà_máy , mẹ là bà Celia_Maria_Cuccittini , một người lao_công . Gia_đình bên nội của anh có nguồn_gốc từ thành_phố Ancona ở Ý rồi chuyển sang Argentina vào năm 1883 .'],
#  ['Lionel_Messi sinh ra ở đâu',
#   'Ở lượt trận đầu_tiên của vòng bảng , Lionel_Messi đã bỏ lỡ một pha ghi_bàn khi thực_hiện quả phạt_đền thất_bại trong trận hoà 1-1 trước đội_tuyển Iceland . Ở trận thứ hai , Argentina lại thua bạc_nhược 0-3 trước Croatia , trước ngày sinh_nhật của anh đúng 2 ngày , khi mà Messi chỉ chạm bóng đúng 49 lần cả trận .'],
#  ['Lionel_Messi sinh ra ở đâu',
#   'Leo_Messi quen cô bạn gái Antonella_Roccuzzo lúc anh mới 5 tuổi , trước khi công_khai chuyện hẹn_hò từ năm 2009 . Hai người đã có với nhau hai cậu con trai : Thiago ( sinh năm 2012 ) và Mateo ( 2015 ) .'],
#  ['Lionel_Messi sinh ra ở đâu',
#   'Hai người đã có với nhau hai cậu con trai : Thiago ( sinh năm 2012 ) và Mateo ( 2015 ) .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'Luật bàn_thắng_vàng đã được sử_dụng ở cấp_độ thế_giới trong World_Cup 1998 và World_Cup 2002 với Pháp là đội_tuyển đầu_tiên tận_dụng được lợi_thế này khi giành chiến_thắng trước Paraguay bằng bàn_thắng_vàng của Laurent_Blanc ( năm 1998 ) , Pháp cũng là đội vô_địch ở giải đấu năm 1998 .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'Giải đấu cấp quốc_tế lớn nhất của bóng_đá thế_giới là World_Cup . World_Cup được FIFA tổ_chức lần đầu năm 1930 và đến nay đã trở_thành giải thi_đấu thể_thao được nhiều người theo_dõi nhất hành_tinh , vượt qua cả Thế_vận_hội , ví_dụ vòng chung_kết World_Cup 2006 tổ_chức tại Đức đã thu_hút 26,29 tỷ lượt khán_giả xem truyền_hình trong đó riêng trận chung_kết đã thu_hút 715,1 triệu khá_giả trên khắp thế_giới .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'World_Cup được tổ_chức theo thể_thức 4 năm một lần với vòng đấu_loại có sự tham_gia của trên 190 quốc_gia thành_viên FIFA và vòng chung_kết có sự góp_mặt của 32 đội_tuyển ( trước năm 1982 là 16 đội , trước năm 1998 là 24 đội ) , vòng chung_kết của World_Cup 2014 được tổ_chức tại Brasil .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'Các nhà vô_địch của các giải đấu cấp châu_lục cùng với đương_kim vô_địch World_Cup sẽ gặp nhau tại Cúp_Liên đoàn các châu_lục , đây là giải đấu khởi_động cho World_Cup và được FIFA tổ_chức trước World_Cup 1 năm .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'Ở cấp_độ quốc_tế , World_Cup 1954 là giải đấu lớn đầu_tiên được truyền_hình . Ngay từ giai_đoạn đầu_mối quan_hệ giữa truyền_hình và bóng_đá đã có nhiều xung_đột . Matt_Busby , huấn_luyện_viên của Manchester_United đã tuyên_bố vào năm 1957 : " Các cầu_thủ bóng_đá phải được trả tiền cho giá_trị của họ .'],
#  ['World_Cup được tổ_chức lần đầu năm mấy',
#   'Một ví_dụ khác là việc tổ_chức World_Cup 2006 chỉ trong vòng 1 tháng đã giúp lượng khách du_lịch đến Đức trong cả năm 2006 tăng thêm 9% .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Ôxy được Carl_Wilhelm_Scheele phát_hiện ở Uppsala năm 1773 hoặc sớm hơn và Joseph_Priestley ở Wiltshire năm 1774 độc_lập nhau , nhưng Priestley thường được cho là phát_hiện ra trước bởi vi ấn_phẩm của ông được xuất_bản trước . Tên gọi " ôxy " ( oxygen ) được Antoine_Lavoisier đặt năm 1777 , các thí_nghiệm của ông với ôxy đã giúp loại_trừ thuyết phlogiston về sự cháy và ăn_mòn phổ_biến vào thời đó .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Tên gọi " ôxy " ( oxygen ) được Antoine_Lavoisier đặt năm 1777 , các thí_nghiệm của ông với ôxy đã giúp loại_trừ thuyết phlogiston về sự cháy và ăn_mòn phổ_biến vào thời đó . Ôxy được sản_xuất trong công_nghiệp bằng cách chưng_cất phân_đoạn không_khí lỏng , sử_dụng zeolit để loại_bỏ carbon dioxit và nitơ ra khỏi không_khí , điện phân nước và các cách khác .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Ôxy được sản_xuất trong công_nghiệp bằng cách chưng_cất phân_đoạn không_khí lỏng , sử_dụng zeolit để loại_bỏ carbon dioxit và nitơ ra khỏi không_khí , điện phân nước và các cách khác . Trong phòng_thí_nghiệm , người ta điều_chế oxy bằng cách_nhiệt phân một_số chất giàu oxy như KMn , KCl .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Trong phòng_thí_nghiệm , người ta điều_chế oxy bằng cách_nhiệt phân một_số chất giàu oxy như KMn , KCl . Ôxy được sử_dụng trong sản_xuất công_nghiệp ( thép , nhựa và dệt ) ; đốt nhiên_liệu ( nhiên_liệu tên_lửa ) ; và hô_hấp ( hỗ_trợ sự sống của con_người trên tàu không_gian , hay khi lặn dưới biển ) .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Oxy hoà_tan trong nước nhiều hơn so với nitơ ; nước chứa khoảng một phân_tử cho mỗi 2 phân_tử , so với tỉ_số trong không_khí là 1:4 . Độ hoà_tan của ôxy trong nước phụ_thuộc vào nhiệt_độ , và ở 0 \xa0°C thì lượng hoà_tan tăng gấp đôi ( 14,6 \xa0mg · L ) so với ở 20 \xa0°C ( 7,6 \xa0mg · L ) .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Ôxy được phát_hiện bởi dược_sĩ người Thuỵ_Điển Carl_Wilhelm_Scheele năm 1772 bằng cách đun nóng oxit đồng và một hỗn_hợp vài muối nitrat . Scheele gọi oxy là " khí cháy " vì nó là khí hỗ_trợ sự cháy duy_nhất được phát_hiện lúc đó .'],
#  ['Tên gọi Oxy do ai đặt',
#   'Scheele gọi oxy là " khí cháy " vì nó là khí hỗ_trợ sự cháy duy_nhất được phát_hiện lúc đó . Ông đã viết một báo_cáo về phát_hiện này trong một bản_thảo của mình với tựa đề " Treatise trên Air và Fire " , sau đó gửi cho nhà_xuất_bản trong năm 1775 .'],
#  ['Tên thành_phố Hồ_Chí_Minh xuất_hiện năm nào',
#   'Ngày 2 tháng 7 năm 1976 , Quốc_hội nước Việt_Nam thống_nhất quyết_định đổi tên Sài_Gòn thành Thành_phố Hồ_Chí_Minh , theo tên vị Chủ_tịch nước đầu_tiên của Việt_Nam Dân_chủ Cộng_hoà .'],
#  ['Tên thành_phố Hồ_Chí_Minh xuất_hiện năm nào',
#   'Đầu năm 1976 , Đảng_bộ và Uỷ_ban_Nhân_dân thành_phố bắt_đầu hoạt_động . Ngày 2 tháng 7 năm 1976 , Quốc_hội đầu_tiên của nước Việt_Nam thống_nhất quyết_định đổi tên nước thành Cộng_hoà_Xã_hội_Chủ_nghĩa_Việt_Nam , đồng_thời đổi tên thành_phố Sài_Gòn – Gia_Định thành Thành_phố Hồ_Chí_Minh , theo tên của nhà_lãnh_đạo cách_mạng và Chủ_tịch nước đầu_tiên , Hồ_Chí_Minh .'],
#  ['Tên thành_phố Hồ_Chí_Minh xuất_hiện năm nào',
#   'Thành_phố Hồ_Chí_Minh ngày_nay bao_gồm toàn_bộ đô_thành Sài_Gòn cũ , cộng thêm toàn_bộ tỉnh Gia_Định , quận Phú_Hoà của tỉnh Bình_Dương và quận Củ_Chi của tỉnh Hậu_Nghĩa cũ .'],
#  ['Tên thành_phố Hồ_Chí_Minh xuất_hiện năm nào',
#   'Về phía Đảng_uỷ , Ban_Chấp_hành Đảng_bộ Thành_phố Hồ_Chí_Minh ( hay thường gọi là Thành_uỷ Thành_phố Hồ_Chí_Minh ) \xa0là cơ_quan lãnh_đạo cao nhất của Đảng_bộ Thành_phố . Thành_uỷ Thành_phố Hồ_Chí_Minh khoá X nhiệm_kỳ 2015 – 2020 gồm 69 uỷ_viên chính_thức , bầu ra Ban Thường_vụ gồm 15 uỷ_viên .'],
#  ['Tên thành_phố Hồ_Chí_Minh xuất_hiện năm nào',
#   'Ngoài báo_chí tiếng Việt , Thành_phố Hồ_Chí_Minh còn có " Saigon_Times daily " , " Thanhniennews " bằng tiếng Anh , một ấn_bản " Sài_Gòn giải_phóng " bằng tiếng Hoa .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Ở điều_kiện nhiệt_độ và áp_suất tiêu_chuẩn hai nguyên_tử ôxy kết_hợp với nhau tạo thành phân_tử ôxy không màu , không mùi , không vị có công_thức . Ôxy phân_tử ( O , thường được gọi là ôxy tự_do ) trên Trái_Đất là không ổn_định về mặt nhiệt động_lực_học .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Ôxy được Carl_Wilhelm_Scheele phát_hiện ở Uppsala năm 1773 hoặc sớm hơn và Joseph_Priestley ở Wiltshire năm 1774 độc_lập nhau , nhưng Priestley thường được cho là phát_hiện ra trước bởi vi ấn_phẩm của ông được xuất_bản trước . Tên gọi " ôxy " ( oxygen ) được Antoine_Lavoisier đặt năm 1777 , các thí_nghiệm của ông với ôxy đã giúp loại_trừ thuyết phlogiston về sự cháy và ăn_mòn phổ_biến vào thời đó .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Phân_tử ở trạng_thái kích_thích tetraoxygen ( ) được phát_hiện năm 2001 , và được giả_thiết về sự tồn_tại của nó là một trong sáu giai_đoạn của ôxy rắn . Điều này được chứng_minh năm 2006 , nó được tạo ra bằng cách nén lên 20 \xa0GPa , trong thực_tế là một ô mạng thoi .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Cấu_trúc ô mạng này có khả_năng có tính ôxy hoá rất mạnh hơn cả hoặc và có_thể được sử_dụng trong nhiên_liệu tên_lửa . Trạng_thái kim_loại được phát_hiện năm 1990 khi ôxy rắn được nén trên 96 GPa và nó được thể_hiện năm 1998 ở nhiệt_độ rất thấp , pha này trở_thành chất siêu_dẫn .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Trạng_thái kim_loại được phát_hiện năm 1990 khi ôxy rắn được nén trên 96 GPa và nó được thể_hiện năm 1998 ở nhiệt_độ rất thấp , pha này trở_thành chất siêu_dẫn .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Hợp_chất của ôxy tìm thấy trong khắp vũ_trụ và quang_phổ của ôxy được tìm thấy ở các ngôi_sao .'],
#  ['Ôxy được phát_hiện năm nào',
#   'Ôxy được phát_hiện bởi dược_sĩ người Thuỵ_Điển Carl_Wilhelm_Scheele năm 1772 bằng cách đun nóng oxit đồng và một hỗn_hợp vài muối nitrat . Scheele gọi oxy là " khí cháy " vì nó là khí hỗ_trợ sự cháy duy_nhất được phát_hiện lúc đó .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Các môn thể_thao tương_tự bóng_đá hiện_đại ( với mục_đích đá bóng vào khung_thành đối_phương ) đã xuất_hiện ở nhiều nơi trên thế_giới từ rất lâu . Theo FIFA thì dạng bóng_đá cổ_xưa nhất bao_gồm đầy_đủ các kỹ_thuật chơi bóng có_lẽ xuất_phát từ Trung_Quốc vào_khoảng thế_kỷ 2 hoặc 3 TCN , môn " xúc cúc " .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Quy_định về thời_gian đá bù xuất_hiện sau trận đấu năm 1891 giữa Stoke và Aston_Villa , khi chỉ còn 2 phút là hết giờ , trong tình_thế bị dẫn trước 1 – 0 , đội Stoke bất_ngờ được hưởng một quả phạt_đền , thủ_môn Villa đã đối_phó bằng cách đá bóng ra khỏi sân và đến khi bóng trở_lại sân thì đồng_hồ đã điểm 90 phút và Stoke thua trận .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Trong trường_hợp này , nếu kết_thúc 90 phút của 2 hiệp chính hai đội vẫn hoà , họ sẽ phải thi_đấu thêm 2 hiệp phụ liên_tiếp , mỗi hiệp 15 phút không có nghỉ giữa giờ . Nếu hết 2 hiệp phụ mà kết_quả vẫn hoà , hai đội sẽ phải thi đá luân_lưu 11 m ( hai đội thay phiên nhau thực_hiện các quả đá phạt_đền ) để xác_định đội giành chiến_thắng .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Nếu hết 2 hiệp phụ mà kết_quả vẫn hoà , hai đội sẽ phải thi đá luân_lưu 11 m ( hai đội thay phiên nhau thực_hiện các quả đá phạt_đền ) để xác_định đội giành chiến_thắng . Các bàn thắng ghi được trong hai hiệp phụ sẽ được tính vào kết_quả chung_cuộc , tuy_nhiên các bàn thắng ghi trong những loạt đá luân_lưu 11 m sẽ không được tính ( mà chỉ dùng để xác_định kết_quả thắng thua ) .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Một lỗi xảy ra khi có cầu_thủ vi_phạm các điều ghi trong Luật_bóng_đá . Các lỗi vi_phạm được quy_định trong điều 12 của Luật_bóng_đá ( đôi_khi còn được gọi là " Luật 12 " ) . Các lỗi thường thấy là câu giờ , đẩy người , kéo áo . Đội có cầu_thủ vi_phạm sẽ chịu cú đá phạt_trực_tiếp hoặc đá phạt_đền từ phía đối_phương .'],
#  ['Khi nào đá phạt_trực_tiếp',
#   'Các lỗi thường thấy là câu giờ , đẩy người , kéo áo . Đội có cầu_thủ vi_phạm sẽ chịu cú đá phạt_trực_tiếp hoặc đá phạt_đền từ phía đối_phương .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Ngày_nay , bóng_đá đã được chơi ở cấp_độ chuyên_nghiệp trên khắp thế_giới với hàng triệu người đến sân theo_dõi các trận đấu cũng như hàng tỷ người theo_dõi qua truyền_hình . Theo một cuộc thăm_dò do FIFA tiến_hành năm 2001 , có trên 240 triệu người từ trên 200 quốc_gia thường_xuyên chơi bóng_đá .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Hiện_nay Luật_bóng_đá chính_thức có 17 điều được áp_dụng cho mọi cấp_độ chơi bóng và chỉ có một_vài sửa_đổi nhỏ cho phù_hợp với bóng_đá nữ và bóng_đá trẻ .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Về mặt phòng_ngự , bước_tiến đáng_kể về chiến_thuật là đội_hình " Catenaccio " do huấn_luyện_viên người Argentina Helenio_Herrera đưa ra và được áp_dụng phổ_biến trong các đội bóng Ý. Tại Đức , đội_hình phòng_ngự lại thường sử_dụng một cầu_thủ phòng_ngự tự_do ( được gọi là libero ) với những đại_diện nổi_tiếng như Franz_Beckenbauer hoặc Lothar_Matthaus .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Bóng_đá hiện_đại ngày_nay thường sử_dụng những đội_hình chắc_chắn thay_vì chỉ tập_trung tấn_công hoa_mỹ , vì_vậy những đội_hình thường được các đội bóng sử_dụng là 4-4-2 , 5-3-2 , 4-5-1 và đội khi là 5-4-1 tuỳ theo đối_thủ và điều_kiện thi_đấu .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Bóng_đá thông_thường được chơi với hai đội_hình 11 người trên sân lớn , tuy_nhiên đôi_khi môn thể_thao này cũng được biến_đổi về số người chơi , luật_lệ để phù_hợp với các điều_kiện chơi bóng khác nhau .'],
#  ['Có bao_nhiêu loại đội_hình trong bóng_đá',
#   'Bóng_đá ba đội , một thể loại bóng_đá mà trong mỗi trận đấu có ba đội tham_gia thi_đấu , đội để thủng lưới ít_nhất là đội chiến_thắng . Trong mỗi trận , các liên_minh tạm_thời giữa hai đội đang thủng lưới nhiều hơn sẽ dồn_ép đội thủng lưới ít_nhất , các liên_minh thành_lập và tan_vỡ liên_tục theo tỉ_số trận đấu .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Máy_phát_điện đầu_tiên được sáng_chế vào năm 1831 là đĩa Faraday , do nhà_khoa_học người Anh Michael_Faraday .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Sau đó , Ông ta cũng đã chế_tạo_máy phát_điện từ đầu_tiên được gọi là " đĩa Faraday " , nó dùng một đĩa bằng đồng quay giữa các cực của một nam_châm hình móng ngựa .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Dynamo là máy_phát_điện đầu_tiên có khả_năng cung_cấp điện_năng cho công_nghiệp . Dynamo sử_dụng nguyên_lý cảm_ứng_điện từ để biến_đổi năng_lượng quay cơ_học thành dòng_điện_xoay_chiều . Cấu_tạo của dynamo bao_gồm một kết_cấu tĩnh mà nó tạo ra từ_trường mạnh và một cuộn dây quay .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Máy phát dynamo đầu_tiên dựa trên nguyên_lý Faraday được chế_tạo vào năm 1832 do Hippolyte_Pixii - một nhà_chế_tạo thiết_bị đo_lường . Máy này đã sử_dụng một nam_châm vĩnh_cửu được quay bằng một tay_quay . Nam_châm quay được định_vị sao cho cực Nam và cực Bắc của nó đi ngang qua một mẫu sắt được quấn bằng dây_dẫn .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Năm 1827 , Anyos_Jedlik bắt_đầu thử_nghiệm với các thiết_bị quay có từ_tính mà ông gọi là các rotor tự từ_hoá . Trong mẫu_vật đầu_tiên của một bộ khởi_động đơn cực , ( đã được hoàn_tất trong khoảng 1852 và 1854 ) cả phần tĩnh lẫn phần quay đều là nam_châm điện .'],
#  ['Máy_phát_điện đầu_tiên ra_đời vào năm mấy',
#   'Những chiếc xe có gắn động_cơ đầu_tiên có khuynh_hướng lắp_đặt các máy_phát_điện một_chiều với bộ điều_hoà điện_thế bằng cơ_khí . Kiểu này không được tin_cậy hoàn_toàn , và hiệu_suất thấp , nên sau_này đã được thay_thế bằng các máy_phát_điện xoay chiều với những mạch chỉnh_lưu lắp trong .'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Thảo_Cầm_Viên Sài_Gòn ( tên gọi tắt : Thảo_Cầm_Viên , người_dân quen gọi Sở thú ) là công_viên bảo_tồn động_vật - thực_vật ở Thành_phố Hồ_Chí_Minh , Việt_Nam . Đây là vườn thú có tuổi_thọ đứng hàng thứ 8 trên thế_giới . Khuôn_viên rộng_lớn này hiện toạ_lạc gần hạ_lưu kênh Nhiêu_Lộc - Thị_Nghè với hai cổng vào nằm ở số 2B đường Nguyễn_Bỉnh_Khiêm và số 1 đường Nguyễn_Thị_Minh_Khai phường Bến_Nghé , Quận 1 , Thành_phố Hồ_Chí_Minh .'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Năm 1956 : lại được tu_sửa , tái_thiết và đổi tên là Thảo_Cầm_Viên Sài_Gòn .'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Theo quy_hoạch động_vật giai_đoạn 2013-2015 do Công_ty TNHH MTV Thảo_Cầm_Viên Sài_Gòn lập và duyệt , số_lượng hổ giữ ở Sài_Gòn là 14 con ( gồm 10 con hổ vàng và bốn con hổ trắng ) , trong khi số_lượng hổ mà Thảo_Cầm_Viên đang sở_hữu là 16 con ( gồm 11 con hổ vàng và năm con hổ trắng ) .'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Hiện_nay , ở Thảo_Cầm_Viên Sài_Gòn , ngoài những khu_vực nuôi_trồng cầm_thú , cây_cảnh và sưu_tập phong_lan , còn có khu dành cho trẻ_em , cho người_lớn vui_chơi , giải_trí ...'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Sau hơn 150 năm tồn_tại , Thảo_Cầm_Viên đã trở_thành một vườn thú lớn với 590 đầu_thú thuộc 125 loài , thực_vật có 1800 cây_gỗ thuộc 260 loài , 23 loài lan nội_địa , 33 loài xương_rồng , 34 loại bon sai ... và đang được bổ_sung thêm .'],
#  ['Có bao_nhiêu loài thực_vật ở Thảo_Cầm_Viên',
#   'Năm 1945 - 1955 , quân_đội Pháp cũng chiếm Thảo_cầm_viên làm đồn_trú và kho_tàng cất_giấu vũ_khí , nên đã phá nhiều chuồng_trại và một_số cây_cổ_thụ .'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Với diện_tích 14 triệu km ( 5,4 triệu dặm ) , châu Nam_Cực là lục_địa lớn thứ năm về diện_tích sau châu_Á , châu_Phi , Bắc_Mỹ , và Nam_Mỹ . Khoảng 98% châu Nam_Cực bị bao_phủ bởi một lớp băng có bề dày trung_bình 1,9 \xa0km ( 1,2 dặm ) .'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Khoảng 98% châu Nam_Cực bị bao_phủ bởi một lớp băng có bề dày trung_bình 1,9 \xa0km ( 1,2 dặm ) . Băng trải rộng ra khắp mọi phía , xa nhất lên phía bắc tới điểm cực Bắc của bán_đảo Nam_Cực .'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Ghi_nhận người đầu_tiên đến châu Nam_Cực và được xác_nhận là Cape_Adair vào năm 1895 .'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Về cơ_bản , châu Nam_Cực được chia làm hai bởi dải núi chạy giữa biển Ross và biển Weddell , tạo thành miền Đông Nam_Cực và Tây_Nam Cực'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Những tuyên_bố mới dành chủ_quyền ở châu Nam_Cực đã không được xét tới từ 1959 và châu Nam_Cực được xem là trung_lập về chính_trị . Tình_trạng pháp_lý của nó được quy_định qua hiệp_ước châu Nam_Cực 1959 và những thoả_hiệp tương_tự , mà cùng được gọi chung là Hệ_thống hiệp_ước châu Nam_Cực .'],
#  ['Phần_lớn châu Nam_Cực được che_lấp bởi gì',
#   'Tình_trạng pháp_lý của nó được quy_định qua hiệp_ước châu Nam_Cực 1959 và những thoả_hiệp tương_tự , mà cùng được gọi chung là Hệ_thống hiệp_ước châu Nam_Cực . Châu_Nam_Cực được định_nghĩa là vùng_đất và những Thềm băng nằm phía nam của 60 ° S. Hiệp_ước châu Nam_Cực đã được 12 nước ký , trong đó có Liên_Xô ( bây_giờ là Nga ) , Vương_quốc_Anh , Argentina , Chile , Úc , và Hoa_Kỳ .'],
#  ['Bình trong Bình_Ba có nghĩa là gì',
#   'Bình_Ba là một đảo nhỏ diện_tích trên 3 \xa0km² thuộc xã Cam_Bình , thành_phố Cam_Ranh , tỉnh Khánh_Hoà , Việt_Nam . Đảo nằm trong vịnh Cam_Ranh , cách thành_phố Nha_Trang khoảng 60 \xa0km về phía nam , cách cảng Ba Ngòi ( Cam_Ranh ) 15 \xa0km về phía đông .'],
#  ['Bình trong Bình_Ba có nghĩa là gì',
#   'Đảo nằm trong vịnh Cam_Ranh , cách thành_phố Nha_Trang khoảng 60 \xa0km về phía nam , cách cảng Ba Ngòi ( Cam_Ranh ) 15 \xa0km về phía đông .'],
#  ['Bình trong Bình_Ba có nghĩa là gì',
#   'Ngư_dân địa_phương cho rằng " Bình " trong tên gọi có_thể là " bình_yên " mà cũng có_thể là " Bình_Định " - là một_cách để người_dân ghi_nhớ tổ_tiên từ Bình_Định đến đây lập_nghiệp giai_đoạn khoảng cuối thế_kỷ XVII , đầu thế_kỷ XVIII .'],
#  ['Bình trong Bình_Ba có nghĩa là gì',
#   'Bình_Ba có phong_cảnh đẹp và các bãi cát trắng trải dài . Đảo có ba bãi biển đẹp nhất_là bãi Chướng ( nhiều đá , nước trong ) , bãi Nồm ( cát trắng , nơi dân địa_phương hay ra tắm ) và bãi Nhà Cũ ( có nhiều cầu_gai ) .'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Với diện_tích 14 triệu km ( 5,4 triệu dặm ) , châu Nam_Cực là lục_địa lớn thứ năm về diện_tích sau châu_Á , châu_Phi , Bắc_Mỹ , và Nam_Mỹ . Khoảng 98% châu Nam_Cực bị bao_phủ bởi một lớp băng có bề dày trung_bình 1,9 \xa0km ( 1,2 dặm ) .'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Khoảng 98% châu Nam_Cực bị bao_phủ bởi một lớp băng có bề dày trung_bình 1,9 \xa0km ( 1,2 dặm ) . Băng trải rộng ra khắp mọi phía , xa nhất lên phía bắc tới điểm cực Bắc của bán_đảo Nam_Cực .'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Ghi_nhận người đầu_tiên đến châu Nam_Cực và được xác_nhận là Cape_Adair vào năm 1895 .'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Về cơ_bản , châu Nam_Cực được chia làm hai bởi dải núi chạy giữa biển Ross và biển Weddell , tạo thành miền Đông Nam_Cực và Tây_Nam Cực'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Những tuyên_bố mới dành chủ_quyền ở châu Nam_Cực đã không được xét tới từ 1959 và châu Nam_Cực được xem là trung_lập về chính_trị . Tình_trạng pháp_lý của nó được quy_định qua hiệp_ước châu Nam_Cực 1959 và những thoả_hiệp tương_tự , mà cùng được gọi chung là Hệ_thống hiệp_ước châu Nam_Cực .'],
#  ['Diện_tích của châu Nam_Cực là bao_nhiêu',
#   'Tình_trạng pháp_lý của nó được quy_định qua hiệp_ước châu Nam_Cực 1959 và những thoả_hiệp tương_tự , mà cùng được gọi chung là Hệ_thống hiệp_ước châu Nam_Cực . Châu_Nam_Cực được định_nghĩa là vùng_đất và những Thềm băng nằm phía nam của 60 ° S. Hiệp_ước châu Nam_Cực đã được 12 nước ký , trong đó có Liên_Xô ( bây_giờ là Nga ) , Vương_quốc_Anh , Argentina , Chile , Úc , và Hoa_Kỳ .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Khí ôxy thường được gọi là " dưỡng_khí " , vì nó duy_trì sự sống của cơ_thể con_người .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Khi ôxy này chìm xuống trở_nên bảo hoà , ôxy tự_do bắt_đầu thoát ra ở dạng khí từ các đại_dương cách nay 3 – 2,7 \xa0tỉ năm , đạt đến 10% với mức như hiện_nay vào_khoảng 1,7 \xa0tỉ năm trước .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Ôxy được phát_hiện bởi dược_sĩ người Thuỵ_Điển Carl_Wilhelm_Scheele năm 1772 bằng cách đun nóng oxit đồng và một hỗn_hợp vài muối nitrat . Scheele gọi oxy là " khí cháy " vì nó là khí hỗ_trợ sự cháy duy_nhất được phát_hiện lúc đó .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Đồng_thời khí nitơ được giải_phóng khỏi lớp zeolit bảo hoà nitơ bằng cách giảm áp_suất vận_hành của bồng và chuyển một phần khí ôxy từ lớp sản_xuất đi qua nó , theo chiều dòng ngược_lại . Sau một thời_gian thiết_lập chu_kỳ hoạt_động , sự_vật hành của hai lớp được thay_đổi cho nhau , từ đó cho_phép cung_cấp liên_tục khí ôxy , được bơn qua đường_ống .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Khí ôxy cũng có_thể được tạo ra qua quá_trình điện phân nước thành phân_tử ôxy và hydro . Phải dùng dòng_điện_một_chiều , vì nếu dùng dòng hai chiều , khi các khí_sinh ra ở một cực sẽ giải_phóng đồng_thời hydro và ôxy , nếu đạt đến tỷ_lệ 2:1 sẽ gây nổ .'],
#  ['Tại_sao gọi khí Ôxy là dưỡng_khí',
#   'Vì các lý_do kinh_tế , ôxy thường được vận_chuyển trong các bồn ở dạng lỏng đặc_biệt các xe_bồn cách_nhiệt đặc_biệt , do một lít ôxy lỏng bằng với 840 \xa0lít khí ôxy ở áp_suất khí_quyển và nhiệt_độ . Các xe_bồn như thế_này được dùng để nạp lại ôxy lỏng , đặt nằm ngoài các bệnh_viện và các việc khác cần sử_dụng một lượng lớn ôxy tinh_khiết .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Ôxy ( bắt_nguồn từ_từ tiếng Pháp " oxygène " / ɔksiʒɛn / ) , còn được viết là ô-xy , ô-xi , là nguyên_tố_hoá_học có ký_hiệu là O thuộc nhóm VI A và số_hiệu nguyên_tử bằng 8 trong bảng_tuần_hoàn các nguyên_tố , nguyên_tử khối bằng 16 .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Ở điều_kiện nhiệt_độ và áp_suất tiêu_chuẩn hai nguyên_tử ôxy kết_hợp với nhau tạo thành phân_tử ôxy không màu , không mùi , không vị có công_thức . Ôxy phân_tử ( O , thường được gọi là ôxy tự_do ) trên Trái_Đất là không ổn_định về mặt nhiệt động_lực_học .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Thậm_chí ở quỹ_đạo Trái_Đất tầm thấp , nguyên_tử ôxy cũng tồn_tại và làm mòn các tàu không_gian .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Ôxy là nguyên_tố phổ_biến nhất ở vỏ Trái_Đất . Ôxy là nguyên_tố phổ_biến thứ 3 trong vũ_trụ sau hydro và heli . Khoảng 0,9% khối_lượng của Mặt_Trời là ôxy . Người ta ước_tính nó chiếm 49,2% khối_lượng của vỏ Trái_Đất . và chiếm khoảng 88,8% khối_lượng các đại_dương ( là HO , hay nước ) và 20% theo thể_tích bầu khí_quyển Trái_Đất ( là O , ôxy phân_tử , hay O , ôzôn ) .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Ôzôn ( O ) được tạo thành trong quá_trình phóng tĩnh_điện với sự có_mặt của ôxy phân_tử . Ôxy phân_tử đôi ( O ) hiện_nay đã biết và tìm thấy như là một phần nhỏ trong ôxy lỏng . Các êpôxít là các ête trong đó nguyên_tử ôxy là một phần của vòng gồm ba nguyên_tử .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Ôxy phân_tử đôi ( O ) hiện_nay đã biết và tìm thấy như là một phần nhỏ trong ôxy lỏng . Các êpôxít là các ête trong đó nguyên_tử ôxy là một phần của vòng gồm ba nguyên_tử .'],
#  ['Nguyên_tử Ôxy nặng bao_nhiêu',
#   'Các êpôxít là các ête trong đó nguyên_tử ôxy là một phần của vòng gồm ba nguyên_tử .'],
#  ['Máy bắn đá là gì',
#   'Máy bắn đá là loại vũ_khí_lạnh thời cổ . Các nhà_nghiên_cứu cho là được phát_minh năm 399 trước công_nguyên .'],
#  ['Máy bắn đá là gì',
#   'Hiện_nay người ta tạm thống_nhất Máy ném đá lớn nhất là của quân_Nguyên - Mông dùng khi đánh Biện_Kinh ( kinh_đô nước Kim ) năm 1234 có 13 sảo , dùng 500 người kéo dây , bắn đạn đá nặng 60 \xa0kg'],
#  ['Máy bắn đá là gì',
#   'Vào cuối những năm 1260 , trong cuộc vây_hãm hai thành Phàn_Thành và Tương_Dương của nhà Tống , quân Mông_Cổ đã nhờ 2 kỹ_sư người Ba Tư lắp_đặt hàng_loạt máy Trebuchet để công_phá Tương_Phàn , mỗi máy bắn đá mới này có_thể phóng các quả đạn nặng 300 \xa0kg và tầm xa 500m .'],
#  ['Máy bắn đá là gì',
#   'Trong cuộc vây_hãm tại lâu_đài Stirling năm 1304 , vua nước Anh là Edward_Longshanks đã cho chế_tạo một cỗ máy Trebuchet khổng_lồ có tên gọi là “ Warwolf ” . Cỗ máy khủng_khiếp này có_thể bắn những tảng đá nặng tới 1,5 tấn , huỷ_diệt được những mục_tiêu kiên_cố nhất của kẻ_thù .'],
#  ['Máy bắn đá là gì',
#   'Cỗ máy khủng_khiếp này có_thể bắn những tảng đá nặng tới 1,5 tấn , huỷ_diệt được những mục_tiêu kiên_cố nhất của kẻ_thù .'],
#  ['Máy bắn đá là gì',
#   'Tuy_vậy , những cỗ máy của họ nhỏ hơn và đóng vai_trò ít quan_trọng hơn trong các trận đánh công thành .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Sân_vận_động Quốc_gia Mỹ_Đình ( ) là sân_vận_động quốc_gia ở Hà_Nội , Việt_Nam có sức chứa lớn thứ nhì Việt_Nam ( sau sân_vận_động Cần_Thơ – tối_đa 45.000 chỗ ) .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Tuy_nhiên Bộ Xây_dựng sau đó lại có văn_bản khác khẳng_định HISG đạt tiêu_chuẩn và trúng_thầu . Theo ông Dự thì " " nếu chúng_ta chọn nhà_thầu Âu - Mỹ , chắc_chắn chất_lượng sân_vận_động Mỹ_Đình sẽ tốt hơn thế_này , thiết_kế cũng đẹp hơn .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Theo ông Dự thì " " nếu chúng_ta chọn nhà_thầu Âu - Mỹ , chắc_chắn chất_lượng sân_vận_động Mỹ_Đình sẽ tốt hơn thế_này , thiết_kế cũng đẹp hơn . Hằng năm ngành thể_thao không phải bỏ ra hàng tỉ đồng để sửa sân như suốt những năm qua " " .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Sân_vận_động Mỹ_Đình còn là nơi tổ_chức lễ khai_mạc Đại_hội Thể_thao Trong nhà châu_Á lần thứ III từ ngày 30 tháng 10 năm 2009 đến 8 tháng 11 . Vào tháng 7 năm 2007 , sân_vận_động Quốc_gia Mỹ_Đình là một trong những sân_vận_động trong 4 nước đăng_cai giải tham_gia tổ_chức Cúp bóng_đá_châu_Á 2007 với 5 trận vòng bảng ( bảng B ) , 1 trận tứ_kết và 1 trận bán_kết .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Nằm tại đường Lê_Đức_Thọ ( phường Mỹ_Đình 1 , quận Nam_Từ_Liêm ) , cách trung_tâm Hà_Nội 10 km về phía tây_nam , sân_vận_động Mỹ_Đình là sân_vận_động có sức chứa lớn thứ nhì Việt_Nam ( sau sân_vận_động Cần_Thơ , có_thể chứa 50.000 người ) .'],
#  ['Sân_vận_động Mỹ_Đình nằm ở đâu',
#   'Chi_phí xây_dựng sân_vận_động Mỹ_Đình là 52.983 triệu đô_la Mỹ với đơn_vị trúng_thầu là Tập_đoàn HISG ( Trung_Quốc ) .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'Luật bàn_thắng_vàng đã được sử_dụng ở cấp_độ thế_giới trong World_Cup 1998 và World_Cup 2002 với Pháp là đội_tuyển đầu_tiên tận_dụng được lợi_thế này khi giành chiến_thắng trước Paraguay bằng bàn_thắng_vàng của Laurent_Blanc ( năm 1998 ) , Pháp cũng là đội vô_địch ở giải đấu năm 1998 .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'Giải đấu cấp quốc_tế lớn nhất của bóng_đá thế_giới là World_Cup . World_Cup được FIFA tổ_chức lần đầu năm 1930 và đến nay đã trở_thành giải thi_đấu thể_thao được nhiều người theo_dõi nhất hành_tinh , vượt qua cả Thế_vận_hội , ví_dụ vòng chung_kết World_Cup 2006 tổ_chức tại Đức đã thu_hút 26,29 tỷ lượt khán_giả xem truyền_hình trong đó riêng trận chung_kết đã thu_hút 715,1 triệu khá_giả trên khắp thế_giới .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'World_Cup được tổ_chức theo thể_thức 4 năm một lần với vòng đấu_loại có sự tham_gia của trên 190 quốc_gia thành_viên FIFA và vòng chung_kết có sự góp_mặt của 32 đội_tuyển ( trước năm 1982 là 16 đội , trước năm 1998 là 24 đội ) , vòng chung_kết của World_Cup 2014 được tổ_chức tại Brasil .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'Các nhà vô_địch của các giải đấu cấp châu_lục cùng với đương_kim vô_địch World_Cup sẽ gặp nhau tại Cúp_Liên đoàn các châu_lục , đây là giải đấu khởi_động cho World_Cup và được FIFA tổ_chức trước World_Cup 1 năm .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'Một ví_dụ khác là việc tổ_chức World_Cup 2006 chỉ trong vòng 1 tháng đã giúp lượng khách du_lịch đến Đức trong cả năm 2006 tăng thêm 9% .'],
#  ['World_Cup tổ_chức mấy năm một lần',
#   'Bóng_đá cũng trở_thành phương_tiện tuyên_truyền cho Mặt_trận giải_phóng Algérie trong thời_gian Chiến_tranh Algérie . Đôi_khi bóng_đá lại trở_thành phương_tiện để thúc_đẩy hoặc hàn_gắn quan_hệ ngoại_giao giữa các nước có mâu_thuẫn , có_thể kể tới trận đấu lịch_sử giữa Mỹ và Iran tại vòng đấu_loại bảng F World_Cup 1998 hay World_Cup 2002 , giải đấu được Nhật_Bản và Hàn_Quốc , hai quốc_gia vốn có nhiều mâu_thuẫn lịch_sử , tổ_chức chung khá thành_công .'],
#  ['Đèn sợi đốt dây_tóc được sáng_chế vào năm nào',
#   'Đèn sợi đốt , còn gọi là đèn dây_tóc là một loại bóng_đèn dùng để chiếu sáng khi bị đốt nóng , dây_tóc là bộ_phận chính để phát ra ánh_sáng , thông_qua vỏ thuỷ_tinh trong suốt . Các dây_tóc - bộ_phận phát sáng chính của đèn được bảo_vệ bên ngoài bằng một lớp thuỷ_tinh trong suốt hoặc mờ đã được rút hết không_khí và bơm vào các khí_trơ .'],
#  ['Đèn sợi đốt dây_tóc được sáng_chế vào năm nào',
#   'Vào năm 1800 , nhà_phát_minh người Italia_Alessandro_Volta đã phát_triển phương_pháp thực_tiễn đầu_tiên làm phát ra điện , đó là cột volta .'],
#  ['Đèn sợi đốt dây_tóc được sáng_chế vào năm nào',
#   'Tháng 1 năm 1879 , tại phòng thi nghiệm của mình tại Menlo_Park , New_Jersey , Thomas_Edison – một trong những nhà_phát_minh nổi_tiếng nhất của mọi thời_đại đã chế_tạo bóng_đèn điện sợi đốt đầu_tiên . Đèn phát sáng khi dòng_điện đi qua dây_tóc mỏng platin đặt trong một bóng thuỷ_tinh hút chân không để chống ôxy hoá .'],
#  ['Đèn sợi đốt dây_tóc được sáng_chế vào năm nào',
#   'Đèn phát sáng khi dòng_điện đi qua dây_tóc mỏng platin đặt trong một bóng thuỷ_tinh hút chân không để chống ôxy hoá . Lúc đó , đèn chỉ cháy trong vài giờ . Chiếc đèn_hiệu quả đầu_tiên dùng dây_tóc là sợi vải tẩm carbon .'],
#  ['Đèn sợi đốt dây_tóc được sáng_chế vào năm nào',
#   'Bóng_đèn sợi đốt vonfram thường bị đen với thời_gian do vonfram bay_hơi khỏi dây_tóc và bám lên thành của bóng_đèn . Hơi halogen dùng để tự làm sạch . Khi các nguyên_tử vonfram bay_hơi khỏi dây_tóc chúng sẽ kết_hợp với các nguyên_tử halogen và lắng_đọng trở_lại chính trên dây_tóc .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Lối chơi của anh được so_sánh với huyền_thoại Diego_Maradona , người tự coi Messi là " truyền nhân " của mình .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Mùa giải 2008-09 là mùa giải thành_công nhất của Messi khi anh đã ghi 38 bàn và trở_thành nhân_tố chủ_chốt trong cú ăn sáu của đội bóng xứ Catalan . Kỉ_lục này sau đó bị phá vỡ ở mùa giải 2009 – 10 , khi Messi ghi được 47 bàn thắng ở tất_cả các giải đấu , cân_bằng với kỉ_lục của Ronaldo ở Barcelona .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Cuối năm đó , anh phá kỉ_lục trở_thành cầu_thủ ghi nhiều bàn thắng nhất trong một năm_dương_lịch với 91 bàn thắng . Hai mùa giải sau đó , Messi đều về nhì trong cuộc đua giành Quả bóng Vàng , xếp sau Cristiano_Ronaldo . Đến mùa giải 2014-15 , Messi là đầu_tàu đưa Barcelona giành được cú ăn ba lần thứ hai trong lịch_sử CLB .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Hai mùa giải sau đó , Messi đều về nhì trong cuộc đua giành Quả bóng Vàng , xếp sau Cristiano_Ronaldo . Đến mùa giải 2014-15 , Messi là đầu_tàu đưa Barcelona giành được cú ăn ba lần thứ hai trong lịch_sử CLB . Anh tiếp_tục giành thêm 2 danh_hiệu La_Liga nữa cùng đội bóng vào các năm 2016 và 2018 .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Messi phải ngồi ngoài trong 6 tuần sau một chấn_thương anh gặp phải vào ngày 4 tháng 3 trong trận gặp Celtic ở cúp C 1 . Đó là lần thứ 4 trong 3 mùa giải Messi gặp phải cùng một loại chấn_thương .'],
#  ['Mùa giải nào thành_công nhất của Messi',
#   'Ngày 30 tháng 6 năm 2017 , Messi kết_hôn với Antonella_Roccuzzo . Đám_cưới của Messi được tổ_chức tại tổ_hợp khách_sạn 5 sao City_Center_Rosario . Leo_Messi quen cô bạn gái Antonella_Roccuzzo lúc anh mới 5 tuổi , trước khi công_khai chuyện hẹn_hò từ năm 2009 .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'Bóng_đá hay Túc_cầu là môn thể_thao đồng_đội được chơi giữa hai đội với nhau , mỗi đội có 11 cầu_thủ trên sân . Trò_chơi này dùng một quả bóng và thường được chơi trên sân_cỏ hình_chữ_nhật với hai khung_thành ở hai đầu sân .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'Trò_chơi này dùng một quả bóng và thường được chơi trên sân_cỏ hình_chữ_nhật với hai khung_thành ở hai đầu sân . Mục_tiêu của trò_chơi là ghi_điểm bằng cách đưa bóng vào khung_thành của đội đối_địch . Ngoại_trừ thủ_môn , các cầu_thủ khác đều không được cố_ý dùng tay hoặc cánh_tay để chơi bóng .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'IFAB được thành_lập năm 1886 tại Manchester trong một buổi họp với sự có_mặt của đại_diện FA , Hiệp_hội bóng_đá Scotland ( Scottish_Football_Association ) , Hiệp_hội bóng_đá xứ Wales ( Football_Association of Wales ) và Hiệp_hội bóng_đá Ireland ( Irish_Football_Association ) .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'Bóng_đá hiện_đại sau hơn 1 thế_kỷ hình_thành và phát_triển đã sản_sinh ra nhiều cầu_thủ lớn với khả_năng và thành_tích đặc_biệt . Những người này thường được gọi là các " ngôi_sao bóng_đá " hay " siêu_sao bóng_đá " .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'Futsal hay bóng_đá trong nhà là môn thể_thao tương_tự bóng_đá nhưng các trận đấu được diễn ra trong nhà với một_số luật_lệ được thay_đổi cho phù_hợp ví_dụ kích_thước sân và bóng được thu nhỏ , các cầu_thủ đi giày đế bằng thay_vì giày_đinh như ở các trận đấu sân_cỏ .'],
#  ['Sân_cỏ bóng_đá có hình gì',
#   'Bóng_đá cho người khuyết_tật có hai loại_hình chính là bóng_đá xe_lăn ( cho người khuyết_tật chi ) và bóng_đá cho người khiếm_thị ( cho người có khuyết_tật về mắt ) . Môn bóng_đá cho người khiếm_thị được đưa vào nội_dung thi_đấu của Paralympic kể từ năm 2004 .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Công_viên Văn_hoá Đầm_Sen là công_viên giải_trí nằm trên đường Hoà_Bình , Quận 11 , Thành_phố Hồ_Chí_Minh . Công_viên có diện_tích 50 hecta gồm 20% là mặt hồ và 60% cây_xanh và vườn hoa .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Trước năm 1975 , mảnh đất thuộc Công_viên Văn_hoá Đầm_Sen hiện_nay là một khu đầm lầy hoang_hoá .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Thành_phố giao cho Quận 11 quản_lý . UBND Quận 11 giao cho 3 đơn_vị : Công_ty Ăn_uống Q. 11 , Công_ty Văn_hoá tổng_hợp và Xí_nghiệp nuôi_trồng thuỷ_sản khai_thác .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Năm 1989 , công_trình được giao cho Công_ty Dịch_vụ Du_lịch Phú_Thọ - đơn_vị vừa_mới tách ra từ Công_ty Ăn_uống Q. 11 - quản_lý và đầu_tư cho đến nay .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Đặc_biệt " Thuỷ_cung Đầm_Sen " là một công_trình phục_vụ tham_quan giải_trí mới của Công_viên văn_hoá Đầm_Sen do Tổng_công_ty Dịch_vụ Du_lịch Phú_Thọ và Công_ty TNHH TM & DV Hải_Thanh làm chủ đầu_tư .'],
#  ['Công_ty nào quản_lý công_viên văn_hoá Đầm_Sen',
#   'Thuỷ_cung toạ_lạc tại vườn Nam_Tú_Thượng_Uyển - khu A Công_viên văn_hoá Đầm_Sen . Công_trình mới khai_trương giai_đoạn 1 vào ngày 04/08/2013 và hiện_tại đang tiếp_tục xây_dựng giai_đoạn 2 với những công_trình_phụ mới_lạ và đặc_sắc nhằm phục_vụ du_khách .'],
#  ['Tên ngôi đền Angkor_Wat có nghĩa là gì',
#   'Vua_Khmer_Suryavarman_II xây_dựng Angkor_Wat vào đầu thế_kỷ XII tại Yaśodharapura ( tiếng Khmer : យសោធរបុរៈ , Angkor ngày_nay ) , thủ_đô của Đế_quốc Khmer như là đền thờ và lăng_mộ của ông . Khác với truyền_thống theo theo đạo Shaiva ( thờ thần Shiva ) của các vị vua tiền_nhiệm , Angkor_Wat thờ thần Vishnu .'],
#  ['Tên ngôi đền Angkor_Wat có nghĩa là gì',
#   'Tên hiện_đại của ngôi đền , Angkor_Wat , nghĩa_là " Thành_phố Đền " hay " Thành_phố của những ngôi Đền " trong tiếng Khmer ; Angkor , nghĩa_là " thành_phố " hay " thủ_đô " , là từ nokor ( នគរ ) , được bắt_nguồn từ_từ tiếng Phạn nagara ( नगर ) , trong tiếng bản_xứ .'],
#  ['Tên ngôi đền Angkor_Wat có nghĩa là gì',
#   'Đến cuối thế_kỷ XII , Angkor_Wat từ một trung_tâm tín_ngưỡng Ấn_Độ_giáo dần chuyển sang Phật_giáo và tiếp_tục cho đến ngày_nay . Không giống nhiều ngôi đền Angkor khác , tuy Angkor_Wat một phần bị quên_lãng từ sau thế_kỷ XVI , nó không bao_giờ hoàn_toàn bị bỏ_hoang , một phần nhờ con hào_bao xung_quanh đã bảo_vệ ngôi đền khỏi sự xâm_lấn của rừng rậm .'],
#  ['Tên ngôi đền Angkor_Wat có nghĩa là gì',
#   'Không giống nhiều ngôi đền Angkor khác , tuy Angkor_Wat một phần bị quên_lãng từ sau thế_kỷ XVI , nó không bao_giờ hoàn_toàn bị bỏ_hoang , một phần nhờ con hào_bao xung_quanh đã bảo_vệ ngôi đền khỏi sự xâm_lấn của rừng rậm .'],
#  ['Tên ngôi đền Angkor_Wat có nghĩa là gì',
#   'Tuy_nhiên Freeman và Jacques lưu_ý rằng một_số ngôi đền khác của Angkor có định_hướng khác với định_hướng Đông nói_chung , và cho rằng việc định_hướng Angkor_Wat là vì nghi_lễ thờ_cúng Vishnu , vị thần có liên_quan với phương Tây .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Hiện_nay , Thành_phố Hồ_Chí_Minh là thành_phố trực_thuộc Trung_ương được xếp loại đô_thị loại đặc_biệt của Việt_Nam , cùng với thủ_đô Hà_Nội .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Sài_Gòn cũng là thủ_đô của Liên_bang Đông_Dương giai_đoạn 1887 – 1901 ( về sau , Pháp chuyển thủ_đô Liên_bang Đông_Dương ra Hà_Nội ) . Năm 1949 , Sài_Gòn trở_thành thủ_đô của Quốc_gia Việt_Nam , một chính_thể thuộc Liên_bang Đông_Dương , và sau_này là thủ_đô của Việt_Nam Cộng_hoà .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Năm 1949 , Sài_Gòn trở_thành thủ_đô của Quốc_gia Việt_Nam , một chính_thể thuộc Liên_bang Đông_Dương , và sau_này là thủ_đô của Việt_Nam Cộng_hoà . Kể từ đó , thành_phố này trở_thành một trong những đô_thị quan_trọng nhất của miền Nam Việt_Nam .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Từ năm 1949 , Sài_Gòn đã là thủ_đô của Quốc_gia Việt_Nam . Đến năm 1955 , Việt_Nam Cộng_hoà được thành_lập , Sài_Gòn khi đó là thành_phố lớn nhất tại miền Nam Việt_Nam đã được chọn làm thủ_đô với tên gọi chính_thức " Đô_thành Sài_Gòn " ( lưu_ý , cách viết thông_dụng là " Saigon " ) .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Những thập_niên gần đây , nhiều trung_tâm thương_mại hiện_đại xuất_hiện như Saigon_Trade_Centre , Diamond_Plaza ... Mức tiêu_thụ của Thành_phố Hồ_Chí_Minh cũng cao hơn nhiều so với các tỉnh khác của Việt_Nam và gấp 1,5 lần thủ_đô Hà_Nội .'],
#  ['Sài_Gòn từng là thủ_đô của nước ta năm bao_nhiêu',
#   'Mức tiêu_thụ của Thành_phố Hồ_Chí_Minh cũng cao hơn nhiều so với các tỉnh khác của Việt_Nam và gấp 1,5 lần thủ_đô Hà_Nội . Sở_Giao_dịch Chứng_khoán Thành_phố Hồ_Chí_Minh , có mã giao_dịch là VN-Index , được thành_lập vào tháng 7 năm 1998 .'],
#  ['Một trận \x1dbóng đá có bao_nhiêu trọng_tài',
#   'Điều_khiển trận đấu là tổ trọng_tài bao_gồm một trọng_tài chính và hai trọng_tài biên , trọng_tài chính_sử_dụng một chiếc còi cùng hai loại thẻ , thẻ_vàng và thẻ_đỏ , và có trách_nhiệm bắt_đầu , kết_thúc hoặc tạm dừng trận đấu .'],
#  ['Một trận \x1dbóng đá có bao_nhiêu trọng_tài',
#   'Ngoài ba trọng_tài làm_việc trên sân còn có một trọng_tài thứ tư ( còn gọi là " trọng_tài bàn " ) quản_lý việc thay người , theo_dõi thời_gian bù giờ và thay_thế trọng_tài trên sân trong trường_hợp cần_thiết .'],
#  ['Một trận \x1dbóng đá có bao_nhiêu trọng_tài',
#   'Cầu_thủ ngoài sân nếu có hành_vi không đúng_mực cũng sẽ bị trọng_tài sử_dụng thẻ_vàng hoặc thẻ_đỏ để cảnh_cáo . Với các thành_viên ban huấn_luyện và huấn_luyện_viên trưởng , trọng_tài không sử_dụng thẻ_vàng , thẻ_đỏ mà có quyền đuổi trực_tiếp người vi_phạm ra khỏi sân .'],
#  ['Một trận \x1dbóng đá có bao_nhiêu trọng_tài',
#   'Truyền_hình không_chỉ ảnh_hưởng tới bóng_đá về mặt kinh_tế . Với công_nghệ tường_thuật ngày_càng tiên_tiến , các lỗi nhận_định của trọng_tài hoặc các pha tiểu_xảo của cầu_thủ trên sân dần không_thể qua nổi mắt khán_giả .'],
#  ['Một trận \x1dbóng đá có bao_nhiêu trọng_tài',
#   'Nghề trọng_tài và luật 12 liên_quan đến lỗi của cầu_thủ vì_thế cũng càng_ngày_càng được hoàn_thiện .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Ngày 2 tháng 7 năm 1976 , Quốc_hội nước Việt_Nam thống_nhất quyết_định đổi tên Sài_Gòn thành Thành_phố Hồ_Chí_Minh , theo tên vị Chủ_tịch nước đầu_tiên của Việt_Nam Dân_chủ Cộng_hoà .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Thành_phố Hồ_Chí_Minh ngày_nay bao_gồm toàn_bộ đô_thành Sài_Gòn cũ , cộng thêm toàn_bộ tỉnh Gia_Định , quận Phú_Hoà của tỉnh Bình_Dương và quận Củ_Chi của tỉnh Hậu_Nghĩa cũ .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Hiện_nay , Thành_phố Hồ_Chí_Minh gồm 19 quận nội_thành và 5 huyện ngoại_thành với 322 phường , xã và thị_trấn .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Thành_phố Hồ_Chí_Minh hiện_nay là một trong 5 thành_phố trực_thuộc Trung_ương của Việt_Nam . Về mặt hành_chính , thành_phố được chia thành 19 quận và 5 huyện . Trong đó có 322 đơn_vị hành_chính cấp xã , bao_gồm 259 phường , 58 xã và 5 thị_trấn .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Quy_hoạch Thành_phố Hồ_Chí_Minh tính tới thời_điểm 2010 có khoảng trên_dưới 600 dự_án quy_hoạch tại 13 quận_huyện .'],
#  ['Thành_phố Hồ_Chí_Minh có mấy quận',
#   'Ngoài báo_chí tiếng Việt , Thành_phố Hồ_Chí_Minh còn có " Saigon_Times daily " , " Thanhniennews " bằng tiếng Anh , một ấn_bản " Sài_Gòn giải_phóng " bằng tiếng Hoa .'],
#  ['Vì sao gọi Sao_Hoả là Hành_tinh Đỏ',
#   'Sao_Hoả còn gọi là : Hoả_Tinh , ( Tiếng Anh : Mars ) là hành_tinh thứ tư tính từ Mặt_Trời trong Thái_Dương Hệ . Đôi_khi hành_tinh này còn được gọi tên là Hoả_Tinh . Nó thường được gọi với tên khác là " Hành_tinh Đỏ " , do sắt ôxít có_mặt rất nhiều trên bề_mặt hành_tinh làm cho bề_mặt nó hiện lên với màu đỏ đặc_trưng .'],
#  ['Vì sao gọi Sao_Hoả là Hành_tinh Đỏ',
#   'Sao_Hoả có hai vệ_tinh , Phobos và Deimos , chúng là các vệ_tinh nhỏ và dị_hình . Đây có_thể là các tiểu hành_tinh bị Hoả_Tinh bắt được , tương_tự như 5261 Eureka-một tiểu hành_tinh Troia của Hoả_Tinh . Hiện_nay có ba tàu quỹ_đạo còn hoạt_động đang bay quanh Sao_Hoả : " Mars_Odyssey " , " Mars_Express " , và " Mars_Reconnaissance_Orbiter " .'],
#  ['Vì sao gọi Sao_Hoả là Hành_tinh Đỏ',
#   'Điều này làm cho hai hành_tinh có giá_trị gia_tốc hấp_dẫn tại bề_mặt gần bằng nhau-của Sao_Hoả chỉ lớn hơn có 1% . Sao_Hoả cũng là hành_tinh có giá_trị kích_thước , khối_lượng và gia_tốc hấp_dẫn bề_mặt ở giữa khi so với Trái_Đất và Mặt_Trăng ( Mặt_Trăng có đường_kính bằng một_nửa của Sao_Hoả , trong khi Trái_Đất có đường_kính gấp đôi Hoả_Tinh ; Trái_Đất có khối_lượng gấp chín lần khối_lượng Sao_Hoả trong khi Mặt_Trăng có khối_lượng chỉ bằng một phần chín so với Hoả_Tinh ) .'],
#  ['Vì sao gọi Sao_Hoả là Hành_tinh Đỏ',
#   'Độ sáng nhỏ nhất của nó tương_ứng với cấp sao +1,6 khi hành_tinh ở vị_trí giao_hội với Mặt_Trời . Sao_Hoả khi quan_sát qua kính_thiên_văn nhỏ thường hiện lên có màu vàng , cam hay đỏ nâu ; trong khi màu_sắc thực_sự của Sao_Hoả gần với màu , và màu đỏ là do khí_quyển Sao_Hoả chứa rất nhiều bụi ; bên dưới là bức ảnh mà robot Spirit chụp được trên Sao_Hoả với màu nâu-xanh nhạt , màu bùn với những tảng đá xám-xanh và cát màu đỏ nhạt .'],
#  ['Vì sao gọi Sao_Hoả là Hành_tinh Đỏ',
# ...
#  ['Thành_phố Hồ_Chí_Minh có bao_nhiêu tôn_giáo',
#   'Về phía Đảng_uỷ , Ban_Chấp_hành Đảng_bộ Thành_phố Hồ_Chí_Minh ( hay thường gọi là Thành_uỷ Thành_phố Hồ_Chí_Minh ) \xa0là cơ_quan lãnh_đạo cao nhất của Đảng_bộ Thành_phố . Thành_uỷ Thành_phố Hồ_Chí_Minh khoá X nhiệm_kỳ 2015 – 2020 gồm 69 uỷ_viên chính_thức , bầu ra Ban Thường_vụ gồm 15 uỷ_viên .'],
#  ['Thành_phố Hồ_Chí_Minh có bao_nhiêu tôn_giáo',
#   'Theo ước_tính năm 2005 , trung_bình mỗi ngày có khoảng 1 triệu khách_vãng_lai tại Thành_phố Hồ_Chí_Minh .'],
#  ['Thành_phố Hồ_Chí_Minh có bao_nhiêu tôn_giáo',
#   'Ngoài báo_chí tiếng Việt , Thành_phố Hồ_Chí_Minh còn có " Saigon_Times daily " , " Thanhniennews " bằng tiếng Anh , một ấn_bản " Sài_Gòn giải_phóng " bằng tiếng Hoa .'],
#  ['Nụ cười của nàng Mona_Lisa bí_ẩn thế_nào',
#   'Mona_Lisa ( La_Gioconda hay La_Joconde , Chân_dung Lisa_Gherardini , vợ của Francesco del Giocondo ) là một bức chân_dung thế_kỷ 16 được vẽ bằng sơn_dầu trên một tấm gỗ dương tại Florence bởi Leonardo da Vinci trong thời_kì Phục_Hưng Italia .'],
#  ['Nụ cười của nàng Mona_Lisa bí_ẩn thế_nào',
#   'Một sự nghiên_cứu và vẽ thử bằng chì_than và graphite về Mona_Lisa được cho là của Leonardo có trong Bộ sưu_tập Hyde , tại Glens_Falls , NY .'],
#  ['Nụ cười của nàng Mona_Lisa bí_ẩn thế_nào',
#   'Bức tranh nàng Mona_Lisa của Leonardo da Vinci đã tạo cảm_hứng cho rất nhiều nhà_phân_tích , từ nghệ_thuật tới khoa_học , từ phân_tích quang_học tới phân_tích tâm_lý_học , hình_thành hình_ảnh " nụ cười Mona_Lisa " trong văn_học , đại_diện cho một cái gì đó rất bí_ẩn nhưng thật sâu_xa , khuôn_mặt nàng không biết nàng đang cười hay đang khóc , đấy là một bí_mật không ai biết .'],
#  ['Nụ cười của nàng Mona_Lisa bí_ẩn thế_nào',
#   'Khuôn_mặt nàng Mona_Lisa trong tranh khiến người ta không_thể đoán_định rằng nàng có đang cười hay không . Nhìn riêng đôi mắt , bạn sẽ thấy ánh lên rất nhiều ý vui , ý lạc_quan , yêu_đời . Nhưng nhìn thấp xuống khoé miệng , đôi môi , ta lại thấy nàng nghiêm_nghị đến kỳ_lạ .'],
#  ['Nụ cười của nàng Mona_Lisa bí_ẩn thế_nào',
#   'Trong cái miệng đó , ta lại thấy rõ sự hồi_hộp , lo_lắng trong cái nhếch mép cười . Bộ_mặt Mona vừa cười , vừa nghiêm_nghị đã trở_thành đề_tài bàn_cãi trong rất nhiều các cuộc khẩu_chiến và bút_chiến .'],
#  ['Châu_lục nào lạnh nhất',
#   'Châu_Nam_Cực , xét trung_bình , là lục_địa lạnh nhất , khô nhất , nhiều gió nhất , và cao nhất trong tất_cả các lục_địa . Châu_Nam_Cực được xem là một hoang_mạc có diện_tích lớn nhất thế_giới , với lượng giáng thuỷ hàng năm chỉ ở mức 200 \xa0mm ( 8 inch ) dọc theo bờ biển và giảm dần khi vào trong nội lục .'],
#  ['Châu_lục nào lạnh nhất',
#   'Châu_Nam_Cực được xem là một hoang_mạc có diện_tích lớn nhất thế_giới , với lượng giáng thuỷ hàng năm chỉ ở mức 200 \xa0mm ( 8 inch ) dọc theo bờ biển và giảm dần khi vào trong nội lục . Nơi đây từng ghi_nhận mức nhiệt − 89 \xa0°C ( − 129 \xa0°F ) , dù_vậy nhiệt_độ trung_bình quý III ( giai_đoạn lạnh nhất trong năm ) là − 63 \xa0°C ( − 81 \xa0°F ) .'],
#  ['Châu_lục nào lạnh nhất',
#   'Chỉ có các vi_sinh_vật ưa lạnh có_thể sống_sót ở châu Nam_Cực như các loại tảo , vi_khuẩn , nấm , ký_sinh_trùng , và một_số loài động_vật nhất_định như mạt , giun_tròn , chim_cánh_cụt , hải_cẩu và gấu nước .'],
#  ['Châu_lục nào lạnh nhất',
#   'Lớp băng phủ dày trung_bình 1.720 m , có tổng_thể tích khoảng 24 triệu km³ , chiếm hơn 90% lượng băng trên mặt Trái_Đất . Độ cao trung_bình bề_mặt lục_địa trên 2.000 m , cao nhất trong các châu_lục . Khoảng 1% mặt lục_địa không có băng phủ , hình_thành những ốc_đảo . Châu_Nam_Cực có khá nhiều ốc_đảo , rộng từ vài km² tới vài trăm km² ( ốc_đảo Banghera rộng 952 \xa0km² ) .'],
#  ['Châu_lục nào lạnh nhất',
#   'Châu_Nam_Cực là lục_địa lạnh nhất trên Trái_Đất . Nhiệt_độ tự_nhiên thấp nhất ghi_nhận được trên Trái_Đất là tại trạm Vostokt của Liên_Xô ( nay là Nga ) ở Nam_Cực vào ngày 21 tháng 7 năm 1983 . Nhiệt_độ này thấp hơn nhiệt_độ của nước_đá khô 11 \xa0°C ( 20 \xa0°F ) ở 1 atm áp_suất riêng phần , nhưng vì CO chỉ chiếm 0,039% trong không_khí , nhiệt_độ dưới -150 \xa0°C có_thể cần đạt được để tạo ra tuyết đá khô ở Nam_Cực .'],
#  ['Châu_lục nào lạnh nhất',
#   'Khoảng_cách quỹ_đạo góp_phần làm cho mùa đông Nam_Cực lạnh hơn ( và mùa hè Nam_Cực ấm hơn ) so với Bắc_Cực , nhưng hai nguyên_nhân đầu là có ảnh_hưởng mạnh nhất .'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   'Hồ Hoàn_Kiếm ( chữ_Nôm : 湖還劍 hoặc 還劍湖 ) còn được gọi là Hồ Gươm ( trong , hồ này được gọi là Hồ Hoàn_Gươm - " Lac de Hoan_Guom " ) , là một hồ nước_ngọt tự_nhiên nằm ở trung_tâm thành_phố Hà_Nội . Hồ có diện_tích khoảng 12 ha . Trước_kia , hồ còn có các tên gọi là hồ Lục_Thuỷ ( vì nước có màu xanh quanh_năm ) , hồ Thuỷ_Quân ( dùng để duyệt thuỷ_binh ) , hồ_Tả_Vọng và Hữu_Vọng ( trong thời Lê_mạt ) .'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   'Theo truyền_thuyết , trong một lần vua Lê_Lợi dạo chơi trên thuyền , bỗng một con rùa vàng nổi lên mặt nước đòi nhà_vua trả thanh gươm mà Long_Vương cho mượn để đánh_đuổi quân Minh xâm_lược . Nhà_vua liền trả gươm cho rùa thần và rùa lặn xuống_nước biến mất . Từ đó hồ được lấy tên là hồ Hoàn_Kiếm .'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   'Tên hồ còn được lấy để đặt cho một quận trung_tâm của Hà_Nội ( quận Hoàn_Kiếm ) và là hồ nước duy_nhất của quận này cho đến ngày_nay .'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   'Tiếp đó đổ ra nhánh chính của sông Hồng . Nơi rộng nhất phân lưu này hình_thành nên hồ Hoàn_Kiếm hiện_nay .'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   '" Từ đó , hồ_Tả_Vọng bắt_đầu mang tên là Hồ Gươm hay hồ Hoàn_Kiếm "'],
#  ['Hồ Hoàn_Kiếm còn có tên gọi khác là gì',
#   'Ngày 19 tháng 1 năm 2016 , cá_thể rùa Hồ Gươm cuối_cùng đã chết .'],
#  ['Toà nhà nào cao nhất Đông_Nam_Á',
#   'The_Landmark 81 là một toà nhà_chọc_trời trong tổ_hợp dự_án Vinhomes_Tân_Cảng , một dự_án có tổng mức đầu_tư 40.000 tỷ đồng , do Công_ty Cổ_phần Đầu_tư xây_dựng Tân_Liên_Phát thuộc Vingroup làm chủ đầu_tư . Toà tháp cao 81 tầng , hiện_tại là toà nhà cao nhất Việt_Nam và là toà nhà cao nhất Đông_Nam_Á từ tháng 3 năm 2018 .'],
#  ['Toà nhà nào cao nhất Đông_Nam_Á',
#   'Toà tháp cao 81 tầng , hiện_tại là toà nhà cao nhất Việt_Nam và là toà nhà cao nhất Đông_Nam_Á từ tháng 3 năm 2018 . Dự_án được xây_dựng ở Tân_Cảng , quận Bình_Thạnh , ven sông Sài_Gòn . Dự_án được khởi_công ngày 26/07/2014 .'],
#  ['Nguyễn_Quang_Hải là ai',
#   'Nguyễn_Quang_Hải ( sinh ngày 12 tháng 4 năm 1997 ) là một cầu_thủ bóng_đá người Việt trưởng_thành tại lò đào_tạo câu_lạc_bộ bóng_đá Hà_Nội T&T và hiện cũng đang chơi cho đội một của câu_lạc_bộ bóng_đá Hà_Nội ở vị_trí tiền_vệ .'],
#  ['Nguyễn_Quang_Hải là ai',
#   'Anh còn là cầu_thủ xuất_sắc nhất tháng 6 V-League 2018 và cũng là cầu_thủ xuất_sắc nhất AFF Cup 2018 .'],
#  ['Nguyễn_Quang_Hải là ai',
#   'Tại giải bóng_đá Vô_địch Đông_Nam_Á diễn ra từ ngày 8 tháng 11 đến ngày 15 tháng 12 năm 2018 ( tiếng Anh : " AFF Championship " , tên gọi khác tiếng Anh : " ASEAN Football_Championship " ) , cầu_thủ Nguyễn_Quang_Hải được bầu_chọn là Cầu_thủ xuất_sắc nhất giải đấu AFF Suzuki_Cup 2018 .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'Đèn sợi đốt , còn gọi là đèn dây_tóc là một loại bóng_đèn dùng để chiếu sáng khi bị đốt nóng , dây_tóc là bộ_phận chính để phát ra ánh_sáng , thông_qua vỏ thuỷ_tinh trong suốt . Các dây_tóc - bộ_phận phát sáng chính của đèn được bảo_vệ bên ngoài bằng một lớp thuỷ_tinh trong suốt hoặc mờ đã được rút hết không_khí và bơm vào các khí_trơ .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'Họ kết_luận rằng phiên_bản đèn sợi đốt ( được sản_xuất hàng_loạt từ năm 1880 ) của Edison hơn các phiên_bản khác do kết_hợp ba yếu_tố : vật_liệu đốt hiệu_quả hơn , độ chân không trong bóng_đèn cao hơn các phiên_bản khác ( bằng cách sử_dụng bơm Sprengel ) và điện_trở cao hơn khiến việc phân_phối điện từ một nguồn trung_tâm có_thể thực_hiện được một_cách kinh_tế ( còn có tên gọi là đèn nung sáng )'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'I. 1.6 a ) . Đó là một trong các đặc_điểm quan_trọng nhất của chiếc_bóng đèn và hệ_thống điện của Edison . Chiếc nhãn dán trên bóng_đèn có dòng chữ ( xem hình H. I. 1.6 b ) , “ New_Type_Edison_Lamp . Patented_Jan . 27 , 1880 OTHER EDISON PATENT . ” Edison đã phát_minh ra đèn sợi đốt và lịch_sử cũng chứng_kiến hàng_loạt những cải_tiến kỳ_diệu và những công_nghệ chiếu sáng mới .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   '- Sợi đốt làm bằng Vonfram , chịu được nhiệt_độ cao , có chức_năng biến_đổi điện_năng thành quang_năng .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'Với những tiến_bộ hiện_thời của đèn_huỳnh_quang thu gọn và đèn sợi đốt pha hơi halogen thì việc tiếp_tục sử_dụng đèn sợi đốt thông_thường là khó chấp_nhận .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'Cũng giống như các bóng sợi đốt khác loại bóng này có thời_gian sống ngắn , hiệu_suất rất thấp .'],
#  ['Đèn sợi đốt còn có tên gọi nào khác',
#   'Điện_áp định_mức của đèn sợi đốt thường dùng : 127 V , 220 V , 110 V.'],
#  ['Oxy có mấy đồng_vị',
#   'Ôxy được sản_xuất trong công_nghiệp bằng cách chưng_cất phân_đoạn không_khí lỏng , sử_dụng zeolit để loại_bỏ carbon dioxit và nitơ ra khỏi không_khí , điện phân nước và các cách khác . Trong phòng_thí_nghiệm , người ta điều_chế oxy bằng cách_nhiệt phân một_số chất giàu oxy như KMn , KCl .'],
#  ['Oxy có mấy đồng_vị',
#   'Ôxy có_mặt trong tự_nhiên là hỗn_hợp của 3 đồng_vị bền gồm , O , O , và O , với O chiếm nhiều nhất ( 99,762% ) .'],
#  ['Oxy có mấy đồng_vị',
#   'Hầu_hết O được tổng_hợp ở giai_đoạn cuối của quá_trình phản_ứng tổng_hợp heli trong các sao lớn nhưng một_số hình_thành trong quá_trình đốt cháy neon . O chủ_yếu được hình thanh trong quá trìn đốt cháy hydro thành heli trong chu_trình CNO , do_vậy nó là đồng_vị phổ_biến trong các đới đốt cháy hydro của các sao.Hầu hết O được tạo ra khi N ( hình_thành phổ_biến trong quá_trình đốt cháy CNO ) bắt các hạt_nhân He , nên O phổ_biến trong các đới giàu heli của quá_trình tiến_hoá sao lớn .'],
#  ['Oxy có mấy đồng_vị',
#   '14 đồng_vị_phóng_xạ của ôxy đã được xác_định . Đồng_vị bền nhất_là O với chu_kỳ bán rã 122,24 \xa0giây và O có chu_kỳ bán rã 70,606 \xa0giây . Tất_cả các đồng_vị_phóng_xạ còn là có chu_kỳ bán rã dưới 27 \xa0s và phổ_biến là dưới 83 \xa0milli giây .'],
#  ['Oxy có mấy đồng_vị',
#   'Tất_cả các đồng_vị_phóng_xạ còn là có chu_kỳ bán rã dưới 27 \xa0s và phổ_biến là dưới 83 \xa0milli giây . Cơ_chế phân_rã phổ_biến nhất của các đồng_vị nhẹ hơn O là phân_rã β để tạo ra nitơ , và cơ_chế phân_rã phổ_biến nhất của các đồng_vị nặng hơn O là phân_rã_beta để tạo ra flo .'],
#  ['Oxy có mấy đồng_vị',
#   'Cơ_chế phân_rã phổ_biến nhất của các đồng_vị nhẹ hơn O là phân_rã β để tạo ra nitơ , và cơ_chế phân_rã phổ_biến nhất của các đồng_vị nặng hơn O là phân_rã_beta để tạo ra flo .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Lionel_Andrés " Leo " Messi_Cuccittini ( ; sinh ngày 24 tháng 6 năm 1987 ) , thường biết tới với tên gọi Lionel_Messi , là một cầu_thủ bóng_đá người Argentina hiện đang chơi ở vị_trí tiền_đạo cho câu_lạc_bộ Barcelona và đội_tuyển bóng_đá quốc_gia Argentina .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Trước trận đó , Messi đã nói : " " Đây có_thể coi là trận đấu đầu_tiên .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Tháng 8 năm 2011 , Sabella đã trao chiếc băng đội_trưởng đội_tuyển cho Messi .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Tháng 6 năm 2010 , Messi ký hợp_đồng có thời_hạn 3 năm với Herbalife trong việc hỗ_trợ quỹ Leo_Messi .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Ngày 30 tháng 6 năm 2017 , Messi kết_hôn với Antonella_Roccuzzo . Đám_cưới của Messi được tổ_chức tại tổ_hợp khách_sạn 5 sao City_Center_Rosario . Leo_Messi quen cô bạn gái Antonella_Roccuzzo lúc anh mới 5 tuổi , trước khi công_khai chuyện hẹn_hò từ năm 2009 .'],
#  ['Lionel_Messi kết_hôn năm nào',
#   'Leo_Messi quen cô bạn gái Antonella_Roccuzzo lúc anh mới 5 tuổi , trước khi công_khai chuyện hẹn_hò từ năm 2009 . Hai người đã có với nhau hai cậu con trai : Thiago ( sinh năm 2012 ) và Mateo ( 2015 ) .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Nguyễn_Quang_Hải ( sinh ngày 12 tháng 4 năm 1997 ) là một cầu_thủ bóng_đá người Việt trưởng_thành tại lò đào_tạo câu_lạc_bộ bóng_đá Hà_Nội T&T và hiện cũng đang chơi cho đội một của câu_lạc_bộ bóng_đá Hà_Nội ở vị_trí tiền_vệ .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Năm 2015 anh khoác_áo số 7 của Câu_lạc_bộ Hà_Nội ( đội bóng đã được đổi tên thành câu_lạc_bộ bóng_đá Sài_Gòn vào năm 2016 ) chơi ở vị_trí tiền_đạo tại " V.League 2 - 2015 . " Nguyễn_Quang_Hải được đánh_giá có phong_độ vô_cùng ổn_định .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Song phải đến năm 2016 anh mới có trận đấu đầu_tiên được góp_mặt tại V-League trong màu áo Hà_Nội T&T , đó là trận đấu derby thủ_đô giữa Hà_Nội T&T và đội bóng cũ của anh - CLB Hà_Nội mới thăng_hạng . Trong mùa đầu_tiên chơi V-League , Quang hải đã nhanh_chóng khẳng_định được giá_trị của mình với khả_năng chơi chân trái khéo_léo , khả_năng xử_lý bóng cận chân rất kỹ_thuật , những pha xử_lý của Quang_Hải được liên_tưởng mang dáng_dấp của người đàn_anh Phạm_Thành_Lương .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Trong mùa đầu_tiên chơi V-League , Quang hải đã nhanh_chóng khẳng_định được giá_trị của mình với khả_năng chơi chân trái khéo_léo , khả_năng xử_lý bóng cận chân rất kỹ_thuật , những pha xử_lý của Quang_Hải được liên_tưởng mang dáng_dấp của người đàn_anh Phạm_Thành_Lương .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Kết_thúc mùa giải , Nguyễn_Quang_Hải cùng Hà_Nội cán đích ở vị_trí thứ 3 trên bảng xếp_hạng và anh cũng giành được danh_hiệu cá_nhân " Cầu_thủ trẻ xuất_sắc nhất " của mùa giải V-League 2017 và danh_hiệu quả bóng đồng Việt_Nam 2017 .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Cũng trong năm 2014 , Quang_Hải cùng U-19 Việt_Nam đạt giải Á_quân Cúp_Hassanal_Bolkiah diễn ra tại Brunei .'],
#  ['Vị_trí của Quang_Hải trong đội bóng',
#   'Tối_ngày 22 tháng 12 năm 2018 tại thành_phố Hồ_Chí_Minh trong đêm gala trao_tặng Quả_Bóng_Vàng Việt Nam năm 2018 Nguyễn_Quang_Hải đã vinh_dự được nhận danh_hiệu Quả_Bóng_Vàng Việt Nam năm 2018 đây là lần đầu_tiên Quang_Hải nhận được danh_hiệu cao_quý này .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Mỗi trận đấu bóng_đá bao_gồm hai đội , mỗi đội 11 cầu_thủ thi_đấu chính_thức trên sân kể_cả 1 thủ_môn . Thủ_môn là người duy_nhất được phép chơi bóng bằng tay , tuy_nhiên việc này cũng chỉ được giới_hạn trong khu cấm_địa phía trước khung_thành do thủ_môn trấn_giữ .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Thủ_môn là người duy_nhất được phép chơi bóng bằng tay , tuy_nhiên việc này cũng chỉ được giới_hạn trong khu cấm_địa phía trước khung_thành do thủ_môn trấn_giữ . Bên cạnh số cầu_thủ chính_thức mỗi đội cũng còn một_số cầu_thủ dự_bị để thay_thế khi cần_thiết , thông_thường trong một trận bóng_đá thi_đấu chính_thức , mỗi đội chỉ được phép thay_đổi 3 cầu_thủ .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Bóng_đá hiện_đại sau hơn 1 thế_kỷ hình_thành và phát_triển đã sản_sinh ra nhiều cầu_thủ lớn với khả_năng và thành_tích đặc_biệt . Những người này thường được gọi là các " ngôi_sao bóng_đá " hay " siêu_sao bóng_đá " .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Bóng_đá bãi biển là môn bóng_đá chơi trên bãi cát , thông_thường là bãi biển . Các trận đấu bóng_đá bãi biển có 2 đội , mỗi đội 5 người với quyền thay người không hạn_chế . Các cầu_thủ chơi trên một sân nhỏ kích_thước 28x37 m trong 3 hiệp , mỗi hiệp 12 phút .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Bóng_đá cho người khuyết_tật có hai loại_hình chính là bóng_đá xe_lăn ( cho người khuyết_tật chi ) và bóng_đá cho người khiếm_thị ( cho người có khuyết_tật về mắt ) . Môn bóng_đá cho người khiếm_thị được đưa vào nội_dung thi_đấu của Paralympic kể từ năm 2004 .'],
#  ['Ai là người duy_nhất được dùng tay_trong bóng_đá',
#   'Môn bóng_đá cho người khiếm_thị được đưa vào nội_dung thi_đấu của Paralympic kể từ năm 2004 . Tại các loại_hình bóng_đá này thì những đội_tuyển Nam_Mỹ như Brasil và Argentina cũng là những người thống_trị .'],
#  ...]

# %%
test_ids = []
for sent in test_text:
    subwords1 = '<q> ' + bpe.encode(sent[0]) + ' </q>'
    encoded_sent1 = vocab.encode_line(subwords1, append_eos=True, add_if_not_exist=False).long().tolist()

    subwords2 = '<a> ' + bpe.encode(sent[1]) + ' </a>'
    encoded_sent2 = vocab.encode_line(subwords2, append_eos=True, add_if_not_exist=False).long().tolist()
    test_ids.append(encoded_sent1 + encoded_sent2)

test_ids = pad_sequences(test_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
len(test_ids)
# Out:
# 2678

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import torch

test_masks = []
for sent in test_ids:
    mask = [int(token_id > 0) for token_id in sent]
    test_masks.append(mask)


test_inputs = torch.tensor(test_ids)
test_masks = torch.tensor(test_masks)

test_data = TensorDataset(test_inputs, test_masks)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=32)

# %%
len(test_dataloader)
# Out:
# 84

# %%
predicts = []

# %%
for batch in tqdm_notebook(test_dataloader):

        batch = tuple(t.to(device) for t in batch)

        t_input_ids, t_input_mask = batch

        with torch.no_grad():
            outputs = BERT_SA(t_input_ids, 
            token_type_ids=None, 
            attention_mask=t_input_mask)
            testpre = outputs[0]
            testpre = testpre.detach().cpu().numpy()
            a = np.argmax(testpre, axis=1).flatten()
            for b in a:
              predicts.append('True' if b == 1 else 'False')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, max=84.0), HTML(value='')))

# %%
predicts
# Out:
# ['True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'True',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  ...]

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['label'] = predicts
df['text'] = test_text

# %%
df
# Out:
#       label                                               text
# 0         1  [Toà nhà nào cao nhất Việt Nam, The Landmark 8...
# 1         1  [Toà nhà nào cao nhất Việt Nam, Toà tháp cao 8...
# 2         1  [Messi thuận chân nào, Đôi chân ngắn nhưng mạn...
# 3         1  [Messi thuận chân nào, Cựu huấn luyện viên Bar...
# 4         0  [Messi thuận chân nào, Ngoài ra anh còn một ch...
# ...     ...                                                ...
# 2673      0  [con sông dài nhất trên thế giới ở nước nào, L...
# 2674      0  [con sông dài nhất trên thế giới ở nước nào, V...
# 2675      1  [Tuần lễ cấp cao APEC 2017 diễn ra tại tỉnh th...
# 2676      1  [Tuần lễ cấp cao APEC 2017 diễn ra tại tỉnh th...
# 2677      1  [Tuần lễ cấp cao APEC 2017 diễn ra tại tỉnh th...
#
# [2678 rows x 2 columns]

# %%
df.to_csv('./test_pred')

# %%
df1 = pd.DataFrame()
df1['labels'] = predicts

# %%
df1.to_csv('./test_labels')
